# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# Using TensorFlow backend.
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 8s 2ms/step - loss: 0.0134 - val_loss: 0.0058
#
# Epoch 00001: val_loss improved from inf to 0.00579, saving model to doubleLSTMmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 2s 603us/step - loss: 0.0111 - val_loss: 0.0047
#
# Epoch 00002: val_loss improved from 0.00579 to 0.00466, saving model to doubleLSTMmodel.h5
# Epoch 3/100
# 3847/3847 [==============================] - 2s 467us/step - loss: 0.0100 - val_loss: 0.0051
#
# Epoch 00003: val_loss did not improve from 0.00466
# Epoch 4/100
# 3847/3847 [==============================] - 3s 672us/step - loss: 0.0099 - val_loss: 0.0049
#
# Epoch 00004: val_loss did not improve from 0.00466
# Epoch 5/100
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0091 - val_loss: 0.0050
#
# Epoch 00005: val_loss did not improve from 0.00466
# Epoch 6/100
# 3847/3847 [==============================] - 3s 730us/step - loss: 0.0090 - val_loss: 0.0055
#
# Epoch 00006: val_loss did not improve from 0.00466
# Epoch 7/100
# 3847/3847 [==============================] - 2s 548us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00007: val_loss did not improve from 0.00466
# Epoch 8/100
# 3847/3847 [==============================] - 3s 681us/step - loss: 0.0088 - val_loss: 0.0061
#
# Epoch 00008: val_loss did not improve from 0.00466
# Epoch 9/100
# 3847/3847 [==============================] - 3s 686us/step - loss: 0.0089 - val_loss: 0.0055
#
# Epoch 00009: val_loss did not improve from 0.00466
# Epoch 10/100
# 3847/3847 [==============================] - 3s 701us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00010: val_loss did not improve from 0.00466
# Epoch 11/100
# 3847/3847 [==============================] - 3s 691us/step - loss: 0.0087 - val_loss: 0.0074
#
# Epoch 00011: val_loss did not improve from 0.00466
# Epoch 12/100
# 3847/3847 [==============================] - 3s 698us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00012: val_loss did not improve from 0.00466
# Epoch 13/100
# 3847/3847 [==============================] - 3s 687us/step - loss: 0.0086 - val_loss: 0.0059
#
# Epoch 00013: val_loss did not improve from 0.00466
# Epoch 14/100
# 3847/3847 [==============================] - 2s 647us/step - loss: 0.0087 - val_loss: 0.0063
#
# Epoch 00014: val_loss did not improve from 0.00466
# Epoch 15/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0087 - val_loss: 0.0044
#
# Epoch 00015: val_loss improved from 0.00466 to 0.00445, saving model to doubleLSTMmodel.h5
# Epoch 16/100
# 3847/3847 [==============================] - 2s 584us/step - loss: 0.0086 - val_loss: 0.0050
#
# Epoch 00016: val_loss did not improve from 0.00445
# Epoch 17/100
# 3847/3847 [==============================] - 3s 660us/step - loss: 0.0087 - val_loss: 0.0060
#
# Epoch 00017: val_loss did not improve from 0.00445
# Epoch 18/100
# 3847/3847 [==============================] - 3s 685us/step - loss: 0.0086 - val_loss: 0.0054
#
# Epoch 00018: val_loss did not improve from 0.00445
# Epoch 19/100
# 3847/3847 [==============================] - 3s 694us/step - loss: 0.0085 - val_loss: 0.0055
#
# Epoch 00019: val_loss did not improve from 0.00445
# Epoch 20/100
# 3847/3847 [==============================] - 3s 678us/step - loss: 0.0085 - val_loss: 0.0051
#
# Epoch 00020: val_loss did not improve from 0.00445
# Epoch 21/100
# 3847/3847 [==============================] - 2s 628us/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00021: val_loss did not improve from 0.00445
# Epoch 22/100
# 3847/3847 [==============================] - 3s 709us/step - loss: 0.0085 - val_loss: 0.0052
#
# Epoch 00022: val_loss did not improve from 0.00445
# Epoch 23/100
# 3847/3847 [==============================] - 3s 686us/step - loss: 0.0084 - val_loss: 0.0048
#
# Epoch 00023: val_loss did not improve from 0.00445
# Epoch 24/100
# 3847/3847 [==============================] - 3s 686us/step - loss: 0.0084 - val_loss: 0.0046
#
# Epoch 00024: val_loss did not improve from 0.00445
# Epoch 25/100
# 3847/3847 [==============================] - 3s 700us/step - loss: 0.0084 - val_loss: 0.0048
#
# Epoch 00025: val_loss did not improve from 0.00445
# Epoch 26/100
# 3847/3847 [==============================] - 3s 701us/step - loss: 0.0082 - val_loss: 0.0058
#
# Epoch 00026: val_loss did not improve from 0.00445
# Epoch 27/100
# 3847/3847 [==============================] - 3s 682us/step - loss: 0.0084 - val_loss: 0.0050
#
# Epoch 00027: val_loss did not improve from 0.00445
# Epoch 28/100
# 3847/3847 [==============================] - 3s 681us/step - loss: 0.0083 - val_loss: 0.0055
#
# Epoch 00028: val_loss did not improve from 0.00445
# Epoch 29/100
# 3847/3847 [==============================] - 3s 680us/step - loss: 0.0085 - val_loss: 0.0063
#
# Epoch 00029: val_loss did not improve from 0.00445
# Epoch 30/100
# 3847/3847 [==============================] - 3s 690us/step - loss: 0.0082 - val_loss: 0.0053
#
# Epoch 00030: val_loss did not improve from 0.00445
# Epoch 31/100
# 3847/3847 [==============================] - 3s 661us/step - loss: 0.0082 - val_loss: 0.0047
#
# Epoch 00031: val_loss did not improve from 0.00445
# Epoch 32/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0082 - val_loss: 0.0056
#
# Epoch 00032: val_loss did not improve from 0.00445
# Epoch 33/100
# 3847/3847 [==============================] - 3s 681us/step - loss: 0.0083 - val_loss: 0.0050
#
# Epoch 00033: val_loss did not improve from 0.00445
# Epoch 34/100
# 3847/3847 [==============================] - 3s 670us/step - loss: 0.0082 - val_loss: 0.0052
#
# Epoch 00034: val_loss did not improve from 0.00445
# Epoch 35/100
# 3847/3847 [==============================] - 3s 668us/step - loss: 0.0083 - val_loss: 0.0049
#
# Epoch 00035: val_loss did not improve from 0.00445
# Epoch 36/100
# 3847/3847 [==============================] - 3s 673us/step - loss: 0.0082 - val_loss: 0.0054
#
# Epoch 00036: val_loss did not improve from 0.00445
# Epoch 37/100
# 3847/3847 [==============================] - 3s 664us/step - loss: 0.0083 - val_loss: 0.0063
#
# Epoch 00037: val_loss did not improve from 0.00445
# Epoch 38/100
# 3847/3847 [==============================] - 3s 658us/step - loss: 0.0084 - val_loss: 0.0046
#
# Epoch 00038: val_loss did not improve from 0.00445
# Epoch 39/100
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0082 - val_loss: 0.0047
#
# Epoch 00039: val_loss did not improve from 0.00445
# Epoch 40/100
# 3847/3847 [==============================] - 3s 671us/step - loss: 0.0082 - val_loss: 0.0053
#
# Epoch 00040: val_loss did not improve from 0.00445
# Epoch 41/100
# 3847/3847 [==============================] - 3s 662us/step - loss: 0.0081 - val_loss: 0.0050A: 0s - loss: 0.0
#
# Epoch 00041: val_loss did not improve from 0.00445
# Epoch 42/100
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0081 - val_loss: 0.0056
#
# Epoch 00042: val_loss did not improve from 0.00445
# Epoch 43/100
# 3847/3847 [==============================] - 3s 735us/step - loss: 0.0082 - val_loss: 0.0048
#
# Epoch 00043: val_loss did not improve from 0.00445
# Epoch 44/100
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0081 - val_loss: 0.0054
#
# Epoch 00044: val_loss did not improve from 0.00445
# Epoch 45/100
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0081 - val_loss: 0.0061
#
# Epoch 00045: val_loss did not improve from 0.00445
# Epoch 46/100
# 3847/3847 [==============================] - 3s 676us/step - loss: 0.0080 - val_loss: 0.0051
#
# Epoch 00046: val_loss did not improve from 0.00445
# Epoch 47/100
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0081 - val_loss: 0.0056
#
# Epoch 00047: val_loss did not improve from 0.00445
# Epoch 48/100
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0080 - val_loss: 0.0057
#
# Epoch 00048: val_loss did not improve from 0.00445
# Epoch 49/100
# 3847/3847 [==============================] - ETA: 0s - loss: 0.008 - 2s 637us/step - loss: 0.0080 - val_loss: 0.0053
#
# Epoch 00049: val_loss did not improve from 0.00445
# Epoch 50/100
# 3847/3847 [==============================] - 2s 566us/step - loss: 0.0080 - val_loss: 0.0050
#
# Epoch 00050: val_loss did not improve from 0.00445
# Epoch 51/100
# 3847/3847 [==============================] - 2s 641us/step - loss: 0.0082 - val_loss: 0.0046
#
# Epoch 00051: val_loss did not improve from 0.00445
# Epoch 52/100
# 3847/3847 [==============================] - 2s 601us/step - loss: 0.0081 - val_loss: 0.0051
#
# Epoch 00052: val_loss did not improve from 0.00445
# Epoch 53/100
# 3847/3847 [==============================] - 3s 659us/step - loss: 0.0083 - val_loss: 0.0047
#
# Epoch 00053: val_loss did not improve from 0.00445
# Epoch 54/100
# 3847/3847 [==============================] - 3s 680us/step - loss: 0.0080 - val_loss: 0.0053
#
# Epoch 00054: val_loss did not improve from 0.00445
# Epoch 55/100
# 3847/3847 [==============================] - 3s 671us/step - loss: 0.0078 - val_loss: 0.0060
#
# Epoch 00055: val_loss did not improve from 0.00445
# Epoch 56/100
# 3847/3847 [==============================] - 2s 632us/step - loss: 0.0079 - val_loss: 0.0052
#
# Epoch 00056: val_loss did not improve from 0.00445
# Epoch 57/100
# 3847/3847 [==============================] - 3s 667us/step - loss: 0.0081 - val_loss: 0.0057
#
# Epoch 00057: val_loss did not improve from 0.00445
# Epoch 58/100
# 3847/3847 [==============================] - 2s 645us/step - loss: 0.0079 - val_loss: 0.0050
#
# Epoch 00058: val_loss did not improve from 0.00445
# Epoch 59/100
# 3847/3847 [==============================] - 3s 683us/step - loss: 0.0078 - val_loss: 0.0050
#
# Epoch 00059: val_loss did not improve from 0.00445
# Epoch 60/100
# 3847/3847 [==============================] - 3s 671us/step - loss: 0.0080 - val_loss: 0.0047
#
# Epoch 00060: val_loss did not improve from 0.00445
# Epoch 61/100
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0078 - val_loss: 0.0055
#
# Epoch 00061: val_loss did not improve from 0.00445
# Epoch 62/100
# 3847/3847 [==============================] - 2s 609us/step - loss: 0.0076 - val_loss: 0.0048
#
# Epoch 00062: val_loss did not improve from 0.00445
# Epoch 63/100
# 3847/3847 [==============================] - 3s 711us/step - loss: 0.0078 - val_loss: 0.0050
#
# Epoch 00063: val_loss did not improve from 0.00445
# Epoch 64/100
# 3847/3847 [==============================] - 2s 642us/step - loss: 0.0077 - val_loss: 0.0046
#
# Epoch 00064: val_loss did not improve from 0.00445
# Epoch 65/100
# 3847/3847 [==============================] - 3s 660us/step - loss: 0.0078 - val_loss: 0.0057
#
# Epoch 00065: val_loss did not improve from 0.00445
# Epoch 66/100
# 3847/3847 [==============================] - 3s 654us/step - loss: 0.0076 - val_loss: 0.0051
#
# Epoch 00066: val_loss did not improve from 0.00445
# Epoch 67/100
# 3847/3847 [==============================] - 3s 688us/step - loss: 0.0073 - val_loss: 0.0047
#
# Epoch 00067: val_loss did not improve from 0.00445
# Epoch 68/100
# 3847/3847 [==============================] - 3s 651us/step - loss: 0.0071 - val_loss: 0.0046
#
# Epoch 00068: val_loss did not improve from 0.00445
# Epoch 69/100
# 3847/3847 [==============================] - 3s 692us/step - loss: 0.0070 - val_loss: 0.0060
#
# Epoch 00069: val_loss did not improve from 0.00445
# Epoch 70/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0069 - val_loss: 0.0048
#
# Epoch 00070: val_loss did not improve from 0.00445
# Epoch 71/100
# 3847/3847 [==============================] - 3s 709us/step - loss: 0.0069 - val_loss: 0.0050
#
# Epoch 00071: val_loss did not improve from 0.00445
# Epoch 72/100
# 3847/3847 [==============================] - 3s 686us/step - loss: 0.0068 - val_loss: 0.0049
#
# Epoch 00072: val_loss did not improve from 0.00445
# Epoch 73/100
# 3847/3847 [==============================] - 3s 699us/step - loss: 0.0066 - val_loss: 0.0051
#
# Epoch 00073: val_loss did not improve from 0.00445
# Epoch 74/100
# 3847/3847 [==============================] - 3s 707us/step - loss: 0.0065 - val_loss: 0.0052
#
# Epoch 00074: val_loss did not improve from 0.00445
# Epoch 75/100
# 3847/3847 [==============================] - 3s 705us/step - loss: 0.0064 - val_loss: 0.0052
#
# Epoch 00075: val_loss did not improve from 0.00445
# Epoch 76/100
# 3847/3847 [==============================] - 3s 688us/step - loss: 0.0062 - val_loss: 0.0049
#
# Epoch 00076: val_loss did not improve from 0.00445
# Epoch 77/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0062 - val_loss: 0.0040
#
# Epoch 00077: val_loss improved from 0.00445 to 0.00400, saving model to doubleLSTMmodel.h5
# Epoch 78/100
# 3847/3847 [==============================] - 2s 602us/step - loss: 0.0061 - val_loss: 0.0053
#
# Epoch 00078: val_loss did not improve from 0.00400
# Epoch 79/100
# 3847/3847 [==============================] - 3s 693us/step - loss: 0.0062 - val_loss: 0.0071
#
# Epoch 00079: val_loss did not improve from 0.00400
# Epoch 80/100
# 3847/3847 [==============================] - 3s 668us/step - loss: 0.0061 - val_loss: 0.0048
#
# Epoch 00080: val_loss did not improve from 0.00400
# Epoch 81/100
# 3847/3847 [==============================] - 3s 687us/step - loss: 0.0060 - val_loss: 0.0051
#
# Epoch 00081: val_loss did not improve from 0.00400
# Epoch 82/100
# 3847/3847 [==============================] - 2s 631us/step - loss: 0.0060 - val_loss: 0.0055
#
# Epoch 00082: val_loss did not improve from 0.00400
# Epoch 83/100
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0060 - val_loss: 0.0045
#
# Epoch 00083: val_loss did not improve from 0.00400
# Epoch 84/100
# 3847/3847 [==============================] - 2s 639us/step - loss: 0.0059 - val_loss: 0.0058
#
# Epoch 00084: val_loss did not improve from 0.00400
# Epoch 85/100
# 3847/3847 [==============================] - 2s 636us/step - loss: 0.0057 - val_loss: 0.0053
#
# Epoch 00085: val_loss did not improve from 0.00400
# Epoch 86/100
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0058 - val_loss: 0.0049
#
# Epoch 00086: val_loss did not improve from 0.00400
# Epoch 87/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0057 - val_loss: 0.0051
#
# Epoch 00087: val_loss did not improve from 0.00400
# Epoch 88/100
# 3847/3847 [==============================] - 3s 654us/step - loss: 0.0058 - val_loss: 0.0058
#
# Epoch 00088: val_loss did not improve from 0.00400
# Epoch 89/100
# 3847/3847 [==============================] - 3s 673us/step - loss: 0.0058 - val_loss: 0.0062
#
# Epoch 00089: val_loss did not improve from 0.00400
# Epoch 90/100
# 3847/3847 [==============================] - 3s 667us/step - loss: 0.0057 - val_loss: 0.0051
#
# Epoch 00090: val_loss did not improve from 0.00400
# Epoch 91/100
# 3847/3847 [==============================] - 2s 629us/step - loss: 0.0056 - val_loss: 0.0052
#
# Epoch 00091: val_loss did not improve from 0.00400
# Epoch 92/100
# 3847/3847 [==============================] - 3s 659us/step - loss: 0.0058 - val_loss: 0.0045
#
# Epoch 00092: val_loss did not improve from 0.00400
# Epoch 93/100
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 00093: val_loss did not improve from 0.00400
# Epoch 94/100
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0057 - val_loss: 0.0057
#
# Epoch 00094: val_loss did not improve from 0.00400
# Epoch 95/100
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0055 - val_loss: 0.0062
#
# Epoch 00095: val_loss did not improve from 0.00400
# Epoch 96/100
# 3847/3847 [==============================] - 3s 680us/step - loss: 0.0055 - val_loss: 0.0076
#
# Epoch 00096: val_loss did not improve from 0.00400
# Epoch 97/100
# 3847/3847 [==============================] - 3s 699us/step - loss: 0.0054 - val_loss: 0.0052
#
# Epoch 00097: val_loss did not improve from 0.00400
# Epoch 98/100
# 3847/3847 [==============================] - 3s 705us/step - loss: 0.0055 - val_loss: 0.0053
#
# Epoch 00098: val_loss did not improve from 0.00400
# Epoch 99/100
# 3847/3847 [==============================] - 3s 699us/step - loss: 0.0054 - val_loss: 0.0060
#
# Epoch 00099: val_loss did not improve from 0.00400
# Epoch 100/100
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00100: val_loss did not improve from 0.00400
# Model loaded
# mae :  5512.058692991579
# mse :  63201477.6912074
# rmse :  7949.93570358952
# std : 7660.70580340978

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 9s 2ms/step - loss: 0.0126 - val_loss: 0.0052
#
# Epoch 00001: val_loss improved from inf to 0.00515, saving model to doubleLSTMmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 3s 701us/step - loss: 0.0112 - val_loss: 0.0048
#
# Epoch 00002: val_loss improved from 0.00515 to 0.00477, saving model to doubleLSTMmodel.h5
# Epoch 3/100
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0102 - val_loss: 0.0046
#
# Epoch 00003: val_loss improved from 0.00477 to 0.00457, saving model to doubleLSTMmodel.h5
# Epoch 4/100
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0093 - val_loss: 0.0060
#
# Epoch 00004: val_loss did not improve from 0.00457
# Epoch 5/100
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0090 - val_loss: 0.0062
#
# Epoch 00005: val_loss did not improve from 0.00457
# Epoch 6/100
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0088 - val_loss: 0.0043
#
# Epoch 00006: val_loss improved from 0.00457 to 0.00431, saving model to doubleLSTMmodel.h5
# Epoch 7/100
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0088 - val_loss: 0.0056
#
# Epoch 00007: val_loss did not improve from 0.00431
# Epoch 8/100
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0089 - val_loss: 0.0052
#
# Epoch 00008: val_loss did not improve from 0.00431
# Epoch 9/100
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0087 - val_loss: 0.0053
#
# Epoch 00009: val_loss did not improve from 0.00431
# Epoch 10/100
# 3847/3847 [==============================] - 3s 716us/step - loss: 0.0086 - val_loss: 0.0055
#
# Epoch 00010: val_loss did not improve from 0.00431
# Epoch 11/100
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0086 - val_loss: 0.0041
#
# Epoch 00011: val_loss improved from 0.00431 to 0.00411, saving model to doubleLSTMmodel.h5
# Epoch 12/100
# 3847/3847 [==============================] - 3s 723us/step - loss: 0.0086 - val_loss: 0.0050
#
# Epoch 00012: val_loss did not improve from 0.00411
# Epoch 13/100
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0086 - val_loss: 0.0063
#
# Epoch 00013: val_loss did not improve from 0.00411
# Epoch 14/100
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0086 - val_loss: 0.0051
#
# Epoch 00014: val_loss did not improve from 0.00411
# Epoch 15/100
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0085 - val_loss: 0.0055
#
# Epoch 00015: val_loss did not improve from 0.00411
# Epoch 16/100
# 3847/3847 [==============================] - 3s 718us/step - loss: 0.0085 - val_loss: 0.0047
#
# Epoch 00016: val_loss did not improve from 0.00411
# Epoch 17/100
# 3847/3847 [==============================] - 3s 724us/step - loss: 0.0084 - val_loss: 0.0054
#
# Epoch 00017: val_loss did not improve from 0.00411
# Epoch 18/100
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0084 - val_loss: 0.0057
#
# Epoch 00018: val_loss did not improve from 0.00411
# Epoch 19/100
# 3847/3847 [==============================] - 3s 718us/step - loss: 0.0084 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00411
# Epoch 20/100
# 3847/3847 [==============================] - 3s 711us/step - loss: 0.0086 - val_loss: 0.0064
#
# Epoch 00020: val_loss did not improve from 0.00411
# Epoch 21/100
# 3847/3847 [==============================] - 3s 716us/step - loss: 0.0084 - val_loss: 0.0046
#
# Epoch 00021: val_loss did not improve from 0.00411
# Epoch 22/100
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0084 - val_loss: 0.0055
#
# Epoch 00022: val_loss did not improve from 0.00411
# Epoch 23/100
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0084 - val_loss: 0.0050
#
# Epoch 00023: val_loss did not improve from 0.00411
# Epoch 24/100
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0084 - val_loss: 0.0061
#
# Epoch 00024: val_loss did not improve from 0.00411
# Epoch 25/100
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00025: val_loss did not improve from 0.00411
# Epoch 26/100
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00026: val_loss did not improve from 0.00411
# Epoch 27/100
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0084 - val_loss: 0.0058
#
# Epoch 00027: val_loss did not improve from 0.00411
# Epoch 28/100
# 3847/3847 [==============================] - 3s 735us/step - loss: 0.0082 - val_loss: 0.0048
#
# Epoch 00028: val_loss did not improve from 0.00411
# Epoch 29/100
# 3847/3847 [==============================] - 3s 735us/step - loss: 0.0083 - val_loss: 0.0065
#
# Epoch 00029: val_loss did not improve from 0.00411
# Epoch 30/100
# 3847/3847 [==============================] - 3s 741us/step - loss: 0.0083 - val_loss: 0.0066
#
# Epoch 00030: val_loss did not improve from 0.00411
# Epoch 31/100
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0083 - val_loss: 0.0053
#
# Epoch 00031: val_loss did not improve from 0.00411
# Epoch 32/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0082 - val_loss: 0.0061
#
# Epoch 00032: val_loss did not improve from 0.00411
# Epoch 33/100
# 3847/3847 [==============================] - 3s 735us/step - loss: 0.0082 - val_loss: 0.0051
#
# Epoch 00033: val_loss did not improve from 0.00411
# Epoch 34/100
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0083 - val_loss: 0.0054
#
# Epoch 00034: val_loss did not improve from 0.00411
# Epoch 35/100
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0084 - val_loss: 0.0055
#
# Epoch 00035: val_loss did not improve from 0.00411
# Epoch 36/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0081 - val_loss: 0.0048
#
# Epoch 00036: val_loss did not improve from 0.00411
# Epoch 37/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0082 - val_loss: 0.0060
#
# Epoch 00037: val_loss did not improve from 0.00411
# Epoch 38/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0083 - val_loss: 0.0065
#
# Epoch 00038: val_loss did not improve from 0.00411
# Epoch 39/100
# 3847/3847 [==============================] - 3s 745us/step - loss: 0.0082 - val_loss: 0.0070
#
# Epoch 00039: val_loss did not improve from 0.00411
# Epoch 40/100
# 3847/3847 [==============================] - 3s 741us/step - loss: 0.0082 - val_loss: 0.0054
#
# Epoch 00040: val_loss did not improve from 0.00411
# Epoch 41/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0081 - val_loss: 0.0062
#
# Epoch 00041: val_loss did not improve from 0.00411
# Epoch 42/100
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0082 - val_loss: 0.0061
#
# Epoch 00042: val_loss did not improve from 0.00411
# Epoch 43/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0080 - val_loss: 0.0061
#
# Epoch 00043: val_loss did not improve from 0.00411
# Epoch 44/100
# 3847/3847 [==============================] - 3s 733us/step - loss: 0.0082 - val_loss: 0.0060
#
# Epoch 00044: val_loss did not improve from 0.00411
# Epoch 45/100
# 3847/3847 [==============================] - 3s 733us/step - loss: 0.0082 - val_loss: 0.0053
#
# Epoch 00045: val_loss did not improve from 0.00411
# Epoch 46/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0084 - val_loss: 0.0062
#
# Epoch 00046: val_loss did not improve from 0.00411
# Epoch 47/100
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0081 - val_loss: 0.0054
#
# Epoch 00047: val_loss did not improve from 0.00411
# Epoch 48/100
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0079 - val_loss: 0.0053
#
# Epoch 00048: val_loss did not improve from 0.00411
# Epoch 49/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0080 - val_loss: 0.0089
#
# Epoch 00049: val_loss did not improve from 0.00411
# Epoch 50/100
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0083 - val_loss: 0.0063
#
# Epoch 00050: val_loss did not improve from 0.00411
# Epoch 51/100
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0080 - val_loss: 0.0060
#
# Epoch 00051: val_loss did not improve from 0.00411
# Epoch 52/100
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0078 - val_loss: 0.0054
#
# Epoch 00052: val_loss did not improve from 0.00411
# Epoch 53/100
# 3847/3847 [==============================] - 3s 716us/step - loss: 0.0081 - val_loss: 0.0059
#
# Epoch 00053: val_loss did not improve from 0.00411
# Epoch 54/100
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0078 - val_loss: 0.0050
#
# Epoch 00054: val_loss did not improve from 0.00411
# Epoch 55/100
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0076 - val_loss: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.00411
# Epoch 56/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0074 - val_loss: 0.0061
#
# Epoch 00056: val_loss did not improve from 0.00411
# Epoch 57/100
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0073 - val_loss: 0.0058
#
# Epoch 00057: val_loss did not improve from 0.00411
# Epoch 58/100
# 3847/3847 [==============================] - 3s 740us/step - loss: 0.0068 - val_loss: 0.0051
#
# Epoch 00058: val_loss did not improve from 0.00411
# Epoch 59/100
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0068 - val_loss: 0.0070
#
# Epoch 00059: val_loss did not improve from 0.00411
# Epoch 60/100
# 3847/3847 [==============================] - 3s 807us/step - loss: 0.0066 - val_loss: 0.0055
#
# Epoch 00060: val_loss did not improve from 0.00411
# Epoch 61/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0066 - val_loss: 0.0050
#
# Epoch 00061: val_loss did not improve from 0.00411
# Epoch 62/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0063 - val_loss: 0.0045
#
# Epoch 00062: val_loss did not improve from 0.00411
# Epoch 63/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0063 - val_loss: 0.0047
#
# Epoch 00063: val_loss did not improve from 0.00411
# Epoch 64/100
# 3847/3847 [==============================] - 3s 763us/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00064: val_loss did not improve from 0.00411
# Epoch 65/100
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0061 - val_loss: 0.0060
#
# Epoch 00065: val_loss did not improve from 0.00411
# Epoch 66/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0060 - val_loss: 0.0057
#
# Epoch 00066: val_loss did not improve from 0.00411
# Epoch 67/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0060 - val_loss: 0.0052
#
# Epoch 00067: val_loss did not improve from 0.00411
# Epoch 68/100
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0058 - val_loss: 0.0052
#
# Epoch 00068: val_loss did not improve from 0.00411
# Epoch 69/100
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0058 - val_loss: 0.0050
#
# Epoch 00069: val_loss did not improve from 0.00411
# Epoch 70/100
# 3847/3847 [==============================] - 3s 727us/step - loss: 0.0057 - val_loss: 0.0045
#
# Epoch 00070: val_loss did not improve from 0.00411
# Epoch 71/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0059 - val_loss: 0.0057
#
# Epoch 00071: val_loss did not improve from 0.00411
# Epoch 72/100
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0058 - val_loss: 0.0069
#
# Epoch 00072: val_loss did not improve from 0.00411
# Epoch 73/100
# 3847/3847 [==============================] - 3s 823us/step - loss: 0.0058 - val_loss: 0.0047
#
# Epoch 00073: val_loss did not improve from 0.00411
# Epoch 74/100
# 3847/3847 [==============================] - 3s 801us/step - loss: 0.0058 - val_loss: 0.0049
#
# Epoch 00074: val_loss did not improve from 0.00411
# Epoch 75/100
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0058 - val_loss: 0.0050
#
# Epoch 00075: val_loss did not improve from 0.00411
# Epoch 76/100
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0057 - val_loss: 0.0053
#
# Epoch 00076: val_loss did not improve from 0.00411
# Epoch 77/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0056 - val_loss: 0.0050
#
# Epoch 00077: val_loss did not improve from 0.00411
# Epoch 78/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0056 - val_loss: 0.0056
#
# Epoch 00078: val_loss did not improve from 0.00411
# Epoch 79/100
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0054 - val_loss: 0.0055
#
# Epoch 00079: val_loss did not improve from 0.00411
# Epoch 80/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0054 - val_loss: 0.0063
#
# Epoch 00080: val_loss did not improve from 0.00411
# Epoch 81/100
# 3847/3847 [==============================] - 4s 916us/step - loss: 0.0054 - val_loss: 0.0050
#
# Epoch 00081: val_loss did not improve from 0.00411
# Epoch 82/100
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0055 - val_loss: 0.0045
#
# Epoch 00082: val_loss did not improve from 0.00411
# Epoch 83/100
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0054 - val_loss: 0.0059
#
# Epoch 00083: val_loss did not improve from 0.00411
# Epoch 84/100
# 3847/3847 [==============================] - 3s 830us/step - loss: 0.0053 - val_loss: 0.0058
#
# Epoch 00084: val_loss did not improve from 0.00411
# Epoch 85/100
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0053 - val_loss: 0.0055
#
# Epoch 00085: val_loss did not improve from 0.00411
# Epoch 86/100
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0052 - val_loss: 0.0050
#
# Epoch 00086: val_loss did not improve from 0.00411
# Epoch 87/100
# 3847/3847 [==============================] - 3s 733us/step - loss: 0.0051 - val_loss: 0.0049
#
# Epoch 00087: val_loss did not improve from 0.00411
# Epoch 88/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0051 - val_loss: 0.0054
#
# Epoch 00088: val_loss did not improve from 0.00411
# Epoch 89/100
# 3847/3847 [==============================] - 3s 783us/step - loss: 0.0051 - val_loss: 0.0046
#
# Epoch 00089: val_loss did not improve from 0.00411
# Epoch 90/100
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0052 - val_loss: 0.0042
#
# Epoch 00090: val_loss did not improve from 0.00411
# Epoch 91/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0052 - val_loss: 0.0062
#
# Epoch 00091: val_loss did not improve from 0.00411
# Epoch 00091: early stopping
# Model loaded
# mae :  4703.773007558847
# mse :  50674190.08575
# rmse :  7118.580622971829
# std : 7118.278213352598

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 12s 3ms/step - loss: 0.0124 - val_loss: 0.0053
#
# Epoch 00001: val_loss improved from inf to 0.00535, saving model to doubleLSTMmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 3s 791us/step - loss: 0.0110 - val_loss: 0.0052
#
# Epoch 00002: val_loss improved from 0.00535 to 0.00522, saving model to doubleLSTMmodel.h5
# Epoch 3/100
# 3847/3847 [==============================] - 3s 788us/step - loss: 0.0097 - val_loss: 0.0047
#
# Epoch 00003: val_loss improved from 0.00522 to 0.00472, saving model to doubleLSTMmodel.h5
# Epoch 4/100
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00004: val_loss did not improve from 0.00472
# Epoch 5/100
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0088 - val_loss: 0.0051
#
# Epoch 00005: val_loss did not improve from 0.00472
# Epoch 6/100
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0087 - val_loss: 0.0063
#
# Epoch 00006: val_loss did not improve from 0.00472
# Epoch 7/100
# 3847/3847 [==============================] - 3s 792us/step - loss: 0.0089 - val_loss: 0.0054
#
# Epoch 00007: val_loss did not improve from 0.00472
# Epoch 8/100
# 3847/3847 [==============================] - 3s 787us/step - loss: 0.0086 - val_loss: 0.0048
#
# Epoch 00008: val_loss did not improve from 0.00472
# Epoch 9/100
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0086 - val_loss: 0.0045
#
# Epoch 00009: val_loss improved from 0.00472 to 0.00452, saving model to doubleLSTMmodel.h5
# Epoch 10/100
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0086 - val_loss: 0.0054
#
# Epoch 00010: val_loss did not improve from 0.00452
# Epoch 11/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00011: val_loss did not improve from 0.00452
# Epoch 12/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0084 - val_loss: 0.0060
#
# Epoch 00012: val_loss did not improve from 0.00452
# Epoch 13/100
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0084 - val_loss: 0.0052
#
# Epoch 00013: val_loss did not improve from 0.00452
# Epoch 14/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0085 - val_loss: 0.0046
#
# Epoch 00014: val_loss did not improve from 0.00452
# Epoch 15/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0083 - val_loss: 0.0055
#
# Epoch 00015: val_loss did not improve from 0.00452
# Epoch 16/100
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0086 - val_loss: 0.0052
#
# Epoch 00016: val_loss did not improve from 0.00452
# Epoch 17/100
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0083 - val_loss: 0.0057
#
# Epoch 00017: val_loss did not improve from 0.00452
# Epoch 18/100
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0084 - val_loss: 0.0048
#
# Epoch 00018: val_loss did not improve from 0.00452
# Epoch 19/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0084 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00452
# Epoch 20/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0083 - val_loss: 0.0053
#
# Epoch 00020: val_loss did not improve from 0.00452
# Epoch 21/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0084 - val_loss: 0.0052
#
# Epoch 00021: val_loss did not improve from 0.00452
# Epoch 22/100
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0086 - val_loss: 0.0059
#
# Epoch 00022: val_loss did not improve from 0.00452
# Epoch 23/100
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0086 - val_loss: 0.0048
#
# Epoch 00023: val_loss did not improve from 0.00452
# Epoch 24/100
# 3847/3847 [==============================] - 3s 766us/step - loss: 0.0082 - val_loss: 0.0045
#
# Epoch 00024: val_loss improved from 0.00452 to 0.00452, saving model to doubleLSTMmodel.h5
# Epoch 25/100
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0084 - val_loss: 0.0059
#
# Epoch 00025: val_loss did not improve from 0.00452
# Epoch 26/100
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0083 - val_loss: 0.0044
#
# Epoch 00026: val_loss improved from 0.00452 to 0.00443, saving model to doubleLSTMmodel.h5
# Epoch 27/100
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0083 - val_loss: 0.0057
#
# Epoch 00027: val_loss did not improve from 0.00443
# Epoch 28/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0082 - val_loss: 0.0052
#
# Epoch 00028: val_loss did not improve from 0.00443
# Epoch 29/100
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0084 - val_loss: 0.0060
#
# Epoch 00029: val_loss did not improve from 0.00443
# Epoch 30/100
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0082 - val_loss: 0.0050
#
# Epoch 00030: val_loss did not improve from 0.00443
# Epoch 31/100
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0081 - val_loss: 0.0056
#
# Epoch 00031: val_loss did not improve from 0.00443
# Epoch 32/100
# 3847/3847 [==============================] - 3s 741us/step - loss: 0.0083 - val_loss: 0.0048
#
# Epoch 00032: val_loss did not improve from 0.00443
# Epoch 33/100
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0084 - val_loss: 0.0054
#
# Epoch 00033: val_loss did not improve from 0.00443
# Epoch 34/100
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0082 - val_loss: 0.0057
#
# Epoch 00034: val_loss did not improve from 0.00443
# Epoch 35/100
# 3847/3847 [==============================] - 3s 735us/step - loss: 0.0082 - val_loss: 0.0062
#
# Epoch 00035: val_loss did not improve from 0.00443
# Epoch 36/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0083 - val_loss: 0.0048
#
# Epoch 00036: val_loss did not improve from 0.00443
# Epoch 37/100
# 3847/3847 [==============================] - 3s 805us/step - loss: 0.0081 - val_loss: 0.0055
#
# Epoch 00037: val_loss did not improve from 0.00443
# Epoch 38/100
# 3847/3847 [==============================] - 3s 783us/step - loss: 0.0082 - val_loss: 0.0064
#
# Epoch 00038: val_loss did not improve from 0.00443
# Epoch 39/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0081 - val_loss: 0.0075
#
# Epoch 00039: val_loss did not improve from 0.00443
# Epoch 40/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0082 - val_loss: 0.0063
#
# Epoch 00040: val_loss did not improve from 0.00443
# Epoch 41/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0082 - val_loss: 0.0057
#
# Epoch 00041: val_loss did not improve from 0.00443
# Epoch 42/100
# 3847/3847 [==============================] - 3s 792us/step - loss: 0.0080 - val_loss: 0.0048
#
# Epoch 00042: val_loss did not improve from 0.00443
# Epoch 43/100
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0080 - val_loss: 0.0045
#
# Epoch 00043: val_loss did not improve from 0.00443
# Epoch 44/100
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0079 - val_loss: 0.0052
#
# Epoch 00044: val_loss did not improve from 0.00443
# Epoch 45/100
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0079 - val_loss: 0.0049
#
# Epoch 00045: val_loss did not improve from 0.00443
# Epoch 46/100
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0079 - val_loss: 0.0049
#
# Epoch 00046: val_loss did not improve from 0.00443
# Epoch 47/100
# 3847/3847 [==============================] - 3s 797us/step - loss: 0.0080 - val_loss: 0.0050
#
# Epoch 00047: val_loss did not improve from 0.00443
# Epoch 48/100
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0081 - val_loss: 0.0063
#
# Epoch 00048: val_loss did not improve from 0.00443
# Epoch 49/100
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0079 - val_loss: 0.0045
#
# Epoch 00049: val_loss did not improve from 0.00443
# Epoch 50/100
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0080 - val_loss: 0.0044
#
# Epoch 00050: val_loss improved from 0.00443 to 0.00441, saving model to doubleLSTMmodel.h5
# Epoch 51/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0079 - val_loss: 0.0054
#
# Epoch 00051: val_loss did not improve from 0.00441
# Epoch 52/100
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0080 - val_loss: 0.0059
#
# Epoch 00052: val_loss did not improve from 0.00441
# Epoch 53/100
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0077 - val_loss: 0.0054
#
# Epoch 00053: val_loss did not improve from 0.00441
# Epoch 54/100
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0076 - val_loss: 0.0061
#
# Epoch 00054: val_loss did not improve from 0.00441
# Epoch 55/100
# 3847/3847 [==============================] - 3s 745us/step - loss: 0.0077 - val_loss: 0.0052
#
# Epoch 00055: val_loss did not improve from 0.00441
# Epoch 56/100
# 3847/3847 [==============================] - 3s 740us/step - loss: 0.0077 - val_loss: 0.0047
#
# Epoch 00056: val_loss did not improve from 0.00441
# Epoch 57/100
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0076 - val_loss: 0.0065
#
# Epoch 00057: val_loss did not improve from 0.00441
# Epoch 58/100
# 3847/3847 [==============================] - 3s 802us/step - loss: 0.0075 - val_loss: 0.0054
#
# Epoch 00058: val_loss did not improve from 0.00441
# Epoch 59/100
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0075 - val_loss: 0.0046
#
# Epoch 00059: val_loss did not improve from 0.00441
# Epoch 60/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0074 - val_loss: 0.0054
#
# Epoch 00060: val_loss did not improve from 0.00441
# Epoch 61/100
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0071 - val_loss: 0.0058
#
# Epoch 00061: val_loss did not improve from 0.00441
# Epoch 62/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0071 - val_loss: 0.0048
#
# Epoch 00062: val_loss did not improve from 0.00441
# Epoch 63/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0072 - val_loss: 0.0050
#
# Epoch 00063: val_loss did not improve from 0.00441
# Epoch 64/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0069 - val_loss: 0.0047
#
# Epoch 00064: val_loss did not improve from 0.00441
# Epoch 65/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0066 - val_loss: 0.0044
#
# Epoch 00065: val_loss improved from 0.00441 to 0.00437, saving model to doubleLSTMmodel.h5
# Epoch 66/100
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0064 - val_loss: 0.0050
#
# Epoch 00066: val_loss did not improve from 0.00437
# Epoch 67/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0061 - val_loss: 0.0046
#
# Epoch 00067: val_loss did not improve from 0.00437
# Epoch 68/100
# 3847/3847 [==============================] - 3s 740us/step - loss: 0.0060 - val_loss: 0.0041
#
# Epoch 00068: val_loss improved from 0.00437 to 0.00409, saving model to doubleLSTMmodel.h5
# Epoch 69/100
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0061 - val_loss: 0.0049
#
# Epoch 00069: val_loss did not improve from 0.00409
# Epoch 70/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0058 - val_loss: 0.0043
#
# Epoch 00070: val_loss did not improve from 0.00409
# Epoch 71/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0060 - val_loss: 0.0043
#
# Epoch 00071: val_loss did not improve from 0.00409
# Epoch 72/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0059 - val_loss: 0.0044
#
# Epoch 00072: val_loss did not improve from 0.00409
# Epoch 73/100
# 3847/3847 [==============================] - 3s 766us/step - loss: 0.0059 - val_loss: 0.0049
#
# Epoch 00073: val_loss did not improve from 0.00409
# Epoch 74/100
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0058 - val_loss: 0.0037
#
# Epoch 00074: val_loss improved from 0.00409 to 0.00375, saving model to doubleLSTMmodel.h5
# Epoch 75/100
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0056 - val_loss: 0.0043
#
# Epoch 00075: val_loss did not improve from 0.00375
# Epoch 76/100
# 3847/3847 [==============================] - 3s 797us/step - loss: 0.0056 - val_loss: 0.0044
#
# Epoch 00076: val_loss did not improve from 0.00375
# Epoch 77/100
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0055 - val_loss: 0.0051
#
# Epoch 00077: val_loss did not improve from 0.00375
# Epoch 78/100
# 3847/3847 [==============================] - 3s 758us/step - loss: 0.0055 - val_loss: 0.0045
#
# Epoch 00078: val_loss did not improve from 0.00375
# Epoch 79/100
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0054 - val_loss: 0.0047
#
# Epoch 00079: val_loss did not improve from 0.00375
# Epoch 80/100
# 3847/3847 [==============================] - 3s 754us/step - loss: 0.0054 - val_loss: 0.0044
#
# Epoch 00080: val_loss did not improve from 0.00375
# Epoch 81/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00081: val_loss did not improve from 0.00375
# Epoch 82/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0054 - val_loss: 0.0052
#
# Epoch 00082: val_loss did not improve from 0.00375
# Epoch 83/100
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0052 - val_loss: 0.0048
#
# Epoch 00083: val_loss did not improve from 0.00375
# Epoch 84/100
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0053 - val_loss: 0.0041
#
# Epoch 00084: val_loss did not improve from 0.00375
# Epoch 85/100
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0051 - val_loss: 0.0043
#
# Epoch 00085: val_loss did not improve from 0.00375
# Epoch 86/100
# 3847/3847 [==============================] - 3s 763us/step - loss: 0.0052 - val_loss: 0.0042
#
# Epoch 00086: val_loss did not improve from 0.00375
# Epoch 87/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0052 - val_loss: 0.0042
#
# Epoch 00087: val_loss did not improve from 0.00375
# Epoch 88/100
# 3847/3847 [==============================] - 3s 757us/step - loss: 0.0052 - val_loss: 0.0049
#
# Epoch 00088: val_loss did not improve from 0.00375
# Epoch 89/100
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0053 - val_loss: 0.0054
#
# Epoch 00089: val_loss did not improve from 0.00375
# Epoch 90/100
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0051 - val_loss: 0.0050
#
# Epoch 00090: val_loss did not improve from 0.00375
# Epoch 91/100
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0050 - val_loss: 0.0041
#
# Epoch 00091: val_loss did not improve from 0.00375
# Epoch 92/100
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0049 - val_loss: 0.0048
#
# Epoch 00092: val_loss did not improve from 0.00375
# Epoch 93/100
# 3847/3847 [==============================] - 3s 763us/step - loss: 0.0049 - val_loss: 0.0050
#
# Epoch 00093: val_loss did not improve from 0.00375
# Epoch 94/100
# 3847/3847 [==============================] - 3s 763us/step - loss: 0.0050 - val_loss: 0.0053
#
# Epoch 00094: val_loss did not improve from 0.00375
# Epoch 95/100
# 3847/3847 [==============================] - 3s 787us/step - loss: 0.0049 - val_loss: 0.0046
#
# Epoch 00095: val_loss did not improve from 0.00375
# Epoch 96/100
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0050 - val_loss: 0.0045
#
# Epoch 00096: val_loss did not improve from 0.00375
# Epoch 97/100
# 3847/3847 [==============================] - 3s 757us/step - loss: 0.0050 - val_loss: 0.0047
#
# Epoch 00097: val_loss did not improve from 0.00375
# Epoch 98/100
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0052 - val_loss: 0.0046
#
# Epoch 00098: val_loss did not improve from 0.00375
# Epoch 99/100
# 3847/3847 [==============================] - 3s 759us/step - loss: 0.0048 - val_loss: 0.0055
#
# Epoch 00099: val_loss did not improve from 0.00375
# Epoch 100/100
# 3847/3847 [==============================] - 3s 763us/step - loss: 0.0046 - val_loss: 0.0041
#
# Epoch 00100: val_loss did not improve from 0.00375
# Model loaded
# mae :  4904.246653053977
# mse :  55182970.3172308
# rmse :  7428.524100871639
# std : 7320.904534134052

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 9s 2ms/step - loss: 0.0120 - val_loss: 0.0060
#
# Epoch 00001: val_loss improved from inf to 0.00595, saving model to doubleLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 938us/step - loss: 0.0108 - val_loss: 0.0053
#
# Epoch 00002: val_loss improved from 0.00595 to 0.00526, saving model to doubleLSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 4s 937us/step - loss: 0.0093 - val_loss: 0.0051
#
# Epoch 00003: val_loss improved from 0.00526 to 0.00509, saving model to doubleLSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 4s 948us/step - loss: 0.0091 - val_loss: 0.0049
#
# Epoch 00004: val_loss improved from 0.00509 to 0.00493, saving model to doubleLSTMmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 4s 925us/step - loss: 0.0089 - val_loss: 0.0063
#
# Epoch 00005: val_loss did not improve from 0.00493
# Epoch 6/70
# 3847/3847 [==============================] - 3s 878us/step - loss: 0.0089 - val_loss: 0.0057
#
# Epoch 00006: val_loss did not improve from 0.00493
# Epoch 7/70
# 3847/3847 [==============================] - 4s 931us/step - loss: 0.0089 - val_loss: 0.0052
#
# Epoch 00007: val_loss did not improve from 0.00493
# Epoch 8/70
# 3847/3847 [==============================] - 4s 930us/step - loss: 0.0086 - val_loss: 0.0046
#
# Epoch 00008: val_loss improved from 0.00493 to 0.00460, saving model to doubleLSTMmodel.h5
# Epoch 9/70
# 3847/3847 [==============================] - 4s 983us/step - loss: 0.0088 - val_loss: 0.0055
#
# Epoch 00009: val_loss did not improve from 0.00460
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0062
#
# Epoch 00010: val_loss did not improve from 0.00460
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00011: val_loss did not improve from 0.00460
# Epoch 12/70
# 3847/3847 [==============================] - 4s 999us/step - loss: 0.0087 - val_loss: 0.0045
#
# Epoch 00012: val_loss improved from 0.00460 to 0.00454, saving model to doubleLSTMmodel.h5
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0052
#
# Epoch 00013: val_loss did not improve from 0.00454
# Epoch 14/70
# 3847/3847 [==============================] - 4s 964us/step - loss: 0.0085 - val_loss: 0.0056
#
# Epoch 00014: val_loss did not improve from 0.00454
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0046
#
# Epoch 00015: val_loss did not improve from 0.00454
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0044
#
# Epoch 00016: val_loss improved from 0.00454 to 0.00442, saving model to doubleLSTMmodel.h5
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0059
#
# Epoch 00017: val_loss did not improve from 0.00442
# Epoch 18/70
# 3847/3847 [==============================] - 4s 975us/step - loss: 0.0086 - val_loss: 0.0052
#
# Epoch 00018: val_loss did not improve from 0.00442
# Epoch 19/70
# 3847/3847 [==============================] - 4s 999us/step - loss: 0.0085 - val_loss: 0.0046
#
# Epoch 00019: val_loss did not improve from 0.00442
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0060
#
# Epoch 00020: val_loss did not improve from 0.00442
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0048
#
# Epoch 00021: val_loss did not improve from 0.00442
# Epoch 22/70
# 3847/3847 [==============================] - 4s 985us/step - loss: 0.0084 - val_loss: 0.0047
#
# Epoch 00022: val_loss did not improve from 0.00442
# Epoch 23/70
# 3847/3847 [==============================] - 4s 968us/step - loss: 0.0084 - val_loss: 0.0047
#
# Epoch 00023: val_loss did not improve from 0.00442
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0060
#
# Epoch 00024: val_loss did not improve from 0.00442
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00025: val_loss did not improve from 0.00442
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0069
#
# Epoch 00026: val_loss did not improve from 0.00442
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0044
#
# Epoch 00027: val_loss improved from 0.00442 to 0.00441, saving model to doubleLSTMmodel.h5
# Epoch 28/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0083 - val_loss: 0.0050
#
# Epoch 00028: val_loss did not improve from 0.00441
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0068
#
# Epoch 00029: val_loss did not improve from 0.00441
# Epoch 30/70
# 3847/3847 [==============================] - 4s 970us/step - loss: 0.0084 - val_loss: 0.0063
#
# Epoch 00030: val_loss did not improve from 0.00441
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0051
#
# Epoch 00031: val_loss did not improve from 0.00441
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0058
#
# Epoch 00032: val_loss did not improve from 0.00441
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0047
#
# Epoch 00033: val_loss did not improve from 0.00441
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0050
#
# Epoch 00034: val_loss did not improve from 0.00441
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0053
#
# Epoch 00035: val_loss did not improve from 0.00441
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0081 - val_loss: 0.0051
#
# Epoch 00036: val_loss did not improve from 0.00441
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0079 - val_loss: 0.0053
#
# Epoch 00037: val_loss did not improve from 0.00441
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0077 - val_loss: 0.0045
#
# Epoch 00038: val_loss did not improve from 0.00441
# Epoch 39/70
# 3847/3847 [==============================] - 4s 995us/step - loss: 0.0074 - val_loss: 0.0041
#
# Epoch 00039: val_loss improved from 0.00441 to 0.00415, saving model to doubleLSTMmodel.h5
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0072 - val_loss: 0.0064
#
# Epoch 00040: val_loss did not improve from 0.00415
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0057
#
# Epoch 00041: val_loss did not improve from 0.00415
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0051
#
# Epoch 00042: val_loss did not improve from 0.00415
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0048
#
# Epoch 00043: val_loss did not improve from 0.00415
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0062 - val_loss: 0.0054
#
# Epoch 00044: val_loss did not improve from 0.00415
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0061 - val_loss: 0.0052
#
# Epoch 00045: val_loss did not improve from 0.00415
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0042
#
# Epoch 00046: val_loss did not improve from 0.00415
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0043
#
# Epoch 00047: val_loss did not improve from 0.00415
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0051
#
# Epoch 00048: val_loss did not improve from 0.00415
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0058 - val_loss: 0.0047
#
# Epoch 00049: val_loss did not improve from 0.00415
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0047
#
# Epoch 00050: val_loss did not improve from 0.00415
# Epoch 51/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0058 - val_loss: 0.0045
#
# Epoch 00051: val_loss did not improve from 0.00415
# Epoch 52/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0058 - val_loss: 0.0047
#
# Epoch 00052: val_loss did not improve from 0.00415
# Epoch 53/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0056 - val_loss: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.00415
# Epoch 54/70
# 3847/3847 [==============================] - 4s 994us/step - loss: 0.0056 - val_loss: 0.0048
#
# Epoch 00054: val_loss did not improve from 0.00415
# Epoch 55/70
# 3847/3847 [==============================] - 4s 972us/step - loss: 0.0056 - val_loss: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.00415
# Epoch 56/70
# 3847/3847 [==============================] - 4s 983us/step - loss: 0.0055 - val_loss: 0.0048
#
# Epoch 00056: val_loss did not improve from 0.00415
# Epoch 57/70
# 3847/3847 [==============================] - 4s 978us/step - loss: 0.0055 - val_loss: 0.0055
#
# Epoch 00057: val_loss did not improve from 0.00415
# Epoch 58/70
# 3847/3847 [==============================] - 4s 988us/step - loss: 0.0054 - val_loss: 0.0045
#
# Epoch 00058: val_loss did not improve from 0.00415
# Epoch 59/70
# 3847/3847 [==============================] - 4s 984us/step - loss: 0.0055 - val_loss: 0.0051
#
# Epoch 00059: val_loss did not improve from 0.00415
# Epoch 60/70
# 3847/3847 [==============================] - 4s 978us/step - loss: 0.0055 - val_loss: 0.0053
#
# Epoch 00060: val_loss did not improve from 0.00415
# Epoch 61/70
# 3847/3847 [==============================] - 4s 980us/step - loss: 0.0053 - val_loss: 0.0053
#
# Epoch 00061: val_loss did not improve from 0.00415
# Epoch 62/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0054 - val_loss: 0.0046
#
# Epoch 00062: val_loss did not improve from 0.00415
# Epoch 63/70
# 3847/3847 [==============================] - 4s 991us/step - loss: 0.0053 - val_loss: 0.0047
#
# Epoch 00063: val_loss did not improve from 0.00415
# Epoch 64/70
# 3847/3847 [==============================] - 4s 983us/step - loss: 0.0054 - val_loss: 0.0060
#
# Epoch 00064: val_loss did not improve from 0.00415
# Epoch 65/70
# 3847/3847 [==============================] - 4s 991us/step - loss: 0.0053 - val_loss: 0.0056
#
# Epoch 00065: val_loss did not improve from 0.00415
# Epoch 66/70
# 3847/3847 [==============================] - 4s 979us/step - loss: 0.0053 - val_loss: 0.0047
#
# Epoch 00066: val_loss did not improve from 0.00415
# Epoch 67/70
# 3847/3847 [==============================] - 4s 983us/step - loss: 0.0053 - val_loss: 0.0058
#
# Epoch 00067: val_loss did not improve from 0.00415
# Epoch 68/70
# 3847/3847 [==============================] - 4s 980us/step - loss: 0.0051 - val_loss: 0.0056
#
# Epoch 00068: val_loss did not improve from 0.00415
# Epoch 69/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0051 - val_loss: 0.0053
#
# Epoch 00069: val_loss did not improve from 0.00415
# Epoch 70/70
# 3847/3847 [==============================] - 4s 979us/step - loss: 0.0051 - val_loss: 0.0058
#
# Epoch 00070: val_loss did not improve from 0.00415
# Model loaded
# mae :  5969.6729923396915
# mse :  60662849.2266695
# rmse :  7788.635902818252
# std : 7469.753707091206

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 12s 3ms/step - loss: 0.0123 - val_loss: 0.0050
#
# Epoch 00001: val_loss improved from inf to 0.00495, saving model to doubleLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 848us/step - loss: 0.0102 - val_loss: 0.0050
#
# Epoch 00002: val_loss did not improve from 0.00495
# Epoch 3/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00003: val_loss improved from 0.00495 to 0.00465, saving model to doubleLSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0093 - val_loss: 0.0048
#
# Epoch 00004: val_loss did not improve from 0.00465
# Epoch 5/70
# 3847/3847 [==============================] - 4s 957us/step - loss: 0.0089 - val_loss: 0.0049
#
# Epoch 00005: val_loss did not improve from 0.00465
# Epoch 6/70
# 3847/3847 [==============================] - 4s 919us/step - loss: 0.0089 - val_loss: 0.0046
#
# Epoch 00006: val_loss improved from 0.00465 to 0.00460, saving model to doubleLSTMmodel.h5
# Epoch 7/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0088 - val_loss: 0.0050
#
# Epoch 00007: val_loss did not improve from 0.00460
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0091 - val_loss: 0.0055
#
# Epoch 00008: val_loss did not improve from 0.00460
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0046
#
# Epoch 00009: val_loss improved from 0.00460 to 0.00459, saving model to doubleLSTMmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0065
#
# Epoch 00010: val_loss did not improve from 0.00459
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0058
#
# Epoch 00011: val_loss did not improve from 0.00459
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0056
#
# Epoch 00012: val_loss did not improve from 0.00459
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0048
#
# Epoch 00013: val_loss did not improve from 0.00459
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0048
#
# Epoch 00014: val_loss did not improve from 0.00459
# Epoch 15/70
# 3847/3847 [==============================] - 4s 978us/step - loss: 0.0087 - val_loss: 0.0061
#
# Epoch 00015: val_loss did not improve from 0.00459
# Epoch 16/70
# 3847/3847 [==============================] - 4s 978us/step - loss: 0.0085 - val_loss: 0.0047
#
# Epoch 00016: val_loss did not improve from 0.00459
# Epoch 17/70
# 3847/3847 [==============================] - 4s 976us/step - loss: 0.0085 - val_loss: 0.0064TA: 1s -
#
# Epoch 00017: val_loss did not improve from 0.00459
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0043
#
# Epoch 00018: val_loss improved from 0.00459 to 0.00434, saving model to doubleLSTMmodel.h5
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0052
#
# Epoch 00019: val_loss did not improve from 0.00434
# Epoch 20/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0085 - val_loss: 0.0044
#
# Epoch 00020: val_loss did not improve from 0.00434
# Epoch 21/70
# 3847/3847 [==============================] - 4s 999us/step - loss: 0.0084 - val_loss: 0.0056
#
# Epoch 00021: val_loss did not improve from 0.00434
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0059
#
# Epoch 00022: val_loss did not improve from 0.00434
# Epoch 23/70
# 3847/3847 [==============================] - 4s 980us/step - loss: 0.0084 - val_loss: 0.0044
#
# Epoch 00023: val_loss did not improve from 0.00434
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0052
#
# Epoch 00024: val_loss did not improve from 0.00434
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0053
#
# Epoch 00025: val_loss did not improve from 0.00434
# Epoch 26/70
# 3847/3847 [==============================] - 4s 975us/step - loss: 0.0083 - val_loss: 0.0062
#
# Epoch 00026: val_loss did not improve from 0.00434
# Epoch 27/70
# 3847/3847 [==============================] - 4s 980us/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00027: val_loss did not improve from 0.00434
# Epoch 28/70
# 3847/3847 [==============================] - 4s 959us/step - loss: 0.0085 - val_loss: 0.0050
#
# Epoch 00028: val_loss did not improve from 0.00434
# Epoch 29/70
# 3847/3847 [==============================] - 4s 966us/step - loss: 0.0083 - val_loss: 0.0057
#
# Epoch 00029: val_loss did not improve from 0.00434
# Epoch 30/70
# 3847/3847 [==============================] - 4s 965us/step - loss: 0.0082 - val_loss: 0.0054
#
# Epoch 00030: val_loss did not improve from 0.00434
# Epoch 31/70
# 3847/3847 [==============================] - 4s 975us/step - loss: 0.0082 - val_loss: 0.0052
#
# Epoch 00031: val_loss did not improve from 0.00434
# Epoch 32/70
# 3847/3847 [==============================] - 4s 964us/step - loss: 0.0083 - val_loss: 0.0053
#
# Epoch 00032: val_loss did not improve from 0.00434
# Epoch 33/70
# 3847/3847 [==============================] - 4s 972us/step - loss: 0.0080 - val_loss: 0.0054 ETA: 1
#
# Epoch 00033: val_loss did not improve from 0.00434
# Epoch 34/70
# 3847/3847 [==============================] - 4s 962us/step - loss: 0.0080 - val_loss: 0.0047
#
# Epoch 00034: val_loss did not improve from 0.00434
# Epoch 35/70
# 3847/3847 [==============================] - 4s 964us/step - loss: 0.0077 - val_loss: 0.0042
#
# Epoch 00035: val_loss improved from 0.00434 to 0.00422, saving model to doubleLSTMmodel.h5
# Epoch 36/70
# 3847/3847 [==============================] - 4s 963us/step - loss: 0.0075 - val_loss: 0.0054
#
# Epoch 00036: val_loss did not improve from 0.00422
# Epoch 37/70
# 3847/3847 [==============================] - 4s 961us/step - loss: 0.0071 - val_loss: 0.0049
#
# Epoch 00037: val_loss did not improve from 0.00422
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0068 - val_loss: 0.0036
#
# Epoch 00038: val_loss improved from 0.00422 to 0.00361, saving model to doubleLSTMmodel.h5
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0050
#
# Epoch 00039: val_loss did not improve from 0.00361
# Epoch 40/70
# 3847/3847 [==============================] - 4s 970us/step - loss: 0.0063 - val_loss: 0.0049
#
# Epoch 00040: val_loss did not improve from 0.00361
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0045
#
# Epoch 00041: val_loss did not improve from 0.00361
# Epoch 42/70
# 3847/3847 [==============================] - 4s 979us/step - loss: 0.0061 - val_loss: 0.0046
#
# Epoch 00042: val_loss did not improve from 0.00361
# Epoch 43/70
# 3847/3847 [==============================] - 4s 980us/step - loss: 0.0061 - val_loss: 0.0047
#
# Epoch 00043: val_loss did not improve from 0.00361
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0036
#
# Epoch 00044: val_loss improved from 0.00361 to 0.00356, saving model to doubleLSTMmodel.h5
# Epoch 45/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0060 - val_loss: 0.0052
#
# Epoch 00045: val_loss did not improve from 0.00356
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0061
#
# Epoch 00046: val_loss did not improve from 0.00356
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0048
#
# Epoch 00047: val_loss did not improve from 0.00356
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0058 - val_loss: 0.0056
#
# Epoch 00048: val_loss did not improve from 0.00356
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0046
#
# Epoch 00049: val_loss did not improve from 0.00356
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0053
#
# Epoch 00050: val_loss did not improve from 0.00356
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0060
#
# Epoch 00051: val_loss did not improve from 0.00356
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0055
#
# Epoch 00052: val_loss did not improve from 0.00356
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0041
#
# Epoch 00053: val_loss did not improve from 0.00356
# Epoch 54/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0058 - val_loss: 0.0056
#
# Epoch 00054: val_loss did not improve from 0.00356
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0041
#
# Epoch 00055: val_loss did not improve from 0.00356
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0057
#
# Epoch 00056: val_loss did not improve from 0.00356
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0048
#
# Epoch 00057: val_loss did not improve from 0.00356
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0049
#
# Epoch 00058: val_loss did not improve from 0.00356
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0056
#
# Epoch 00059: val_loss did not improve from 0.00356
# Epoch 60/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0060
#
# Epoch 00060: val_loss did not improve from 0.00356
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0066
#
# Epoch 00061: val_loss did not improve from 0.00356
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0060
#
# Epoch 00062: val_loss did not improve from 0.00356
# Epoch 63/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0051
#
# Epoch 00063: val_loss did not improve from 0.00356
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0052
#
# Epoch 00064: val_loss did not improve from 0.00356
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0052
#
# Epoch 00065: val_loss did not improve from 0.00356
# Epoch 66/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0057
#
# Epoch 00066: val_loss did not improve from 0.00356
# Epoch 67/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0046
#
# Epoch 00067: val_loss did not improve from 0.00356
# Epoch 68/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0051
#
# Epoch 00068: val_loss did not improve from 0.00356
# Epoch 69/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0052 - val_loss: 0.0055
#
# Epoch 00069: val_loss did not improve from 0.00356
# Epoch 70/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0051
#
# Epoch 00070: val_loss did not improve from 0.00356
# Model loaded
# mae :  5422.999875076096
# mse :  61073344.55830088
# rmse :  7814.94366955392
# std : 7372.804999321174

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 16s 4ms/step - loss: 0.0123 - val_loss: 0.0050
#
# Epoch 00001: val_loss improved from inf to 0.00498, saving model to doubleLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 903us/step - loss: 0.0099 - val_loss: 0.0053
#
# Epoch 00002: val_loss did not improve from 0.00498
# Epoch 3/70
# 3847/3847 [==============================] - 4s 912us/step - loss: 0.0093 - val_loss: 0.0051
#
# Epoch 00003: val_loss did not improve from 0.00498
# Epoch 4/70
# 3847/3847 [==============================] - 3s 879us/step - loss: 0.0090 - val_loss: 0.0050
#
# Epoch 00004: val_loss did not improve from 0.00498
# Epoch 5/70
# 3847/3847 [==============================] - 3s 879us/step - loss: 0.0090 - val_loss: 0.0051
#
# Epoch 00005: val_loss did not improve from 0.00498
# Epoch 6/70
# 3847/3847 [==============================] - 3s 874us/step - loss: 0.0088 - val_loss: 0.0055
#
# Epoch 00006: val_loss did not improve from 0.00498
# Epoch 7/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0087 - val_loss: 0.0058
#
# Epoch 00007: val_loss did not improve from 0.00498
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0056
#
# Epoch 00008: val_loss did not improve from 0.00498
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0053
#
# Epoch 00009: val_loss did not improve from 0.00498
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0057
#
# Epoch 00010: val_loss did not improve from 0.00498
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0059
#
# Epoch 00011: val_loss did not improve from 0.00498
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0051
#
# Epoch 00012: val_loss did not improve from 0.00498
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0050
#
# Epoch 00013: val_loss did not improve from 0.00498
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0049
#
# Epoch 00014: val_loss improved from 0.00498 to 0.00492, saving model to doubleLSTMmodel.h5
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0047
#
# Epoch 00015: val_loss improved from 0.00492 to 0.00471, saving model to doubleLSTMmodel.h5
# Epoch 16/70
# 3847/3847 [==============================] - 4s 991us/step - loss: 0.0084 - val_loss: 0.0056
#
# Epoch 00016: val_loss did not improve from 0.00471
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0067
#
# Epoch 00017: val_loss did not improve from 0.00471
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0052
#
# Epoch 00018: val_loss did not improve from 0.00471
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0045
#
# Epoch 00019: val_loss improved from 0.00471 to 0.00448, saving model to doubleLSTMmodel.h5
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0051
#
# Epoch 00020: val_loss did not improve from 0.00448
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0049
#
# Epoch 00021: val_loss did not improve from 0.00448
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0049
#
# Epoch 00022: val_loss did not improve from 0.00448
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0058
#
# Epoch 00023: val_loss did not improve from 0.00448
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0051
#
# Epoch 00024: val_loss did not improve from 0.00448
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0050
#
# Epoch 00025: val_loss did not improve from 0.00448
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0052
#
# Epoch 00026: val_loss did not improve from 0.00448
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0062
#
# Epoch 00027: val_loss did not improve from 0.00448
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0051
#
# Epoch 00028: val_loss did not improve from 0.00448
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0049
#
# Epoch 00029: val_loss did not improve from 0.00448
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0047
#
# Epoch 00030: val_loss did not improve from 0.00448
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0047
#
# Epoch 00031: val_loss did not improve from 0.00448
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0049
#
# Epoch 00032: val_loss did not improve from 0.00448
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0081 - val_loss: 0.0046
#
# Epoch 00033: val_loss did not improve from 0.00448
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0080 - val_loss: 0.0052
#
# Epoch 00034: val_loss did not improve from 0.00448
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0079 - val_loss: 0.0047
#
# Epoch 00035: val_loss did not improve from 0.00448
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0077 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00448
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0071 - val_loss: 0.0045
#
# Epoch 00037: val_loss improved from 0.00448 to 0.00447, saving model to doubleLSTMmodel.h5
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0045
#
# Epoch 00038: val_loss did not improve from 0.00447
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0044
#
# Epoch 00039: val_loss improved from 0.00447 to 0.00436, saving model to doubleLSTMmodel.h5
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0044
#
# Epoch 00040: val_loss did not improve from 0.00436
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0062 - val_loss: 0.0048
#
# Epoch 00041: val_loss did not improve from 0.00436
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0061 - val_loss: 0.0041
#
# Epoch 00042: val_loss improved from 0.00436 to 0.00414, saving model to doubleLSTMmodel.h5
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0053
#
# Epoch 00043: val_loss did not improve from 0.00414
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0047
#
# Epoch 00044: val_loss did not improve from 0.00414
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0050
#
# Epoch 00045: val_loss did not improve from 0.00414
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0041
#
# Epoch 00046: val_loss improved from 0.00414 to 0.00413, saving model to doubleLSTMmodel.h5
# Epoch 47/70
# 3847/3847 [==============================] - 4s 979us/step - loss: 0.0059 - val_loss: 0.0050
#
# Epoch 00047: val_loss did not improve from 0.00413
# Epoch 48/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0058 - val_loss: 0.0046
#
# Epoch 00048: val_loss did not improve from 0.00413
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0044
#
# Epoch 00049: val_loss did not improve from 0.00413
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0045
#
# Epoch 00050: val_loss did not improve from 0.00413
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0052
#
# Epoch 00051: val_loss did not improve from 0.00413
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0046
#
# Epoch 00052: val_loss did not improve from 0.00413
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0045
#
# Epoch 00053: val_loss did not improve from 0.00413
# Epoch 54/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0052
#
# Epoch 00054: val_loss did not improve from 0.00413
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0051
#
# Epoch 00055: val_loss did not improve from 0.00413
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0052
#
# Epoch 00056: val_loss did not improve from 0.00413
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0064
#
# Epoch 00057: val_loss did not improve from 0.00413
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0060
#
# Epoch 00058: val_loss did not improve from 0.00413
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0052
#
# Epoch 00059: val_loss did not improve from 0.00413
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0055 - val_loss: 0.0055
#
# Epoch 00060: val_loss did not improve from 0.00413
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0045
#
# Epoch 00061: val_loss did not improve from 0.00413
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00062: val_loss did not improve from 0.00413
# Epoch 63/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0051
#
# Epoch 00063: val_loss did not improve from 0.00413
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0039
#
# Epoch 00064: val_loss improved from 0.00413 to 0.00390, saving model to doubleLSTMmodel.h5
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0054
#
# Epoch 00065: val_loss did not improve from 0.00390
# Epoch 66/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0052 - val_loss: 0.0055
#
# Epoch 00066: val_loss did not improve from 0.00390
# Epoch 67/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0044
#
# Epoch 00067: val_loss did not improve from 0.00390
# Epoch 68/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0052 - val_loss: 0.0050
#
# Epoch 00068: val_loss did not improve from 0.00390
# Epoch 69/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0050
#
# Epoch 00069: val_loss did not improve from 0.00390
# Epoch 70/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0051 - val_loss: 0.0061
#
# Epoch 00070: val_loss did not improve from 0.00390
# Model loaded
# mae :  4781.317425710505
# mse :  58115487.134316385
# rmse :  7623.351437151274
# std : 7612.775602058431

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('doubleLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('doubleLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 17s 5ms/step - loss: 0.0119 - val_loss: 0.0055
#
# Epoch 00001: val_loss improved from inf to 0.00555, saving model to doubleLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0102 - val_loss: 0.0055
#
# Epoch 00002: val_loss improved from 0.00555 to 0.00551, saving model to doubleLSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 4s 923us/step - loss: 0.0091 - val_loss: 0.0056
#
# Epoch 00003: val_loss did not improve from 0.00551
# Epoch 4/70
# 3847/3847 [==============================] - 4s 933us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00004: val_loss improved from 0.00551 to 0.00451, saving model to doubleLSTMmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 3s 905us/step - loss: 0.0091 - val_loss: 0.0056
#
# Epoch 00005: val_loss did not improve from 0.00451
# Epoch 6/70
# 3847/3847 [==============================] - 4s 952us/step - loss: 0.0088 - val_loss: 0.0047
#
# Epoch 00006: val_loss did not improve from 0.00451
# Epoch 7/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00007: val_loss did not improve from 0.00451
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0062
#
# Epoch 00008: val_loss did not improve from 0.00451
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00009: val_loss did not improve from 0.00451
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0061
#
# Epoch 00010: val_loss did not improve from 0.00451
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0051
#
# Epoch 00011: val_loss did not improve from 0.00451
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0058
#
# Epoch 00012: val_loss did not improve from 0.00451
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0047
#
# Epoch 00013: val_loss did not improve from 0.00451
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0048
#
# Epoch 00014: val_loss did not improve from 0.00451
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0041
#
# Epoch 00015: val_loss improved from 0.00451 to 0.00413, saving model to doubleLSTMmodel.h5
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0043
#
# Epoch 00016: val_loss did not improve from 0.00413
# Epoch 17/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0085 - val_loss: 0.0047
#
# Epoch 00017: val_loss did not improve from 0.00413
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0049
#
# Epoch 00018: val_loss did not improve from 0.00413
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0054
#
# Epoch 00019: val_loss did not improve from 0.00413
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0049
#
# Epoch 00020: val_loss did not improve from 0.00413
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0055
#
# Epoch 00021: val_loss did not improve from 0.00413
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0045
#
# Epoch 00022: val_loss did not improve from 0.00413
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0056
#
# Epoch 00023: val_loss did not improve from 0.00413
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0050
#
# Epoch 00024: val_loss did not improve from 0.00413
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0044
#
# Epoch 00025: val_loss did not improve from 0.00413
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0050
#
# Epoch 00026: val_loss did not improve from 0.00413
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0049
#
# Epoch 00027: val_loss did not improve from 0.00413
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0052
#
# Epoch 00028: val_loss did not improve from 0.00413
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0052
#
# Epoch 00029: val_loss did not improve from 0.00413
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0084 - val_loss: 0.0046
#
# Epoch 00030: val_loss did not improve from 0.00413
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0053
#
# Epoch 00031: val_loss did not improve from 0.00413
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0083 - val_loss: 0.0054
#
# Epoch 00032: val_loss did not improve from 0.00413
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0052
#
# Epoch 00033: val_loss did not improve from 0.00413
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0081 - val_loss: 0.0042
#
# Epoch 00034: val_loss did not improve from 0.00413
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0062
#
# Epoch 00035: val_loss did not improve from 0.00413
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0082 - val_loss: 0.0049
#
# Epoch 00036: val_loss did not improve from 0.00413
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0079 - val_loss: 0.0047
#
# Epoch 00037: val_loss did not improve from 0.00413
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0081 - val_loss: 0.0044
#
# Epoch 00038: val_loss did not improve from 0.00413
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0080 - val_loss: 0.0057
#
# Epoch 00039: val_loss did not improve from 0.00413
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0076 - val_loss: 0.0045
#
# Epoch 00040: val_loss did not improve from 0.00413
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0074 - val_loss: 0.0066
#
# Epoch 00041: val_loss did not improve from 0.00413
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0073 - val_loss: 0.0040
#
# Epoch 00042: val_loss improved from 0.00413 to 0.00400, saving model to doubleLSTMmodel.h5
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0047
#
# Epoch 00043: val_loss did not improve from 0.00400
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0048
#
# Epoch 00044: val_loss did not improve from 0.00400
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0064
#
# Epoch 00045: val_loss did not improve from 0.00400
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0061 - val_loss: 0.0040
#
# Epoch 00046: val_loss did not improve from 0.00400
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0061 - val_loss: 0.0040
#
# Epoch 00047: val_loss improved from 0.00400 to 0.00398, saving model to doubleLSTMmodel.h5
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0054
#
# Epoch 00048: val_loss did not improve from 0.00398
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0060 - val_loss: 0.0050
#
# Epoch 00049: val_loss did not improve from 0.00398
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0042
#
# Epoch 00050: val_loss did not improve from 0.00398
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0059 - val_loss: 0.0040
#
# Epoch 00051: val_loss did not improve from 0.00398
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0057 - val_loss: 0.0046
#
# Epoch 00052: val_loss did not improve from 0.00398
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0053
#
# Epoch 00053: val_loss did not improve from 0.00398
# Epoch 54/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0058 - val_loss: 0.0043
#
# Epoch 00054: val_loss did not improve from 0.00398
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0058 - val_loss: 0.0047
#
# Epoch 00055: val_loss did not improve from 0.00398
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0053
#
# Epoch 00056: val_loss did not improve from 0.00398
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0052
#
# Epoch 00057: val_loss did not improve from 0.00398
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0047
#
# Epoch 00058: val_loss did not improve from 0.00398
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0056 - val_loss: 0.0047
#
# Epoch 00059: val_loss did not improve from 0.00398
# Epoch 60/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0046
#
# Epoch 00060: val_loss did not improve from 0.00398
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0055 - val_loss: 0.0058
#
# Epoch 00061: val_loss did not improve from 0.00398
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0045
#
# Epoch 00062: val_loss did not improve from 0.00398
# Epoch 63/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0044
#
# Epoch 00063: val_loss did not improve from 0.00398
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0052
#
# Epoch 00064: val_loss did not improve from 0.00398
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00065: val_loss did not improve from 0.00398
# Epoch 66/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0046
#
# Epoch 00066: val_loss did not improve from 0.00398
# Epoch 67/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0054 - val_loss: 0.0039 - ETA:
#
# Epoch 00067: val_loss improved from 0.00398 to 0.00390, saving model to doubleLSTMmodel.h5
# Epoch 68/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0046
#
# Epoch 00068: val_loss did not improve from 0.00390
# Epoch 69/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0052 - val_loss: 0.0048
#
# Epoch 00069: val_loss did not improve from 0.00390
# Epoch 70/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0053 - val_loss: 0.0044
#
# Epoch 00070: val_loss did not improve from 0.00390
# Model loaded
# mae :  5558.322269984654
# mse :  69779391.66349149
# rmse :  8353.405991779131
# std : 7983.003369444848
