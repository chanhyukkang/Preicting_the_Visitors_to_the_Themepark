# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
mcp_save2 = ModelCheckpoint('DNNmodel2.h5', save_best_only=True, monitor='loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save, mcp_save2])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 1s 260us/step - loss: 0.0079 - val_loss: 0.0037
#
# Epoch 00001: val_loss improved from inf to 0.00367, saving model to DNNmodel.h5
#
# Epoch 00001: loss improved from inf to 0.00789, saving model to DNNmodel2.h5
# Epoch 2/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0040 - val_loss: 0.0043
#
# Epoch 00002: val_loss did not improve from 0.00367
#
# Epoch 00002: loss improved from 0.00789 to 0.00400, saving model to DNNmodel2.h5
# Epoch 3/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00003: val_loss improved from 0.00367 to 0.00356, saving model to DNNmodel.h5
#
# Epoch 00003: loss improved from 0.00400 to 0.00364, saving model to DNNmodel2.h5
# Epoch 4/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0034 - val_loss: 0.0029
#
# Epoch 00004: val_loss improved from 0.00356 to 0.00286, saving model to DNNmodel.h5
#
# Epoch 00004: loss improved from 0.00364 to 0.00336, saving model to DNNmodel2.h5
# Epoch 5/100
# 3847/3847 [==============================] - 0s 63us/step - loss: 0.0033 - val_loss: 0.0041
#
# Epoch 00005: val_loss did not improve from 0.00286
#
# Epoch 00005: loss improved from 0.00336 to 0.00327, saving model to DNNmodel2.h5
# Epoch 6/100
# 3847/3847 [==============================] - 0s 63us/step - loss: 0.0032 - val_loss: 0.0025
#
# Epoch 00006: val_loss improved from 0.00286 to 0.00246, saving model to DNNmodel.h5
#
# Epoch 00006: loss improved from 0.00327 to 0.00323, saving model to DNNmodel2.h5
# Epoch 7/100
# 3847/3847 [==============================] - 0s 50us/step - loss: 0.0031 - val_loss: 0.0028
#
# Epoch 00007: val_loss did not improve from 0.00246
#
# Epoch 00007: loss improved from 0.00323 to 0.00311, saving model to DNNmodel2.h5
# Epoch 8/100
# 3847/3847 [==============================] - 0s 61us/step - loss: 0.0031 - val_loss: 0.0032
#
# Epoch 00008: val_loss did not improve from 0.00246
#
# Epoch 00008: loss improved from 0.00311 to 0.00309, saving model to DNNmodel2.h5
# Epoch 9/100
# 3847/3847 [==============================] - 0s 52us/step - loss: 0.0030 - val_loss: 0.0027
#
# Epoch 00009: val_loss did not improve from 0.00246
#
# Epoch 00009: loss improved from 0.00309 to 0.00303, saving model to DNNmodel2.h5
# Epoch 10/100
# 3847/3847 [==============================] - 0s 54us/step - loss: 0.0030 - val_loss: 0.0069
#
# Epoch 00010: val_loss did not improve from 0.00246
#
# Epoch 00010: loss did not improve from 0.00303
# Epoch 11/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0032 - val_loss: 0.0036
#
# Epoch 00011: val_loss did not improve from 0.00246
#
# Epoch 00011: loss did not improve from 0.00303
# Epoch 12/100
# 3847/3847 [==============================] - 0s 59us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00012: val_loss did not improve from 0.00246
#
# Epoch 00012: loss improved from 0.00303 to 0.00298, saving model to DNNmodel2.h5
# Epoch 13/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00013: val_loss did not improve from 0.00246
#
# Epoch 00013: loss did not improve from 0.00298
# Epoch 14/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0029 - val_loss: 0.0045
#
# Epoch 00014: val_loss did not improve from 0.00246
#
# Epoch 00014: loss improved from 0.00298 to 0.00293, saving model to DNNmodel2.h5
# Epoch 15/100
# 3847/3847 [==============================] - 0s 52us/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00015: val_loss did not improve from 0.00246
#
# Epoch 00015: loss improved from 0.00293 to 0.00288, saving model to DNNmodel2.h5
# Epoch 16/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0029 - val_loss: 0.0031
#
# Epoch 00016: val_loss did not improve from 0.00246
#
# Epoch 00016: loss improved from 0.00288 to 0.00286, saving model to DNNmodel2.h5
# Epoch 17/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00017: val_loss did not improve from 0.00246
#
# Epoch 00017: loss improved from 0.00286 to 0.00282, saving model to DNNmodel2.h5
# Epoch 18/100
# 3847/3847 [==============================] - 0s 60us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00018: val_loss did not improve from 0.00246
#
# Epoch 00018: loss did not improve from 0.00282
# Epoch 19/100
# 3847/3847 [==============================] - 0s 52us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00019: val_loss did not improve from 0.00246
#
# Epoch 00019: loss did not improve from 0.00282
# Epoch 20/100
# 3847/3847 [==============================] - 0s 50us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00020: val_loss did not improve from 0.00246
#
# Epoch 00020: loss improved from 0.00282 to 0.00276, saving model to DNNmodel2.h5
# Epoch 21/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0028 - val_loss: 0.0054
#
# Epoch 00021: val_loss did not improve from 0.00246
#
# Epoch 00021: loss did not improve from 0.00276
# Epoch 22/100
# 3847/3847 [==============================] - 0s 49us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00022: val_loss did not improve from 0.00246
#
# Epoch 00022: loss did not improve from 0.00276
# Epoch 23/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00023: val_loss did not improve from 0.00246
#
# Epoch 00023: loss improved from 0.00276 to 0.00271, saving model to DNNmodel2.h5
# Epoch 24/100
# 3847/3847 [==============================] - 0s 60us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00024: val_loss did not improve from 0.00246
#
# Epoch 00024: loss improved from 0.00271 to 0.00268, saving model to DNNmodel2.h5
# Epoch 25/100
# 3847/3847 [==============================] - 0s 49us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00025: val_loss did not improve from 0.00246
#
# Epoch 00025: loss improved from 0.00268 to 0.00267, saving model to DNNmodel2.h5
# Epoch 26/100
# 3847/3847 [==============================] - 0s 50us/step - loss: 0.0027 - val_loss: 0.0044
#
# Epoch 00026: val_loss did not improve from 0.00246
#
# Epoch 00026: loss did not improve from 0.00267
# Epoch 27/100
# 3847/3847 [==============================] - 0s 55us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00027: val_loss did not improve from 0.00246
#
# Epoch 00027: loss did not improve from 0.00267
# Epoch 28/100
# 3847/3847 [==============================] - 0s 57us/step - loss: 0.0026 - val_loss: 0.0055
#
# Epoch 00028: val_loss did not improve from 0.00246
#
# Epoch 00028: loss improved from 0.00267 to 0.00263, saving model to DNNmodel2.h5
# Epoch 29/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00029: val_loss did not improve from 0.00246
#
# Epoch 00029: loss did not improve from 0.00263
# Epoch 30/100
# 3847/3847 [==============================] - 0s 56us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00030: val_loss did not improve from 0.00246
#
# Epoch 00030: loss improved from 0.00263 to 0.00262, saving model to DNNmodel2.h5
# Epoch 31/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0026 - val_loss: 0.0064
#
# Epoch 00031: val_loss did not improve from 0.00246
#
# Epoch 00031: loss did not improve from 0.00262
# Epoch 32/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0028 - val_loss: 0.0046
#
# Epoch 00032: val_loss did not improve from 0.00246
#
# Epoch 00032: loss did not improve from 0.00262
# Epoch 33/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0026 - val_loss: 0.0055
#
# Epoch 00033: val_loss did not improve from 0.00246
#
# Epoch 00033: loss did not improve from 0.00262
# Epoch 34/100
# 3847/3847 [==============================] - 0s 57us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00034: val_loss did not improve from 0.00246
#
# Epoch 00034: loss did not improve from 0.00262
# Epoch 35/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0025 - val_loss: 0.0045
#
# Epoch 00035: val_loss did not improve from 0.00246
#
# Epoch 00035: loss improved from 0.00262 to 0.00255, saving model to DNNmodel2.h5
# Epoch 36/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00036: val_loss did not improve from 0.00246
#
# Epoch 00036: loss did not improve from 0.00255
# Epoch 37/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0026 - val_loss: 0.0053
#
# Epoch 00037: val_loss did not improve from 0.00246
#
# Epoch 00037: loss did not improve from 0.00255
# Epoch 38/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00038: val_loss did not improve from 0.00246
#
# Epoch 00038: loss did not improve from 0.00255
# Epoch 39/100
# 3847/3847 [==============================] - 0s 54us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00039: val_loss did not improve from 0.00246
#
# Epoch 00039: loss did not improve from 0.00255
# Epoch 40/100
# 3847/3847 [==============================] - 0s 61us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00040: val_loss did not improve from 0.00246
#
# Epoch 00040: loss did not improve from 0.00255
# Epoch 41/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00041: val_loss did not improve from 0.00246
#
# Epoch 00041: loss did not improve from 0.00255
# Epoch 42/100
# 3847/3847 [==============================] - 0s 60us/step - loss: 0.0025 - val_loss: 0.0029
#
# Epoch 00042: val_loss did not improve from 0.00246
#
# Epoch 00042: loss improved from 0.00255 to 0.00250, saving model to DNNmodel2.h5
# Epoch 43/100
# 3847/3847 [==============================] - 0s 54us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00043: val_loss did not improve from 0.00246
#
# Epoch 00043: loss did not improve from 0.00250
# Epoch 44/100
# 3847/3847 [==============================] - 0s 55us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00044: val_loss did not improve from 0.00246
#
# Epoch 00044: loss did not improve from 0.00250
# Epoch 45/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00045: val_loss did not improve from 0.00246
#
# Epoch 00045: loss did not improve from 0.00250
# Epoch 46/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00046: val_loss did not improve from 0.00246
#
# Epoch 00046: loss did not improve from 0.00250
# Epoch 47/100
# 3847/3847 [==============================] - 0s 54us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00047: val_loss did not improve from 0.00246
#
# Epoch 00047: loss did not improve from 0.00250
# Epoch 48/100
# 3847/3847 [==============================] - 0s 55us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00048: val_loss did not improve from 0.00246
#
# Epoch 00048: loss did not improve from 0.00250
# Epoch 49/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00049: val_loss did not improve from 0.00246
#
# Epoch 00049: loss improved from 0.00250 to 0.00247, saving model to DNNmodel2.h5
# Epoch 50/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00050: val_loss did not improve from 0.00246
#
# Epoch 00050: loss did not improve from 0.00247
# Epoch 51/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00051: val_loss did not improve from 0.00246
#
# Epoch 00051: loss did not improve from 0.00247
# Epoch 52/100
# 3847/3847 [==============================] - 0s 53us/step - loss: 0.0024 - val_loss: 0.0041
#
# Epoch 00052: val_loss did not improve from 0.00246
#
# Epoch 00052: loss improved from 0.00247 to 0.00242, saving model to DNNmodel2.h5
# Epoch 53/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.00246
#
# Epoch 00053: loss did not improve from 0.00242
# Epoch 54/100
# 3847/3847 [==============================] - 0s 55us/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00054: val_loss did not improve from 0.00246
#
# Epoch 00054: loss improved from 0.00242 to 0.00241, saving model to DNNmodel2.h5
# Epoch 55/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0025 - val_loss: 0.0051
#
# Epoch 00055: val_loss did not improve from 0.00246
#
# Epoch 00055: loss did not improve from 0.00241
# Epoch 56/100
# 3847/3847 [==============================] - 0s 60us/step - loss: 0.0026 - val_loss: 0.0058
#
# Epoch 00056: val_loss did not improve from 0.00246
#
# Epoch 00056: loss did not improve from 0.00241
# Epoch 57/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00057: val_loss did not improve from 0.00246
#
# Epoch 00057: loss did not improve from 0.00241
# Epoch 58/100
# 3847/3847 [==============================] - 0s 46us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00058: val_loss did not improve from 0.00246
#
# Epoch 00058: loss did not improve from 0.00241
# Epoch 59/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0024 - val_loss: 0.0040
#
# Epoch 00059: val_loss did not improve from 0.00246
#
# Epoch 00059: loss improved from 0.00241 to 0.00240, saving model to DNNmodel2.h5
# Epoch 60/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00060: val_loss did not improve from 0.00246
#
# Epoch 00060: loss did not improve from 0.00240
# Epoch 61/100
# 3847/3847 [==============================] - 0s 53us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00061: val_loss did not improve from 0.00246
#
# Epoch 00061: loss did not improve from 0.00240
# Epoch 62/100
# 3847/3847 [==============================] - 0s 40us/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00062: val_loss did not improve from 0.00246
#
# Epoch 00062: loss did not improve from 0.00240
# Epoch 63/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0024 - val_loss: 0.0057
#
# Epoch 00063: val_loss did not improve from 0.00246
#
# Epoch 00063: loss did not improve from 0.00240
# Epoch 64/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00064: val_loss did not improve from 0.00246
#
# Epoch 00064: loss did not improve from 0.00240
# Epoch 65/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00065: val_loss did not improve from 0.00246
#
# Epoch 00065: loss did not improve from 0.00240
# Epoch 66/100
# 3847/3847 [==============================] - 0s 57us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00066: val_loss did not improve from 0.00246
#
# Epoch 00066: loss did not improve from 0.00240
# Epoch 67/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00067: val_loss did not improve from 0.00246
#
# Epoch 00067: loss did not improve from 0.00240
# Epoch 68/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0060
#
# Epoch 00068: val_loss did not improve from 0.00246
#
# Epoch 00068: loss did not improve from 0.00240
# Epoch 69/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00069: val_loss did not improve from 0.00246
#
# Epoch 00069: loss improved from 0.00240 to 0.00240, saving model to DNNmodel2.h5
# Epoch 70/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00070: val_loss did not improve from 0.00246
#
# Epoch 00070: loss improved from 0.00240 to 0.00240, saving model to DNNmodel2.h5
# Epoch 71/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00071: val_loss did not improve from 0.00246
#
# Epoch 00071: loss improved from 0.00240 to 0.00235, saving model to DNNmodel2.h5
# Epoch 72/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00072: val_loss did not improve from 0.00246
#
# Epoch 00072: loss did not improve from 0.00235
# Epoch 73/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0047
#
# Epoch 00073: val_loss did not improve from 0.00246
#
# Epoch 00073: loss did not improve from 0.00235
# Epoch 74/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00074: val_loss did not improve from 0.00246
#
# Epoch 00074: loss did not improve from 0.00235
# Epoch 75/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00075: val_loss did not improve from 0.00246
#
# Epoch 00075: loss did not improve from 0.00235
# Epoch 76/100
# 3847/3847 [==============================] - 0s 58us/step - loss: 0.0023 - val_loss: 0.0044
#
# Epoch 00076: val_loss did not improve from 0.00246
#
# Epoch 00076: loss improved from 0.00235 to 0.00229, saving model to DNNmodel2.h5
# Epoch 77/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00077: val_loss did not improve from 0.00246
#
# Epoch 00077: loss did not improve from 0.00229
# Epoch 78/100
# 3847/3847 [==============================] - 0s 42us/step - loss: 0.0023 - val_loss: 0.0043
#
# Epoch 00078: val_loss did not improve from 0.00246
#
# Epoch 00078: loss did not improve from 0.00229
# Epoch 79/100
# 3847/3847 [==============================] - 0s 42us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00079: val_loss did not improve from 0.00246
#
# Epoch 00079: loss did not improve from 0.00229
# Epoch 80/100
# 3847/3847 [==============================] - 0s 43us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00080: val_loss did not improve from 0.00246
#
# Epoch 00080: loss did not improve from 0.00229
# Epoch 81/100
# 3847/3847 [==============================] - 0s 42us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00081: val_loss did not improve from 0.00246
#
# Epoch 00081: loss did not improve from 0.00229
# Epoch 82/100
# 3847/3847 [==============================] - 0s 41us/step - loss: 0.0023 - val_loss: 0.0049
#
# Epoch 00082: val_loss did not improve from 0.00246
#
# Epoch 00082: loss did not improve from 0.00229
# Epoch 83/100
# 3847/3847 [==============================] - 0s 42us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00083: val_loss did not improve from 0.00246
#
# Epoch 00083: loss did not improve from 0.00229
# Epoch 84/100
# 3847/3847 [==============================] - 0s 41us/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00084: val_loss did not improve from 0.00246
#
# Epoch 00084: loss did not improve from 0.00229
# Epoch 85/100
# 3847/3847 [==============================] - 0s 46us/step - loss: 0.0023 - val_loss: 0.0054
#
# Epoch 00085: val_loss did not improve from 0.00246
#
# Epoch 00085: loss did not improve from 0.00229
# Epoch 86/100
# 3847/3847 [==============================] - 0s 48us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00086: val_loss did not improve from 0.00246
#
# Epoch 00086: loss did not improve from 0.00229
# Epoch 87/100
# 3847/3847 [==============================] - 0s 45us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00087: val_loss did not improve from 0.00246
#
# Epoch 00087: loss did not improve from 0.00229
# Epoch 88/100
# 3847/3847 [==============================] - 0s 43us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00088: val_loss did not improve from 0.00246
#
# Epoch 00088: loss did not improve from 0.00229
# Epoch 89/100
# 3847/3847 [==============================] - 0s 51us/step - loss: 0.0023 - val_loss: 0.0040
#
# Epoch 00089: val_loss did not improve from 0.00246
#
# Epoch 00089: loss improved from 0.00229 to 0.00226, saving model to DNNmodel2.h5
# Epoch 90/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00090: val_loss did not improve from 0.00246
#
# Epoch 00090: loss did not improve from 0.00226
# Epoch 91/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00091: val_loss did not improve from 0.00246
#
# Epoch 00091: loss did not improve from 0.00226
# Epoch 92/100
# 3847/3847 [==============================] - 0s 47us/step - loss: 0.0023 - val_loss: 0.0051
#
# Epoch 00092: val_loss did not improve from 0.00246
#
# Epoch 00092: loss did not improve from 0.00226
# Epoch 93/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0023 - val_loss: 0.0049
#
# Epoch 00093: val_loss did not improve from 0.00246
#
# Epoch 00093: loss did not improve from 0.00226
# Epoch 94/100
# 3847/3847 [==============================] - 0s 41us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00094: val_loss did not improve from 0.00246
#
# Epoch 00094: loss did not improve from 0.00226
# Epoch 95/100
# 3847/3847 [==============================] - 0s 41us/step - loss: 0.0023 - val_loss: 0.0046
#
# Epoch 00095: val_loss did not improve from 0.00246
#
# Epoch 00095: loss did not improve from 0.00226
# Epoch 96/100
# 3847/3847 [==============================] - 0s 43us/step - loss: 0.0023 - val_loss: 0.0049
#
# Epoch 00096: val_loss did not improve from 0.00246
#
# Epoch 00096: loss did not improve from 0.00226
# Epoch 97/100
# 3847/3847 [==============================] - 0s 42us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00097: val_loss did not improve from 0.00246
#
# Epoch 00097: loss did not improve from 0.00226
# Epoch 98/100
# 3847/3847 [==============================] - 0s 43us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00098: val_loss did not improve from 0.00246
#
# Epoch 00098: loss improved from 0.00226 to 0.00226, saving model to DNNmodel2.h5
# Epoch 99/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00099: val_loss did not improve from 0.00246
#
# Epoch 00099: loss did not improve from 0.00226
# Epoch 100/100
# 3847/3847 [==============================] - 0s 44us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00100: val_loss did not improve from 0.00246
#
# Epoch 00100: loss did not improve from 0.00226
# Model loaded
# mae :  4263.003286386465
# mse :  39968462.58827364
# rmse :  6322.06157738705
# std : 5480.176363633587

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
mcp_save2 = ModelCheckpoint('DNNmodel2.h5', save_best_only=True, monitor='loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save, mcp_save2])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0156 - val_loss: 0.0048
#
# Epoch 00001: val_loss improved from inf to 0.00478, saving model to DNNmodel.h5
#
# Epoch 00001: loss improved from inf to 0.01558, saving model to DNNmodel2.h5
# Epoch 2/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0041 - val_loss: 0.0023
#
# Epoch 00002: val_loss improved from 0.00478 to 0.00235, saving model to DNNmodel.h5
#
# Epoch 00002: loss improved from 0.01558 to 0.00408, saving model to DNNmodel2.h5
# Epoch 3/100
# 3847/3847 [==============================] - 0s 74us/step - loss: 0.0038 - val_loss: 0.0035
#
# Epoch 00003: val_loss did not improve from 0.00235
#
# Epoch 00003: loss improved from 0.00408 to 0.00382, saving model to DNNmodel2.h5
# Epoch 4/100
# 3847/3847 [==============================] - 0s 92us/step - loss: 0.0036 - val_loss: 0.0040
#
# Epoch 00004: val_loss did not improve from 0.00235
#
# Epoch 00004: loss improved from 0.00382 to 0.00356, saving model to DNNmodel2.h5
# Epoch 5/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0033 - val_loss: 0.0046
#
# Epoch 00005: val_loss did not improve from 0.00235
#
# Epoch 00005: loss improved from 0.00356 to 0.00331, saving model to DNNmodel2.h5
# Epoch 6/100
# 3847/3847 [==============================] - 0s 73us/step - loss: 0.0033 - val_loss: 0.0041
#
# Epoch 00006: val_loss did not improve from 0.00235
#
# Epoch 00006: loss improved from 0.00331 to 0.00329, saving model to DNNmodel2.h5
# Epoch 7/100
# 3847/3847 [==============================] - 0s 73us/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00235
#
# Epoch 00007: loss improved from 0.00329 to 0.00329, saving model to DNNmodel2.h5
# Epoch 8/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0034 - val_loss: 0.0048
#
# Epoch 00008: val_loss did not improve from 0.00235
#
# Epoch 00008: loss did not improve from 0.00329
# Epoch 9/100
# 3847/3847 [==============================] - 0s 70us/step - loss: 0.0032 - val_loss: 0.0037
#
# Epoch 00009: val_loss did not improve from 0.00235
#
# Epoch 00009: loss improved from 0.00329 to 0.00319, saving model to DNNmodel2.h5
# Epoch 10/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0032 - val_loss: 0.0034
#
# Epoch 00010: val_loss did not improve from 0.00235
#
# Epoch 00010: loss improved from 0.00319 to 0.00318, saving model to DNNmodel2.h5
# Epoch 11/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0031 - val_loss: 0.0039
#
# Epoch 00011: val_loss did not improve from 0.00235
#
# Epoch 00011: loss improved from 0.00318 to 0.00309, saving model to DNNmodel2.h5
# Epoch 12/100
# 3847/3847 [==============================] - 0s 73us/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00012: val_loss did not improve from 0.00235
#
# Epoch 00012: loss improved from 0.00309 to 0.00301, saving model to DNNmodel2.h5
# Epoch 13/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0031 - val_loss: 0.0042
#
# Epoch 00013: val_loss did not improve from 0.00235
#
# Epoch 00013: loss did not improve from 0.00301
# Epoch 14/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0030 - val_loss: 0.0042
#
# Epoch 00014: val_loss did not improve from 0.00235
#
# Epoch 00014: loss did not improve from 0.00301
# Epoch 15/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0030 - val_loss: 0.0039
#
# Epoch 00015: val_loss did not improve from 0.00235
#
# Epoch 00015: loss improved from 0.00301 to 0.00298, saving model to DNNmodel2.h5
# Epoch 16/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0030 - val_loss: 0.0038
#
# Epoch 00016: val_loss did not improve from 0.00235
#
# Epoch 00016: loss did not improve from 0.00298
# Epoch 17/100
# 3847/3847 [==============================] - 0s 75us/step - loss: 0.0030 - val_loss: 0.0030
#
# Epoch 00017: val_loss did not improve from 0.00235
#
# Epoch 00017: loss did not improve from 0.00298
# Epoch 18/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00018: val_loss did not improve from 0.00235
#
# Epoch 00018: loss did not improve from 0.00298
# Epoch 19/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0033 - val_loss: 0.0042
#
# Epoch 00019: val_loss did not improve from 0.00235
#
# Epoch 00019: loss did not improve from 0.00298
# Epoch 20/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0030 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00235
#
# Epoch 00020: loss improved from 0.00298 to 0.00297, saving model to DNNmodel2.h5
# Epoch 21/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0029 - val_loss: 0.0051
#
# Epoch 00021: val_loss did not improve from 0.00235
#
# Epoch 00021: loss improved from 0.00297 to 0.00286, saving model to DNNmodel2.h5
# Epoch 22/100
# 3847/3847 [==============================] - 0s 75us/step - loss: 0.0029 - val_loss: 0.0036
#
# Epoch 00022: val_loss did not improve from 0.00235
#
# Epoch 00022: loss did not improve from 0.00286
# Epoch 23/100
# 3847/3847 [==============================] - 0s 97us/step - loss: 0.0029 - val_loss: 0.0049
#
# Epoch 00023: val_loss did not improve from 0.00235
#
# Epoch 00023: loss did not improve from 0.00286
# Epoch 24/100
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00024: val_loss did not improve from 0.00235
#
# Epoch 00024: loss improved from 0.00286 to 0.00284, saving model to DNNmodel2.h5
# Epoch 25/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00025: val_loss did not improve from 0.00235
#
# Epoch 00025: loss improved from 0.00284 to 0.00276, saving model to DNNmodel2.h5
# Epoch 26/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0030 - val_loss: 0.0026
#
# Epoch 00026: val_loss did not improve from 0.00235
#
# Epoch 00026: loss did not improve from 0.00276
# Epoch 27/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0030 - val_loss: 0.0051
#
# Epoch 00027: val_loss did not improve from 0.00235
#
# Epoch 00027: loss did not improve from 0.00276
# Epoch 28/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0028 - val_loss: 0.0056
#
# Epoch 00028: val_loss did not improve from 0.00235
#
# Epoch 00028: loss did not improve from 0.00276
# Epoch 29/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0028 - val_loss: 0.0032
#
# Epoch 00029: val_loss did not improve from 0.00235
#
# Epoch 00029: loss did not improve from 0.00276
# Epoch 30/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0029 - val_loss: 0.0036
#
# Epoch 00030: val_loss did not improve from 0.00235
#
# Epoch 00030: loss did not improve from 0.00276
# Epoch 31/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00031: val_loss did not improve from 0.00235
#
# Epoch 00031: loss improved from 0.00276 to 0.00274, saving model to DNNmodel2.h5
# Epoch 32/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00032: val_loss did not improve from 0.00235
#
# Epoch 00032: loss did not improve from 0.00274
# Epoch 33/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0028 - val_loss: 0.0048
#
# Epoch 00033: val_loss did not improve from 0.00235
#
# Epoch 00033: loss did not improve from 0.00274
# Epoch 34/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0052
#
# Epoch 00034: val_loss did not improve from 0.00235
#
# Epoch 00034: loss improved from 0.00274 to 0.00268, saving model to DNNmodel2.h5
# Epoch 35/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00035: val_loss did not improve from 0.00235
#
# Epoch 00035: loss did not improve from 0.00268
# Epoch 36/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0056
#
# Epoch 00036: val_loss did not improve from 0.00235
#
# Epoch 00036: loss improved from 0.00268 to 0.00264, saving model to DNNmodel2.h5
# Epoch 37/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00037: val_loss did not improve from 0.00235
#
# Epoch 00037: loss did not improve from 0.00264
# Epoch 38/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00038: val_loss did not improve from 0.00235
#
# Epoch 00038: loss did not improve from 0.00264
# Epoch 39/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00039: val_loss did not improve from 0.00235
#
# Epoch 00039: loss improved from 0.00264 to 0.00262, saving model to DNNmodel2.h5
# Epoch 40/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0029 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00235
#
# Epoch 00040: loss did not improve from 0.00262
# Epoch 41/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00041: val_loss did not improve from 0.00235
#
# Epoch 00041: loss did not improve from 0.00262
# Epoch 42/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00042: val_loss did not improve from 0.00235
#
# Epoch 00042: loss did not improve from 0.00262
# Epoch 43/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00043: val_loss did not improve from 0.00235
#
# Epoch 00043: loss did not improve from 0.00262
# Epoch 44/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0026 - val_loss: 0.0043
#
# Epoch 00044: val_loss did not improve from 0.00235
#
# Epoch 00044: loss did not improve from 0.00262
# Epoch 45/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00045: val_loss did not improve from 0.00235
#
# Epoch 00045: loss did not improve from 0.00262
# Epoch 46/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00046: val_loss did not improve from 0.00235
#
# Epoch 00046: loss did not improve from 0.00262
# Epoch 47/100
# 3847/3847 [==============================] - 0s 74us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00047: val_loss did not improve from 0.00235
#
# Epoch 00047: loss improved from 0.00262 to 0.00254, saving model to DNNmodel2.h5
# Epoch 48/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00048: val_loss did not improve from 0.00235
#
# Epoch 00048: loss did not improve from 0.00254
# Epoch 49/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00049: val_loss did not improve from 0.00235
#
# Epoch 00049: loss did not improve from 0.00254
# Epoch 50/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0027 - val_loss: 0.0054
#
# Epoch 00050: val_loss did not improve from 0.00235
#
# Epoch 00050: loss did not improve from 0.00254
# Epoch 51/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0025 - val_loss: 0.0045
#
# Epoch 00051: val_loss did not improve from 0.00235
#
# Epoch 00051: loss did not improve from 0.00254
# Epoch 52/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00052: val_loss did not improve from 0.00235
#
# Epoch 00052: loss did not improve from 0.00254
# Epoch 53/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00053: val_loss did not improve from 0.00235
#
# Epoch 00053: loss improved from 0.00254 to 0.00254, saving model to DNNmodel2.h5
# Epoch 54/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0050
#
# Epoch 00054: val_loss did not improve from 0.00235
#
# Epoch 00054: loss improved from 0.00254 to 0.00252, saving model to DNNmodel2.h5
# Epoch 55/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00055: val_loss did not improve from 0.00235
#
# Epoch 00055: loss did not improve from 0.00252
# Epoch 56/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00056: val_loss did not improve from 0.00235
#
# Epoch 00056: loss did not improve from 0.00252
# Epoch 57/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00057: val_loss did not improve from 0.00235
#
# Epoch 00057: loss did not improve from 0.00252
# Epoch 58/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00058: val_loss did not improve from 0.00235
#
# Epoch 00058: loss did not improve from 0.00252
# Epoch 59/100
# 3847/3847 [==============================] - 0s 93us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00059: val_loss did not improve from 0.00235
#
# Epoch 00059: loss improved from 0.00252 to 0.00249, saving model to DNNmodel2.h5
# Epoch 60/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0025 - val_loss: 0.0029
#
# Epoch 00060: val_loss did not improve from 0.00235
#
# Epoch 00060: loss did not improve from 0.00249
# Epoch 61/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00061: val_loss did not improve from 0.00235
#
# Epoch 00061: loss did not improve from 0.00249
# Epoch 62/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00062: val_loss did not improve from 0.00235
#
# Epoch 00062: loss did not improve from 0.00249
# Epoch 63/100
# 3847/3847 [==============================] - 0s 79us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00063: val_loss did not improve from 0.00235
#
# Epoch 00063: loss did not improve from 0.00249
# Epoch 64/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0055
#
# Epoch 00064: val_loss did not improve from 0.00235
#
# Epoch 00064: loss did not improve from 0.00249
# Epoch 65/100
# 3847/3847 [==============================] - 0s 89us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00065: val_loss did not improve from 0.00235
#
# Epoch 00065: loss did not improve from 0.00249
# Epoch 66/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00066: val_loss did not improve from 0.00235
#
# Epoch 00066: loss improved from 0.00249 to 0.00246, saving model to DNNmodel2.h5
# Epoch 67/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00067: val_loss did not improve from 0.00235
#
# Epoch 00067: loss did not improve from 0.00246
# Epoch 68/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00068: val_loss did not improve from 0.00235
#
# Epoch 00068: loss did not improve from 0.00246
# Epoch 69/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00069: val_loss did not improve from 0.00235
#
# Epoch 00069: loss improved from 0.00246 to 0.00243, saving model to DNNmodel2.h5
# Epoch 70/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00070: val_loss did not improve from 0.00235
#
# Epoch 00070: loss improved from 0.00243 to 0.00243, saving model to DNNmodel2.h5
# Epoch 71/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00071: val_loss did not improve from 0.00235
#
# Epoch 00071: loss did not improve from 0.00243
# Epoch 72/100
# 3847/3847 [==============================] - 0s 88us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00072: val_loss did not improve from 0.00235
#
# Epoch 00072: loss did not improve from 0.00243
# Epoch 73/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00073: val_loss did not improve from 0.00235
#
# Epoch 00073: loss did not improve from 0.00243
# Epoch 74/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00074: val_loss did not improve from 0.00235
#
# Epoch 00074: loss did not improve from 0.00243
# Epoch 75/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00075: val_loss did not improve from 0.00235
#
# Epoch 00075: loss did not improve from 0.00243
# Epoch 76/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00076: val_loss did not improve from 0.00235
#
# Epoch 00076: loss improved from 0.00243 to 0.00237, saving model to DNNmodel2.h5
# Epoch 77/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00077: val_loss did not improve from 0.00235
#
# Epoch 00077: loss improved from 0.00237 to 0.00237, saving model to DNNmodel2.h5
# Epoch 78/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00078: val_loss did not improve from 0.00235
#
# Epoch 00078: loss did not improve from 0.00237
# Epoch 79/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00079: val_loss did not improve from 0.00235
#
# Epoch 00079: loss did not improve from 0.00237
# Epoch 80/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00080: val_loss did not improve from 0.00235
#
# Epoch 00080: loss did not improve from 0.00237
# Epoch 81/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00081: val_loss did not improve from 0.00235
#
# Epoch 00081: loss did not improve from 0.00237
# Epoch 82/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00082: val_loss did not improve from 0.00235
#
# Epoch 00082: loss did not improve from 0.00237
# Epoch 83/100
# 3847/3847 [==============================] - 0s 76us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00083: val_loss did not improve from 0.00235
#
# Epoch 00083: loss did not improve from 0.00237
# Epoch 84/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00084: val_loss did not improve from 0.00235
#
# Epoch 00084: loss improved from 0.00237 to 0.00233, saving model to DNNmodel2.h5
# Epoch 85/100
# 3847/3847 [==============================] - 0s 91us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00085: val_loss did not improve from 0.00235
#
# Epoch 00085: loss did not improve from 0.00233
# Epoch 86/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00086: val_loss did not improve from 0.00235
#
# Epoch 00086: loss did not improve from 0.00233
# Epoch 87/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00087: val_loss did not improve from 0.00235
#
# Epoch 00087: loss did not improve from 0.00233
# Epoch 88/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0023 - val_loss: 0.0046
#
# Epoch 00088: val_loss did not improve from 0.00235
#
# Epoch 00088: loss did not improve from 0.00233
# Epoch 89/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00089: val_loss did not improve from 0.00235
#
# Epoch 00089: loss did not improve from 0.00233
# Epoch 90/100
# 3847/3847 [==============================] - 0s 69us/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00090: val_loss did not improve from 0.00235
#
# Epoch 00090: loss did not improve from 0.00233
# Epoch 91/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00091: val_loss did not improve from 0.00235
#
# Epoch 00091: loss did not improve from 0.00233
# Epoch 92/100
# 3847/3847 [==============================] - 0s 71us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00092: val_loss did not improve from 0.00235
#
# Epoch 00092: loss did not improve from 0.00233
# Epoch 93/100
# 3847/3847 [==============================] - 0s 74us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00093: val_loss did not improve from 0.00235
#
# Epoch 00093: loss improved from 0.00233 to 0.00233, saving model to DNNmodel2.h5
# Epoch 94/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00094: val_loss did not improve from 0.00235
#
# Epoch 00094: loss did not improve from 0.00233
# Epoch 95/100
# 3847/3847 [==============================] - 0s 86us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00095: val_loss did not improve from 0.00235
#
# Epoch 00095: loss did not improve from 0.00233
# Epoch 96/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00096: val_loss did not improve from 0.00235
#
# Epoch 00096: loss did not improve from 0.00233
# Epoch 97/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00097: val_loss did not improve from 0.00235
#
# Epoch 00097: loss did not improve from 0.00233
# Epoch 98/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00098: val_loss did not improve from 0.00235
#
# Epoch 00098: loss did not improve from 0.00233
# Epoch 99/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00099: val_loss did not improve from 0.00235
#
# Epoch 00099: loss did not improve from 0.00233
# Epoch 100/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00100: val_loss did not improve from 0.00235
#
# Epoch 00100: loss did not improve from 0.00233
# Model loaded
# mae :  4134.8278204224325
# mse :  35906340.38745053
# rmse :  5992.189949213103
# std : 5524.338953422365

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 3s 736us/step - loss: 0.0238 - val_loss: 0.0045
#
# Epoch 00001: val_loss improved from inf to 0.00448, saving model to DNNmodel.h5
#
# Epoch 00001: loss improved from inf to 0.02382, saving model to DNNmodel2.h5
# Epoch 2/100
# 3847/3847 [==============================] - 0s 80us/step - loss: 0.0042 - val_loss: 0.0044
#
# Epoch 00002: val_loss improved from 0.00448 to 0.00444, saving model to DNNmodel.h5
#
# Epoch 00002: loss improved from 0.02382 to 0.00423, saving model to DNNmodel2.h5
# Epoch 3/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0040 - val_loss: 0.0032
#
# Epoch 00003: val_loss improved from 0.00444 to 0.00316, saving model to DNNmodel.h5
#
# Epoch 00003: loss improved from 0.00423 to 0.00400, saving model to DNNmodel2.h5
# Epoch 4/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0036 - val_loss: 0.0030
#
# Epoch 00004: val_loss improved from 0.00316 to 0.00304, saving model to DNNmodel.h5
#
# Epoch 00004: loss improved from 0.00400 to 0.00355, saving model to DNNmodel2.h5
# Epoch 5/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0035 - val_loss: 0.0037
#
# Epoch 00005: val_loss did not improve from 0.00304
#
# Epoch 00005: loss improved from 0.00355 to 0.00345, saving model to DNNmodel2.h5
# Epoch 6/100
# 3847/3847 [==============================] - 0s 88us/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00006: val_loss did not improve from 0.00304
#
# Epoch 00006: loss did not improve from 0.00345
# Epoch 7/100
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0033 - val_loss: 0.0034
#
# Epoch 00007: val_loss did not improve from 0.00304
#
# Epoch 00007: loss improved from 0.00345 to 0.00334, saving model to DNNmodel2.h5
# Epoch 8/100
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0035 - val_loss: 0.0047
#
# Epoch 00008: val_loss did not improve from 0.00304
#
# Epoch 00008: loss did not improve from 0.00334
# Epoch 9/100
# 3847/3847 [==============================] - 0s 96us/step - loss: 0.0033 - val_loss: 0.0027
#
# Epoch 00009: val_loss improved from 0.00304 to 0.00266, saving model to DNNmodel.h5
#
# Epoch 00009: loss improved from 0.00334 to 0.00330, saving model to DNNmodel2.h5
# Epoch 10/100
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0034 - val_loss: 0.0048
#
# Epoch 00010: val_loss did not improve from 0.00266
#
# Epoch 00010: loss did not improve from 0.00330
# Epoch 11/100
# 3847/3847 [==============================] - 0s 100us/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00011: val_loss did not improve from 0.00266
#
# Epoch 00011: loss improved from 0.00330 to 0.00315, saving model to DNNmodel2.h5
# Epoch 12/100
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0032 - val_loss: 0.0038
#
# Epoch 00012: val_loss did not improve from 0.00266
#
# Epoch 00012: loss did not improve from 0.00315
# Epoch 13/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0032 - val_loss: 0.0044
#
# Epoch 00013: val_loss did not improve from 0.00266
#
# Epoch 00013: loss did not improve from 0.00315
# Epoch 14/100
# 3847/3847 [==============================] - 0s 78us/step - loss: 0.0032 - val_loss: 0.0052
#
# Epoch 00014: val_loss did not improve from 0.00266
#
# Epoch 00014: loss did not improve from 0.00315
# Epoch 15/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0031 - val_loss: 0.0053
#
# Epoch 00015: val_loss did not improve from 0.00266
#
# Epoch 00015: loss improved from 0.00315 to 0.00313, saving model to DNNmodel2.h5
# Epoch 16/100
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00016: val_loss did not improve from 0.00266
#
# Epoch 00016: loss improved from 0.00313 to 0.00293, saving model to DNNmodel2.h5
# Epoch 17/100
# 3847/3847 [==============================] - 0s 90us/step - loss: 0.0030 - val_loss: 0.0038
#
# Epoch 00017: val_loss did not improve from 0.00266
#
# Epoch 00017: loss did not improve from 0.00293
# Epoch 18/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0029 - val_loss: 0.0047
#
# Epoch 00018: val_loss did not improve from 0.00266
#
# Epoch 00018: loss improved from 0.00293 to 0.00287, saving model to DNNmodel2.h5
# Epoch 19/100
# 3847/3847 [==============================] - 0s 93us/step - loss: 0.0031 - val_loss: 0.0053
#
# Epoch 00019: val_loss did not improve from 0.00266
#
# Epoch 00019: loss did not improve from 0.00287
# Epoch 20/100
# 3847/3847 [==============================] - 0s 93us/step - loss: 0.0030 - val_loss: 0.0040
#
# Epoch 00020: val_loss did not improve from 0.00266
#
# Epoch 00020: loss did not improve from 0.00287
# Epoch 21/100
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00021: val_loss did not improve from 0.00266
#
# Epoch 00021: loss did not improve from 0.00287
# Epoch 22/100
# 3847/3847 [==============================] - 0s 91us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00022: val_loss did not improve from 0.00266
#
# Epoch 00022: loss did not improve from 0.00287
# Epoch 23/100
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00023: val_loss did not improve from 0.00266
#
# Epoch 00023: loss improved from 0.00287 to 0.00280, saving model to DNNmodel2.h5
# Epoch 24/100
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0028 - val_loss: 0.0051
#
# Epoch 00024: val_loss did not improve from 0.00266
#
# Epoch 00024: loss did not improve from 0.00280
# Epoch 25/100
# 3847/3847 [==============================] - 0s 97us/step - loss: 0.0029 - val_loss: 0.0053
#
# Epoch 00025: val_loss did not improve from 0.00266
#
# Epoch 00025: loss did not improve from 0.00280
# Epoch 26/100
# 3847/3847 [==============================] - 0s 96us/step - loss: 0.0029 - val_loss: 0.0039
#
# Epoch 00026: val_loss did not improve from 0.00266
#
# Epoch 00026: loss did not improve from 0.00280
# Epoch 27/100
# 3847/3847 [==============================] - 0s 81us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00027: val_loss did not improve from 0.00266
#
# Epoch 00027: loss improved from 0.00280 to 0.00274, saving model to DNNmodel2.h5
# Epoch 28/100
# 3847/3847 [==============================] - 0s 89us/step - loss: 0.0028 - val_loss: 0.0040
#
# Epoch 00028: val_loss did not improve from 0.00266
#
# Epoch 00028: loss did not improve from 0.00274
# Epoch 29/100
# 3847/3847 [==============================] - 0s 90us/step - loss: 0.0030 - val_loss: 0.0051
#
# Epoch 00029: val_loss did not improve from 0.00266
#
# Epoch 00029: loss did not improve from 0.00274
# Epoch 30/100
# 3847/3847 [==============================] - 0s 89us/step - loss: 0.0030 - val_loss: 0.0061
#
# Epoch 00030: val_loss did not improve from 0.00266
#
# Epoch 00030: loss did not improve from 0.00274
# Epoch 31/100
# 3847/3847 [==============================] - 0s 88us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00031: val_loss did not improve from 0.00266
#
# Epoch 00031: loss did not improve from 0.00274
# Epoch 32/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0028 - val_loss: 0.0032
#
# Epoch 00032: val_loss did not improve from 0.00266
#
# Epoch 00032: loss did not improve from 0.00274
# Epoch 33/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0028 - val_loss: 0.0048
#
# Epoch 00033: val_loss did not improve from 0.00266
#
# Epoch 00033: loss did not improve from 0.00274
# Epoch 34/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00034: val_loss did not improve from 0.00266
#
# Epoch 00034: loss did not improve from 0.00274
# Epoch 35/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00035: val_loss did not improve from 0.00266
#
# Epoch 00035: loss did not improve from 0.00274
# Epoch 36/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00266
#
# Epoch 00036: loss improved from 0.00274 to 0.00273, saving model to DNNmodel2.h5
# Epoch 37/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00037: val_loss did not improve from 0.00266
#
# Epoch 00037: loss improved from 0.00273 to 0.00272, saving model to DNNmodel2.h5
# Epoch 38/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0028 - val_loss: 0.0026
#
# Epoch 00038: val_loss improved from 0.00266 to 0.00259, saving model to DNNmodel.h5
#
# Epoch 00038: loss did not improve from 0.00272
# Epoch 39/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00039: val_loss did not improve from 0.00259
#
# Epoch 00039: loss did not improve from 0.00272
# Epoch 40/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0028 - val_loss: 0.0049
#
# Epoch 00040: val_loss did not improve from 0.00259
#
# Epoch 00040: loss did not improve from 0.00272
# Epoch 41/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0046
#
# Epoch 00041: val_loss did not improve from 0.00259
#
# Epoch 00041: loss improved from 0.00272 to 0.00270, saving model to DNNmodel2.h5
# Epoch 42/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0046
#
# Epoch 00042: val_loss did not improve from 0.00259
#
# Epoch 00042: loss improved from 0.00270 to 0.00266, saving model to DNNmodel2.h5
# Epoch 43/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00043: val_loss did not improve from 0.00259
#
# Epoch 00043: loss improved from 0.00266 to 0.00265, saving model to DNNmodel2.h5
# Epoch 44/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00044: val_loss did not improve from 0.00259
#
# Epoch 00044: loss did not improve from 0.00265
# Epoch 45/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00045: val_loss did not improve from 0.00259
#
# Epoch 00045: loss did not improve from 0.00265
# Epoch 46/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00046: val_loss did not improve from 0.00259
#
# Epoch 00046: loss did not improve from 0.00265
# Epoch 47/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0056
#
# Epoch 00047: val_loss did not improve from 0.00259
#
# Epoch 00047: loss did not improve from 0.00265
# Epoch 48/100
# 3847/3847 [==============================] - 0s 86us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00048: val_loss did not improve from 0.00259
#
# Epoch 00048: loss did not improve from 0.00265
# Epoch 49/100
# 3847/3847 [==============================] - 0s 77us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00049: val_loss did not improve from 0.00259
#
# Epoch 00049: loss did not improve from 0.00265
# Epoch 50/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0027 - val_loss: 0.0040
#
# Epoch 00050: val_loss did not improve from 0.00259
#
# Epoch 00050: loss did not improve from 0.00265
# Epoch 51/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00051: val_loss did not improve from 0.00259
#
# Epoch 00051: loss did not improve from 0.00265
# Epoch 52/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00052: val_loss did not improve from 0.00259
#
# Epoch 00052: loss improved from 0.00265 to 0.00263, saving model to DNNmodel2.h5
# Epoch 53/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00053: val_loss did not improve from 0.00259
#
# Epoch 00053: loss improved from 0.00263 to 0.00262, saving model to DNNmodel2.h5
# Epoch 54/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00054: val_loss did not improve from 0.00259
#
# Epoch 00054: loss did not improve from 0.00262
# Epoch 55/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00055: val_loss did not improve from 0.00259
#
# Epoch 00055: loss did not improve from 0.00262
# Epoch 56/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00056: val_loss did not improve from 0.00259
#
# Epoch 00056: loss improved from 0.00262 to 0.00262, saving model to DNNmodel2.h5
# Epoch 57/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00057: val_loss did not improve from 0.00259
#
# Epoch 00057: loss improved from 0.00262 to 0.00255, saving model to DNNmodel2.h5
# Epoch 58/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0048
#
# Epoch 00058: val_loss did not improve from 0.00259
#
# Epoch 00058: loss improved from 0.00255 to 0.00252, saving model to DNNmodel2.h5
# Epoch 59/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0026 - val_loss: 0.0046
#
# Epoch 00059: val_loss did not improve from 0.00259
#
# Epoch 00059: loss did not improve from 0.00252
# Epoch 60/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00060: val_loss did not improve from 0.00259
#
# Epoch 00060: loss did not improve from 0.00252
# Epoch 61/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00061: val_loss did not improve from 0.00259
#
# Epoch 00061: loss did not improve from 0.00252
# Epoch 62/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00062: val_loss did not improve from 0.00259
#
# Epoch 00062: loss did not improve from 0.00252
# Epoch 63/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00063: val_loss did not improve from 0.00259
#
# Epoch 00063: loss did not improve from 0.00252
# Epoch 64/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00064: val_loss did not improve from 0.00259
#
# Epoch 00064: loss did not improve from 0.00252
# Epoch 65/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00065: val_loss did not improve from 0.00259
#
# Epoch 00065: loss did not improve from 0.00252
# Epoch 66/100
# 3847/3847 [==============================] - 0s 92us/step - loss: 0.0025 - val_loss: 0.0058
#
# Epoch 00066: val_loss did not improve from 0.00259
#
# Epoch 00066: loss did not improve from 0.00252
# Epoch 67/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00067: val_loss did not improve from 0.00259
#
# Epoch 00067: loss did not improve from 0.00252
# Epoch 68/100
# 3847/3847 [==============================] - 0s 87us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00068: val_loss did not improve from 0.00259
#
# Epoch 00068: loss improved from 0.00252 to 0.00249, saving model to DNNmodel2.h5
# Epoch 69/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0026 - val_loss: 0.0044
#
# Epoch 00069: val_loss did not improve from 0.00259
#
# Epoch 00069: loss did not improve from 0.00249
# Epoch 70/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00070: val_loss did not improve from 0.00259
#
# Epoch 00070: loss improved from 0.00249 to 0.00248, saving model to DNNmodel2.h5
# Epoch 71/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00071: val_loss did not improve from 0.00259
#
# Epoch 00071: loss improved from 0.00248 to 0.00248, saving model to DNNmodel2.h5
# Epoch 72/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00072: val_loss did not improve from 0.00259
#
# Epoch 00072: loss did not improve from 0.00248
# Epoch 73/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00073: val_loss did not improve from 0.00259
#
# Epoch 00073: loss did not improve from 0.00248
# Epoch 74/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00074: val_loss did not improve from 0.00259
#
# Epoch 00074: loss did not improve from 0.00248
# Epoch 75/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00075: val_loss did not improve from 0.00259
#
# Epoch 00075: loss did not improve from 0.00248
# Epoch 76/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0026 - val_loss: 0.0050
#
# Epoch 00076: val_loss did not improve from 0.00259
#
# Epoch 00076: loss did not improve from 0.00248
# Epoch 77/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00077: val_loss did not improve from 0.00259
#
# Epoch 00077: loss did not improve from 0.00248
# Epoch 78/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00078: val_loss did not improve from 0.00259
#
# Epoch 00078: loss improved from 0.00248 to 0.00247, saving model to DNNmodel2.h5
# Epoch 79/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00079: val_loss did not improve from 0.00259
#
# Epoch 00079: loss improved from 0.00247 to 0.00243, saving model to DNNmodel2.h5
# Epoch 80/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00080: val_loss did not improve from 0.00259
#
# Epoch 00080: loss improved from 0.00243 to 0.00243, saving model to DNNmodel2.h5
# Epoch 81/100
# 3847/3847 [==============================] - 0s 86us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00081: val_loss did not improve from 0.00259
#
# Epoch 00081: loss did not improve from 0.00243
# Epoch 82/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0052
#
# Epoch 00082: val_loss did not improve from 0.00259
#
# Epoch 00082: loss did not improve from 0.00243
# Epoch 83/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00083: val_loss did not improve from 0.00259
#
# Epoch 00083: loss did not improve from 0.00243
# Epoch 84/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0025 - val_loss: 0.0053
#
# Epoch 00084: val_loss did not improve from 0.00259
#
# Epoch 00084: loss did not improve from 0.00243
# Epoch 85/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00085: val_loss did not improve from 0.00259
#
# Epoch 00085: loss did not improve from 0.00243
# Epoch 86/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0053
#
# Epoch 00086: val_loss did not improve from 0.00259
#
# Epoch 00086: loss did not improve from 0.00243
# Epoch 87/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0026 - val_loss: 0.0048
#
# Epoch 00087: val_loss did not improve from 0.00259
#
# Epoch 00087: loss did not improve from 0.00243
# Epoch 88/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00088: val_loss did not improve from 0.00259
#
# Epoch 00088: loss improved from 0.00243 to 0.00241, saving model to DNNmodel2.h5
# Epoch 89/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00089: val_loss did not improve from 0.00259
#
# Epoch 00089: loss did not improve from 0.00241
# Epoch 90/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00090: val_loss did not improve from 0.00259
#
# Epoch 00090: loss did not improve from 0.00241
# Epoch 91/100
# 3847/3847 [==============================] - 0s 82us/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00091: val_loss did not improve from 0.00259
#
# Epoch 00091: loss did not improve from 0.00241
# Epoch 92/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0049
#
# Epoch 00092: val_loss did not improve from 0.00259
#
# Epoch 00092: loss improved from 0.00241 to 0.00238, saving model to DNNmodel2.h5
# Epoch 93/100
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00093: val_loss did not improve from 0.00259
#
# Epoch 00093: loss improved from 0.00238 to 0.00235, saving model to DNNmodel2.h5
# Epoch 94/100
# 3847/3847 [==============================] - 0s 73us/step - loss: 0.0023 - val_loss: 0.0042
#
# Epoch 00094: val_loss did not improve from 0.00259
#
# Epoch 00094: loss improved from 0.00235 to 0.00231, saving model to DNNmodel2.h5
# Epoch 95/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00095: val_loss did not improve from 0.00259
#
# Epoch 00095: loss did not improve from 0.00231
# Epoch 96/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00096: val_loss did not improve from 0.00259
#
# Epoch 00096: loss did not improve from 0.00231
# Epoch 97/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00097: val_loss did not improve from 0.00259
#
# Epoch 00097: loss did not improve from 0.00231
# Epoch 98/100
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00098: val_loss did not improve from 0.00259
#
# Epoch 00098: loss did not improve from 0.00231
# Epoch 99/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00099: val_loss did not improve from 0.00259
#
# Epoch 00099: loss did not improve from 0.00231
# Epoch 100/100
# 3847/3847 [==============================] - 0s 83us/step - loss: 0.0022 - val_loss: 0.0040
#
# Epoch 00100: val_loss did not improve from 0.00259
#
# Epoch 00100: loss improved from 0.00231 to 0.00223, saving model to DNNmodel2.h5
# Model loaded
# mae :  4498.083331665435
# mse :  41157200.064512424
# rmse :  6415.387756364569
# std : 5529.725312184292

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 2s 610us/step - loss: 0.0075 - val_loss: 0.0055
#
# Epoch 00001: val_loss improved from inf to 0.00548, saving model to DNNmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0043 - val_loss: 0.0050
#
# Epoch 00002: val_loss improved from 0.00548 to 0.00505, saving model to DNNmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0037 - val_loss: 0.0038
#
# Epoch 00003: val_loss improved from 0.00505 to 0.00384, saving model to DNNmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 0s 111us/step - loss: 0.0034 - val_loss: 0.0027
#
# Epoch 00004: val_loss improved from 0.00384 to 0.00271, saving model to DNNmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 0s 100us/step - loss: 0.0034 - val_loss: 0.0032
#
# Epoch 00005: val_loss did not improve from 0.00271
# Epoch 6/70
# 3847/3847 [==============================] - 0s 87us/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00006: val_loss did not improve from 0.00271
# Epoch 7/70
# 3847/3847 [==============================] - 0s 86us/step - loss: 0.0031 - val_loss: 0.0039
#
# Epoch 00007: val_loss did not improve from 0.00271
# Epoch 8/70
# 3847/3847 [==============================] - 0s 87us/step - loss: 0.0031 - val_loss: 0.0041
#
# Epoch 00008: val_loss did not improve from 0.00271
# Epoch 9/70
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0031 - val_loss: 0.0023
#
# Epoch 00009: val_loss improved from 0.00271 to 0.00229, saving model to DNNmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 0s 95us/step - loss: 0.0033 - val_loss: 0.0045
#
# Epoch 00010: val_loss did not improve from 0.00229
# Epoch 11/70
# 3847/3847 [==============================] - 0s 95us/step - loss: 0.0031 - val_loss: 0.0043
#
# Epoch 00011: val_loss did not improve from 0.00229
# Epoch 12/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00012: val_loss did not improve from 0.00229
# Epoch 13/70
# 3847/3847 [==============================] - 0s 99us/step - loss: 0.0031 - val_loss: 0.0030
#
# Epoch 00013: val_loss did not improve from 0.00229
# Epoch 14/70
# 3847/3847 [==============================] - 0s 98us/step - loss: 0.0030 - val_loss: 0.0034
#
# Epoch 00014: val_loss did not improve from 0.00229
# Epoch 15/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0031 - val_loss: 0.0034
#
# Epoch 00015: val_loss did not improve from 0.00229
# Epoch 16/70
# 3847/3847 [==============================] - 0s 85us/step - loss: 0.0029 - val_loss: 0.0048
#
# Epoch 00016: val_loss did not improve from 0.00229
# Epoch 17/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00017: val_loss did not improve from 0.00229
# Epoch 18/70
# 3847/3847 [==============================] - 0s 95us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00018: val_loss did not improve from 0.00229
# Epoch 19/70
# 3847/3847 [==============================] - 0s 86us/step - loss: 0.0028 - val_loss: 0.0048
#
# Epoch 00019: val_loss did not improve from 0.00229
# Epoch 20/70
# 3847/3847 [==============================] - 0s 90us/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00229
# Epoch 21/70
# 3847/3847 [==============================] - 0s 92us/step - loss: 0.0028 - val_loss: 0.0033
#
# Epoch 00021: val_loss did not improve from 0.00229
# Epoch 22/70
# 3847/3847 [==============================] - 0s 88us/step - loss: 0.0028 - val_loss: 0.0033
#
# Epoch 00022: val_loss did not improve from 0.00229
# Epoch 23/70
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00023: val_loss did not improve from 0.00229
# Epoch 24/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00024: val_loss did not improve from 0.00229
# Epoch 25/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0028 - val_loss: 0.0056
#
# Epoch 00025: val_loss did not improve from 0.00229
# Epoch 26/70
# 3847/3847 [==============================] - 0s 95us/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00026: val_loss did not improve from 0.00229
# Epoch 27/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00027: val_loss did not improve from 0.00229
# Epoch 28/70
# 3847/3847 [==============================] - 0s 121us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00028: val_loss did not improve from 0.00229
# Epoch 29/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0027 - val_loss: 0.0048
#
# Epoch 00029: val_loss did not improve from 0.00229
# Epoch 30/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00030: val_loss did not improve from 0.00229
# Epoch 31/70
# 3847/3847 [==============================] - 0s 100us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00031: val_loss did not improve from 0.00229
# Epoch 32/70
# 3847/3847 [==============================] - 0s 84us/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00032: val_loss did not improve from 0.00229
# Epoch 33/70
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0027 - val_loss: 0.0053
#
# Epoch 00033: val_loss did not improve from 0.00229
# Epoch 34/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0027 - val_loss: 0.0046
#
# Epoch 00034: val_loss did not improve from 0.00229
# Epoch 35/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00035: val_loss did not improve from 0.00229
# Epoch 36/70
# 3847/3847 [==============================] - 0s 92us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00229
# Epoch 37/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00037: val_loss did not improve from 0.00229
# Epoch 38/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00038: val_loss did not improve from 0.00229
# Epoch 39/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00039: val_loss did not improve from 0.00229
# Epoch 40/70
# 3847/3847 [==============================] - 0s 106us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00229
# Epoch 41/70
# 3847/3847 [==============================] - 0s 89us/step - loss: 0.0027 - val_loss: 0.0063
#
# Epoch 00041: val_loss did not improve from 0.00229
# Epoch 42/70
# 3847/3847 [==============================] - 0s 96us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00042: val_loss did not improve from 0.00229
# Epoch 43/70
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00043: val_loss did not improve from 0.00229
# Epoch 44/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00044: val_loss did not improve from 0.00229
# Epoch 45/70
# 3847/3847 [==============================] - 0s 93us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00045: val_loss did not improve from 0.00229
# Epoch 46/70
# 3847/3847 [==============================] - 0s 95us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00046: val_loss did not improve from 0.00229
# Epoch 47/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00047: val_loss did not improve from 0.00229
# Epoch 48/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00048: val_loss did not improve from 0.00229
# Epoch 49/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00049: val_loss did not improve from 0.00229
# Epoch 50/70
# 3847/3847 [==============================] - 0s 108us/step - loss: 0.0026 - val_loss: 0.0060
#
# Epoch 00050: val_loss did not improve from 0.00229
# Epoch 51/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0026 - val_loss: 0.0049
#
# Epoch 00051: val_loss did not improve from 0.00229
# Epoch 52/70
# 3847/3847 [==============================] - 0s 88us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00052: val_loss did not improve from 0.00229
# Epoch 53/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00053: val_loss did not improve from 0.00229
# Epoch 54/70
# 3847/3847 [==============================] - 0s 100us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00054: val_loss did not improve from 0.00229
# Epoch 55/70
# 3847/3847 [==============================] - 0s 99us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00055: val_loss did not improve from 0.00229
# Epoch 56/70
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00056: val_loss did not improve from 0.00229
# Epoch 57/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00057: val_loss did not improve from 0.00229
# Epoch 58/70
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00058: val_loss did not improve from 0.00229
# Epoch 59/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00059: val_loss did not improve from 0.00229
# Epoch 60/70
# 3847/3847 [==============================] - 0s 106us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00060: val_loss did not improve from 0.00229
# Epoch 61/70
# 3847/3847 [==============================] - 0s 97us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00061: val_loss did not improve from 0.00229
# Epoch 62/70
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0026 - val_loss: 0.0053
#
# Epoch 00062: val_loss did not improve from 0.00229
# Epoch 63/70
# 3847/3847 [==============================] - 0s 90us/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00063: val_loss did not improve from 0.00229
# Epoch 64/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00064: val_loss did not improve from 0.00229
# Epoch 65/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00065: val_loss did not improve from 0.00229
# Epoch 66/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00066: val_loss did not improve from 0.00229
# Epoch 67/70
# 3847/3847 [==============================] - 0s 96us/step - loss: 0.0024 - val_loss: 0.0047
#
# Epoch 00067: val_loss did not improve from 0.00229
# Epoch 68/70
# 3847/3847 [==============================] - 0s 93us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00068: val_loss did not improve from 0.00229
# Epoch 69/70
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00069: val_loss did not improve from 0.00229
# Epoch 70/70
# 3847/3847 [==============================] - 0s 94us/step - loss: 0.0024 - val_loss: 0.0047
#
# Epoch 00070: val_loss did not improve from 0.00229
# Model loaded
# mae :  5020.567099038657
# mse :  43569114.844639115
# rmse :  6600.690482414632
# std : 5439.9013141201585

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 2s 554us/step - loss: 0.0091 - val_loss: 0.0041
#
# Epoch 00001: val_loss improved from inf to 0.00406, saving model to DNNmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0048 - val_loss: 0.0033
#
# Epoch 00002: val_loss improved from 0.00406 to 0.00327, saving model to DNNmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0042 - val_loss: 0.0040
#
# Epoch 00003: val_loss did not improve from 0.00327
# Epoch 4/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0037 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00327 to 0.00193, saving model to DNNmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0036 - val_loss: 0.0033
#
# Epoch 00005: val_loss did not improve from 0.00193
# Epoch 6/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00006: val_loss did not improve from 0.00193
# Epoch 7/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0034 - val_loss: 0.0042
#
# Epoch 00007: val_loss did not improve from 0.00193
# Epoch 8/70
# 3847/3847 [==============================] - 0s 96us/step - loss: 0.0033 - val_loss: 0.0042
#
# Epoch 00008: val_loss did not improve from 0.00193
# Epoch 9/70
# 3847/3847 [==============================] - 0s 98us/step - loss: 0.0031 - val_loss: 0.0044
#
# Epoch 00009: val_loss did not improve from 0.00193
# Epoch 10/70
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00010: val_loss did not improve from 0.00193
# Epoch 11/70
# 3847/3847 [==============================] - 0s 98us/step - loss: 0.0031 - val_loss: 0.0045
#
# Epoch 00011: val_loss did not improve from 0.00193
# Epoch 12/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00012: val_loss did not improve from 0.00193
# Epoch 13/70
# 3847/3847 [==============================] - 0s 111us/step - loss: 0.0031 - val_loss: 0.0032
#
# Epoch 00013: val_loss did not improve from 0.00193
# Epoch 14/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0031 - val_loss: 0.0023
#
# Epoch 00014: val_loss did not improve from 0.00193
# Epoch 15/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00015: val_loss did not improve from 0.00193
# Epoch 16/70
# 3847/3847 [==============================] - 0s 111us/step - loss: 0.0029 - val_loss: 0.0040
#
# Epoch 00016: val_loss did not improve from 0.00193
# Epoch 17/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0030 - val_loss: 0.0049
#
# Epoch 00017: val_loss did not improve from 0.00193
# Epoch 18/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00018: val_loss did not improve from 0.00193
# Epoch 19/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0030 - val_loss: 0.0030
#
# Epoch 00019: val_loss did not improve from 0.00193
# Epoch 20/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0029 - val_loss: 0.0036
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0028 - val_loss: 0.0051
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0027 - val_loss: 0.0040
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0028 - val_loss: 0.0043
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0027 - val_loss: 0.0051
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/70
# 3847/3847 [==============================] - 0s 106us/step - loss: 0.0028 - val_loss: 0.0047
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0028 - val_loss: 0.0063
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0028 - val_loss: 0.0044
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0026 - val_loss: 0.0053
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0028 - val_loss: 0.0030
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/70
# 3847/3847 [==============================] - 0s 128us/step - loss: 0.0026 - val_loss: 0.0052
#
# Epoch 00041: val_loss did not improve from 0.00193
# Epoch 42/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00042: val_loss did not improve from 0.00193
# Epoch 43/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00043: val_loss did not improve from 0.00193
# Epoch 44/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00044: val_loss did not improve from 0.00193
# Epoch 45/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00045: val_loss did not improve from 0.00193
# Epoch 46/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00046: val_loss did not improve from 0.00193
# Epoch 47/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0027 - val_loss: 0.0058
#
# Epoch 00047: val_loss did not improve from 0.00193
# Epoch 48/70
# 3847/3847 [==============================] - 0s 121us/step - loss: 0.0026 - val_loss: 0.0049
#
# Epoch 00048: val_loss did not improve from 0.00193
# Epoch 49/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00049: val_loss did not improve from 0.00193
# Epoch 50/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00050: val_loss did not improve from 0.00193
# Epoch 51/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00051: val_loss did not improve from 0.00193
# Epoch 52/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00052: val_loss did not improve from 0.00193
# Epoch 53/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00053: val_loss did not improve from 0.00193
# Epoch 54/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0025 - val_loss: 0.0049
#
# Epoch 00054: val_loss did not improve from 0.00193
# Epoch 55/70
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00055: val_loss did not improve from 0.00193
# Epoch 56/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00056: val_loss did not improve from 0.00193
# Epoch 57/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0025 - val_loss: 0.0049
#
# Epoch 00057: val_loss did not improve from 0.00193
# Epoch 58/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00058: val_loss did not improve from 0.00193
# Epoch 59/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0025 - val_loss: 0.0054
#
# Epoch 00059: val_loss did not improve from 0.00193
# Epoch 60/70
# 3847/3847 [==============================] - 0s 111us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00060: val_loss did not improve from 0.00193
# Epoch 61/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0025 - val_loss: 0.0050
#
# Epoch 00061: val_loss did not improve from 0.00193
# Epoch 62/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00062: val_loss did not improve from 0.00193
# Epoch 63/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00063: val_loss did not improve from 0.00193
# Epoch 64/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00064: val_loss did not improve from 0.00193
# Epoch 65/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00065: val_loss did not improve from 0.00193
# Epoch 66/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00066: val_loss did not improve from 0.00193
# Epoch 67/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00067: val_loss did not improve from 0.00193
# Epoch 68/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00068: val_loss did not improve from 0.00193
# Epoch 69/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00069: val_loss did not improve from 0.00193
# Epoch 70/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00070: val_loss did not improve from 0.00193
# Model loaded
# mae :  3027.862561510755
# mse :  25081596.01116865
# rmse :  5008.152954050889
# std : 4874.721552094836

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 2s 570us/step - loss: 0.0092 - val_loss: 0.0029
#
# Epoch 00001: val_loss improved from inf to 0.00293, saving model to DNNmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0044 - val_loss: 0.0037
#
# Epoch 00002: val_loss did not improve from 0.00293
# Epoch 3/70
# 3847/3847 [==============================] - 0s 121us/step - loss: 0.0039 - val_loss: 0.0036
#
# Epoch 00003: val_loss did not improve from 0.00293
# Epoch 4/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00004: val_loss did not improve from 0.00293
# Epoch 5/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0034 - val_loss: 0.0037
#
# Epoch 00005: val_loss did not improve from 0.00293
# Epoch 6/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0033 - val_loss: 0.0051
#
# Epoch 00006: val_loss did not improve from 0.00293
# Epoch 7/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0032 - val_loss: 0.0066
#
# Epoch 00007: val_loss did not improve from 0.00293
# Epoch 8/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0032 - val_loss: 0.0040
#
# Epoch 00008: val_loss did not improve from 0.00293
# Epoch 9/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00009: val_loss did not improve from 0.00293
# Epoch 10/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0030 - val_loss: 0.0024
#
# Epoch 00010: val_loss improved from 0.00293 to 0.00235, saving model to DNNmodel.h5
# Epoch 11/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00011: val_loss did not improve from 0.00235
# Epoch 12/70
# 3847/3847 [==============================] - 1s 145us/step - loss: 0.0029 - val_loss: 0.0039
#
# Epoch 00012: val_loss did not improve from 0.00235
# Epoch 13/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0030 - val_loss: 0.0054
#
# Epoch 00013: val_loss did not improve from 0.00235
# Epoch 14/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00014: val_loss did not improve from 0.00235
# Epoch 15/70
# 3847/3847 [==============================] - 1s 143us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00015: val_loss did not improve from 0.00235
# Epoch 16/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0029 - val_loss: 0.0041
#
# Epoch 00016: val_loss did not improve from 0.00235
# Epoch 17/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0029 - val_loss: 0.0055
#
# Epoch 00017: val_loss did not improve from 0.00235
# Epoch 18/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0029 - val_loss: 0.0031
#
# Epoch 00018: val_loss did not improve from 0.00235
# Epoch 19/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0030 - val_loss: 0.0035
#
# Epoch 00019: val_loss did not improve from 0.00235
# Epoch 20/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0030 - val_loss: 0.0023
#
# Epoch 00020: val_loss improved from 0.00235 to 0.00235, saving model to DNNmodel.h5
# Epoch 21/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0029 - val_loss: 0.0048
#
# Epoch 00021: val_loss did not improve from 0.00235
# Epoch 22/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0029 - val_loss: 0.0035
#
# Epoch 00022: val_loss did not improve from 0.00235
# Epoch 23/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00023: val_loss did not improve from 0.00235
# Epoch 24/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0029 - val_loss: 0.0039
#
# Epoch 00024: val_loss did not improve from 0.00235
# Epoch 25/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00025: val_loss did not improve from 0.00235
# Epoch 26/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0028 - val_loss: 0.0041
#
# Epoch 00026: val_loss did not improve from 0.00235
# Epoch 27/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0027 - val_loss: 0.0053
#
# Epoch 00027: val_loss did not improve from 0.00235
# Epoch 28/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00028: val_loss did not improve from 0.00235
# Epoch 29/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00029: val_loss did not improve from 0.00235
# Epoch 30/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00030: val_loss did not improve from 0.00235
# Epoch 31/70
# 3847/3847 [==============================] - 1s 135us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00031: val_loss did not improve from 0.00235
# Epoch 32/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00032: val_loss did not improve from 0.00235
# Epoch 33/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00033: val_loss did not improve from 0.00235
# Epoch 34/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00034: val_loss did not improve from 0.00235
# Epoch 35/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00035: val_loss did not improve from 0.00235
# Epoch 36/70
# 3847/3847 [==============================] - 1s 135us/step - loss: 0.0028 - val_loss: 0.0054
#
# Epoch 00036: val_loss did not improve from 0.00235
# Epoch 37/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00037: val_loss did not improve from 0.00235
# Epoch 38/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0027 - val_loss: 0.0050
#
# Epoch 00038: val_loss did not improve from 0.00235
# Epoch 39/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00039: val_loss did not improve from 0.00235
# Epoch 40/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0026 - val_loss: 0.0044
#
# Epoch 00040: val_loss did not improve from 0.00235
# Epoch 41/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00041: val_loss did not improve from 0.00235
# Epoch 42/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0026 - val_loss: 0.0022
#
# Epoch 00042: val_loss improved from 0.00235 to 0.00219, saving model to DNNmodel.h5
# Epoch 43/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00043: val_loss did not improve from 0.00219
# Epoch 44/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0026 - val_loss: 0.0044
#
# Epoch 00044: val_loss did not improve from 0.00219
# Epoch 45/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00045: val_loss did not improve from 0.00219
# Epoch 46/70
# 3847/3847 [==============================] - 0s 108us/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00046: val_loss did not improve from 0.00219
# Epoch 47/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0026 - val_loss: 0.0050
#
# Epoch 00047: val_loss did not improve from 0.00219
# Epoch 48/70
# 3847/3847 [==============================] - 0s 121us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00048: val_loss did not improve from 0.00219
# Epoch 49/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0025 - val_loss: 0.0051
#
# Epoch 00049: val_loss did not improve from 0.00219
# Epoch 50/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0026 - val_loss: 0.0055
#
# Epoch 00050: val_loss did not improve from 0.00219
# Epoch 51/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00051: val_loss did not improve from 0.00219
# Epoch 52/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0025 - val_loss: 0.0048
#
# Epoch 00052: val_loss did not improve from 0.00219
# Epoch 53/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00053: val_loss did not improve from 0.00219
# Epoch 54/70
# 3847/3847 [==============================] - 0s 107us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00054: val_loss did not improve from 0.00219
# Epoch 55/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0026 - val_loss: 0.0045
#
# Epoch 00055: val_loss did not improve from 0.00219
# Epoch 56/70
# 3847/3847 [==============================] - 0s 112us/step - loss: 0.0025 - val_loss: 0.0070
#
# Epoch 00056: val_loss did not improve from 0.00219
# Epoch 57/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00057: val_loss did not improve from 0.00219
# Epoch 58/70
# 3847/3847 [==============================] - 0s 110us/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00058: val_loss did not improve from 0.00219
# Epoch 59/70
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00059: val_loss did not improve from 0.00219
# Epoch 60/70
# 3847/3847 [==============================] - 0s 109us/step - loss: 0.0025 - val_loss: 0.0056
#
# Epoch 00060: val_loss did not improve from 0.00219
# Epoch 61/70
# 3847/3847 [==============================] - 0s 111us/step - loss: 0.0026 - val_loss: 0.0048
#
# Epoch 00061: val_loss did not improve from 0.00219
# Epoch 62/70
# 3847/3847 [==============================] - 0s 116us/step - loss: 0.0026 - val_loss: 0.0046
#
# Epoch 00062: val_loss did not improve from 0.00219
# Epoch 63/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0025 - val_loss: 0.0054
#
# Epoch 00063: val_loss did not improve from 0.00219
# Epoch 64/70
# 3847/3847 [==============================] - 0s 106us/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00064: val_loss did not improve from 0.00219
# Epoch 65/70
# 3847/3847 [==============================] - 0s 115us/step - loss: 0.0024 - val_loss: 0.0044
#
# Epoch 00065: val_loss did not improve from 0.00219
# Epoch 66/70
# 3847/3847 [==============================] - 0s 101us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00066: val_loss did not improve from 0.00219
# Epoch 67/70
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00067: val_loss did not improve from 0.00219
# Epoch 68/70
# 3847/3847 [==============================] - 0s 104us/step - loss: 0.0025 - val_loss: 0.0054
#
# Epoch 00068: val_loss did not improve from 0.00219
# Epoch 69/70
# 3847/3847 [==============================] - 0s 102us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00069: val_loss did not improve from 0.00219
# Epoch 70/70
# 3847/3847 [==============================] - 0s 103us/step - loss: 0.0024 - val_loss: 0.0052
#
# Epoch 00070: val_loss did not improve from 0.00219
# Model loaded
# mae :  4505.753592671977
# mse :  34184211.69893228
# rmse :  5846.726579799357
# std : 4886.502206288334

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 3s 903us/step - loss: 0.0088 - val_loss: 0.0085
#
# Epoch 00001: val_loss improved from inf to 0.00848, saving model to DNNmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0044 - val_loss: 0.0050
#
# Epoch 00002: val_loss improved from 0.00848 to 0.00503, saving model to DNNmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 1s 140us/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00003: val_loss improved from 0.00503 to 0.00409, saving model to DNNmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 1s 140us/step - loss: 0.0041 - val_loss: 0.0033
#
# Epoch 00004: val_loss improved from 0.00409 to 0.00334, saving model to DNNmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0037 - val_loss: 0.0033
#
# Epoch 00005: val_loss improved from 0.00334 to 0.00329, saving model to DNNmodel.h5
# Epoch 6/70
# 3847/3847 [==============================] - 1s 143us/step - loss: 0.0035 - val_loss: 0.0039
#
# Epoch 00006: val_loss did not improve from 0.00329
# Epoch 7/70
# 3847/3847 [==============================] - 1s 139us/step - loss: 0.0033 - val_loss: 0.0052
#
# Epoch 00007: val_loss did not improve from 0.00329
# Epoch 8/70
# 3847/3847 [==============================] - 1s 135us/step - loss: 0.0032 - val_loss: 0.0063
#
# Epoch 00008: val_loss did not improve from 0.00329
# Epoch 9/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0033 - val_loss: 0.0025
#
# Epoch 00009: val_loss improved from 0.00329 to 0.00249, saving model to DNNmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0032 - val_loss: 0.0037
#
# Epoch 00010: val_loss did not improve from 0.00249
# Epoch 11/70
# 3847/3847 [==============================] - 0s 128us/step - loss: 0.0031 - val_loss: 0.0045
#
# Epoch 00011: val_loss did not improve from 0.00249
# Epoch 12/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0032 - val_loss: 0.0053
#
# Epoch 00012: val_loss did not improve from 0.00249
# Epoch 13/70
# 3847/3847 [==============================] - 1s 141us/step - loss: 0.0031 - val_loss: 0.0043
#
# Epoch 00013: val_loss did not improve from 0.00249
# Epoch 14/70
# 3847/3847 [==============================] - 1s 134us/step - loss: 0.0031 - val_loss: 0.0030
#
# Epoch 00014: val_loss did not improve from 0.00249
# Epoch 15/70
# 3847/3847 [==============================] - 1s 140us/step - loss: 0.0030 - val_loss: 0.0035
#
# Epoch 00015: val_loss did not improve from 0.00249
# Epoch 16/70
# 3847/3847 [==============================] - 1s 134us/step - loss: 0.0030 - val_loss: 0.0041
#
# Epoch 00016: val_loss did not improve from 0.00249
# Epoch 17/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0030 - val_loss: 0.0044
#
# Epoch 00017: val_loss did not improve from 0.00249
# Epoch 18/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00018: val_loss did not improve from 0.00249
# Epoch 19/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0030 - val_loss: 0.0047
#
# Epoch 00019: val_loss did not improve from 0.00249
# Epoch 20/70
# 3847/3847 [==============================] - 0s 128us/step - loss: 0.0028 - val_loss: 0.0055
#
# Epoch 00020: val_loss did not improve from 0.00249
# Epoch 21/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0030 - val_loss: 0.0035
#
# Epoch 00021: val_loss did not improve from 0.00249
# Epoch 22/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0029 - val_loss: 0.0036
#
# Epoch 00022: val_loss did not improve from 0.00249
# Epoch 23/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0028 - val_loss: 0.0053
#
# Epoch 00023: val_loss did not improve from 0.00249
# Epoch 24/70
# 3847/3847 [==============================] - 0s 114us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00024: val_loss did not improve from 0.00249
# Epoch 25/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00025: val_loss did not improve from 0.00249
# Epoch 26/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00026: val_loss did not improve from 0.00249
# Epoch 27/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0029 - val_loss: 0.0048
#
# Epoch 00027: val_loss did not improve from 0.00249
# Epoch 28/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0028 - val_loss: 0.0027
#
# Epoch 00028: val_loss did not improve from 0.00249
# Epoch 29/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00029: val_loss did not improve from 0.00249
# Epoch 30/70
# 3847/3847 [==============================] - 1s 138us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00030: val_loss did not improve from 0.00249
# Epoch 31/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0028 - val_loss: 0.0032
#
# Epoch 00031: val_loss did not improve from 0.00249
# Epoch 32/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00032: val_loss did not improve from 0.00249
# Epoch 33/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0027 - val_loss: 0.0049
#
# Epoch 00033: val_loss did not improve from 0.00249
# Epoch 34/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0028 - val_loss: 0.0052
#
# Epoch 00034: val_loss did not improve from 0.00249
# Epoch 35/70
# 3847/3847 [==============================] - 0s 121us/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00035: val_loss did not improve from 0.00249
# Epoch 36/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00249
# Epoch 37/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00037: val_loss did not improve from 0.00249
# Epoch 38/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0027 - val_loss: 0.0040
#
# Epoch 00038: val_loss did not improve from 0.00249
# Epoch 39/70
# 3847/3847 [==============================] - 1s 137us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00039: val_loss did not improve from 0.00249
# Epoch 40/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0028 - val_loss: 0.0045
#
# Epoch 00040: val_loss did not improve from 0.00249
# Epoch 41/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0028 - val_loss: 0.0045
#
# Epoch 00041: val_loss did not improve from 0.00249
# Epoch 42/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00042: val_loss did not improve from 0.00249
# Epoch 43/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0027 - val_loss: 0.0051
#
# Epoch 00043: val_loss did not improve from 0.00249
# Epoch 44/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00044: val_loss did not improve from 0.00249
# Epoch 45/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00045: val_loss did not improve from 0.00249
# Epoch 46/70
# 3847/3847 [==============================] - 0s 113us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00046: val_loss did not improve from 0.00249
# Epoch 47/70
# 3847/3847 [==============================] - 0s 128us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00047: val_loss did not improve from 0.00249
# Epoch 48/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0027 - val_loss: 0.0068
#
# Epoch 00048: val_loss did not improve from 0.00249
# Epoch 49/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00049: val_loss did not improve from 0.00249
# Epoch 50/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00050: val_loss did not improve from 0.00249
# Epoch 51/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 00051: val_loss did not improve from 0.00249
# Epoch 52/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00052: val_loss did not improve from 0.00249
# Epoch 53/70
# 3847/3847 [==============================] - 1s 134us/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00053: val_loss did not improve from 0.00249
# Epoch 54/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00054: val_loss did not improve from 0.00249
# Epoch 55/70
# 3847/3847 [==============================] - 1s 135us/step - loss: 0.0026 - val_loss: 0.0043
#
# Epoch 00055: val_loss did not improve from 0.00249
# Epoch 56/70
# 3847/3847 [==============================] - 1s 144us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00056: val_loss did not improve from 0.00249
# Epoch 57/70
# 3847/3847 [==============================] - 1s 145us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00057: val_loss did not improve from 0.00249
# Epoch 58/70
# 3847/3847 [==============================] - 1s 148us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00058: val_loss did not improve from 0.00249
# Epoch 59/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00059: val_loss did not improve from 0.00249
# Epoch 60/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00060: val_loss did not improve from 0.00249
# Epoch 61/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00061: val_loss did not improve from 0.00249
# Epoch 62/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00062: val_loss did not improve from 0.00249
# Epoch 63/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00063: val_loss did not improve from 0.00249
# Epoch 64/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0026 - val_loss: 0.0043
#
# Epoch 00064: val_loss did not improve from 0.00249
# Epoch 65/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00065: val_loss did not improve from 0.00249
# Epoch 66/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00066: val_loss did not improve from 0.00249
# Epoch 67/70
# 3847/3847 [==============================] - 0s 117us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00067: val_loss did not improve from 0.00249
# Epoch 68/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00068: val_loss did not improve from 0.00249
# Epoch 69/70
# 3847/3847 [==============================] - 1s 140us/step - loss: 0.0025 - val_loss: 0.0052
#
# Epoch 00069: val_loss did not improve from 0.00249
# Epoch 70/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00070: val_loss did not improve from 0.00249
# Model loaded
# mae :  4129.588146497058
# mse :  38107116.78672601
# rmse :  6173.096207473686
# std : 5461.4063406808355

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model3.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs= model3.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_sc, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_sc)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0069 - val_loss: 0.0033
#
# Epoch 00001: val_loss improved from inf to 0.00332, saving model to DNNmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 1s 148us/step - loss: 0.0039 - val_loss: 0.0069
#
# Epoch 00002: val_loss did not improve from 0.00332
# Epoch 3/70
# 3847/3847 [==============================] - 1s 150us/step - loss: 0.0038 - val_loss: 0.0037
#
# Epoch 00003: val_loss did not improve from 0.00332
# Epoch 4/70
# 3847/3847 [==============================] - 1s 156us/step - loss: 0.0036 - val_loss: 0.0032
#
# Epoch 00004: val_loss improved from 0.00332 to 0.00318, saving model to DNNmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 1s 142us/step - loss: 0.0037 - val_loss: 0.0052
#
# Epoch 00005: val_loss did not improve from 0.00318
# Epoch 6/70
# 3847/3847 [==============================] - 1s 155us/step - loss: 0.0033 - val_loss: 0.0037
#
# Epoch 00006: val_loss did not improve from 0.00318
# Epoch 7/70
# 3847/3847 [==============================] - 1s 144us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00007: val_loss improved from 0.00318 to 0.00310, saving model to DNNmodel.h5
# Epoch 8/70
# 3847/3847 [==============================] - 1s 141us/step - loss: 0.0034 - val_loss: 0.0036
#
# Epoch 00008: val_loss did not improve from 0.00310
# Epoch 9/70
# 3847/3847 [==============================] - 1s 154us/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00009: val_loss did not improve from 0.00310
# Epoch 10/70
# 3847/3847 [==============================] - 1s 168us/step - loss: 0.0032 - val_loss: 0.0039
#
# Epoch 00010: val_loss did not improve from 0.00310
# Epoch 11/70
# 3847/3847 [==============================] - 1s 147us/step - loss: 0.0030 - val_loss: 0.0054
#
# Epoch 00011: val_loss did not improve from 0.00310
# Epoch 12/70
# 3847/3847 [==============================] - 1s 156us/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00012: val_loss did not improve from 0.00310
# Epoch 13/70
# 3847/3847 [==============================] - 1s 150us/step - loss: 0.0029 - val_loss: 0.0028
#
# Epoch 00013: val_loss improved from 0.00310 to 0.00280, saving model to DNNmodel.h5
# Epoch 14/70
# 3847/3847 [==============================] - 1s 153us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00014: val_loss did not improve from 0.00280
# Epoch 15/70
# 3847/3847 [==============================] - 1s 145us/step - loss: 0.0030 - val_loss: 0.0034
#
# Epoch 00015: val_loss did not improve from 0.00280
# Epoch 16/70
# 3847/3847 [==============================] - 1s 147us/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00016: val_loss did not improve from 0.00280
# Epoch 17/70
# 3847/3847 [==============================] - 1s 158us/step - loss: 0.0031 - val_loss: 0.0036
#
# Epoch 00017: val_loss did not improve from 0.00280
# Epoch 18/70
# 3847/3847 [==============================] - 1s 139us/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00018: val_loss did not improve from 0.00280
# Epoch 19/70
# 3847/3847 [==============================] - 1s 157us/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00019: val_loss did not improve from 0.00280
# Epoch 20/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0030 - val_loss: 0.0048
#
# Epoch 00020: val_loss did not improve from 0.00280
# Epoch 21/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00021: val_loss did not improve from 0.00280
# Epoch 22/70
# 3847/3847 [==============================] - 1s 136us/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00022: val_loss improved from 0.00280 to 0.00251, saving model to DNNmodel.h5
# Epoch 23/70
# 3847/3847 [==============================] - 1s 148us/step - loss: 0.0028 - val_loss: 0.0045
#
# Epoch 00023: val_loss did not improve from 0.00251
# Epoch 24/70
# 3847/3847 [==============================] - 1s 134us/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00024: val_loss did not improve from 0.00251
# Epoch 25/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0029 - val_loss: 0.0048
#
# Epoch 00025: val_loss did not improve from 0.00251
# Epoch 26/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0028 - val_loss: 0.0056
#
# Epoch 00026: val_loss did not improve from 0.00251
# Epoch 27/70
# 3847/3847 [==============================] - 1s 138us/step - loss: 0.0028 - val_loss: 0.0046
#
# Epoch 00027: val_loss did not improve from 0.00251
# Epoch 28/70
# 3847/3847 [==============================] - 1s 136us/step - loss: 0.0028 - val_loss: 0.0053
#
# Epoch 00028: val_loss did not improve from 0.00251
# Epoch 29/70
# 3847/3847 [==============================] - 1s 134us/step - loss: 0.0027 - val_loss: 0.0044
#
# Epoch 00029: val_loss did not improve from 0.00251
# Epoch 30/70
# 3847/3847 [==============================] - 1s 139us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00030: val_loss did not improve from 0.00251
# Epoch 31/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0026 - val_loss: 0.0045
#
# Epoch 00031: val_loss did not improve from 0.00251
# Epoch 32/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00032: val_loss did not improve from 0.00251
# Epoch 33/70
# 3847/3847 [==============================] - 0s 120us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00033: val_loss did not improve from 0.00251
# Epoch 34/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0028 - val_loss: 0.0044
#
# Epoch 00034: val_loss did not improve from 0.00251
# Epoch 35/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00035: val_loss did not improve from 0.00251
# Epoch 36/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00251
# Epoch 37/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00037: val_loss did not improve from 0.00251
# Epoch 38/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00038: val_loss did not improve from 0.00251
# Epoch 39/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00039: val_loss did not improve from 0.00251
# Epoch 40/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00040: val_loss did not improve from 0.00251
# Epoch 41/70
# 3847/3847 [==============================] - 0s 127us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00041: val_loss did not improve from 0.00251
# Epoch 42/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00251
# Epoch 43/70
# 3847/3847 [==============================] - 0s 123us/step - loss: 0.0026 - val_loss: 0.0054
#
# Epoch 00043: val_loss did not improve from 0.00251
# Epoch 44/70
# 3847/3847 [==============================] - 0s 118us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00044: val_loss did not improve from 0.00251
# Epoch 45/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00045: val_loss did not improve from 0.00251
# Epoch 46/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00046: val_loss did not improve from 0.00251
# Epoch 47/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0026 - val_loss: 0.0050
#
# Epoch 00047: val_loss did not improve from 0.00251
# Epoch 48/70
# 3847/3847 [==============================] - 0s 128us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00048: val_loss did not improve from 0.00251
# Epoch 49/70
# 3847/3847 [==============================] - 1s 133us/step - loss: 0.0025 - val_loss: 0.0029
#
# Epoch 00049: val_loss did not improve from 0.00251
# Epoch 50/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00050: val_loss did not improve from 0.00251
# Epoch 51/70
# 3847/3847 [==============================] - 0s 124us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00051: val_loss did not improve from 0.00251
# Epoch 52/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00052: val_loss did not improve from 0.00251
# Epoch 53/70
# 3847/3847 [==============================] - 0s 122us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00053: val_loss did not improve from 0.00251
# Epoch 54/70
# 3847/3847 [==============================] - 1s 145us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00054: val_loss did not improve from 0.00251
# Epoch 55/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0025 - val_loss: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.00251
# Epoch 56/70
# 3847/3847 [==============================] - 0s 125us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00056: val_loss did not improve from 0.00251
# Epoch 57/70
# 3847/3847 [==============================] - 1s 153us/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00057: val_loss did not improve from 0.00251
# Epoch 58/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0026 - val_loss: 0.0058
#
# Epoch 00058: val_loss did not improve from 0.00251
# Epoch 59/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00059: val_loss did not improve from 0.00251
# Epoch 60/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0024 - val_loss: 0.0064
#
# Epoch 00060: val_loss did not improve from 0.00251
# Epoch 61/70
# 3847/3847 [==============================] - 0s 130us/step - loss: 0.0025 - val_loss: 0.0048
#
# Epoch 00061: val_loss did not improve from 0.00251
# Epoch 62/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00062: val_loss did not improve from 0.00251
# Epoch 63/70
# 3847/3847 [==============================] - 1s 132us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00063: val_loss did not improve from 0.00251
# Epoch 64/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0024 - val_loss: 0.0033
#
# Epoch 00064: val_loss did not improve from 0.00251
# Epoch 65/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0025 - val_loss: 0.0051
#
# Epoch 00065: val_loss did not improve from 0.00251
# Epoch 66/70
# 3847/3847 [==============================] - 1s 131us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00066: val_loss did not improve from 0.00251
# Epoch 67/70
# 3847/3847 [==============================] - 0s 129us/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00067: val_loss did not improve from 0.00251
# Epoch 68/70
# 3847/3847 [==============================] - 1s 130us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00068: val_loss did not improve from 0.00251
# Epoch 69/70
# 3847/3847 [==============================] - 0s 126us/step - loss: 0.0024 - val_loss: 0.0056
#
# Epoch 00069: val_loss did not improve from 0.00251
# Epoch 70/70
# 3847/3847 [==============================] - 0s 119us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00070: val_loss did not improve from 0.00251
# Model loaded
# mae :  5005.2565371823
# mse :  45664150.82920384
# rmse :  6757.525496008419
# std : 5501.186463367149
