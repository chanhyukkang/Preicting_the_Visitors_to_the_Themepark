# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# Using TensorFlow backend.
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0129 - val_loss: 0.0053
#
# Epoch 00001: val_loss improved from inf to 0.00530, saving model to LSTMmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 1s 333us/step - loss: 0.0111 - val_loss: 0.0050
#
# Epoch 00002: val_loss improved from 0.00530 to 0.00497, saving model to LSTMmodel.h5
# Epoch 3/100
# 3847/3847 [==============================] - 1s 338us/step - loss: 0.0097 - val_loss: 0.0056
#
# Epoch 00003: val_loss did not improve from 0.00497
# Epoch 4/100
# 3847/3847 [==============================] - 1s 336us/step - loss: 0.0097 - val_loss: 0.0047
#
# Epoch 00004: val_loss improved from 0.00497 to 0.00465, saving model to LSTMmodel.h5
# Epoch 5/100
# 3847/3847 [==============================] - 1s 340us/step - loss: 0.0094 - val_loss: 0.0048
#
# Epoch 00005: val_loss did not improve from 0.00465
# Epoch 6/100
# 3847/3847 [==============================] - 1s 341us/step - loss: 0.0093 - val_loss: 0.0045
#
# Epoch 00006: val_loss improved from 0.00465 to 0.00450, saving model to LSTMmodel.h5
# Epoch 7/100
# 3847/3847 [==============================] - 1s 362us/step - loss: 0.0093 - val_loss: 0.0050
#
# Epoch 00007: val_loss did not improve from 0.00450
# Epoch 8/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0094 - val_loss: 0.0051
#
# Epoch 00008: val_loss did not improve from 0.00450
# Epoch 9/100
# 3847/3847 [==============================] - 1s 378us/step - loss: 0.0093 - val_loss: 0.0047
#
# Epoch 00009: val_loss did not improve from 0.00450
# Epoch 10/100
# 3847/3847 [==============================] - 1s 390us/step - loss: 0.0093 - val_loss: 0.0044
#
# Epoch 00010: val_loss improved from 0.00450 to 0.00444, saving model to LSTMmodel.h5
# Epoch 11/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00011: val_loss did not improve from 0.00444
# Epoch 12/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0092 - val_loss: 0.0044
#
# Epoch 00012: val_loss improved from 0.00444 to 0.00443, saving model to LSTMmodel.h5
# Epoch 13/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0093 - val_loss: 0.0055
#
# Epoch 00013: val_loss did not improve from 0.00443
# Epoch 14/100
# 3847/3847 [==============================] - 2s 391us/step - loss: 0.0092 - val_loss: 0.0047
#
# Epoch 00014: val_loss did not improve from 0.00443
# Epoch 15/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0094 - val_loss: 0.0049
#
# Epoch 00015: val_loss did not improve from 0.00443
# Epoch 16/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00016: val_loss did not improve from 0.00443
# Epoch 17/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00017: val_loss did not improve from 0.00443
# Epoch 18/100
# 3847/3847 [==============================] - 1s 385us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00018: val_loss did not improve from 0.00443
# Epoch 19/100
# 3847/3847 [==============================] - 1s 376us/step - loss: 0.0091 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00443
# Epoch 20/100
# 3847/3847 [==============================] - 1s 388us/step - loss: 0.0091 - val_loss: 0.0046
#
# Epoch 00020: val_loss did not improve from 0.00443
# Epoch 21/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00021: val_loss did not improve from 0.00443
# Epoch 22/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00022: val_loss did not improve from 0.00443
# Epoch 23/100
# 3847/3847 [==============================] - 1s 383us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00023: val_loss did not improve from 0.00443
# Epoch 24/100
# 3847/3847 [==============================] - 1s 383us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00024: val_loss did not improve from 0.00443
# Epoch 25/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0091 - val_loss: 0.0053
#
# Epoch 00025: val_loss did not improve from 0.00443
# Epoch 26/100
# 3847/3847 [==============================] - 1s 383us/step - loss: 0.0091 - val_loss: 0.0051
#
# Epoch 00026: val_loss did not improve from 0.00443
# Epoch 27/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00027: val_loss did not improve from 0.00443
# Epoch 28/100
# 3847/3847 [==============================] - 1s 383us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00028: val_loss did not improve from 0.00443
# Epoch 29/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00029: val_loss did not improve from 0.00443
# Epoch 30/100
# 3847/3847 [==============================] - 1s 374us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00030: val_loss did not improve from 0.00443
# Epoch 31/100
# 3847/3847 [==============================] - 1s 382us/step - loss: 0.0091 - val_loss: 0.0054
#
# Epoch 00031: val_loss did not improve from 0.00443
# Epoch 32/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00032: val_loss did not improve from 0.00443
# Epoch 33/100
# 3847/3847 [==============================] - 2s 399us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00033: val_loss did not improve from 0.00443
# Epoch 34/100
# 3847/3847 [==============================] - 1s 383us/step - loss: 0.0091 - val_loss: 0.0048
#
# Epoch 00034: val_loss did not improve from 0.00443
# Epoch 35/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00035: val_loss did not improve from 0.00443
# Epoch 36/100
# 3847/3847 [==============================] - 1s 385us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00036: val_loss did not improve from 0.00443
# Epoch 37/100
# 3847/3847 [==============================] - 1s 388us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00037: val_loss did not improve from 0.00443
# Epoch 38/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00038: val_loss did not improve from 0.00443
# Epoch 39/100
# 3847/3847 [==============================] - 1s 385us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00039: val_loss did not improve from 0.00443
# Epoch 40/100
# 3847/3847 [==============================] - 2s 398us/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00040: val_loss did not improve from 0.00443
# Epoch 41/100
# 3847/3847 [==============================] - 1s 379us/step - loss: 0.0089 - val_loss: 0.0045
# Epoch 00041: val_loss did not improve from 0.00443
# Epoch 42/100
# 3847/3847 [==============================] - 2s 392us/step - loss: 0.0088 - val_loss: 0.0046
#
# Epoch 00042: val_loss did not improve from 0.00443
# Epoch 43/100
# 3847/3847 [==============================] - 2s 394us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00043: val_loss improved from 0.00443 to 0.00439, saving model to LSTMmodel.h5
# Epoch 44/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0088 - val_loss: 0.0046
#
# Epoch 00044: val_loss did not improve from 0.00439
# Epoch 45/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00045: val_loss did not improve from 0.00439
# Epoch 46/100
# 3847/3847 [==============================] - 1s 381us/step - loss: 0.0089 - val_loss: 0.0053
#
# Epoch 00046: val_loss did not improve from 0.00439
# Epoch 47/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0089 - val_loss: 0.0049
#
# Epoch 00047: val_loss did not improve from 0.00439
# Epoch 48/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00048: val_loss did not improve from 0.00439
# Epoch 49/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0088 - val_loss: 0.0047
#
# Epoch 00049: val_loss did not improve from 0.00439
# Epoch 50/100
# 3847/3847 [==============================] - 2s 419us/step - loss: 0.0088 - val_loss: 0.0044
#
# Epoch 00050: val_loss did not improve from 0.00439
# Epoch 51/100
# 3847/3847 [==============================] - 2s 421us/step - loss: 0.0089 - val_loss: 0.0048
#
# Epoch 00051: val_loss did not improve from 0.00439
# Epoch 52/100
# 3847/3847 [==============================] - 2s 404us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00052: val_loss did not improve from 0.00439
# Epoch 53/100
# 3847/3847 [==============================] - 2s 394us/step - loss: 0.0093 - val_loss: 0.0047
#
# Epoch 00053: val_loss did not improve from 0.00439
# Epoch 54/100
# 3847/3847 [==============================] - 2s 394us/step - loss: 0.0088 - val_loss: 0.0046
#
# Epoch 00054: val_loss did not improve from 0.00439
# Epoch 55/100
# 3847/3847 [==============================] - 2s 395us/step - loss: 0.0088 - val_loss: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.00439
# Epoch 56/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0088 - val_loss: 0.0048
#
# Epoch 00056: val_loss did not improve from 0.00439
# Epoch 57/100
# 3847/3847 [==============================] - 2s 396us/step - loss: 0.0087 - val_loss: 0.0048
#
# Epoch 00057: val_loss did not improve from 0.00439
# Epoch 58/100
# 3847/3847 [==============================] - 1s 386us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00058: val_loss did not improve from 0.00439
# Epoch 59/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00059: val_loss did not improve from 0.00439
# Epoch 60/100
# 3847/3847 [==============================] - 1s 376us/step - loss: 0.0088 - val_loss: 0.0046
#
# Epoch 00060: val_loss did not improve from 0.00439
# Epoch 61/100
# 3847/3847 [==============================] - 1s 374us/step - loss: 0.0087 - val_loss: 0.0044
#
# Epoch 00061: val_loss improved from 0.00439 to 0.00437, saving model to LSTMmodel.h5
# Epoch 62/100
# 3847/3847 [==============================] - 1s 372us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00062: val_loss did not improve from 0.00437
# Epoch 63/100
# 3847/3847 [==============================] - 1s 365us/step - loss: 0.0087 - val_loss: 0.0046
#
# Epoch 00063: val_loss did not improve from 0.00437
# Epoch 64/100
# 3847/3847 [==============================] - 1s 375us/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00064: val_loss did not improve from 0.00437
# Epoch 65/100
# 3847/3847 [==============================] - 2s 403us/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00065: val_loss did not improve from 0.00437
# Epoch 66/100
# 3847/3847 [==============================] - 2s 423us/step - loss: 0.0086 - val_loss: 0.0050
#
# Epoch 00066: val_loss did not improve from 0.00437
# Epoch 67/100
# 3847/3847 [==============================] - 2s 404us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00067: val_loss did not improve from 0.00437
# Epoch 68/100
# 3847/3847 [==============================] - 1s 388us/step - loss: 0.0087 - val_loss: 0.0044
#
# Epoch 00068: val_loss improved from 0.00437 to 0.00437, saving model to LSTMmodel.h5
# Epoch 69/100
# 3847/3847 [==============================] - 2s 398us/step - loss: 0.0086 - val_loss: 0.0048
#
# Epoch 00069: val_loss did not improve from 0.00437
# Epoch 70/100
# 3847/3847 [==============================] - 2s 391us/step - loss: 0.0085 - val_loss: 0.0044
#
# Epoch 00070: val_loss did not improve from 0.00437
# Epoch 71/100
# 3847/3847 [==============================] - 2s 392us/step - loss: 0.0084 - val_loss: 0.0045
#
# Epoch 00071: val_loss did not improve from 0.00437
# Epoch 72/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0083 - val_loss: 0.0051
#
# Epoch 00072: val_loss did not improve from 0.00437
# Epoch 73/100
# 3847/3847 [==============================] - 1s 384us/step - loss: 0.0082 - val_loss: 0.0047
#
# Epoch 00073: val_loss did not improve from 0.00437
# Epoch 74/100
# 3847/3847 [==============================] - 1s 387us/step - loss: 0.0081 - val_loss: 0.0045
#
# Epoch 00074: val_loss did not improve from 0.00437
# Epoch 75/100
# 3847/3847 [==============================] - 2s 392us/step - loss: 0.0075 - val_loss: 0.0042
#
# Epoch 00075: val_loss improved from 0.00437 to 0.00423, saving model to LSTMmodel.h5
# Epoch 76/100
# 3847/3847 [==============================] - 2s 393us/step - loss: 0.0074 - val_loss: 0.0045
#
# Epoch 00076: val_loss did not improve from 0.00423
# Epoch 77/100
# 3847/3847 [==============================] - 2s 394us/step - loss: 0.0072 - val_loss: 0.0042
#
# Epoch 00077: val_loss improved from 0.00423 to 0.00421, saving model to LSTMmodel.h5
# Epoch 78/100
# 3847/3847 [==============================] - 2s 395us/step - loss: 0.0070 - val_loss: 0.0054
#
# Epoch 00078: val_loss did not improve from 0.00421
# Epoch 79/100
# 3847/3847 [==============================] - 2s 419us/step - loss: 0.0073 - val_loss: 0.0042
#
# Epoch 00079: val_loss improved from 0.00421 to 0.00421, saving model to LSTMmodel.h5
# Epoch 80/100
# 3847/3847 [==============================] - 2s 413us/step - loss: 0.0069 - val_loss: 0.0043
#
# Epoch 00080: val_loss did not improve from 0.00421
# Epoch 81/100
# 3847/3847 [==============================] - 2s 392us/step - loss: 0.0071 - val_loss: 0.0041
#
# Epoch 00081: val_loss improved from 0.00421 to 0.00406, saving model to LSTMmodel.h5
# Epoch 82/100
# 3847/3847 [==============================] - 2s 393us/step - loss: 0.0068 - val_loss: 0.0039
#
# Epoch 00082: val_loss improved from 0.00406 to 0.00392, saving model to LSTMmodel.h5
# Epoch 83/100
# 3847/3847 [==============================] - 2s 395us/step - loss: 0.0069 - val_loss: 0.0046
#
# Epoch 00083: val_loss did not improve from 0.00392
# Epoch 84/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0068 - val_loss: 0.0042
#
# Epoch 00084: val_loss did not improve from 0.00392
# Epoch 85/100
# 3847/3847 [==============================] - 1s 375us/step - loss: 0.0068 - val_loss: 0.0042
#
# Epoch 00085: val_loss did not improve from 0.00392
# Epoch 86/100
# 3847/3847 [==============================] - 1s 376us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00086: val_loss did not improve from 0.00392
# Epoch 87/100
# 3847/3847 [==============================] - 1s 378us/step - loss: 0.0067 - val_loss: 0.0043
#
# Epoch 00087: val_loss did not improve from 0.00392
# Epoch 88/100
# 3847/3847 [==============================] - 1s 373us/step - loss: 0.0066 - val_loss: 0.0040
#
# Epoch 00088: val_loss did not improve from 0.00392
# Epoch 89/100
# 3847/3847 [==============================] - 1s 376us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00089: val_loss did not improve from 0.00392
# Epoch 90/100
# 3847/3847 [==============================] - 2s 394us/step - loss: 0.0066 - val_loss: 0.0041
#
# Epoch 00090: val_loss did not improve from 0.00392
# Epoch 91/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0066 - val_loss: 0.0044
#
# Epoch 00091: val_loss did not improve from 0.00392
# Epoch 92/100
# 3847/3847 [==============================] - 2s 400us/step - loss: 0.0066 - val_loss: 0.0043
#
# Epoch 00092: val_loss did not improve from 0.00392
# Epoch 93/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0065 - val_loss: 0.0042
#
# Epoch 00093: val_loss did not improve from 0.00392
# Epoch 94/100
# 3847/3847 [==============================] - 1s 388us/step - loss: 0.0064 - val_loss: 0.0040
#
# Epoch 00094: val_loss did not improve from 0.00392
# Epoch 95/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00095: val_loss did not improve from 0.00392
# Epoch 96/100
# 3847/3847 [==============================] - 2s 391us/step - loss: 0.0064 - val_loss: 0.0041
#
# Epoch 00096: val_loss did not improve from 0.00392
# Epoch 97/100
# 3847/3847 [==============================] - 2s 405us/step - loss: 0.0063 - val_loss: 0.0044
#
# Epoch 00097: val_loss did not improve from 0.00392
# Epoch 98/100
# 3847/3847 [==============================] - 2s 421us/step - loss: 0.0062 - val_loss: 0.0044
#
# Epoch 00098: val_loss did not improve from 0.00392
# Epoch 99/100
# 3847/3847 [==============================] - 1s 389us/step - loss: 0.0065 - val_loss: 0.0041
#
# Epoch 00099: val_loss did not improve from 0.00392
# Epoch 100/100
# 3847/3847 [==============================] - 1s 381us/step - loss: 0.0063 - val_loss: 0.0039
#
# Epoch 00100: val_loss did not improve from 0.00392
# Model loaded
# mae :  4428.795295219917
# mse :  46170323.270721264
# rmse :  6794.874779620392
# std : 6791.257236425007

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 7s 2ms/step - loss: 0.0135 - val_loss: 0.0060
#
# Epoch 00001: val_loss improved from inf to 0.00596, saving model to LSTMmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 2s 588us/step - loss: 0.0118 - val_loss: 0.0055
#
# Epoch 00002: val_loss improved from 0.00596 to 0.00549, saving model to LSTMmodel.h5
# Epoch 3/100
# 3847/3847 [==============================] - 2s 618us/step - loss: 0.0108 - val_loss: 0.0053
#
# Epoch 00003: val_loss improved from 0.00549 to 0.00531, saving model to LSTMmodel.h5
# Epoch 4/100
# 3847/3847 [==============================] - 2s 619us/step - loss: 0.0102 - val_loss: 0.0049
#
# Epoch 00004: val_loss improved from 0.00531 to 0.00492, saving model to LSTMmodel.h5
# Epoch 5/100
# 3847/3847 [==============================] - 2s 593us/step - loss: 0.0097 - val_loss: 0.0044
#
# Epoch 00005: val_loss improved from 0.00492 to 0.00440, saving model to LSTMmodel.h5
# Epoch 6/100
# 3847/3847 [==============================] - 2s 595us/step - loss: 0.0096 - val_loss: 0.0054
#
# Epoch 00006: val_loss did not improve from 0.00440
# Epoch 7/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0093 - val_loss: 0.0047
#
# Epoch 00007: val_loss did not improve from 0.00440
# Epoch 8/100
# 3847/3847 [==============================] - 2s 609us/step - loss: 0.0094 - val_loss: 0.0050
#
# Epoch 00008: val_loss did not improve from 0.00440
# Epoch 9/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0094 - val_loss: 0.0051
#
# Epoch 00009: val_loss did not improve from 0.00440
# Epoch 10/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0093 - val_loss: 0.0045
#
# Epoch 00010: val_loss did not improve from 0.00440
# Epoch 11/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0092 - val_loss: 0.0048
#
# Epoch 00011: val_loss did not improve from 0.00440
# Epoch 12/100
# 3847/3847 [==============================] - 2s 588us/step - loss: 0.0092 - val_loss: 0.0044
#
# Epoch 00012: val_loss did not improve from 0.00440
# Epoch 13/100
# 3847/3847 [==============================] - 2s 590us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00013: val_loss did not improve from 0.00440
# Epoch 14/100
# 3847/3847 [==============================] - 2s 586us/step - loss: 0.0092 - val_loss: 0.0044
#
# Epoch 00014: val_loss did not improve from 0.00440
# Epoch 15/100
# 3847/3847 [==============================] - 2s 592us/step - loss: 0.0091 - val_loss: 0.0052
#
# Epoch 00015: val_loss did not improve from 0.00440
# Epoch 16/100
# 3847/3847 [==============================] - 2s 589us/step - loss: 0.0095 - val_loss: 0.0044
#
# Epoch 00016: val_loss improved from 0.00440 to 0.00439, saving model to LSTMmodel.h5
# Epoch 17/100
# 3847/3847 [==============================] - 2s 589us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00017: val_loss did not improve from 0.00439
# Epoch 18/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0091 - val_loss: 0.0049
#
# Epoch 00018: val_loss did not improve from 0.00439
# Epoch 19/100
# 3847/3847 [==============================] - 2s 584us/step - loss: 0.0092 - val_loss: 0.0047
#
# Epoch 00019: val_loss did not improve from 0.00439
# Epoch 20/100
# 3847/3847 [==============================] - 2s 585us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00020: val_loss did not improve from 0.00439
# Epoch 21/100
# 3847/3847 [==============================] - 2s 585us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00021: val_loss improved from 0.00439 to 0.00437, saving model to LSTMmodel.h5
# Epoch 22/100
# 3847/3847 [==============================] - 2s 582us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00022: val_loss did not improve from 0.00437
# Epoch 23/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0090 - val_loss: 0.0051
#
# Epoch 00023: val_loss did not improve from 0.00437
# Epoch 24/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00024: val_loss improved from 0.00437 to 0.00437, saving model to LSTMmodel.h5
# Epoch 25/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00025: val_loss did not improve from 0.00437
# Epoch 26/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00026: val_loss did not improve from 0.00437
# Epoch 27/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00027: val_loss did not improve from 0.00437
# Epoch 28/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00028: val_loss did not improve from 0.00437
# Epoch 29/100
# 3847/3847 [==============================] - 2s 573us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00029: val_loss did not improve from 0.00437
# Epoch 30/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00030: val_loss did not improve from 0.00437
# Epoch 31/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00031: val_loss did not improve from 0.00437
# Epoch 32/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0091 - val_loss: 0.0051
#
# Epoch 00032: val_loss did not improve from 0.00437
# Epoch 33/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00033: val_loss did not improve from 0.00437
# Epoch 34/100
# 3847/3847 [==============================] - 2s 572us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00034: val_loss did not improve from 0.00437
# Epoch 35/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00035: val_loss did not improve from 0.00437
# Epoch 36/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0089 - val_loss: 0.0048
#
# Epoch 00036: val_loss did not improve from 0.00437
# Epoch 37/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0089 - val_loss: 0.0054
#
# Epoch 00037: val_loss did not improve from 0.00437
# Epoch 38/100
# 3847/3847 [==============================] - 2s 579us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00038: val_loss did not improve from 0.00437
# Epoch 39/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00039: val_loss did not improve from 0.00437
# Epoch 40/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00040: val_loss improved from 0.00437 to 0.00433, saving model to LSTMmodel.h5
# Epoch 41/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00041: val_loss did not improve from 0.00433
# Epoch 42/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00042: val_loss did not improve from 0.00433
# Epoch 43/100
# 3847/3847 [==============================] - 2s 573us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00043: val_loss did not improve from 0.00433
# Epoch 44/100
# 3847/3847 [==============================] - 2s 575us/step - loss: 0.0090 - val_loss: 0.0050
#
# Epoch 00044: val_loss did not improve from 0.00433
# Epoch 45/100
# 3847/3847 [==============================] - 2s 571us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00045: val_loss did not improve from 0.00433
# Epoch 46/100
# 3847/3847 [==============================] - 2s 571us/step - loss: 0.0089 - val_loss: 0.0049
#
# Epoch 00046: val_loss did not improve from 0.00433
# Epoch 47/100
# 3847/3847 [==============================] - 2s 575us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00047: val_loss did not improve from 0.00433
# Epoch 48/100
# 3847/3847 [==============================] - 2s 588us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00048: val_loss did not improve from 0.00433
# Epoch 49/100
# 3847/3847 [==============================] - 2s 594us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00049: val_loss did not improve from 0.00433
# Epoch 50/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0089 - val_loss: 0.0044
# Epoch 00050: val_loss did not improve from 0.00433
# Epoch 51/100
# 3847/3847 [==============================] - 2s 570us/step - loss: 0.0088 - val_loss: 0.0047
#
# Epoch 00051: val_loss did not improve from 0.00433
# Epoch 52/100
# 3847/3847 [==============================] - 2s 624us/step - loss: 0.0088 - val_loss: 0.0044
#
# Epoch 00052: val_loss did not improve from 0.00433
# Epoch 53/100
# 3847/3847 [==============================] - 2s 627us/step - loss: 0.0088 - val_loss: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.00433
# Epoch 54/100
# 3847/3847 [==============================] - 2s 601us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00054: val_loss did not improve from 0.00433
# Epoch 55/100
# 3847/3847 [==============================] - 2s 584us/step - loss: 0.0090 - val_loss: 0.0048
#
# Epoch 00055: val_loss did not improve from 0.00433
# Epoch 56/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0088 - val_loss: 0.0049
#
# Epoch 00056: val_loss did not improve from 0.00433
# Epoch 57/100
# 3847/3847 [==============================] - 2s 593us/step - loss: 0.0087 - val_loss: 0.0048
#
# Epoch 00057: val_loss did not improve from 0.00433
# Epoch 58/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0087 - val_loss: 0.0055
#
# Epoch 00058: val_loss did not improve from 0.00433
# Epoch 59/100
# 3847/3847 [==============================] - 2s 586us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00059: val_loss did not improve from 0.00433
# Epoch 60/100
# 3847/3847 [==============================] - 2s 605us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00060: val_loss did not improve from 0.00433
# Epoch 61/100
# 3847/3847 [==============================] - 2s 612us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00061: val_loss improved from 0.00433 to 0.00430, saving model to LSTMmodel.h5
# Epoch 62/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00062: val_loss did not improve from 0.00430
# Epoch 63/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0087 - val_loss: 0.0046
#
# Epoch 00063: val_loss did not improve from 0.00430
# Epoch 64/100
# 3847/3847 [==============================] - 2s 586us/step - loss: 0.0087 - val_loss: 0.0043
#
# Epoch 00064: val_loss did not improve from 0.00430
# Epoch 65/100
# 3847/3847 [==============================] - 2s 609us/step - loss: 0.0087 - val_loss: 0.0043
#
# Epoch 00065: val_loss did not improve from 0.00430
# Epoch 66/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00066: val_loss did not improve from 0.00430
# Epoch 67/100
# 3847/3847 [==============================] - 2s 594us/step - loss: 0.0086 - val_loss: 0.0046
#
# Epoch 00067: val_loss did not improve from 0.00430
# Epoch 68/100
# 3847/3847 [==============================] - 2s 586us/step - loss: 0.0086 - val_loss: 0.0047
#
# Epoch 00068: val_loss did not improve from 0.00430
# Epoch 69/100
# 3847/3847 [==============================] - 2s 585us/step - loss: 0.0086 - val_loss: 0.0045
#
# Epoch 00069: val_loss did not improve from 0.00430
# Epoch 70/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0086 - val_loss: 0.0044
#
# Epoch 00070: val_loss did not improve from 0.00430
# Epoch 71/100
# 3847/3847 [==============================] - 2s 579us/step - loss: 0.0086 - val_loss: 0.0042
#
# Epoch 00071: val_loss improved from 0.00430 to 0.00420, saving model to LSTMmodel.h5
# Epoch 72/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0087 - val_loss: 0.0042
#
# Epoch 00072: val_loss did not improve from 0.00420
# Epoch 73/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0084 - val_loss: 0.0045
#
# Epoch 00073: val_loss did not improve from 0.00420
# Epoch 74/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0084 - val_loss: 0.0041
#
# Epoch 00074: val_loss improved from 0.00420 to 0.00412, saving model to LSTMmodel.h5
# Epoch 75/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0085 - val_loss: 0.0045
#
# Epoch 00075: val_loss did not improve from 0.00412
# Epoch 76/100
# 3847/3847 [==============================] - 2s 593us/step - loss: 0.0084 - val_loss: 0.0043
#
# Epoch 00076: val_loss did not improve from 0.00412
# Epoch 77/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0082 - val_loss: 0.0053
#
# Epoch 00077: val_loss did not improve from 0.00412
# Epoch 78/100
# 3847/3847 [==============================] - 2s 579us/step - loss: 0.0081 - val_loss: 0.0042
#
# Epoch 00078: val_loss did not improve from 0.00412
# Epoch 79/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0080 - val_loss: 0.0051
#
# Epoch 00079: val_loss did not improve from 0.00412
# Epoch 80/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0079 - val_loss: 0.0043
#
# Epoch 00080: val_loss did not improve from 0.00412
# Epoch 81/100
# 3847/3847 [==============================] - 2s 579us/step - loss: 0.0076 - val_loss: 0.0041
#
# Epoch 00081: val_loss improved from 0.00412 to 0.00407, saving model to LSTMmodel.h5
# Epoch 82/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0075 - val_loss: 0.0044
#
# Epoch 00082: val_loss did not improve from 0.00407
# Epoch 83/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0074 - val_loss: 0.0049
#
# Epoch 00083: val_loss did not improve from 0.00407
# Epoch 84/100
# 3847/3847 [==============================] - 2s 582us/step - loss: 0.0072 - val_loss: 0.0038
#
# Epoch 00084: val_loss improved from 0.00407 to 0.00384, saving model to LSTMmodel.h5
# Epoch 85/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0074 - val_loss: 0.0040
#
# Epoch 00085: val_loss did not improve from 0.00384
# Epoch 86/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0072 - val_loss: 0.0044
#
# Epoch 00086: val_loss did not improve from 0.00384
# Epoch 87/100
# 3847/3847 [==============================] - 2s 578us/step - loss: 0.0071 - val_loss: 0.0040
#
# Epoch 00087: val_loss did not improve from 0.00384
# Epoch 88/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0070 - val_loss: 0.0042
#
# Epoch 00088: val_loss did not improve from 0.00384
# Epoch 89/100
# 3847/3847 [==============================] - 2s 627us/step - loss: 0.0069 - val_loss: 0.0041
#
# Epoch 00089: val_loss did not improve from 0.00384
# Epoch 90/100
# 3847/3847 [==============================] - 2s 640us/step - loss: 0.0069 - val_loss: 0.0040
#
# Epoch 00090: val_loss did not improve from 0.00384
# Epoch 91/100
# 3847/3847 [==============================] - 2s 611us/step - loss: 0.0069 - val_loss: 0.0040
#
# Epoch 00091: val_loss did not improve from 0.00384
# Epoch 92/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0069 - val_loss: 0.0039
#
# Epoch 00092: val_loss did not improve from 0.00384
# Epoch 93/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0068 - val_loss: 0.0045
#
# Epoch 00093: val_loss did not improve from 0.00384
# Epoch 94/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0069 - val_loss: 0.0040
#
# Epoch 00094: val_loss did not improve from 0.00384
# Epoch 95/100
# 3847/3847 [==============================] - 2s 646us/step - loss: 0.0066 - val_loss: 0.0042
#
# Epoch 00095: val_loss did not improve from 0.00384
# Epoch 96/100
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0067 - val_loss: 0.0038
#
# Epoch 00096: val_loss improved from 0.00384 to 0.00381, saving model to LSTMmodel.h5
# Epoch 97/100
# 3847/3847 [==============================] - 2s 608us/step - loss: 0.0067 - val_loss: 0.0040
#
# Epoch 00097: val_loss did not improve from 0.00381
# Epoch 98/100
# 3847/3847 [==============================] - 2s 583us/step - loss: 0.0067 - val_loss: 0.0042
#
# Epoch 00098: val_loss did not improve from 0.00381
# Epoch 99/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0068 - val_loss: 0.0042
#
# Epoch 00099: val_loss did not improve from 0.00381
# Epoch 100/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0066 - val_loss: 0.0039
#
# Epoch 00100: val_loss did not improve from 0.00381
# Model loaded
# mae :  4582.166459517045
# mse :  43640895.40947326
# rmse :  6606.125597464315
# std : 6559.0845545607635

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0127 - val_loss: 0.0056
#
# Epoch 00001: val_loss improved from inf to 0.00563, saving model to LSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 657us/step - loss: 0.0105 - val_loss: 0.0050
#
# Epoch 00002: val_loss improved from 0.00563 to 0.00499, saving model to LSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 2s 647us/step - loss: 0.0099 - val_loss: 0.0045
#
# Epoch 00003: val_loss improved from 0.00499 to 0.00449, saving model to LSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 2s 648us/step - loss: 0.0096 - val_loss: 0.0048
#
# Epoch 00004: val_loss did not improve from 0.00449
# Epoch 5/70
# 3847/3847 [==============================] - 3s 650us/step - loss: 0.0096 - val_loss: 0.0057
#
# Epoch 00005: val_loss did not improve from 0.00449
# Epoch 6/70
# 3847/3847 [==============================] - 2s 648us/step - loss: 0.0094 - val_loss: 0.0049
#
# Epoch 00006: val_loss did not improve from 0.00449
# Epoch 7/70
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0093 - val_loss: 0.0051
#
# Epoch 00007: val_loss did not improve from 0.00449
# Epoch 8/70
# 3847/3847 [==============================] - 3s 657us/step - loss: 0.0093 - val_loss: 0.0044
#
# Epoch 00008: val_loss improved from 0.00449 to 0.00440, saving model to LSTMmodel.h5
# Epoch 9/70
# 3847/3847 [==============================] - 3s 652us/step - loss: 0.0096 - val_loss: 0.0052
#
# Epoch 00009: val_loss did not improve from 0.00440
# Epoch 10/70
# 3847/3847 [==============================] - 3s 652us/step - loss: 0.0093 - val_loss: 0.0051
#
# Epoch 00010: val_loss did not improve from 0.00440
# Epoch 11/70
# 3847/3847 [==============================] - 2s 647us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00011: val_loss did not improve from 0.00440
# Epoch 12/70
# 3847/3847 [==============================] - 3s 653us/step - loss: 0.0095 - val_loss: 0.0049
#
# Epoch 00012: val_loss did not improve from 0.00440
# Epoch 13/70
# 3847/3847 [==============================] - 3s 650us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00013: val_loss did not improve from 0.00440
# Epoch 14/70
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00014: val_loss did not improve from 0.00440
# Epoch 15/70
# 3847/3847 [==============================] - 3s 667us/step - loss: 0.0094 - val_loss: 0.0047
#
# Epoch 00015: val_loss did not improve from 0.00440
# Epoch 16/70
# 3847/3847 [==============================] - 3s 659us/step - loss: 0.0092 - val_loss: 0.0054
#
# Epoch 00016: val_loss did not improve from 0.00440
# Epoch 17/70
# 3847/3847 [==============================] - 3s 692us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00017: val_loss did not improve from 0.00440
# Epoch 18/70
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0093 - val_loss: 0.0052
#
# Epoch 00018: val_loss did not improve from 0.00440
# Epoch 19/70
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00019: val_loss did not improve from 0.00440
# Epoch 20/70
# 3847/3847 [==============================] - 3s 705us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00020: val_loss did not improve from 0.00440
# Epoch 21/70
# 3847/3847 [==============================] - 3s 707us/step - loss: 0.0090 - val_loss: 0.0050
#
# Epoch 00021: val_loss did not improve from 0.00440
# Epoch 22/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00022: val_loss did not improve from 0.00440
# Epoch 23/70
# 3847/3847 [==============================] - 3s 706us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00023: val_loss improved from 0.00440 to 0.00438, saving model to LSTMmodel.h5
# Epoch 24/70
# 3847/3847 [==============================] - 3s 706us/step - loss: 0.0091 - val_loss: 0.0051
#
# Epoch 00024: val_loss did not improve from 0.00438
# Epoch 25/70
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0091 - val_loss: 0.0043
#
# Epoch 00025: val_loss improved from 0.00438 to 0.00430, saving model to LSTMmodel.h5
# Epoch 26/70
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00026: val_loss did not improve from 0.00430
# Epoch 27/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00027: val_loss did not improve from 0.00430
# Epoch 28/70
# 3847/3847 [==============================] - 3s 716us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00028: val_loss did not improve from 0.00430
# Epoch 29/70
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0092 - val_loss: 0.0048
#
# Epoch 00029: val_loss did not improve from 0.00430
# Epoch 30/70
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0090 - val_loss: 0.0050
#
# Epoch 00030: val_loss did not improve from 0.00430
# Epoch 31/70
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00031: val_loss did not improve from 0.00430
# Epoch 32/70
# 3847/3847 [==============================] - 3s 711us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00032: val_loss improved from 0.00430 to 0.00426, saving model to LSTMmodel.h5
# Epoch 33/70
# 3847/3847 [==============================] - 3s 718us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00033: val_loss did not improve from 0.00426
# Epoch 34/70
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0088 - val_loss: 0.0046
#
# Epoch 00034: val_loss did not improve from 0.00426
# Epoch 35/70
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0087 - val_loss: 0.0045
#
# Epoch 00035: val_loss did not improve from 0.00426
# Epoch 36/70
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0086 - val_loss: 0.0044
#
# Epoch 00036: val_loss did not improve from 0.00426
# Epoch 37/70
# 3847/3847 [==============================] - 3s 711us/step - loss: 0.0085 - val_loss: 0.0046
#
# Epoch 00037: val_loss did not improve from 0.00426
# Epoch 38/70
# 3847/3847 [==============================] - 3s 720us/step - loss: 0.0086 - val_loss: 0.0044
#
# Epoch 00038: val_loss did not improve from 0.00426
# Epoch 39/70
# 3847/3847 [==============================] - 3s 720us/step - loss: 0.0083 - val_loss: 0.0044
#
# Epoch 00039: val_loss did not improve from 0.00426
# Epoch 40/70
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0079 - val_loss: 0.0040
#
# Epoch 00040: val_loss improved from 0.00426 to 0.00399, saving model to LSTMmodel.h5
# Epoch 41/70
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0076 - val_loss: 0.0047
#
# Epoch 00041: val_loss did not improve from 0.00399
# Epoch 42/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0074 - val_loss: 0.0054
#
# Epoch 00042: val_loss did not improve from 0.00399
# Epoch 43/70
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0072 - val_loss: 0.0040
#
# Epoch 00043: val_loss did not improve from 0.00399
# Epoch 44/70
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0072 - val_loss: 0.0045
#
# Epoch 00044: val_loss did not improve from 0.00399
# Epoch 45/70
# 3847/3847 [==============================] - 3s 849us/step - loss: 0.0072 - val_loss: 0.0043
#
# Epoch 00045: val_loss did not improve from 0.00399
# Epoch 46/70
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0070 - val_loss: 0.0046
#
# Epoch 00046: val_loss did not improve from 0.00399
# Epoch 47/70
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0069 - val_loss: 0.0051
#
# Epoch 00047: val_loss did not improve from 0.00399
# Epoch 48/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0069 - val_loss: 0.0042
#
# Epoch 00048: val_loss did not improve from 0.00399
# Epoch 49/70
# 3847/3847 [==============================] - 3s 723us/step - loss: 0.0069 - val_loss: 0.0044
#
# Epoch 00049: val_loss did not improve from 0.00399
# Epoch 50/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0070 - val_loss: 0.0040
#
# Epoch 00050: val_loss did not improve from 0.00399
# Epoch 51/70
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0069 - val_loss: 0.0047
#
# Epoch 00051: val_loss did not improve from 0.00399
# Epoch 52/70
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0068 - val_loss: 0.0047
#
# Epoch 00052: val_loss did not improve from 0.00399
# Epoch 53/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0069 - val_loss: 0.0046
#
# Epoch 00053: val_loss did not improve from 0.00399
# Epoch 54/70
# 3847/3847 [==============================] - 3s 706us/step - loss: 0.0068 - val_loss: 0.0045
#
# Epoch 00054: val_loss did not improve from 0.00399
# Epoch 55/70
# 3847/3847 [==============================] - 3s 706us/step - loss: 0.0067 - val_loss: 0.0040
#
# Epoch 00055: val_loss improved from 0.00399 to 0.00398, saving model to LSTMmodel.h5
# Epoch 56/70
# 3847/3847 [==============================] - 3s 703us/step - loss: 0.0067 - val_loss: 0.0045
#
# Epoch 00056: val_loss did not improve from 0.00398
# Epoch 57/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0069 - val_loss: 0.0041
#
# Epoch 00057: val_loss did not improve from 0.00398
# Epoch 58/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00058: val_loss did not improve from 0.00398
# Epoch 59/70
# 3847/3847 [==============================] - 3s 703us/step - loss: 0.0066 - val_loss: 0.0046
#
# Epoch 00059: val_loss did not improve from 0.00398
# Epoch 60/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0068 - val_loss: 0.0043
#
# Epoch 00060: val_loss did not improve from 0.00398
# Epoch 61/70
# 3847/3847 [==============================] - 3s 702us/step - loss: 0.0067 - val_loss: 0.0053
#
# Epoch 00061: val_loss did not improve from 0.00398
# Epoch 62/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0066 - val_loss: 0.0039
#
# Epoch 00062: val_loss improved from 0.00398 to 0.00389, saving model to LSTMmodel.h5
# Epoch 63/70
# 3847/3847 [==============================] - 3s 701us/step - loss: 0.0066 - val_loss: 0.0041
#
# Epoch 00063: val_loss did not improve from 0.00389
# Epoch 64/70
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00064: val_loss did not improve from 0.00389
# Epoch 65/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0066 - val_loss: 0.0043
#
# Epoch 00065: val_loss did not improve from 0.00389
# Epoch 66/70
# 3847/3847 [==============================] - 3s 705us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00066: val_loss did not improve from 0.00389
# Epoch 67/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0066 - val_loss: 0.0040
#
# Epoch 00067: val_loss did not improve from 0.00389
# Epoch 68/70
# 3847/3847 [==============================] - 3s 704us/step - loss: 0.0066 - val_loss: 0.0041
#
# Epoch 00068: val_loss did not improve from 0.00389
# Epoch 69/70
# 3847/3847 [==============================] - 3s 705us/step - loss: 0.0065 - val_loss: 0.0047
#
# Epoch 00069: val_loss did not improve from 0.00389
# Epoch 70/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0065 - val_loss: 0.0045
#
# Epoch 00070: val_loss did not improve from 0.00389
# Model loaded
# mae :  4599.520798244724
# mse :  48288520.21125752
# rmse :  6948.9941870214225
# std : 6925.063216949562

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 7s 2ms/step - loss: 0.0118 - val_loss: 0.0050
#
# Epoch 00001: val_loss improved from inf to 0.00499, saving model to LSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 683us/step - loss: 0.0100 - val_loss: 0.0051
#
# Epoch 00002: val_loss did not improve from 0.00499
# Epoch 3/70
# 3847/3847 [==============================] - 3s 672us/step - loss: 0.0102 - val_loss: 0.0048
#
# Epoch 00003: val_loss improved from 0.00499 to 0.00480, saving model to LSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 682us/step - loss: 0.0097 - val_loss: 0.0052
#
# Epoch 00004: val_loss did not improve from 0.00480
# Epoch 5/70
# 3847/3847 [==============================] - 3s 671us/step - loss: 0.0096 - val_loss: 0.0051
#
# Epoch 00005: val_loss did not improve from 0.00480
# Epoch 6/70
# 3847/3847 [==============================] - 3s 676us/step - loss: 0.0094 - val_loss: 0.0045
#
# Epoch 00006: val_loss improved from 0.00480 to 0.00448, saving model to LSTMmodel.h5
# Epoch 7/70
# 3847/3847 [==============================] - 3s 672us/step - loss: 0.0095 - val_loss: 0.0052
#
# Epoch 00007: val_loss did not improve from 0.00448
# Epoch 8/70
# 3847/3847 [==============================] - 3s 667us/step - loss: 0.0094 - val_loss: 0.0054
#
# Epoch 00008: val_loss did not improve from 0.00448
# Epoch 9/70
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0093 - val_loss: 0.0051
#
# Epoch 00009: val_loss did not improve from 0.00448
# Epoch 10/70
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0096 - val_loss: 0.0046
#
# Epoch 00010: val_loss did not improve from 0.00448
# Epoch 11/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0094 - val_loss: 0.0046
#
# Epoch 00011: val_loss did not improve from 0.00448
# Epoch 12/70
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00012: val_loss did not improve from 0.00448
# Epoch 13/70
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0092 - val_loss: 0.0050
#
# Epoch 00013: val_loss did not improve from 0.00448
# Epoch 14/70
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00014: val_loss improved from 0.00448 to 0.00446, saving model to LSTMmodel.h5
# Epoch 15/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0092 - val_loss: 0.0050
#
# Epoch 00015: val_loss did not improve from 0.00446
# Epoch 16/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0094 - val_loss: 0.0047
#
# Epoch 00016: val_loss did not improve from 0.00446
# Epoch 17/70
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00017: val_loss did not improve from 0.00446
# Epoch 18/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00018: val_loss did not improve from 0.00446
# Epoch 19/70
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00019: val_loss did not improve from 0.00446
# Epoch 20/70
# 3847/3847 [==============================] - 3s 730us/step - loss: 0.0091 - val_loss: 0.0046
#
# Epoch 00020: val_loss did not improve from 0.00446
# Epoch 21/70
# 3847/3847 [==============================] - 3s 727us/step - loss: 0.0091 - val_loss: 0.0048
#
# Epoch 00021: val_loss did not improve from 0.00446
# Epoch 22/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00022: val_loss did not improve from 0.00446
# Epoch 23/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0091 - val_loss: 0.0043
#
# Epoch 00023: val_loss improved from 0.00446 to 0.00433, saving model to LSTMmodel.h5
# Epoch 24/70
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0091 - val_loss: 0.0054
#
# Epoch 00024: val_loss did not improve from 0.00433
# Epoch 25/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0092 - val_loss: 0.0050
#
# Epoch 00025: val_loss did not improve from 0.00433
# Epoch 26/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00026: val_loss did not improve from 0.00433
# Epoch 27/70
# 3847/3847 [==============================] - 3s 724us/step - loss: 0.0092 - val_loss: 0.0044
#
# Epoch 00027: val_loss did not improve from 0.00433
# Epoch 28/70
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0093 - val_loss: 0.0046
#
# Epoch 00028: val_loss did not improve from 0.00433
# Epoch 29/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0091 - val_loss: 0.0048
#
# Epoch 00029: val_loss did not improve from 0.00433
# Epoch 30/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0089 - val_loss: 0.0045
#
# Epoch 00030: val_loss did not improve from 0.00433
# Epoch 31/70
# 3847/3847 [==============================] - 3s 716us/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00031: val_loss did not improve from 0.00433
# Epoch 32/70
# 3847/3847 [==============================] - 3s 718us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00032: val_loss did not improve from 0.00433
# Epoch 33/70
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00033: val_loss did not improve from 0.00433
# Epoch 34/70
# 3847/3847 [==============================] - 3s 724us/step - loss: 0.0090 - val_loss: 0.0045
#
# Epoch 00034: val_loss did not improve from 0.00433
# Epoch 35/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00035: val_loss did not improve from 0.00433
# Epoch 36/70
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0091 - val_loss: 0.0060
#
# Epoch 00036: val_loss did not improve from 0.00433
# Epoch 37/70
# 3847/3847 [==============================] - 3s 720us/step - loss: 0.0089 - val_loss: 0.0048
#
# Epoch 00037: val_loss did not improve from 0.00433
# Epoch 38/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00038: val_loss did not improve from 0.00433
# Epoch 39/70
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00039: val_loss improved from 0.00433 to 0.00430, saving model to LSTMmodel.h5
# Epoch 40/70
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0090 - val_loss: 0.0047
#
# Epoch 00040: val_loss did not improve from 0.00430
# Epoch 41/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00041: val_loss did not improve from 0.00430
# Epoch 42/70
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00042: val_loss did not improve from 0.00430
# Epoch 43/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0089 - val_loss: 0.0045
#
# Epoch 00043: val_loss did not improve from 0.00430
# Epoch 44/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0088 - val_loss: 0.0044
#
# Epoch 00044: val_loss did not improve from 0.00430
# Epoch 45/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0089 - val_loss: 0.0049
#
# Epoch 00045: val_loss did not improve from 0.00430
# Epoch 46/70
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0090 - val_loss: 0.0057
#
# Epoch 00046: val_loss did not improve from 0.00430
# Epoch 47/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0091 - val_loss: 0.0046
#
# Epoch 00047: val_loss did not improve from 0.00430
# Epoch 48/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0088 - val_loss: 0.0044
#
# Epoch 00048: val_loss did not improve from 0.00430
# Epoch 49/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00049: val_loss did not improve from 0.00430
# Epoch 50/70
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0089 - val_loss: 0.0042
#
# Epoch 00050: val_loss improved from 0.00430 to 0.00423, saving model to LSTMmodel.h5
# Epoch 51/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0086 - val_loss: 0.0042
#
# Epoch 00051: val_loss improved from 0.00423 to 0.00422, saving model to LSTMmodel.h5
# Epoch 52/70
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0086 - val_loss: 0.0050
#
# Epoch 00052: val_loss did not improve from 0.00422
# Epoch 53/70
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0082 - val_loss: 0.0043
#
# Epoch 00053: val_loss did not improve from 0.00422
# Epoch 54/70
# 3847/3847 [==============================] - 3s 726us/step - loss: 0.0075 - val_loss: 0.0040
#
# Epoch 00054: val_loss improved from 0.00422 to 0.00402, saving model to LSTMmodel.h5
# Epoch 55/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0073 - val_loss: 0.0043
#
# Epoch 00055: val_loss did not improve from 0.00402
# Epoch 56/70
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0071 - val_loss: 0.0041
#
# Epoch 00056: val_loss did not improve from 0.00402
# Epoch 57/70
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0070 - val_loss: 0.0039
#
# Epoch 00057: val_loss improved from 0.00402 to 0.00390, saving model to LSTMmodel.h5
# Epoch 58/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0069 - val_loss: 0.0039
#
# Epoch 00058: val_loss improved from 0.00390 to 0.00386, saving model to LSTMmodel.h5
# Epoch 59/70
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0069 - val_loss: 0.0042
#
# Epoch 00059: val_loss did not improve from 0.00386
# Epoch 60/70
# 3847/3847 [==============================] - 3s 727us/step - loss: 0.0068 - val_loss: 0.0038
#
# Epoch 00060: val_loss improved from 0.00386 to 0.00379, saving model to LSTMmodel.h5
# Epoch 61/70
# 3847/3847 [==============================] - 3s 733us/step - loss: 0.0069 - val_loss: 0.0040
#
# Epoch 00061: val_loss did not improve from 0.00379
# Epoch 62/70
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0069 - val_loss: 0.0038
#
# Epoch 00062: val_loss did not improve from 0.00379
# Epoch 63/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00063: val_loss did not improve from 0.00379
# Epoch 64/70
# 3847/3847 [==============================] - 3s 730us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00064: val_loss did not improve from 0.00379
# Epoch 65/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0067 - val_loss: 0.0042
#
# Epoch 00065: val_loss did not improve from 0.00379
# Epoch 66/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0068 - val_loss: 0.0041
#
# Epoch 00066: val_loss did not improve from 0.00379
# Epoch 67/70
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0066 - val_loss: 0.0039
#
# Epoch 00067: val_loss did not improve from 0.00379
# Epoch 68/70
# 3847/3847 [==============================] - 3s 732us/step - loss: 0.0066 - val_loss: 0.0045
#
# Epoch 00068: val_loss did not improve from 0.00379
# Epoch 69/70
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0066 - val_loss: 0.0037
#
# Epoch 00069: val_loss improved from 0.00379 to 0.00369, saving model to LSTMmodel.h5
# Epoch 70/70
# 3847/3847 [==============================] - 3s 730us/step - loss: 0.0068 - val_loss: 0.0037
#
# Epoch 00070: val_loss improved from 0.00369 to 0.00369, saving model to LSTMmodel.h5
# Model loaded
# mae :  4853.828725522524
# mse :  48031807.57072736
# rmse :  6930.4983638067015
# std : 6859.680765514118

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 8s 2ms/step - loss: 0.0118 - val_loss: 0.0047
#
# Epoch 00001: val_loss improved from inf to 0.00469, saving model to LSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 699us/step - loss: 0.0099 - val_loss: 0.0048
#
# Epoch 00002: val_loss did not improve from 0.00469
# Epoch 3/70
# 3847/3847 [==============================] - 3s 690us/step - loss: 0.0096 - val_loss: 0.0046
#
# Epoch 00003: val_loss improved from 0.00469 to 0.00456, saving model to LSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 690us/step - loss: 0.0097 - val_loss: 0.0050
#
# Epoch 00004: val_loss did not improve from 0.00456
# Epoch 5/70
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0094 - val_loss: 0.0047
#
# Epoch 00005: val_loss did not improve from 0.00456
# Epoch 6/70
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0094 - val_loss: 0.0050
#
# Epoch 00006: val_loss did not improve from 0.00456
# Epoch 7/70
# 3847/3847 [==============================] - 3s 688us/step - loss: 0.0094 - val_loss: 0.0046
#
# Epoch 00007: val_loss did not improve from 0.00456
# Epoch 8/70
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0094 - val_loss: 0.0048
#
# Epoch 00008: val_loss did not improve from 0.00456
# Epoch 9/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0094 - val_loss: 0.0045
#
# Epoch 00009: val_loss improved from 0.00456 to 0.00453, saving model to LSTMmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0094 - val_loss: 0.0054
#
# Epoch 00010: val_loss did not improve from 0.00453
# Epoch 11/70
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0094 - val_loss: 0.0059
#
# Epoch 00011: val_loss did not improve from 0.00453
# Epoch 12/70
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0093 - val_loss: 0.0045
#
# Epoch 00012: val_loss did not improve from 0.00453
# Epoch 13/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0093 - val_loss: 0.0046
#
# Epoch 00013: val_loss did not improve from 0.00453
# Epoch 14/70
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00014: val_loss improved from 0.00453 to 0.00446, saving model to LSTMmodel.h5
# Epoch 15/70
# 3847/3847 [==============================] - 3s 741us/step - loss: 0.0094 - val_loss: 0.0050
#
# Epoch 00015: val_loss did not improve from 0.00446
# Epoch 16/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00016: val_loss did not improve from 0.00446
# Epoch 17/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0093 - val_loss: 0.0049
#
# Epoch 00017: val_loss did not improve from 0.00446
# Epoch 18/70
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00018: val_loss did not improve from 0.00446
# Epoch 19/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0092 - val_loss: 0.0054
#
# Epoch 00019: val_loss did not improve from 0.00446
# Epoch 20/70
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0093 - val_loss: 0.0050
#
# Epoch 00020: val_loss did not improve from 0.00446
# Epoch 21/70
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00021: val_loss did not improve from 0.00446
# Epoch 22/70
# 3847/3847 [==============================] - 3s 764us/step - loss: 0.0090 - val_loss: 0.0046
#
# Epoch 00022: val_loss did not improve from 0.00446
# Epoch 23/70
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0093 - val_loss: 0.0045
#
# Epoch 00023: val_loss did not improve from 0.00446
# Epoch 24/70
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00024: val_loss did not improve from 0.00446
# Epoch 25/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00025: val_loss improved from 0.00446 to 0.00439, saving model to LSTMmodel.h5
# Epoch 26/70
# 3847/3847 [==============================] - 3s 740us/step - loss: 0.0090 - val_loss: 0.0052
#
# Epoch 00026: val_loss did not improve from 0.00439
# Epoch 27/70
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00027: val_loss did not improve from 0.00439
# Epoch 28/70
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00028: val_loss improved from 0.00439 to 0.00438, saving model to LSTMmodel.h5
# Epoch 29/70
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0086 - val_loss: 0.0043
#
# Epoch 00029: val_loss improved from 0.00438 to 0.00428, saving model to LSTMmodel.h5
# Epoch 30/70
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0079 - val_loss: 0.0042
#
# Epoch 00030: val_loss improved from 0.00428 to 0.00419, saving model to LSTMmodel.h5
# Epoch 31/70
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0075 - val_loss: 0.0040
#
# Epoch 00031: val_loss improved from 0.00419 to 0.00399, saving model to LSTMmodel.h5
# Epoch 32/70
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0074 - val_loss: 0.0046
#
# Epoch 00032: val_loss did not improve from 0.00399
# Epoch 33/70
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0071 - val_loss: 0.0050
#
# Epoch 00033: val_loss did not improve from 0.00399
# Epoch 34/70
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0070 - val_loss: 0.0042
#
# Epoch 00034: val_loss did not improve from 0.00399
# Epoch 35/70
# 3847/3847 [==============================] - 3s 738us/step - loss: 0.0071 - val_loss: 0.0042
#
# Epoch 00035: val_loss did not improve from 0.00399
# Epoch 36/70
# 3847/3847 [==============================] - 3s 771us/step - loss: 0.0070 - val_loss: 0.0039
#
# Epoch 00036: val_loss improved from 0.00399 to 0.00392, saving model to LSTMmodel.h5
# Epoch 37/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0068 - val_loss: 0.0042
#
# Epoch 00037: val_loss did not improve from 0.00392
# Epoch 38/70
# 3847/3847 [==============================] - 3s 787us/step - loss: 0.0069 - val_loss: 0.0039
#
# Epoch 00038: val_loss did not improve from 0.00392
# Epoch 39/70
# 3847/3847 [==============================] - 3s 802us/step - loss: 0.0068 - val_loss: 0.0043
#
# Epoch 00039: val_loss did not improve from 0.00392
# Epoch 40/70
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00392
# Epoch 41/70
# 3847/3847 [==============================] - 3s 795us/step - loss: 0.0067 - val_loss: 0.0040
#
# Epoch 00041: val_loss did not improve from 0.00392
# Epoch 42/70
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0067 - val_loss: 0.0044
#
# Epoch 00042: val_loss did not improve from 0.00392
# Epoch 43/70
# 3847/3847 [==============================] - 3s 807us/step - loss: 0.0067 - val_loss: 0.0045
#
# Epoch 00043: val_loss did not improve from 0.00392
# Epoch 44/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0068 - val_loss: 0.0038
#
# Epoch 00044: val_loss improved from 0.00392 to 0.00383, saving model to LSTMmodel.h5
# Epoch 45/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0068 - val_loss: 0.0040
#
# Epoch 00045: val_loss did not improve from 0.00383
# Epoch 46/70
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00046: val_loss did not improve from 0.00383
# Epoch 47/70
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0066 - val_loss: 0.0040
#
# Epoch 00047: val_loss did not improve from 0.00383
# Epoch 48/70
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0067 - val_loss: 0.0040
#
# Epoch 00048: val_loss did not improve from 0.00383
# Epoch 49/70
# 3847/3847 [==============================] - 3s 796us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00049: val_loss did not improve from 0.00383
# Epoch 50/70
# 3847/3847 [==============================] - 3s 813us/step - loss: 0.0066 - val_loss: 0.0040
#
# Epoch 00050: val_loss did not improve from 0.00383
# Epoch 51/70
# 3847/3847 [==============================] - 3s 782us/step - loss: 0.0066 - val_loss: 0.0039
#
# Epoch 00051: val_loss did not improve from 0.00383
# Epoch 52/70
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0067 - val_loss: 0.0044
#
# Epoch 00052: val_loss did not improve from 0.00383
# Epoch 53/70
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0067 - val_loss: 0.0044
#
# Epoch 00053: val_loss did not improve from 0.00383
# Epoch 54/70
# 3847/3847 [==============================] - 3s 794us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00054: val_loss did not improve from 0.00383
# Epoch 55/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0066 - val_loss: 0.0039
#
# Epoch 00055: val_loss did not improve from 0.00383
# Epoch 56/70
# 3847/3847 [==============================] - 3s 808us/step - loss: 0.0066 - val_loss: 0.0042
#
# Epoch 00056: val_loss did not improve from 0.00383
# Epoch 57/70
# 3847/3847 [==============================] - 3s 803us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00057: val_loss did not improve from 0.00383
# Epoch 58/70
# 3847/3847 [==============================] - 3s 796us/step - loss: 0.0066 - val_loss: 0.0041
#
# Epoch 00058: val_loss did not improve from 0.00383
# Epoch 59/70
# 3847/3847 [==============================] - 3s 806us/step - loss: 0.0065 - val_loss: 0.0048
#
# Epoch 00059: val_loss did not improve from 0.00383
# Epoch 60/70
# 3847/3847 [==============================] - 3s 808us/step - loss: 0.0066 - val_loss: 0.0042
#
# Epoch 00060: val_loss did not improve from 0.00383
# Epoch 61/70
# 3847/3847 [==============================] - 3s 803us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00061: val_loss did not improve from 0.00383
# Epoch 62/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0065 - val_loss: 0.0039
#
# Epoch 00062: val_loss did not improve from 0.00383
# Epoch 63/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0064 - val_loss: 0.0040
#
# Epoch 00063: val_loss did not improve from 0.00383
# Epoch 64/70
# 3847/3847 [==============================] - 3s 826us/step - loss: 0.0064 - val_loss: 0.0038
#
# Epoch 00064: val_loss improved from 0.00383 to 0.00381, saving model to LSTMmodel.h5
# Epoch 65/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0063 - val_loss: 0.0041
#
# Epoch 00065: val_loss did not improve from 0.00381
# Epoch 66/70
# 3847/3847 [==============================] - 3s 835us/step - loss: 0.0064 - val_loss: 0.0042
#
# Epoch 00066: val_loss did not improve from 0.00381
# Epoch 67/70
# 3847/3847 [==============================] - 3s 830us/step - loss: 0.0064 - val_loss: 0.0044
#
# Epoch 00067: val_loss did not improve from 0.00381
# Epoch 68/70
# 3847/3847 [==============================] - 3s 832us/step - loss: 0.0064 - val_loss: 0.0038
#
# Epoch 00068: val_loss improved from 0.00381 to 0.00377, saving model to LSTMmodel.h5
# Epoch 69/70
# 3847/3847 [==============================] - 3s 806us/step - loss: 0.0063 - val_loss: 0.0040
#
# Epoch 00069: val_loss did not improve from 0.00377
# Epoch 70/70
# 3847/3847 [==============================] - 3s 824us/step - loss: 0.0063 - val_loss: 0.0039
#
# Epoch 00070: val_loss did not improve from 0.00377
# Model loaded
# mae :  4438.828002295556
# mse :  47729874.44612157
# rmse :  6908.681093097406
# std : 6891.254022830253

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = model.output

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=model.input, outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('LSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit(X_train_tLSTM, y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('LSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict(X_test_tLSTM)
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 9s 2ms/step - loss: 0.0118 - val_loss: 0.0048
#
# Epoch 00001: val_loss improved from inf to 0.00479, saving model to LSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 733us/step - loss: 0.0101 - val_loss: 0.0056
#
# Epoch 00002: val_loss did not improve from 0.00479
# Epoch 3/70
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0100 - val_loss: 0.0049
#
# Epoch 00003: val_loss did not improve from 0.00479
# Epoch 4/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0094 - val_loss: 0.0053
#
# Epoch 00004: val_loss did not improve from 0.00479
# Epoch 5/70
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0096 - val_loss: 0.0048
#
# Epoch 00005: val_loss did not improve from 0.00479
# Epoch 6/70
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0095 - val_loss: 0.0051
#
# Epoch 00006: val_loss did not improve from 0.00479
# Epoch 7/70
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0094 - val_loss: 0.0054
#
# Epoch 00007: val_loss did not improve from 0.00479
# Epoch 8/70
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0095 - val_loss: 0.0047
#
# Epoch 00008: val_loss improved from 0.00479 to 0.00473, saving model to LSTMmodel.h5
# Epoch 9/70
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0093 - val_loss: 0.0050
#
# Epoch 00009: val_loss did not improve from 0.00473
# Epoch 10/70
# 3847/3847 [==============================] - 3s 698us/step - loss: 0.0093 - val_loss: 0.0044
#
# Epoch 00010: val_loss improved from 0.00473 to 0.00440, saving model to LSTMmodel.h5
# Epoch 11/70
# 3847/3847 [==============================] - 3s 700us/step - loss: 0.0093 - val_loss: 0.0049
#
# Epoch 00011: val_loss did not improve from 0.00440
# Epoch 12/70
# 3847/3847 [==============================] - 3s 697us/step - loss: 0.0092 - val_loss: 0.0047
#
# Epoch 00012: val_loss did not improve from 0.00440
# Epoch 13/70
# 3847/3847 [==============================] - 3s 700us/step - loss: 0.0094 - val_loss: 0.0045
#
# Epoch 00013: val_loss did not improve from 0.00440
# Epoch 14/70
# 3847/3847 [==============================] - 3s 730us/step - loss: 0.0092 - val_loss: 0.0045
#
# Epoch 00014: val_loss did not improve from 0.00440
# Epoch 15/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00015: val_loss did not improve from 0.00440
# Epoch 16/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0092 - val_loss: 0.0048
#
# Epoch 00016: val_loss did not improve from 0.00440
# Epoch 17/70
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0092 - val_loss: 0.0046
#
# Epoch 00017: val_loss did not improve from 0.00440
# Epoch 18/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0094 - val_loss: 0.0046
#
# Epoch 00018: val_loss did not improve from 0.00440
# Epoch 19/70
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0092 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00440
# Epoch 20/70
# 3847/3847 [==============================] - 3s 767us/step - loss: 0.0092 - val_loss: 0.0048
#
# Epoch 00020: val_loss did not improve from 0.00440
# Epoch 21/70
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0091 - val_loss: 0.0050
#
# Epoch 00021: val_loss did not improve from 0.00440
# Epoch 22/70
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0093 - val_loss: 0.0047
#
# Epoch 00022: val_loss did not improve from 0.00440
# Epoch 23/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00023: val_loss did not improve from 0.00440
# Epoch 24/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00024: val_loss did not improve from 0.00440
# Epoch 25/70
# 3847/3847 [==============================] - 3s 757us/step - loss: 0.0091 - val_loss: 0.0046
#
# Epoch 00025: val_loss did not improve from 0.00440
# Epoch 26/70
# 3847/3847 [==============================] - 3s 754us/step - loss: 0.0092 - val_loss: 0.0050
#
# Epoch 00026: val_loss did not improve from 0.00440
# Epoch 27/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0090 - val_loss: 0.0049
#
# Epoch 00027: val_loss did not improve from 0.00440
# Epoch 28/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0091 - val_loss: 0.0045
#
# Epoch 00028: val_loss did not improve from 0.00440
# Epoch 29/70
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0092 - val_loss: 0.0062
#
# Epoch 00029: val_loss did not improve from 0.00440
# Epoch 30/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0091 - val_loss: 0.0044
#
# Epoch 00030: val_loss did not improve from 0.00440
# Epoch 31/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0091 - val_loss: 0.0047
#
# Epoch 00031: val_loss did not improve from 0.00440
# Epoch 32/70
# 3847/3847 [==============================] - 3s 760us/step - loss: 0.0090 - val_loss: 0.0048
#
# Epoch 00032: val_loss did not improve from 0.00440
# Epoch 33/70
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0090 - val_loss: 0.0048
#
# Epoch 00033: val_loss did not improve from 0.00440
# Epoch 34/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0089 - val_loss: 0.0046
#
# Epoch 00034: val_loss did not improve from 0.00440
# Epoch 35/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00035: val_loss improved from 0.00440 to 0.00435, saving model to LSTMmodel.h5
# Epoch 36/70
# 3847/3847 [==============================] - 3s 754us/step - loss: 0.0089 - val_loss: 0.0052
#
# Epoch 00036: val_loss did not improve from 0.00435
# Epoch 37/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0089 - val_loss: 0.0044
#
# Epoch 00037: val_loss did not improve from 0.00435
# Epoch 38/70
# 3847/3847 [==============================] - 3s 849us/step - loss: 0.0089 - val_loss: 0.0051
#
# Epoch 00038: val_loss did not improve from 0.00435
# Epoch 39/70
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00039: val_loss did not improve from 0.00435
# Epoch 40/70
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0090 - val_loss: 0.0042
#
# Epoch 00040: val_loss improved from 0.00435 to 0.00419, saving model to LSTMmodel.h5
# Epoch 41/70
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0089 - val_loss: 0.0043
#
# Epoch 00041: val_loss did not improve from 0.00419
# Epoch 42/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0089 - val_loss: 0.0045
#
# Epoch 00042: val_loss did not improve from 0.00419
# Epoch 43/70
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0087 - val_loss: 0.0043
#
# Epoch 00043: val_loss did not improve from 0.00419
# Epoch 44/70
# 3847/3847 [==============================] - 3s 755us/step - loss: 0.0087 - val_loss: 0.0043
#
# Epoch 00044: val_loss did not improve from 0.00419
# Epoch 45/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0085 - val_loss: 0.0043
#
# Epoch 00045: val_loss did not improve from 0.00419
# Epoch 46/70
# 3847/3847 [==============================] - 3s 758us/step - loss: 0.0084 - val_loss: 0.0044
#
# Epoch 00046: val_loss did not improve from 0.00419
# Epoch 47/70
# 3847/3847 [==============================] - 3s 754us/step - loss: 0.0084 - val_loss: 0.0048
#
# Epoch 00047: val_loss did not improve from 0.00419
# Epoch 48/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0082 - val_loss: 0.0043
#
# Epoch 00048: val_loss did not improve from 0.00419
# Epoch 49/70
# 3847/3847 [==============================] - 3s 761us/step - loss: 0.0081 - val_loss: 0.0046
#
# Epoch 00049: val_loss did not improve from 0.00419
# Epoch 50/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0078 - val_loss: 0.0050
#
# Epoch 00050: val_loss did not improve from 0.00419
# Epoch 51/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0075 - val_loss: 0.0041
#
# Epoch 00051: val_loss improved from 0.00419 to 0.00414, saving model to LSTMmodel.h5
# Epoch 52/70
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0073 - val_loss: 0.0040
#
# Epoch 00052: val_loss improved from 0.00414 to 0.00405, saving model to LSTMmodel.h5
# Epoch 53/70
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0071 - val_loss: 0.0044
#
# Epoch 00053: val_loss did not improve from 0.00405
# Epoch 54/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0071 - val_loss: 0.0038
#
# Epoch 00054: val_loss improved from 0.00405 to 0.00383, saving model to LSTMmodel.h5
# Epoch 55/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0070 - val_loss: 0.0043
#
# Epoch 00055: val_loss did not improve from 0.00383
# Epoch 56/70
# 3847/3847 [==============================] - 3s 754us/step - loss: 0.0069 - val_loss: 0.0038
#
# Epoch 00056: val_loss improved from 0.00383 to 0.00382, saving model to LSTMmodel.h5
# Epoch 57/70
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0067 - val_loss: 0.0040
#
# Epoch 00057: val_loss did not improve from 0.00382
# Epoch 58/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0068 - val_loss: 0.0046
#
# Epoch 00058: val_loss did not improve from 0.00382
# Epoch 59/70
# 3847/3847 [==============================] - 3s 745us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00059: val_loss did not improve from 0.00382
# Epoch 60/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00060: val_loss did not improve from 0.00382
# Epoch 61/70
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0067 - val_loss: 0.0041
#
# Epoch 00061: val_loss did not improve from 0.00382
# Epoch 62/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0066 - val_loss: 0.0047
#
# Epoch 00062: val_loss did not improve from 0.00382
# Epoch 63/70
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0067 - val_loss: 0.0039
#
# Epoch 00063: val_loss did not improve from 0.00382
# Epoch 64/70
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00064: val_loss did not improve from 0.00382
# Epoch 65/70
# 3847/3847 [==============================] - 3s 764us/step - loss: 0.0067 - val_loss: 0.0036
#
# Epoch 00065: val_loss improved from 0.00382 to 0.00364, saving model to LSTMmodel.h5
# Epoch 66/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0066 - val_loss: 0.0038
#
# Epoch 00066: val_loss did not improve from 0.00364
# Epoch 67/70
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0065 - val_loss: 0.0044
#
# Epoch 00067: val_loss did not improve from 0.00364
# Epoch 68/70
# 3847/3847 [==============================] - 3s 750us/step - loss: 0.0064 - val_loss: 0.0044
#
# Epoch 00068: val_loss did not improve from 0.00364
# Epoch 69/70
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0065 - val_loss: 0.0040
#
# Epoch 00069: val_loss did not improve from 0.00364
# Epoch 70/70
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0064 - val_loss: 0.0043
#
# Epoch 00070: val_loss did not improve from 0.00364
# Model loaded
# mae :  4216.506869546469
# mse :  45280999.643982485
# rmse :  6729.115814427812
# std : 6725.134198371388
