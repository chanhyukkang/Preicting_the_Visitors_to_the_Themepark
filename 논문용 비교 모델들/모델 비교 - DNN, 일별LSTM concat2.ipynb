# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
mcp_save2 = ModelCheckpoint('DNNLSTMmodel2.h5', save_best_only=True, monitor='loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save, mcp_save2])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# Using TensorFlow backend.
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 4s 949us/step - loss: 0.0124 - val_loss: 0.0028
#
# Epoch 00001: val_loss improved from inf to 0.00277, saving model to DNNLSTMmodel.h5
#
# Epoch 00001: loss improved from inf to 0.01244, saving model to DNNLSTMmodel2.h5
# Epoch 2/100
# 3847/3847 [==============================] - 1s 370us/step - loss: 0.0040 - val_loss: 0.0039
#
# Epoch 00002: val_loss did not improve from 0.00277
#
# Epoch 00002: loss improved from 0.01244 to 0.00400, saving model to DNNLSTMmodel2.h5
# Epoch 3/100
# 3847/3847 [==============================] - 2s 416us/step - loss: 0.0036 - val_loss: 0.0034
#
# Epoch 00003: val_loss did not improve from 0.00277
#
# Epoch 00003: loss improved from 0.00400 to 0.00357, saving model to DNNLSTMmodel2.h5
# Epoch 4/100
# 3847/3847 [==============================] - 2s 406us/step - loss: 0.0034 - val_loss: 0.0051
#
# Epoch 00004: val_loss did not improve from 0.00277
#
# Epoch 00004: loss improved from 0.00357 to 0.00345, saving model to DNNLSTMmodel2.h5
# Epoch 5/100
# 3847/3847 [==============================] - 2s 441us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00005: val_loss did not improve from 0.00277
#
# Epoch 00005: loss improved from 0.00345 to 0.00332, saving model to DNNLSTMmodel2.h5
# Epoch 6/100
# 3847/3847 [==============================] - 2s 442us/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00006: val_loss did not improve from 0.00277
#
# Epoch 00006: loss improved from 0.00332 to 0.00322, saving model to DNNLSTMmodel2.h5
# Epoch 7/100
# 3847/3847 [==============================] - 2s 411us/step - loss: 0.0032 - val_loss: 0.0051
#
# Epoch 00007: val_loss did not improve from 0.00277
#
# Epoch 00007: loss improved from 0.00322 to 0.00321, saving model to DNNLSTMmodel2.h5
# Epoch 8/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0031 - val_loss: 0.0028
#
# Epoch 00008: val_loss did not improve from 0.00277
#
# Epoch 00008: loss improved from 0.00321 to 0.00313, saving model to DNNLSTMmodel2.h5
# Epoch 9/100
# 3847/3847 [==============================] - 2s 416us/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00009: val_loss did not improve from 0.00277
#
# Epoch 00009: loss improved from 0.00313 to 0.00307, saving model to DNNLSTMmodel2.h5
# Epoch 10/100
# 3847/3847 [==============================] - 2s 413us/step - loss: 0.0031 - val_loss: 0.0038
#
# Epoch 00010: val_loss did not improve from 0.00277
#
# Epoch 00010: loss did not improve from 0.00307
# Epoch 11/100
# 3847/3847 [==============================] - 2s 418us/step - loss: 0.0031 - val_loss: 0.0049
#
# Epoch 00011: val_loss did not improve from 0.00277
#
# Epoch 00011: loss improved from 0.00307 to 0.00306, saving model to DNNLSTMmodel2.h5
# Epoch 12/100
# 3847/3847 [==============================] - 2s 413us/step - loss: 0.0030 - val_loss: 0.0030
#
# Epoch 00012: val_loss did not improve from 0.00277
#
# Epoch 00012: loss improved from 0.00306 to 0.00299, saving model to DNNLSTMmodel2.h5
# Epoch 13/100
# 3847/3847 [==============================] - 2s 410us/step - loss: 0.0031 - val_loss: 0.0037
#
# Epoch 00013: val_loss did not improve from 0.00277
#
# Epoch 00013: loss did not improve from 0.00299
# Epoch 14/100
# 3847/3847 [==============================] - 2s 423us/step - loss: 0.0031 - val_loss: 0.0050
#
# Epoch 00014: val_loss did not improve from 0.00277
#
# Epoch 00014: loss did not improve from 0.00299
# Epoch 15/100
# 3847/3847 [==============================] - 2s 445us/step - loss: 0.0033 - val_loss: 0.0025
#
# Epoch 00015: val_loss improved from 0.00277 to 0.00248, saving model to DNNLSTMmodel.h5
#
# Epoch 00015: loss did not improve from 0.00299
# Epoch 16/100
# 3847/3847 [==============================] - 2s 450us/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00016: val_loss did not improve from 0.00248
#
# Epoch 00016: loss did not improve from 0.00299
# Epoch 17/100
# 3847/3847 [==============================] - 2s 409us/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00017: val_loss did not improve from 0.00248
#
# Epoch 00017: loss improved from 0.00299 to 0.00291, saving model to DNNLSTMmodel2.h5
# Epoch 18/100
# 3847/3847 [==============================] - 2s 421us/step - loss: 0.0029 - val_loss: 0.0040
#
# Epoch 00018: val_loss did not improve from 0.00248
#
# Epoch 00018: loss improved from 0.00291 to 0.00286, saving model to DNNLSTMmodel2.h5
# Epoch 19/100
# 3847/3847 [==============================] - 2s 416us/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00019: val_loss did not improve from 0.00248
#
# Epoch 00019: loss improved from 0.00286 to 0.00278, saving model to DNNLSTMmodel2.h5
# Epoch 20/100
# 3847/3847 [==============================] - 2s 429us/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00248
#
# Epoch 00020: loss did not improve from 0.00278
# Epoch 21/100
# 3847/3847 [==============================] - 2s 460us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00021: val_loss did not improve from 0.00248
#
# Epoch 00021: loss improved from 0.00278 to 0.00273, saving model to DNNLSTMmodel2.h5
# Epoch 22/100
# 3847/3847 [==============================] - 2s 477us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00022: val_loss did not improve from 0.00248
#
# Epoch 00022: loss improved from 0.00273 to 0.00267, saving model to DNNLSTMmodel2.h5
# Epoch 23/100
# 3847/3847 [==============================] - 2s 450us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00023: val_loss did not improve from 0.00248
#
# Epoch 00023: loss did not improve from 0.00267
# Epoch 24/100
# 3847/3847 [==============================] - 2s 446us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00024: val_loss did not improve from 0.00248
#
# Epoch 00024: loss did not improve from 0.00267
# Epoch 25/100
# 3847/3847 [==============================] - 2s 412us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00025: val_loss did not improve from 0.00248
#
# Epoch 00025: loss improved from 0.00267 to 0.00260, saving model to DNNLSTMmodel2.h5
# Epoch 26/100
# 3847/3847 [==============================] - 2s 404us/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00026: val_loss did not improve from 0.00248
#
# Epoch 00026: loss did not improve from 0.00260
# Epoch 27/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0026 - val_loss: 0.0049
#
# Epoch 00027: val_loss did not improve from 0.00248
#
# Epoch 00027: loss improved from 0.00260 to 0.00258, saving model to DNNLSTMmodel2.h5
# Epoch 28/100
# 3847/3847 [==============================] - 2s 414us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00028: val_loss did not improve from 0.00248
#
# Epoch 00028: loss did not improve from 0.00258
# Epoch 29/100
# 3847/3847 [==============================] - 2s 422us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00029: val_loss did not improve from 0.00248
#
# Epoch 00029: loss improved from 0.00258 to 0.00254, saving model to DNNLSTMmodel2.h5
# Epoch 30/100
# 3847/3847 [==============================] - 2s 407us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00030: val_loss did not improve from 0.00248
#
# Epoch 00030: loss improved from 0.00254 to 0.00252, saving model to DNNLSTMmodel2.h5
# Epoch 31/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00031: val_loss did not improve from 0.00248
#
# Epoch 00031: loss did not improve from 0.00252
# Epoch 32/100
# 3847/3847 [==============================] - 2s 411us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00032: val_loss did not improve from 0.00248
#
# Epoch 00032: loss did not improve from 0.00252
# Epoch 33/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00033: val_loss did not improve from 0.00248
#
# Epoch 00033: loss did not improve from 0.00252
# Epoch 34/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00034: val_loss did not improve from 0.00248
#
# Epoch 00034: loss improved from 0.00252 to 0.00241, saving model to DNNLSTMmodel2.h5
# Epoch 35/100
# 3847/3847 [==============================] - 2s 405us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00035: val_loss did not improve from 0.00248
#
# Epoch 00035: loss did not improve from 0.00241
# Epoch 36/100
# 3847/3847 [==============================] - 2s 401us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00036: val_loss did not improve from 0.00248
#
# Epoch 00036: loss did not improve from 0.00241
# Epoch 37/100
# 3847/3847 [==============================] - 2s 398us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00037: val_loss did not improve from 0.00248
#
# Epoch 00037: loss did not improve from 0.00241
# Epoch 38/100
# 3847/3847 [==============================] - 2s 403us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00038: val_loss did not improve from 0.00248
#
# Epoch 00038: loss improved from 0.00241 to 0.00238, saving model to DNNLSTMmodel2.h5
# Epoch 39/100
# 3847/3847 [==============================] - 2s 395us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00039: val_loss did not improve from 0.00248
#
# Epoch 00039: loss improved from 0.00238 to 0.00235, saving model to DNNLSTMmodel2.h5
# Epoch 40/100
# 3847/3847 [==============================] - 2s 396us/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00040: val_loss did not improve from 0.00248
#
# Epoch 00040: loss did not improve from 0.00235
# Epoch 41/100
# 3847/3847 [==============================] - 2s 408us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00041: val_loss did not improve from 0.00248
#
# Epoch 00041: loss did not improve from 0.00235
# Epoch 42/100
# 3847/3847 [==============================] - 2s 407us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00042: val_loss did not improve from 0.00248
#
# Epoch 00042: loss did not improve from 0.00235
# Epoch 43/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00043: val_loss did not improve from 0.00248
#
# Epoch 00043: loss did not improve from 0.00235
# Epoch 44/100
# 3847/3847 [==============================] - 2s 424us/step - loss: 0.0023 - val_loss: 0.0032
#
# Epoch 00044: val_loss did not improve from 0.00248
#
# Epoch 00044: loss improved from 0.00235 to 0.00234, saving model to DNNLSTMmodel2.h5
# Epoch 45/100
# 3847/3847 [==============================] - 2s 407us/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00248
#
# Epoch 00045: loss improved from 0.00234 to 0.00225, saving model to DNNLSTMmodel2.h5
# Epoch 46/100
# 3847/3847 [==============================] - 2s 416us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00046: val_loss did not improve from 0.00248
#
# Epoch 00046: loss did not improve from 0.00225
# Epoch 47/100
# 3847/3847 [==============================] - 2s 404us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00047: val_loss did not improve from 0.00248
#
# Epoch 00047: loss did not improve from 0.00225
# Epoch 48/100
# 3847/3847 [==============================] - 2s 404us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00048: val_loss did not improve from 0.00248
#
# Epoch 00048: loss did not improve from 0.00225
# Epoch 49/100
# 3847/3847 [==============================] - 2s 405us/step - loss: 0.0023 - val_loss: 0.0046
#
# Epoch 00049: val_loss did not improve from 0.00248
#
# Epoch 00049: loss did not improve from 0.00225
# Epoch 50/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00050: val_loss did not improve from 0.00248
#
# Epoch 00050: loss improved from 0.00225 to 0.00224, saving model to DNNLSTMmodel2.h5
# Epoch 51/100
# 3847/3847 [==============================] - 2s 413us/step - loss: 0.0022 - val_loss: 0.0045
#
# Epoch 00051: val_loss did not improve from 0.00248
#
# Epoch 00051: loss improved from 0.00224 to 0.00222, saving model to DNNLSTMmodel2.h5
# Epoch 52/100
# 3847/3847 [==============================] - 2s 423us/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00052: val_loss did not improve from 0.00248
#
# Epoch 00052: loss improved from 0.00222 to 0.00218, saving model to DNNLSTMmodel2.h5
# Epoch 53/100
# 3847/3847 [==============================] - 2s 409us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00053: val_loss did not improve from 0.00248
#
# Epoch 00053: loss did not improve from 0.00218
# Epoch 54/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0022 - val_loss: 0.0037
#
# Epoch 00054: val_loss did not improve from 0.00248
#
# Epoch 00054: loss improved from 0.00218 to 0.00215, saving model to DNNLSTMmodel2.h5
# Epoch 55/100
# 3847/3847 [==============================] - 2s 398us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00055: val_loss did not improve from 0.00248
#
# Epoch 00055: loss improved from 0.00215 to 0.00211, saving model to DNNLSTMmodel2.h5
# Epoch 56/100
# 3847/3847 [==============================] - 2s 412us/step - loss: 0.0021 - val_loss: 0.0045
#
# Epoch 00056: val_loss did not improve from 0.00248
#
# Epoch 00056: loss did not improve from 0.00211
# Epoch 57/100
# 3847/3847 [==============================] - 2s 423us/step - loss: 0.0022 - val_loss: 0.0039
#
# Epoch 00057: val_loss did not improve from 0.00248
#
# Epoch 00057: loss did not improve from 0.00211
# Epoch 58/100
# 3847/3847 [==============================] - 2s 399us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00058: val_loss did not improve from 0.00248
#
# Epoch 00058: loss did not improve from 0.00211
# Epoch 59/100
# 3847/3847 [==============================] - 2s 403us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00059: val_loss did not improve from 0.00248
#
# Epoch 00059: loss did not improve from 0.00211
# Epoch 60/100
# 3847/3847 [==============================] - 2s 399us/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00060: val_loss did not improve from 0.00248
#
# Epoch 00060: loss improved from 0.00211 to 0.00211, saving model to DNNLSTMmodel2.h5
# Epoch 61/100
# 3847/3847 [==============================] - 2s 419us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00061: val_loss did not improve from 0.00248
#
# Epoch 00061: loss did not improve from 0.00211
# Epoch 62/100
# 3847/3847 [==============================] - 2s 448us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00062: val_loss did not improve from 0.00248
#
# Epoch 00062: loss improved from 0.00211 to 0.00210, saving model to DNNLSTMmodel2.h5
# Epoch 63/100
# 3847/3847 [==============================] - 2s 426us/step - loss: 0.0022 - val_loss: 0.0041
#
# Epoch 00063: val_loss did not improve from 0.00248
#
# Epoch 00063: loss did not improve from 0.00210
# Epoch 64/100
# 3847/3847 [==============================] - 2s 444us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00064: val_loss did not improve from 0.00248
#
# Epoch 00064: loss improved from 0.00210 to 0.00210, saving model to DNNLSTMmodel2.h5
# Epoch 65/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00065: val_loss did not improve from 0.00248
#
# Epoch 00065: loss improved from 0.00210 to 0.00208, saving model to DNNLSTMmodel2.h5
# Epoch 66/100
# 3847/3847 [==============================] - 2s 423us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00066: val_loss did not improve from 0.00248
#
# Epoch 00066: loss improved from 0.00208 to 0.00206, saving model to DNNLSTMmodel2.h5
# Epoch 67/100
# 3847/3847 [==============================] - 2s 399us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00067: val_loss did not improve from 0.00248
#
# Epoch 00067: loss did not improve from 0.00206
# Epoch 68/100
# 3847/3847 [==============================] - 2s 419us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00068: val_loss did not improve from 0.00248
#
# Epoch 00068: loss did not improve from 0.00206
# Epoch 69/100
# 3847/3847 [==============================] - 2s 434us/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00069: val_loss did not improve from 0.00248
#
# Epoch 00069: loss did not improve from 0.00206
# Epoch 70/100
# 3847/3847 [==============================] - 2s 398us/step - loss: 0.0021 - val_loss: 0.0039
#
# Epoch 00070: val_loss did not improve from 0.00248
#
# Epoch 00070: loss did not improve from 0.00206
# Epoch 71/100
# 3847/3847 [==============================] - 2s 415us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00071: val_loss did not improve from 0.00248
#
# Epoch 00071: loss did not improve from 0.00206
# Epoch 72/100
# 3847/3847 [==============================] - 2s 435us/step - loss: 0.0020 - val_loss: 0.0040
#
# Epoch 00072: val_loss did not improve from 0.00248
#
# Epoch 00072: loss improved from 0.00206 to 0.00204, saving model to DNNLSTMmodel2.h5
# Epoch 73/100
# 3847/3847 [==============================] - 2s 426us/step - loss: 0.0020 - val_loss: 0.0046
#
# Epoch 00073: val_loss did not improve from 0.00248
#
# Epoch 00073: loss improved from 0.00204 to 0.00197, saving model to DNNLSTMmodel2.h5
# Epoch 74/100
# 3847/3847 [==============================] - 2s 420us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00074: val_loss did not improve from 0.00248
#
# Epoch 00074: loss did not improve from 0.00197
# Epoch 75/100
# 3847/3847 [==============================] - 2s 427us/step - loss: 0.0019 - val_loss: 0.0034
#
# Epoch 00075: val_loss did not improve from 0.00248
#
# Epoch 00075: loss improved from 0.00197 to 0.00191, saving model to DNNLSTMmodel2.h5
# Epoch 76/100
# 3847/3847 [==============================] - 2s 432us/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00076: val_loss did not improve from 0.00248
#
# Epoch 00076: loss did not improve from 0.00191
# Epoch 77/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00077: val_loss did not improve from 0.00248
#
# Epoch 00077: loss did not improve from 0.00191
# Epoch 78/100
# 3847/3847 [==============================] - 2s 409us/step - loss: 0.0020 - val_loss: 0.0041
#
# Epoch 00078: val_loss did not improve from 0.00248
#
# Epoch 00078: loss did not improve from 0.00191
# Epoch 79/100
# 3847/3847 [==============================] - 2s 403us/step - loss: 0.0019 - val_loss: 0.0041
#
# Epoch 00079: val_loss did not improve from 0.00248
#
# Epoch 00079: loss did not improve from 0.00191
# Epoch 80/100
# 3847/3847 [==============================] - 2s 430us/step - loss: 0.0019 - val_loss: 0.0030
#
# Epoch 00080: val_loss did not improve from 0.00248
#
# Epoch 00080: loss did not improve from 0.00191
# Epoch 81/100
# 3847/3847 [==============================] - 2s 412us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00081: val_loss did not improve from 0.00248
#
# Epoch 00081: loss did not improve from 0.00191
# Epoch 82/100
# 3847/3847 [==============================] - 2s 449us/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00082: val_loss did not improve from 0.00248
#
# Epoch 00082: loss did not improve from 0.00191
# Epoch 83/100
# 3847/3847 [==============================] - 2s 424us/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00083: val_loss did not improve from 0.00248
#
# Epoch 00083: loss improved from 0.00191 to 0.00185, saving model to DNNLSTMmodel2.h5
# Epoch 84/100
# 3847/3847 [==============================] - 2s 435us/step - loss: 0.0018 - val_loss: 0.0041
#
# Epoch 00084: val_loss did not improve from 0.00248
#
# Epoch 00084: loss improved from 0.00185 to 0.00182, saving model to DNNLSTMmodel2.h5
# Epoch 85/100
# 3847/3847 [==============================] - 2s 395us/step - loss: 0.0018 - val_loss: 0.0030
#
# Epoch 00085: val_loss did not improve from 0.00248
#
# Epoch 00085: loss did not improve from 0.00182
# Epoch 86/100
# 3847/3847 [==============================] - 2s 414us/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00086: val_loss did not improve from 0.00248
#
# Epoch 00086: loss did not improve from 0.00182
# Epoch 87/100
# 3847/3847 [==============================] - 2s 397us/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00087: val_loss did not improve from 0.00248
#
# Epoch 00087: loss did not improve from 0.00182
# Epoch 88/100
# 3847/3847 [==============================] - 2s 409us/step - loss: 0.0019 - val_loss: 0.0031
#
# Epoch 00088: val_loss did not improve from 0.00248
#
# Epoch 00088: loss did not improve from 0.00182
# Epoch 89/100
# 3847/3847 [==============================] - 2s 426us/step - loss: 0.0019 - val_loss: 0.0040
#
# Epoch 00089: val_loss did not improve from 0.00248
#
# Epoch 00089: loss did not improve from 0.00182
# Epoch 90/100
# 3847/3847 [==============================] - 2s 417us/step - loss: 0.0018 - val_loss: 0.0037
#
# Epoch 00090: val_loss did not improve from 0.00248
#
# Epoch 00090: loss did not improve from 0.00182
# Epoch 91/100
# 3847/3847 [==============================] - 2s 406us/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00091: val_loss did not improve from 0.00248
#
# Epoch 00091: loss did not improve from 0.00182
# Epoch 92/100
# 3847/3847 [==============================] - 2s 435us/step - loss: 0.0018 - val_loss: 0.0031
#
# Epoch 00092: val_loss did not improve from 0.00248
#
# Epoch 00092: loss did not improve from 0.00182
# Epoch 93/100
# 3847/3847 [==============================] - 2s 422us/step - loss: 0.0018 - val_loss: 0.0042
#
# Epoch 00093: val_loss did not improve from 0.00248
#
# Epoch 00093: loss improved from 0.00182 to 0.00177, saving model to DNNLSTMmodel2.h5
# Epoch 94/100
# 3847/3847 [==============================] - 2s 422us/step - loss: 0.0018 - val_loss: 0.0038
#
# Epoch 00094: val_loss did not improve from 0.00248
#
# Epoch 00094: loss did not improve from 0.00177
# Epoch 95/100
# 3847/3847 [==============================] - 2s 408us/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00095: val_loss did not improve from 0.00248
#
# Epoch 00095: loss did not improve from 0.00177
# Epoch 00095: early stopping
# Model loaded
# mae :  4441.302210899452
# mse :  42782286.23754081
# rmse :  6540.816939613951
# std : 5633.715437532936

# %%
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# mae :  4441.302210899452
# mse :  42782286.23754081
# rmse :  6540.816939613951
# std : 5633.715437532936

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 7s 2ms/step - loss: 0.0077 - val_loss: 0.0029
#
# Epoch 00001: val_loss improved from inf to 0.00287, saving model to DNNLSTMmodel.h5
#
# Epoch 00001: loss improved from inf to 0.00767, saving model to DNNLSTMmodel2.h5
# Epoch 2/100
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00002: val_loss did not improve from 0.00287
#
# Epoch 00002: loss improved from 0.00767 to 0.00407, saving model to DNNLSTMmodel2.h5
# Epoch 3/100
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0038 - val_loss: 0.0042
#
# Epoch 00003: val_loss did not improve from 0.00287
#
# Epoch 00003: loss improved from 0.00407 to 0.00377, saving model to DNNLSTMmodel2.h5
# Epoch 4/100
# 3847/3847 [==============================] - 2s 585us/step - loss: 0.0034 - val_loss: 0.0032
#
# Epoch 00004: val_loss did not improve from 0.00287
#
# Epoch 00004: loss improved from 0.00377 to 0.00343, saving model to DNNLSTMmodel2.h5
# Epoch 5/100
# 3847/3847 [==============================] - 2s 568us/step - loss: 0.0032 - val_loss: 0.0036
#
# Epoch 00005: val_loss did not improve from 0.00287
#
# Epoch 00005: loss improved from 0.00343 to 0.00322, saving model to DNNLSTMmodel2.h5
# Epoch 6/100
# 3847/3847 [==============================] - 2s 485us/step - loss: 0.0032 - val_loss: 0.0047
#
# Epoch 00006: val_loss did not improve from 0.00287
#
# Epoch 00006: loss did not improve from 0.00322
# Epoch 7/100
# 3847/3847 [==============================] - 2s 538us/step - loss: 0.0033 - val_loss: 0.0052
#
# Epoch 00007: val_loss did not improve from 0.00287
#
# Epoch 00007: loss did not improve from 0.00322
# Epoch 8/100
# 3847/3847 [==============================] - 2s 531us/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00008: val_loss did not improve from 0.00287
#
# Epoch 00008: loss improved from 0.00322 to 0.00318, saving model to DNNLSTMmodel2.h5
# Epoch 9/100
# 3847/3847 [==============================] - 2s 630us/step - loss: 0.0031 - val_loss: 0.0041
#
# Epoch 00009: val_loss did not improve from 0.00287
#
# Epoch 00009: loss improved from 0.00318 to 0.00306, saving model to DNNLSTMmodel2.h5
# Epoch 10/100
# 3847/3847 [==============================] - 2s 610us/step - loss: 0.0030 - val_loss: 0.0034
#
# Epoch 00010: val_loss did not improve from 0.00287
#
# Epoch 00010: loss improved from 0.00306 to 0.00301, saving model to DNNLSTMmodel2.h5
# Epoch 11/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0030 - val_loss: 0.0026
#
# Epoch 00011: val_loss improved from 0.00287 to 0.00265, saving model to DNNLSTMmodel.h5
#
# Epoch 00011: loss did not improve from 0.00301
# Epoch 12/100
# 3847/3847 [==============================] - 2s 548us/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00012: val_loss did not improve from 0.00265
#
# Epoch 00012: loss did not improve from 0.00301
# Epoch 13/100
# 3847/3847 [==============================] - 2s 561us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00013: val_loss did not improve from 0.00265
#
# Epoch 00013: loss improved from 0.00301 to 0.00290, saving model to DNNLSTMmodel2.h5
# Epoch 14/100
# 3847/3847 [==============================] - 2s 624us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00014: val_loss did not improve from 0.00265
#
# Epoch 00014: loss did not improve from 0.00290
# Epoch 15/100
# 3847/3847 [==============================] - 3s 668us/step - loss: 0.0029 - val_loss: 0.0027
#
# Epoch 00015: val_loss did not improve from 0.00265
#
# Epoch 00015: loss did not improve from 0.00290
# Epoch 16/100
# 3847/3847 [==============================] - 3s 681us/step - loss: 0.0028 - val_loss: 0.0051
#
# Epoch 00016: val_loss did not improve from 0.00265
#
# Epoch 00016: loss improved from 0.00290 to 0.00282, saving model to DNNLSTMmodel2.h5
# Epoch 17/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0030 - val_loss: 0.0029
#
# Epoch 00017: val_loss did not improve from 0.00265
#
# Epoch 00017: loss did not improve from 0.00282
# Epoch 18/100
# 3847/3847 [==============================] - 3s 686us/step - loss: 0.0029 - val_loss: 0.0025
#
# Epoch 00018: val_loss improved from 0.00265 to 0.00253, saving model to DNNLSTMmodel.h5
#
# Epoch 00018: loss did not improve from 0.00282
# Epoch 19/100
# 3847/3847 [==============================] - 2s 641us/step - loss: 0.0027 - val_loss: 0.0055
#
# Epoch 00019: val_loss did not improve from 0.00253
#
# Epoch 00019: loss improved from 0.00282 to 0.00271, saving model to DNNLSTMmodel2.h5
# Epoch 20/100
# 3847/3847 [==============================] - 3s 661us/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00020: val_loss did not improve from 0.00253
#
# Epoch 00020: loss improved from 0.00271 to 0.00267, saving model to DNNLSTMmodel2.h5
# Epoch 21/100
# 3847/3847 [==============================] - 3s 657us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00021: val_loss did not improve from 0.00253
#
# Epoch 00021: loss did not improve from 0.00267
# Epoch 22/100
# 3847/3847 [==============================] - 3s 668us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00022: val_loss did not improve from 0.00253
#
# Epoch 00022: loss did not improve from 0.00267
# Epoch 23/100
# 3847/3847 [==============================] - 2s 563us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00023: val_loss did not improve from 0.00253
#
# Epoch 00023: loss did not improve from 0.00267
# Epoch 24/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00024: val_loss did not improve from 0.00253
#
# Epoch 00024: loss improved from 0.00267 to 0.00259, saving model to DNNLSTMmodel2.h5
# Epoch 25/100
# 3847/3847 [==============================] - 2s 621us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00025: val_loss did not improve from 0.00253
#
# Epoch 00025: loss improved from 0.00259 to 0.00257, saving model to DNNLSTMmodel2.h5
# Epoch 26/100
# 3847/3847 [==============================] - 2s 643us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00026: val_loss did not improve from 0.00253
#
# Epoch 00026: loss improved from 0.00257 to 0.00254, saving model to DNNLSTMmodel2.h5
# Epoch 27/100
# 3847/3847 [==============================] - 2s 570us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00027: val_loss did not improve from 0.00253
#
# Epoch 00027: loss did not improve from 0.00254
# Epoch 28/100
# 3847/3847 [==============================] - 2s 514us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00028: val_loss did not improve from 0.00253
#
# Epoch 00028: loss did not improve from 0.00254
# Epoch 29/100
# 3847/3847 [==============================] - 2s 529us/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00029: val_loss did not improve from 0.00253
#
# Epoch 00029: loss did not improve from 0.00254
# Epoch 30/100
# 3847/3847 [==============================] - 2s 573us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00030: val_loss did not improve from 0.00253
#
# Epoch 00030: loss did not improve from 0.00254
# Epoch 31/100
# 3847/3847 [==============================] - 2s 503us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00031: val_loss did not improve from 0.00253
#
# Epoch 00031: loss improved from 0.00254 to 0.00253, saving model to DNNLSTMmodel2.h5
# Epoch 32/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00032: val_loss did not improve from 0.00253
#
# Epoch 00032: loss did not improve from 0.00253
# Epoch 33/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00033: val_loss did not improve from 0.00253
#
# Epoch 00033: loss did not improve from 0.00253
# Epoch 34/100
# 3847/3847 [==============================] - 2s 505us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00034: val_loss did not improve from 0.00253
#
# Epoch 00034: loss improved from 0.00253 to 0.00251, saving model to DNNLSTMmodel2.h5
# Epoch 35/100
# 3847/3847 [==============================] - 2s 590us/step - loss: 0.0025 - val_loss: 0.0053
#
# Epoch 00035: val_loss did not improve from 0.00253
#
# Epoch 00035: loss did not improve from 0.00251
# Epoch 36/100
# 3847/3847 [==============================] - 2s 485us/step - loss: 0.0024 - val_loss: 0.0041
#
# Epoch 00036: val_loss did not improve from 0.00253
#
# Epoch 00036: loss improved from 0.00251 to 0.00242, saving model to DNNLSTMmodel2.h5
# Epoch 37/100
# 3847/3847 [==============================] - 2s 559us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00037: val_loss did not improve from 0.00253
#
# Epoch 00037: loss improved from 0.00242 to 0.00240, saving model to DNNLSTMmodel2.h5
# Epoch 38/100
# 3847/3847 [==============================] - 2s 526us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00038: val_loss did not improve from 0.00253
#
# Epoch 00038: loss did not improve from 0.00240
# Epoch 39/100
# 3847/3847 [==============================] - 2s 531us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00039: val_loss did not improve from 0.00253
#
# Epoch 00039: loss improved from 0.00240 to 0.00237, saving model to DNNLSTMmodel2.h5
# Epoch 40/100
# 3847/3847 [==============================] - 2s 562us/step - loss: 0.0024 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00253
#
# Epoch 00040: loss did not improve from 0.00237
# Epoch 41/100
# 3847/3847 [==============================] - 2s 546us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00041: val_loss did not improve from 0.00253
#
# Epoch 00041: loss did not improve from 0.00237
# Epoch 42/100
# 3847/3847 [==============================] - 2s 505us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00042: val_loss did not improve from 0.00253
#
# Epoch 00042: loss did not improve from 0.00237
# Epoch 43/100
# 3847/3847 [==============================] - 2s 538us/step - loss: 0.0024 - val_loss: 0.0059
#
# Epoch 00043: val_loss did not improve from 0.00253
#
# Epoch 00043: loss did not improve from 0.00237
# Epoch 44/100
# 3847/3847 [==============================] - 2s 513us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00044: val_loss did not improve from 0.00253
#
# Epoch 00044: loss improved from 0.00237 to 0.00234, saving model to DNNLSTMmodel2.h5
# Epoch 45/100
# 3847/3847 [==============================] - 2s 618us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00045: val_loss did not improve from 0.00253
#
# Epoch 00045: loss did not improve from 0.00234
# Epoch 46/100
# 3847/3847 [==============================] - 2s 535us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00046: val_loss did not improve from 0.00253
#
# Epoch 00046: loss improved from 0.00234 to 0.00226, saving model to DNNLSTMmodel2.h5
# Epoch 47/100
# 3847/3847 [==============================] - 2s 587us/step - loss: 0.0023 - val_loss: 0.0022
#
# Epoch 00047: val_loss improved from 0.00253 to 0.00224, saving model to DNNLSTMmodel.h5
#
# Epoch 00047: loss did not improve from 0.00226
# Epoch 48/100
# 3847/3847 [==============================] - 2s 480us/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00048: val_loss did not improve from 0.00224
#
# Epoch 00048: loss did not improve from 0.00226
# Epoch 49/100
# 3847/3847 [==============================] - 2s 528us/step - loss: 0.0023 - val_loss: 0.0044
#
# Epoch 00049: val_loss did not improve from 0.00224
#
# Epoch 00049: loss did not improve from 0.00226
# Epoch 50/100
# 3847/3847 [==============================] - 2s 490us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00050: val_loss did not improve from 0.00224
#
# Epoch 00050: loss did not improve from 0.00226
# Epoch 51/100
# 3847/3847 [==============================] - 2s 483us/step - loss: 0.0022 - val_loss: 0.0035
#
# Epoch 00051: val_loss did not improve from 0.00224
#
# Epoch 00051: loss improved from 0.00226 to 0.00219, saving model to DNNLSTMmodel2.h5
# Epoch 52/100
# 3847/3847 [==============================] - 2s 510us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00052: val_loss did not improve from 0.00224
#
# Epoch 00052: loss did not improve from 0.00219
# Epoch 53/100
# 3847/3847 [==============================] - 2s 533us/step - loss: 0.0022 - val_loss: 0.0037
#
# Epoch 00053: val_loss did not improve from 0.00224
#
# Epoch 00053: loss did not improve from 0.00219
# Epoch 54/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00054: val_loss did not improve from 0.00224
#
# Epoch 00054: loss did not improve from 0.00219
# Epoch 55/100
# 3847/3847 [==============================] - 2s 523us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00055: val_loss did not improve from 0.00224
#
# Epoch 00055: loss did not improve from 0.00219
# Epoch 56/100
# 3847/3847 [==============================] - 2s 529us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00056: val_loss did not improve from 0.00224
#
# Epoch 00056: loss did not improve from 0.00219
# Epoch 57/100
# 3847/3847 [==============================] - 2s 636us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00057: val_loss did not improve from 0.00224
#
# Epoch 00057: loss did not improve from 0.00219
# Epoch 58/100
# 3847/3847 [==============================] - 2s 620us/step - loss: 0.0022 - val_loss: 0.0035
#
# Epoch 00058: val_loss did not improve from 0.00224
#
# Epoch 00058: loss did not improve from 0.00219
# Epoch 59/100
# 3847/3847 [==============================] - 3s 657us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00059: val_loss did not improve from 0.00224
#
# Epoch 00059: loss improved from 0.00219 to 0.00216, saving model to DNNLSTMmodel2.h5
# Epoch 60/100
# 3847/3847 [==============================] - 3s 677us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00060: val_loss did not improve from 0.00224
#
# Epoch 00060: loss improved from 0.00216 to 0.00214, saving model to DNNLSTMmodel2.h5
# Epoch 61/100
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00061: val_loss did not improve from 0.00224
#
# Epoch 00061: loss did not improve from 0.00214
# Epoch 62/100
# 3847/3847 [==============================] - 3s 676us/step - loss: 0.0022 - val_loss: 0.0041
#
# Epoch 00062: val_loss did not improve from 0.00224
#
# Epoch 00062: loss did not improve from 0.00214
# Epoch 63/100
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0021 - val_loss: 0.0041
#
# Epoch 00063: val_loss did not improve from 0.00224
#
# Epoch 00063: loss improved from 0.00214 to 0.00211, saving model to DNNLSTMmodel2.h5
# Epoch 64/100
# 3847/3847 [==============================] - 3s 736us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00064: val_loss did not improve from 0.00224
#
# Epoch 00064: loss did not improve from 0.00211
# Epoch 65/100
# 3847/3847 [==============================] - 3s 731us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00065: val_loss did not improve from 0.00224
#
# Epoch 00065: loss did not improve from 0.00211
# Epoch 66/100
# 3847/3847 [==============================] - 2s 646us/step - loss: 0.0022 - val_loss: 0.0046
#
# Epoch 00066: val_loss did not improve from 0.00224
#
# Epoch 00066: loss did not improve from 0.00211
# Epoch 67/100
# 3847/3847 [==============================] - 3s 712us/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00067: val_loss did not improve from 0.00224
#
# Epoch 00067: loss improved from 0.00211 to 0.00207, saving model to DNNLSTMmodel2.h5
# Epoch 68/100
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00068: val_loss did not improve from 0.00224
#
# Epoch 00068: loss did not improve from 0.00207
# Epoch 69/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00069: val_loss did not improve from 0.00224
#
# Epoch 00069: loss improved from 0.00207 to 0.00207, saving model to DNNLSTMmodel2.h5
# Epoch 70/100
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00070: val_loss did not improve from 0.00224
#
# Epoch 00070: loss did not improve from 0.00207
# Epoch 71/100
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00071: val_loss did not improve from 0.00224
#
# Epoch 00071: loss improved from 0.00207 to 0.00206, saving model to DNNLSTMmodel2.h5
# Epoch 72/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0020 - val_loss: 0.0042
#
# Epoch 00072: val_loss did not improve from 0.00224
#
# Epoch 00072: loss improved from 0.00206 to 0.00200, saving model to DNNLSTMmodel2.h5
# Epoch 73/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00073: val_loss did not improve from 0.00224
#
# Epoch 00073: loss did not improve from 0.00200
# Epoch 74/100
# 3847/3847 [==============================] - 3s 717us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00074: val_loss did not improve from 0.00224
#
# Epoch 00074: loss did not improve from 0.00200
# Epoch 75/100
# 3847/3847 [==============================] - 2s 638us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00075: val_loss did not improve from 0.00224
#
# Epoch 00075: loss did not improve from 0.00200
# Epoch 76/100
# 3847/3847 [==============================] - 3s 707us/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00076: val_loss did not improve from 0.00224
#
# Epoch 00076: loss improved from 0.00200 to 0.00200, saving model to DNNLSTMmodel2.h5
# Epoch 77/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00077: val_loss did not improve from 0.00224
#
# Epoch 00077: loss improved from 0.00200 to 0.00198, saving model to DNNLSTMmodel2.h5
# Epoch 78/100
# 3847/3847 [==============================] - 3s 692us/step - loss: 0.0020 - val_loss: 0.0038
#
# Epoch 00078: val_loss did not improve from 0.00224
#
# Epoch 00078: loss did not improve from 0.00198
# Epoch 79/100
# 3847/3847 [==============================] - 3s 684us/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00079: val_loss did not improve from 0.00224
#
# Epoch 00079: loss did not improve from 0.00198
# Epoch 80/100
# 3847/3847 [==============================] - 3s 655us/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00080: val_loss did not improve from 0.00224
#
# Epoch 00080: loss did not improve from 0.00198
# Epoch 81/100
# 3847/3847 [==============================] - 3s 652us/step - loss: 0.0021 - val_loss: 0.0026
#
# Epoch 00081: val_loss did not improve from 0.00224
#
# Epoch 00081: loss did not improve from 0.00198
# Epoch 82/100
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0021 - val_loss: 0.0042
#
# Epoch 00082: val_loss did not improve from 0.00224
#
# Epoch 00082: loss did not improve from 0.00198
# Epoch 83/100
# 3847/3847 [==============================] - 3s 680us/step - loss: 0.0020 - val_loss: 0.0038
#
# Epoch 00083: val_loss did not improve from 0.00224
#
# Epoch 00083: loss did not improve from 0.00198
# Epoch 84/100
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0019 - val_loss: 0.0033
#
# Epoch 00084: val_loss did not improve from 0.00224
#
# Epoch 00084: loss improved from 0.00198 to 0.00189, saving model to DNNLSTMmodel2.h5
# Epoch 85/100
# 3847/3847 [==============================] - 3s 678us/step - loss: 0.0020 - val_loss: 0.0033
#
# Epoch 00085: val_loss did not improve from 0.00224
#
# Epoch 00085: loss did not improve from 0.00189
# Epoch 86/100
# 3847/3847 [==============================] - 3s 690us/step - loss: 0.0020 - val_loss: 0.0040
#
# Epoch 00086: val_loss did not improve from 0.00224
#
# Epoch 00086: loss did not improve from 0.00189
# Epoch 87/100
# 3847/3847 [==============================] - 3s 678us/step - loss: 0.0019 - val_loss: 0.0045
#
# Epoch 00087: val_loss did not improve from 0.00224
#
# Epoch 00087: loss improved from 0.00189 to 0.00188, saving model to DNNLSTMmodel2.h5
# Epoch 88/100
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00088: val_loss did not improve from 0.00224
#
# Epoch 00088: loss did not improve from 0.00188
# Epoch 89/100
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00089: val_loss did not improve from 0.00224
#
# Epoch 00089: loss did not improve from 0.00188
# Epoch 90/100
# 3847/3847 [==============================] - 3s 746us/step - loss: 0.0019 - val_loss: 0.0038
#
# Epoch 00090: val_loss did not improve from 0.00224
#
# Epoch 00090: loss did not improve from 0.00188
# Epoch 91/100
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0020 - val_loss: 0.0041
#
# Epoch 00091: val_loss did not improve from 0.00224
#
# Epoch 00091: loss did not improve from 0.00188
# Epoch 92/100
# 3847/3847 [==============================] - 3s 728us/step - loss: 0.0019 - val_loss: 0.0037
#
# Epoch 00092: val_loss did not improve from 0.00224
#
# Epoch 00092: loss did not improve from 0.00188
# Epoch 93/100
# 3847/3847 [==============================] - 3s 710us/step - loss: 0.0019 - val_loss: 0.0049
#
# Epoch 00093: val_loss did not improve from 0.00224
#
# Epoch 00093: loss did not improve from 0.00188
# Epoch 94/100
# 3847/3847 [==============================] - 3s 691us/step - loss: 0.0020 - val_loss: 0.0040
#
# Epoch 00094: val_loss did not improve from 0.00224
#
# Epoch 00094: loss did not improve from 0.00188
# Epoch 95/100
# 3847/3847 [==============================] - 3s 701us/step - loss: 0.0019 - val_loss: 0.0035
#
# Epoch 00095: val_loss did not improve from 0.00224
#
# Epoch 00095: loss did not improve from 0.00188
# Epoch 96/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00096: val_loss did not improve from 0.00224
#
# Epoch 00096: loss improved from 0.00188 to 0.00188, saving model to DNNLSTMmodel2.h5
# Epoch 97/100
# 3847/3847 [==============================] - 3s 743us/step - loss: 0.0018 - val_loss: 0.0047
#
# Epoch 00097: val_loss did not improve from 0.00224
#
# Epoch 00097: loss improved from 0.00188 to 0.00178, saving model to DNNLSTMmodel2.h5
# Epoch 98/100
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0018 - val_loss: 0.0030
#
# Epoch 00098: val_loss did not improve from 0.00224
#
# Epoch 00098: loss improved from 0.00178 to 0.00177, saving model to DNNLSTMmodel2.h5
# Epoch 99/100
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0019 - val_loss: 0.0038
#
# Epoch 00099: val_loss did not improve from 0.00224
#
# Epoch 00099: loss did not improve from 0.00177
# Epoch 100/100
# 3847/3847 [==============================] - 3s 745us/step - loss: 0.0018 - val_loss: 0.0032
#
# Epoch 00100: val_loss did not improve from 0.00224
#
# Epoch 00100: loss did not improve from 0.00177
# Model loaded
# mae :  3737.5741883116884
# mse :  32044534.998772882
# rmse :  5660.789255816973
# std : 5366.921811973905

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0064 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00248, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 749us/step - loss: 0.0039 - val_loss: 0.0086
#
# Epoch 00002: val_loss did not improve from 0.00248
# Epoch 3/70
# 3847/3847 [==============================] - 3s 690us/step - loss: 0.0038 - val_loss: 0.0035
#
# Epoch 00003: val_loss did not improve from 0.00248
# Epoch 4/70
# 3847/3847 [==============================] - 3s 719us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00004: val_loss did not improve from 0.00248
# Epoch 5/70
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0035 - val_loss: 0.0039
#
# Epoch 00005: val_loss did not improve from 0.00248
# Epoch 6/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0035 - val_loss: 0.0039
#
# Epoch 00006: val_loss did not improve from 0.00248
# Epoch 7/70
# 3847/3847 [==============================] - 3s 786us/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00248
# Epoch 8/70
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0031 - val_loss: 0.0040
#
# Epoch 00008: val_loss did not improve from 0.00248
# Epoch 9/70
# 3847/3847 [==============================] - 3s 855us/step - loss: 0.0030 - val_loss: 0.0024
#
# Epoch 00009: val_loss improved from 0.00248 to 0.00237, saving model to DNNLSTMmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 3s 779us/step - loss: 0.0034 - val_loss: 0.0020
#
# Epoch 00010: val_loss improved from 0.00237 to 0.00200, saving model to DNNLSTMmodel.h5
# Epoch 11/70
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0031 - val_loss: 0.0034
#
# Epoch 00011: val_loss did not improve from 0.00200
# Epoch 12/70
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0028 - val_loss: 0.0024
#
# Epoch 00012: val_loss did not improve from 0.00200
# Epoch 13/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0028 - val_loss: 0.0047
#
# Epoch 00013: val_loss did not improve from 0.00200
# Epoch 14/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0028 - val_loss: 0.0042
#
# Epoch 00014: val_loss did not improve from 0.00200
# Epoch 15/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00015: val_loss did not improve from 0.00200
# Epoch 16/70
# 3847/3847 [==============================] - 3s 779us/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00016: val_loss did not improve from 0.00200
# Epoch 17/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00017: val_loss did not improve from 0.00200
# Epoch 18/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00018: val_loss did not improve from 0.00200
# Epoch 19/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00019: val_loss did not improve from 0.00200
# Epoch 20/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00020: val_loss did not improve from 0.00200
# Epoch 21/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00021: val_loss did not improve from 0.00200
# Epoch 22/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0028 - val_loss: 0.0053
#
# Epoch 00022: val_loss did not improve from 0.00200
# Epoch 23/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0027 - val_loss: 0.0023
#
# Epoch 00023: val_loss did not improve from 0.00200
# Epoch 24/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00024: val_loss did not improve from 0.00200
# Epoch 25/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00025: val_loss did not improve from 0.00200
# Epoch 26/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00026: val_loss did not improve from 0.00200
# Epoch 27/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00027: val_loss did not improve from 0.00200
# Epoch 28/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00028: val_loss did not improve from 0.00200
# Epoch 29/70
# 3847/3847 [==============================] - 3s 779us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00029: val_loss did not improve from 0.00200
# Epoch 30/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00030: val_loss did not improve from 0.00200
# Epoch 31/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00031: val_loss did not improve from 0.00200
# Epoch 32/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00032: val_loss did not improve from 0.00200
# Epoch 33/70
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0026 - val_loss: 0.0045
#
# Epoch 00033: val_loss did not improve from 0.00200
# Epoch 34/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00034: val_loss did not improve from 0.00200
# Epoch 35/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00035: val_loss did not improve from 0.00200
# Epoch 36/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00036: val_loss did not improve from 0.00200
# Epoch 37/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00037: val_loss did not improve from 0.00200
# Epoch 38/70
# 3847/3847 [==============================] - 3s 779us/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00038: val_loss did not improve from 0.00200
# Epoch 39/70
# 3847/3847 [==============================] - 3s 794us/step - loss: 0.0023 - val_loss: 0.0039
#
# Epoch 00039: val_loss did not improve from 0.00200
# Epoch 40/70
# 3847/3847 [==============================] - 3s 782us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00040: val_loss did not improve from 0.00200
# Epoch 41/70
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00041: val_loss did not improve from 0.00200
# Epoch 42/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00200
# Epoch 43/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0039
#
# Epoch 00043: val_loss did not improve from 0.00200
# Epoch 44/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00044: val_loss did not improve from 0.00200
# Epoch 45/70
# 3847/3847 [==============================] - 3s 782us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00045: val_loss did not improve from 0.00200
# Epoch 46/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0023 - val_loss: 0.0040
#
# Epoch 00046: val_loss did not improve from 0.00200
# Epoch 47/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0042
#
# Epoch 00047: val_loss did not improve from 0.00200
# Epoch 48/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0042
#
# Epoch 00048: val_loss did not improve from 0.00200
# Epoch 49/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0050
#
# Epoch 00049: val_loss did not improve from 0.00200
# Epoch 50/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00050: val_loss did not improve from 0.00200
# Epoch 51/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00051: val_loss did not improve from 0.00200
# Epoch 52/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00052: val_loss did not improve from 0.00200
# Epoch 53/70
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00053: val_loss did not improve from 0.00200
# Epoch 54/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00054: val_loss did not improve from 0.00200
# Epoch 55/70
# 3847/3847 [==============================] - 3s 830us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00055: val_loss did not improve from 0.00200
# Epoch 56/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0021 - val_loss: 0.0042
#
# Epoch 00056: val_loss did not improve from 0.00200
# Epoch 57/70
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00057: val_loss did not improve from 0.00200
# Epoch 58/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00058: val_loss did not improve from 0.00200
# Epoch 59/70
# 3847/3847 [==============================] - 3s 790us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00059: val_loss did not improve from 0.00200
# Epoch 60/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00060: val_loss did not improve from 0.00200
# Epoch 61/70
# 3847/3847 [==============================] - 3s 790us/step - loss: 0.0020 - val_loss: 0.0042
#
# Epoch 00061: val_loss did not improve from 0.00200
# Epoch 62/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0020 - val_loss: 0.0044
#
# Epoch 00062: val_loss did not improve from 0.00200
# Epoch 63/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00063: val_loss did not improve from 0.00200
# Epoch 64/70
# 3847/3847 [==============================] - 3s 788us/step - loss: 0.0020 - val_loss: 0.0038
#
# Epoch 00064: val_loss did not improve from 0.00200
# Epoch 65/70
# 3847/3847 [==============================] - 3s 788us/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00065: val_loss did not improve from 0.00200
# Epoch 66/70
# 3847/3847 [==============================] - 3s 785us/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00066: val_loss did not improve from 0.00200
# Epoch 67/70
# 3847/3847 [==============================] - 3s 784us/step - loss: 0.0020 - val_loss: 0.0038
#
# Epoch 00067: val_loss did not improve from 0.00200
# Epoch 68/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00068: val_loss did not improve from 0.00200
# Epoch 69/70
# 3847/3847 [==============================] - 3s 793us/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00069: val_loss did not improve from 0.00200
# Epoch 70/70
# 3847/3847 [==============================] - 3s 788us/step - loss: 0.0019 - val_loss: 0.0034
#
# Epoch 00070: val_loss did not improve from 0.00200
# Model loaded
# mae :  4052.504994736709
# mse :  34117761.48969374
# rmse :  5841.04113062849
# std : 5199.172113292461

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 8s 2ms/step - loss: 0.0077 - val_loss: 0.0033
#
# Epoch 00001: val_loss improved from inf to 0.00329, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 734us/step - loss: 0.0043 - val_loss: 0.0025
#
# Epoch 00002: val_loss improved from 0.00329 to 0.00247, saving model to DNNLSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 3s 729us/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00003: val_loss did not improve from 0.00247
# Epoch 4/70
# 3847/3847 [==============================] - 3s 727us/step - loss: 0.0035 - val_loss: 0.0037
#
# Epoch 00004: val_loss did not improve from 0.00247
# Epoch 5/70
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0034 - val_loss: 0.0045
#
# Epoch 00005: val_loss did not improve from 0.00247
# Epoch 6/70
# 3847/3847 [==============================] - 3s 725us/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00006: val_loss did not improve from 0.00247
# Epoch 7/70
# 3847/3847 [==============================] - 3s 739us/step - loss: 0.0034 - val_loss: 0.0042
#
# Epoch 00007: val_loss did not improve from 0.00247
# Epoch 8/70
# 3847/3847 [==============================] - 3s 740us/step - loss: 0.0033 - val_loss: 0.0035
#
# Epoch 00008: val_loss did not improve from 0.00247
# Epoch 9/70
# 3847/3847 [==============================] - 3s 723us/step - loss: 0.0033 - val_loss: 0.0038
#
# Epoch 00009: val_loss did not improve from 0.00247
# Epoch 10/70
# 3847/3847 [==============================] - 3s 723us/step - loss: 0.0032 - val_loss: 0.0048
#
# Epoch 00010: val_loss did not improve from 0.00247
# Epoch 11/70
# 3847/3847 [==============================] - 3s 723us/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00247
# Epoch 12/70
# 3847/3847 [==============================] - 3s 722us/step - loss: 0.0031 - val_loss: 0.0038
#
# Epoch 00012: val_loss did not improve from 0.00247
# Epoch 13/70
# 3847/3847 [==============================] - 3s 724us/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00013: val_loss did not improve from 0.00247
# Epoch 14/70
# 3847/3847 [==============================] - 3s 727us/step - loss: 0.0031 - val_loss: 0.0044
#
# Epoch 00014: val_loss did not improve from 0.00247
# Epoch 15/70
# 3847/3847 [==============================] - 3s 721us/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00015: val_loss did not improve from 0.00247
# Epoch 16/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00016: val_loss did not improve from 0.00247
# Epoch 17/70
# 3847/3847 [==============================] - 3s 802us/step - loss: 0.0029 - val_loss: 0.0034
#
# Epoch 00017: val_loss did not improve from 0.00247
# Epoch 18/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0029 - val_loss: 0.0026
#
# Epoch 00018: val_loss did not improve from 0.00247
# Epoch 19/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00019: val_loss did not improve from 0.00247
# Epoch 20/70
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00020: val_loss did not improve from 0.00247
# Epoch 21/70
# 3847/3847 [==============================] - 3s 784us/step - loss: 0.0029 - val_loss: 0.0045
#
# Epoch 00021: val_loss did not improve from 0.00247
# Epoch 22/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00022: val_loss did not improve from 0.00247
# Epoch 23/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0027 - val_loss: 0.0045
#
# Epoch 00023: val_loss did not improve from 0.00247
# Epoch 24/70
# 3847/3847 [==============================] - 3s 767us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00024: val_loss did not improve from 0.00247
# Epoch 25/70
# 3847/3847 [==============================] - 3s 767us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00025: val_loss did not improve from 0.00247
# Epoch 26/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00026: val_loss did not improve from 0.00247
# Epoch 27/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00027: val_loss did not improve from 0.00247
# Epoch 28/70
# 3847/3847 [==============================] - 3s 771us/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00028: val_loss did not improve from 0.00247
# Epoch 29/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00029: val_loss did not improve from 0.00247
# Epoch 30/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00030: val_loss did not improve from 0.00247
# Epoch 31/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00031: val_loss did not improve from 0.00247
# Epoch 32/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00032: val_loss did not improve from 0.00247
# Epoch 33/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00033: val_loss did not improve from 0.00247
# Epoch 34/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00034: val_loss did not improve from 0.00247
# Epoch 35/70
# 3847/3847 [==============================] - 3s 769us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00035: val_loss did not improve from 0.00247
# Epoch 36/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00036: val_loss did not improve from 0.00247
# Epoch 37/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00037: val_loss did not improve from 0.00247
# Epoch 38/70
# 3847/3847 [==============================] - 3s 784us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00038: val_loss did not improve from 0.00247
# Epoch 39/70
# 3847/3847 [==============================] - 3s 801us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00039: val_loss did not improve from 0.00247
# Epoch 40/70
# 3847/3847 [==============================] - 3s 804us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00040: val_loss did not improve from 0.00247
# Epoch 41/70
# 3847/3847 [==============================] - 3s 786us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00041: val_loss did not improve from 0.00247
# Epoch 42/70
# 3847/3847 [==============================] - 3s 805us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00042: val_loss did not improve from 0.00247
# Epoch 43/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00043: val_loss did not improve from 0.00247
# Epoch 44/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00044: val_loss did not improve from 0.00247
# Epoch 45/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00045: val_loss did not improve from 0.00247
# Epoch 46/70
# 3847/3847 [==============================] - 3s 780us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00046: val_loss did not improve from 0.00247
# Epoch 47/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00047: val_loss did not improve from 0.00247
# Epoch 48/70
# 3847/3847 [==============================] - 3s 781us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00048: val_loss did not improve from 0.00247
# Epoch 49/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0023 - val_loss: 0.0042
#
# Epoch 00049: val_loss did not improve from 0.00247
# Epoch 50/70
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0022 - val_loss: 0.0041
#
# Epoch 00050: val_loss did not improve from 0.00247
# Epoch 51/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0022 - val_loss: 0.0034
#
# Epoch 00051: val_loss did not improve from 0.00247
# Epoch 52/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00052: val_loss did not improve from 0.00247
# Epoch 53/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00053: val_loss did not improve from 0.00247
# Epoch 54/70
# 3847/3847 [==============================] - 3s 778us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00054: val_loss improved from 0.00247 to 0.00245, saving model to DNNLSTMmodel.h5
# Epoch 55/70
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0022 - val_loss: 0.0046
#
# Epoch 00055: val_loss did not improve from 0.00245
# Epoch 56/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0021 - val_loss: 0.0037
#
# Epoch 00056: val_loss did not improve from 0.00245
# Epoch 57/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0021 - val_loss: 0.0039
#
# Epoch 00057: val_loss did not improve from 0.00245
# Epoch 58/70
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00058: val_loss did not improve from 0.00245
# Epoch 59/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0022 - val_loss: 0.0035
#
# Epoch 00059: val_loss did not improve from 0.00245
# Epoch 60/70
# 3847/3847 [==============================] - 3s 787us/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00060: val_loss did not improve from 0.00245
# Epoch 61/70
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0021 - val_loss: 0.0041
#
# Epoch 00061: val_loss did not improve from 0.00245
# Epoch 62/70
# 3847/3847 [==============================] - 3s 772us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00062: val_loss did not improve from 0.00245
# Epoch 63/70
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00063: val_loss did not improve from 0.00245
# Epoch 64/70
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0020 - val_loss: 0.0033
#
# Epoch 00064: val_loss did not improve from 0.00245
# Epoch 65/70
# 3847/3847 [==============================] - 3s 788us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00065: val_loss did not improve from 0.00245
# Epoch 66/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00066: val_loss did not improve from 0.00245
# Epoch 67/70
# 3847/3847 [==============================] - 3s 779us/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00067: val_loss did not improve from 0.00245
# Epoch 68/70
# 3847/3847 [==============================] - 3s 785us/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00068: val_loss improved from 0.00245 to 0.00244, saving model to DNNLSTMmodel.h5
# Epoch 69/70
# 3847/3847 [==============================] - 3s 787us/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00069: val_loss did not improve from 0.00244
# Epoch 70/70
# 3847/3847 [==============================] - 3s 771us/step - loss: 0.0019 - val_loss: 0.0038
#
# Epoch 00070: val_loss did not improve from 0.00244
# Model loaded
# mae :  4190.9596688431575
# mse :  37757601.36690537
# rmse :  6144.721423051282
# std : 5576.911110569038

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 10s 2ms/step - loss: 0.0062 - val_loss: 0.0034
#
# Epoch 00001: val_loss improved from inf to 0.00342, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 946us/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00002: val_loss did not improve from 0.00342
# Epoch 3/70
# 3847/3847 [==============================] - 3s 806us/step - loss: 0.0039 - val_loss: 0.0035
#
# Epoch 00003: val_loss did not improve from 0.00342
# Epoch 4/70
# 3847/3847 [==============================] - 3s 790us/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00004: val_loss did not improve from 0.00342
# Epoch 5/70
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0037 - val_loss: 0.0043
#
# Epoch 00005: val_loss did not improve from 0.00342
# Epoch 6/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0034 - val_loss: 0.0026
#
# Epoch 00006: val_loss improved from 0.00342 to 0.00263, saving model to DNNLSTMmodel.h5
# Epoch 7/70
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00007: val_loss did not improve from 0.00263
# Epoch 8/70
# 3847/3847 [==============================] - 3s 819us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00008: val_loss did not improve from 0.00263
# Epoch 9/70
# 3847/3847 [==============================] - 3s 829us/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00009: val_loss did not improve from 0.00263
# Epoch 10/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0030 - val_loss: 0.0041
#
# Epoch 00010: val_loss did not improve from 0.00263
# Epoch 11/70
# 3847/3847 [==============================] - 4s 932us/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00263
# Epoch 12/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0030 - val_loss: 0.0038
#
# Epoch 00012: val_loss did not improve from 0.00263
# Epoch 13/70
# 3847/3847 [==============================] - 3s 827us/step - loss: 0.0030 - val_loss: 0.0048
#
# Epoch 00013: val_loss did not improve from 0.00263
# Epoch 14/70
# 3847/3847 [==============================] - 3s 850us/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00014: val_loss did not improve from 0.00263
# Epoch 15/70
# 3847/3847 [==============================] - 3s 823us/step - loss: 0.0029 - val_loss: 0.0031
#
# Epoch 00015: val_loss did not improve from 0.00263
# Epoch 16/70
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0029 - val_loss: 0.0041
#
# Epoch 00016: val_loss did not improve from 0.00263
# Epoch 17/70
# 3847/3847 [==============================] - 3s 824us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00017: val_loss did not improve from 0.00263
# Epoch 18/70
# 3847/3847 [==============================] - 3s 826us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00018: val_loss did not improve from 0.00263
# Epoch 19/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00019: val_loss did not improve from 0.00263
# Epoch 20/70
# 3847/3847 [==============================] - 3s 824us/step - loss: 0.0028 - val_loss: 0.0048
#
# Epoch 00020: val_loss did not improve from 0.00263
# Epoch 21/70
# 3847/3847 [==============================] - 3s 821us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00021: val_loss did not improve from 0.00263
# Epoch 22/70
# 3847/3847 [==============================] - 3s 813us/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00022: val_loss did not improve from 0.00263
# Epoch 23/70
# 3847/3847 [==============================] - 3s 828us/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00023: val_loss did not improve from 0.00263
# Epoch 24/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00024: val_loss did not improve from 0.00263
# Epoch 25/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0026 - val_loss: 0.0052
#
# Epoch 00025: val_loss did not improve from 0.00263
# Epoch 26/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00026: val_loss did not improve from 0.00263
# Epoch 27/70
# 3847/3847 [==============================] - 3s 827us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00027: val_loss did not improve from 0.00263
# Epoch 28/70
# 3847/3847 [==============================] - 3s 847us/step - loss: 0.0027 - val_loss: 0.0024
#
# Epoch 00028: val_loss improved from 0.00263 to 0.00238, saving model to DNNLSTMmodel.h5
# Epoch 29/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00029: val_loss did not improve from 0.00238
# Epoch 30/70
# 3847/3847 [==============================] - 3s 819us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00030: val_loss did not improve from 0.00238
# Epoch 31/70
# 3847/3847 [==============================] - 3s 842us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00031: val_loss did not improve from 0.00238
# Epoch 32/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00032: val_loss did not improve from 0.00238
# Epoch 33/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00033: val_loss did not improve from 0.00238
# Epoch 34/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00034: val_loss did not improve from 0.00238
# Epoch 35/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00035: val_loss did not improve from 0.00238
# Epoch 36/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00036: val_loss did not improve from 0.00238
# Epoch 37/70
# 3847/3847 [==============================] - 3s 820us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00037: val_loss did not improve from 0.00238
# Epoch 38/70
# 3847/3847 [==============================] - 3s 821us/step - loss: 0.0024 - val_loss: 0.0051
#
# Epoch 00038: val_loss did not improve from 0.00238
# Epoch 39/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0022 - val_loss: 0.0043
#
# Epoch 00039: val_loss did not improve from 0.00238
# Epoch 40/70
# 3847/3847 [==============================] - 3s 820us/step - loss: 0.0023 - val_loss: 0.0049
#
# Epoch 00040: val_loss did not improve from 0.00238
# Epoch 41/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00041: val_loss did not improve from 0.00238
# Epoch 42/70
# 3847/3847 [==============================] - 3s 819us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00238
# Epoch 43/70
# 3847/3847 [==============================] - 3s 845us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00043: val_loss did not improve from 0.00238
# Epoch 44/70
# 3847/3847 [==============================] - 3s 850us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00044: val_loss did not improve from 0.00238
# Epoch 45/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0022 - val_loss: 0.0042
#
# Epoch 00045: val_loss did not improve from 0.00238
# Epoch 46/70
# 3847/3847 [==============================] - 3s 835us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00046: val_loss did not improve from 0.00238
# Epoch 47/70
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0023 - val_loss: 0.0039
#
# Epoch 00047: val_loss did not improve from 0.00238
# Epoch 48/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00048: val_loss did not improve from 0.00238
# Epoch 49/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00049: val_loss did not improve from 0.00238
# Epoch 50/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0022 - val_loss: 0.0037
#
# Epoch 00050: val_loss did not improve from 0.00238
# Epoch 51/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00238
# Epoch 52/70
# 3847/3847 [==============================] - 3s 798us/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00052: val_loss did not improve from 0.00238
# Epoch 53/70
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00053: val_loss did not improve from 0.00238
# Epoch 54/70
# 3847/3847 [==============================] - 3s 829us/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00054: val_loss did not improve from 0.00238
# Epoch 55/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00055: val_loss did not improve from 0.00238
# Epoch 56/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0022 - val_loss: 0.0037
#
# Epoch 00056: val_loss did not improve from 0.00238
# Epoch 57/70
# 3847/3847 [==============================] - 3s 798us/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00057: val_loss did not improve from 0.00238
# Epoch 58/70
# 3847/3847 [==============================] - 3s 807us/step - loss: 0.0021 - val_loss: 0.0042
#
# Epoch 00058: val_loss did not improve from 0.00238
# Epoch 59/70
# 3847/3847 [==============================] - 3s 799us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00059: val_loss did not improve from 0.00238
# Epoch 60/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0020 - val_loss: 0.0035
#
# Epoch 00060: val_loss did not improve from 0.00238
# Epoch 61/70
# 3847/3847 [==============================] - 3s 803us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00061: val_loss did not improve from 0.00238
# Epoch 62/70
# 3847/3847 [==============================] - 3s 807us/step - loss: 0.0019 - val_loss: 0.0036
#
# Epoch 00062: val_loss did not improve from 0.00238
# Epoch 63/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00063: val_loss did not improve from 0.00238
# Epoch 64/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00064: val_loss did not improve from 0.00238
# Epoch 65/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00065: val_loss did not improve from 0.00238
# Epoch 66/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0020 - val_loss: 0.0053
#
# Epoch 00066: val_loss did not improve from 0.00238
# Epoch 67/70
# 3847/3847 [==============================] - 3s 831us/step - loss: 0.0020 - val_loss: 0.0035
#
# Epoch 00067: val_loss did not improve from 0.00238
# Epoch 68/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00068: val_loss did not improve from 0.00238
# Epoch 69/70
# 3847/3847 [==============================] - 3s 823us/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00069: val_loss did not improve from 0.00238
# Epoch 70/70
# 3847/3847 [==============================] - 3s 823us/step - loss: 0.0018 - val_loss: 0.0041
#
# Epoch 00070: val_loss did not improve from 0.00238
# Model loaded
# mae :  4188.068869107729
# mse :  35641110.86095542
# rmse :  5970.017660020397
# std : 5314.300373115978

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 10s 3ms/step - loss: 0.0108 - val_loss: 0.0038
#
# Epoch 00001: val_loss improved from inf to 0.00379, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 773us/step - loss: 0.0044 - val_loss: 0.0051
#
# Epoch 00002: val_loss did not improve from 0.00379
# Epoch 3/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0043 - val_loss: 0.0020
#
# Epoch 00003: val_loss improved from 0.00379 to 0.00205, saving model to DNNLSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 776us/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00004: val_loss did not improve from 0.00205
# Epoch 5/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0034 - val_loss: 0.0030
#
# Epoch 00005: val_loss did not improve from 0.00205
# Epoch 6/70
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0035 - val_loss: 0.0027
#
# Epoch 00006: val_loss did not improve from 0.00205
# Epoch 7/70
# 3847/3847 [==============================] - 3s 752us/step - loss: 0.0034 - val_loss: 0.0048
#
# Epoch 00007: val_loss did not improve from 0.00205
# Epoch 8/70
# 3847/3847 [==============================] - 3s 775us/step - loss: 0.0033 - val_loss: 0.0048
#
# Epoch 00008: val_loss did not improve from 0.00205
# Epoch 9/70
# 3847/3847 [==============================] - 3s 765us/step - loss: 0.0032 - val_loss: 0.0051
#
# Epoch 00009: val_loss did not improve from 0.00205
# Epoch 10/70
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0032 - val_loss: 0.0043
#
# Epoch 00010: val_loss did not improve from 0.00205
# Epoch 11/70
# 3847/3847 [==============================] - 3s 759us/step - loss: 0.0030 - val_loss: 0.0030
#
# Epoch 00011: val_loss did not improve from 0.00205
# Epoch 12/70
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0031 - val_loss: 0.0030
#
# Epoch 00012: val_loss did not improve from 0.00205
# Epoch 13/70
# 3847/3847 [==============================] - 3s 785us/step - loss: 0.0033 - val_loss: 0.0043
#
# Epoch 00013: val_loss did not improve from 0.00205
# Epoch 14/70
# 3847/3847 [==============================] - 3s 817us/step - loss: 0.0032 - val_loss: 0.0061
#
# Epoch 00014: val_loss did not improve from 0.00205
# Epoch 15/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00015: val_loss did not improve from 0.00205
# Epoch 16/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00016: val_loss did not improve from 0.00205
# Epoch 17/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0030 - val_loss: 0.0040
#
# Epoch 00017: val_loss did not improve from 0.00205
# Epoch 18/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00018: val_loss did not improve from 0.00205
# Epoch 19/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00019: val_loss did not improve from 0.00205
# Epoch 20/70
# 3847/3847 [==============================] - 3s 835us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00020: val_loss did not improve from 0.00205
# Epoch 21/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00021: val_loss did not improve from 0.00205
# Epoch 22/70
# 3847/3847 [==============================] - 3s 834us/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00022: val_loss did not improve from 0.00205
# Epoch 23/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00023: val_loss did not improve from 0.00205
# Epoch 24/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00024: val_loss did not improve from 0.00205
# Epoch 25/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00025: val_loss did not improve from 0.00205
# Epoch 26/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0028 - val_loss: 0.0043
#
# Epoch 00026: val_loss did not improve from 0.00205
# Epoch 27/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00027: val_loss did not improve from 0.00205
# Epoch 28/70
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00028: val_loss did not improve from 0.00205
# Epoch 29/70
# 3847/3847 [==============================] - 3s 865us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00029: val_loss did not improve from 0.00205
# Epoch 30/70
# 3847/3847 [==============================] - 4s 951us/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00030: val_loss did not improve from 0.00205
# Epoch 31/70
# 3847/3847 [==============================] - 3s 833us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00031: val_loss did not improve from 0.00205
# Epoch 32/70
# 3847/3847 [==============================] - 3s 802us/step - loss: 0.0026 - val_loss: 0.0059
#
# Epoch 00032: val_loss did not improve from 0.00205
# Epoch 33/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00033: val_loss did not improve from 0.00205
# Epoch 34/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00034: val_loss did not improve from 0.00205
# Epoch 35/70
# 3847/3847 [==============================] - 3s 803us/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00035: val_loss did not improve from 0.00205
# Epoch 36/70
# 3847/3847 [==============================] - 3s 805us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00036: val_loss did not improve from 0.00205
# Epoch 37/70
# 3847/3847 [==============================] - 3s 803us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00037: val_loss did not improve from 0.00205
# Epoch 38/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00038: val_loss did not improve from 0.00205
# Epoch 39/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0026 - val_loss: 0.0051
#
# Epoch 00039: val_loss did not improve from 0.00205
# Epoch 40/70
# 3847/3847 [==============================] - 3s 802us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00040: val_loss did not improve from 0.00205
# Epoch 41/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00041: val_loss did not improve from 0.00205
# Epoch 42/70
# 3847/3847 [==============================] - 4s 911us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00042: val_loss did not improve from 0.00205
# Epoch 43/70
# 3847/3847 [==============================] - 3s 830us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00043: val_loss did not improve from 0.00205
# Epoch 44/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00044: val_loss did not improve from 0.00205
# Epoch 45/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00205
# Epoch 46/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00046: val_loss did not improve from 0.00205
# Epoch 47/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00047: val_loss did not improve from 0.00205
# Epoch 48/70
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0023 - val_loss: 0.0032
#
# Epoch 00048: val_loss did not improve from 0.00205
# Epoch 49/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00049: val_loss did not improve from 0.00205
# Epoch 50/70
# 3847/3847 [==============================] - 3s 820us/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00050: val_loss did not improve from 0.00205
# Epoch 51/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00205
# Epoch 52/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00052: val_loss did not improve from 0.00205
# Epoch 53/70
# 3847/3847 [==============================] - 3s 813us/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00053: val_loss did not improve from 0.00205
# Epoch 54/70
# 3847/3847 [==============================] - 3s 826us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00054: val_loss did not improve from 0.00205
# Epoch 55/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0023 - val_loss: 0.0040
#
# Epoch 00055: val_loss did not improve from 0.00205
# Epoch 56/70
# 3847/3847 [==============================] - 3s 809us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00056: val_loss did not improve from 0.00205
# Epoch 57/70
# 3847/3847 [==============================] - 3s 818us/step - loss: 0.0022 - val_loss: 0.0050
#
# Epoch 00057: val_loss did not improve from 0.00205
# Epoch 58/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00058: val_loss did not improve from 0.00205
# Epoch 59/70
# 3847/3847 [==============================] - 3s 811us/step - loss: 0.0021 - val_loss: 0.0041
#
# Epoch 00059: val_loss did not improve from 0.00205
# Epoch 60/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00060: val_loss did not improve from 0.00205
# Epoch 61/70
# 3847/3847 [==============================] - 3s 813us/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00061: val_loss did not improve from 0.00205
# Epoch 62/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00062: val_loss did not improve from 0.00205
# Epoch 63/70
# 3847/3847 [==============================] - 3s 822us/step - loss: 0.0022 - val_loss: 0.0048
#
# Epoch 00063: val_loss did not improve from 0.00205
# Epoch 64/70
# 3847/3847 [==============================] - 3s 815us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00064: val_loss did not improve from 0.00205
# Epoch 65/70
# 3847/3847 [==============================] - 3s 816us/step - loss: 0.0021 - val_loss: 0.0037
#
# Epoch 00065: val_loss did not improve from 0.00205
# Epoch 66/70
# 3847/3847 [==============================] - 3s 825us/step - loss: 0.0021 - val_loss: 0.0042
#
# Epoch 00066: val_loss did not improve from 0.00205
# Epoch 67/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00067: val_loss did not improve from 0.00205
# Epoch 68/70
# 3847/3847 [==============================] - 3s 810us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00068: val_loss did not improve from 0.00205
# Epoch 69/70
# 3847/3847 [==============================] - 3s 814us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00069: val_loss did not improve from 0.00205
# Epoch 70/70
# 3847/3847 [==============================] - 3s 808us/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00070: val_loss did not improve from 0.00205
# Model loaded
# mae :  3503.1536647301214
# mse :  24403744.06950665
# rmse :  4940.01458191235
# std : 4928.680495449945

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 11s 3ms/step - loss: 0.0068 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00234, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00002: val_loss did not improve from 0.00234
# Epoch 3/70
# 3847/3847 [==============================] - 3s 837us/step - loss: 0.0038 - val_loss: 0.0028
#
# Epoch 00003: val_loss did not improve from 0.00234
# Epoch 4/70
# 3847/3847 [==============================] - 3s 827us/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00004: val_loss did not improve from 0.00234
# Epoch 5/70
# 3847/3847 [==============================] - 3s 812us/step - loss: 0.0035 - val_loss: 0.0055
#
# Epoch 00005: val_loss did not improve from 0.00234
# Epoch 6/70
# 3847/3847 [==============================] - 3s 826us/step - loss: 0.0033 - val_loss: 0.0042
#
# Epoch 00006: val_loss did not improve from 0.00234
# Epoch 7/70
# 3847/3847 [==============================] - 3s 805us/step - loss: 0.0033 - val_loss: 0.0040
#
# Epoch 00007: val_loss did not improve from 0.00234
# Epoch 8/70
# 3847/3847 [==============================] - 3s 881us/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00008: val_loss did not improve from 0.00234
# Epoch 9/70
# 3847/3847 [==============================] - 3s 878us/step - loss: 0.0031 - val_loss: 0.0047
#
# Epoch 00009: val_loss did not improve from 0.00234
# Epoch 10/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0032 - val_loss: 0.0038
#
# Epoch 00010: val_loss did not improve from 0.00234
# Epoch 11/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0030 - val_loss: 0.0028
#
# Epoch 00011: val_loss did not improve from 0.00234
# Epoch 12/70
# 3847/3847 [==============================] - 3s 873us/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00012: val_loss did not improve from 0.00234
# Epoch 13/70
# 3847/3847 [==============================] - 3s 871us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00013: val_loss did not improve from 0.00234
# Epoch 14/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00014: val_loss did not improve from 0.00234
# Epoch 15/70
# 3847/3847 [==============================] - 3s 871us/step - loss: 0.0028 - val_loss: 0.0035
#
# Epoch 00015: val_loss did not improve from 0.00234
# Epoch 16/70
# 3847/3847 [==============================] - 3s 874us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00016: val_loss did not improve from 0.00234
# Epoch 17/70
# 3847/3847 [==============================] - 3s 868us/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00017: val_loss did not improve from 0.00234
# Epoch 18/70
# 3847/3847 [==============================] - 3s 869us/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00018: val_loss did not improve from 0.00234
# Epoch 19/70
# 3847/3847 [==============================] - 3s 871us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00019: val_loss did not improve from 0.00234
# Epoch 20/70
# 3847/3847 [==============================] - 3s 869us/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00020: val_loss did not improve from 0.00234
# Epoch 21/70
# 3847/3847 [==============================] - 3s 869us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00021: val_loss did not improve from 0.00234
# Epoch 22/70
# 3847/3847 [==============================] - 3s 864us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00022: val_loss did not improve from 0.00234
# Epoch 23/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00023: val_loss did not improve from 0.00234
# Epoch 24/70
# 3847/3847 [==============================] - 3s 872us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00024: val_loss did not improve from 0.00234
# Epoch 25/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0026 - val_loss: 0.0045
#
# Epoch 00025: val_loss did not improve from 0.00234
# Epoch 26/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00026: val_loss did not improve from 0.00234
# Epoch 27/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0026 - val_loss: 0.0037
#
# Epoch 00027: val_loss did not improve from 0.00234
# Epoch 28/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0025 - val_loss: 0.0046
#
# Epoch 00028: val_loss did not improve from 0.00234
# Epoch 29/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0025 - val_loss: 0.0023
#
# Epoch 00029: val_loss improved from 0.00234 to 0.00229, saving model to DNNLSTMmodel.h5
# Epoch 30/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00030: val_loss did not improve from 0.00229
# Epoch 31/70
# 3847/3847 [==============================] - 3s 853us/step - loss: 0.0026 - val_loss: 0.0022
#
# Epoch 00031: val_loss improved from 0.00229 to 0.00218, saving model to DNNLSTMmodel.h5
# Epoch 32/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00032: val_loss did not improve from 0.00218
# Epoch 33/70
# 3847/3847 [==============================] - 3s 909us/step - loss: 0.0024 - val_loss: 0.0046
#
# Epoch 00033: val_loss did not improve from 0.00218
# Epoch 34/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00034: val_loss did not improve from 0.00218
# Epoch 35/70
# 3847/3847 [==============================] - 3s 876us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00035: val_loss did not improve from 0.00218
# Epoch 36/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00036: val_loss did not improve from 0.00218
# Epoch 37/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00037: val_loss improved from 0.00218 to 0.00214, saving model to DNNLSTMmodel.h5
# Epoch 38/70
# 3847/3847 [==============================] - 3s 876us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00038: val_loss did not improve from 0.00214
# Epoch 39/70
# 3847/3847 [==============================] - 3s 867us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00039: val_loss did not improve from 0.00214
# Epoch 40/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00040: val_loss did not improve from 0.00214
# Epoch 41/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00041: val_loss did not improve from 0.00214
# Epoch 42/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0023 - val_loss: 0.0046
#
# Epoch 00042: val_loss did not improve from 0.00214
# Epoch 43/70
# 3847/3847 [==============================] - 3s 864us/step - loss: 0.0024 - val_loss: 0.0033
#
# Epoch 00043: val_loss did not improve from 0.00214
# Epoch 44/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00044: val_loss did not improve from 0.00214
# Epoch 45/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00045: val_loss did not improve from 0.00214
# Epoch 46/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00046: val_loss did not improve from 0.00214
# Epoch 47/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0022 - val_loss: 0.0045
#
# Epoch 00047: val_loss did not improve from 0.00214
# Epoch 48/70
# 3847/3847 [==============================] - 3s 853us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00048: val_loss did not improve from 0.00214
# Epoch 49/70
# 3847/3847 [==============================] - 3s 865us/step - loss: 0.0023 - val_loss: 0.0054
#
# Epoch 00049: val_loss did not improve from 0.00214
# Epoch 50/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00050: val_loss did not improve from 0.00214
# Epoch 51/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00051: val_loss did not improve from 0.00214
# Epoch 52/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00052: val_loss did not improve from 0.00214
# Epoch 53/70
# 3847/3847 [==============================] - 3s 851us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00053: val_loss did not improve from 0.00214
# Epoch 54/70
# 3847/3847 [==============================] - 3s 852us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00054: val_loss did not improve from 0.00214
# Epoch 55/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00055: val_loss did not improve from 0.00214
# Epoch 56/70
# 3847/3847 [==============================] - 3s 853us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00056: val_loss did not improve from 0.00214
# Epoch 57/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00057: val_loss did not improve from 0.00214
# Epoch 58/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0021 - val_loss: 0.0050
#
# Epoch 00058: val_loss did not improve from 0.00214
# Epoch 59/70
# 3847/3847 [==============================] - 3s 868us/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00059: val_loss did not improve from 0.00214
# Epoch 60/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00060: val_loss did not improve from 0.00214
# Epoch 61/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0021 - val_loss: 0.0039
#
# Epoch 00061: val_loss did not improve from 0.00214
# Epoch 62/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00062: val_loss did not improve from 0.00214
# Epoch 63/70
# 3847/3847 [==============================] - 3s 882us/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00063: val_loss did not improve from 0.00214
# Epoch 64/70
# 3847/3847 [==============================] - 3s 867us/step - loss: 0.0020 - val_loss: 0.0041
#
# Epoch 00064: val_loss did not improve from 0.00214
# Epoch 65/70
# 3847/3847 [==============================] - 3s 868us/step - loss: 0.0020 - val_loss: 0.0045
#
# Epoch 00065: val_loss did not improve from 0.00214
# Epoch 66/70
# 3847/3847 [==============================] - 3s 879us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00066: val_loss did not improve from 0.00214
# Epoch 67/70
# 3847/3847 [==============================] - 3s 856us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00067: val_loss did not improve from 0.00214
# Epoch 68/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00068: val_loss did not improve from 0.00214
# Epoch 69/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0020 - val_loss: 0.0044
#
# Epoch 00069: val_loss did not improve from 0.00214
# Epoch 70/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0019 - val_loss: 0.0030
#
# Epoch 00070: val_loss did not improve from 0.00214
# Model loaded
# mae :  3575.3113461581142
# mse :  30410479.708011314
# rmse :  5514.569766356331
# std : 5313.779724357138

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 12s 3ms/step - loss: 0.0139 - val_loss: 0.0038
#
# Epoch 00001: val_loss improved from inf to 0.00378, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 882us/step - loss: 0.0042 - val_loss: 0.0040
#
# Epoch 00002: val_loss did not improve from 0.00378
# Epoch 3/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0039 - val_loss: 0.0025
#
# Epoch 00003: val_loss improved from 0.00378 to 0.00254, saving model to DNNLSTMmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 876us/step - loss: 0.0039 - val_loss: 0.0066
#
# Epoch 00004: val_loss did not improve from 0.00254
# Epoch 5/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0040 - val_loss: 0.0039
#
# Epoch 00005: val_loss did not improve from 0.00254
# Epoch 6/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0037 - val_loss: 0.0035
#
# Epoch 00006: val_loss did not improve from 0.00254
# Epoch 7/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0035 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00254
# Epoch 8/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0035 - val_loss: 0.0045
#
# Epoch 00008: val_loss did not improve from 0.00254
# Epoch 9/70
# 3847/3847 [==============================] - 3s 856us/step - loss: 0.0036 - val_loss: 0.0041
#
# Epoch 00009: val_loss did not improve from 0.00254
# Epoch 10/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0033 - val_loss: 0.0040
#
# Epoch 00010: val_loss did not improve from 0.00254
# Epoch 11/70
# 3847/3847 [==============================] - 4s 910us/step - loss: 0.0032 - val_loss: 0.0040
#
# Epoch 00011: val_loss did not improve from 0.00254
# Epoch 12/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0031 - val_loss: 0.0045
#
# Epoch 00012: val_loss did not improve from 0.00254
# Epoch 13/70
# 3847/3847 [==============================] - 3s 901us/step - loss: 0.0032 - val_loss: 0.0047
#
# Epoch 00013: val_loss did not improve from 0.00254
# Epoch 14/70
# 3847/3847 [==============================] - 3s 897us/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00014: val_loss did not improve from 0.00254
# Epoch 15/70
# 3847/3847 [==============================] - 3s 902us/step - loss: 0.0031 - val_loss: 0.0037
#
# Epoch 00015: val_loss did not improve from 0.00254
# Epoch 16/70
# 3847/3847 [==============================] - 4s 970us/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00016: val_loss did not improve from 0.00254
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0027
#
# Epoch 00017: val_loss did not improve from 0.00254
# Epoch 18/70
# 3847/3847 [==============================] - 3s 903us/step - loss: 0.0031 - val_loss: 0.0043
#
# Epoch 00018: val_loss did not improve from 0.00254
# Epoch 19/70
# 3847/3847 [==============================] - 4s 921us/step - loss: 0.0029 - val_loss: 0.0050
#
# Epoch 00019: val_loss did not improve from 0.00254
# Epoch 20/70
# 3847/3847 [==============================] - 4s 936us/step - loss: 0.0029 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00254
# Epoch 21/70
# 3847/3847 [==============================] - 4s 914us/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00021: val_loss did not improve from 0.00254
# Epoch 22/70
# 3847/3847 [==============================] - 4s 912us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00022: val_loss did not improve from 0.00254
# Epoch 23/70
# 3847/3847 [==============================] - 3s 881us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00023: val_loss did not improve from 0.00254
# Epoch 24/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0029 - val_loss: 0.0049
#
# Epoch 00024: val_loss did not improve from 0.00254
# Epoch 25/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00025: val_loss did not improve from 0.00254
# Epoch 26/70
# 3847/3847 [==============================] - 4s 999us/step - loss: 0.0027 - val_loss: 0.0023
#
# Epoch 00026: val_loss improved from 0.00254 to 0.00232, saving model to DNNLSTMmodel.h5
# Epoch 27/70
# 3847/3847 [==============================] - 4s 925us/step - loss: 0.0029 - val_loss: 0.0050
#
# Epoch 00027: val_loss did not improve from 0.00232
# Epoch 28/70
# 3847/3847 [==============================] - 3s 902us/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00028: val_loss did not improve from 0.00232
# Epoch 29/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00029: val_loss did not improve from 0.00232
# Epoch 30/70
# 3847/3847 [==============================] - 3s 895us/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00030: val_loss did not improve from 0.00232
# Epoch 31/70
# 3847/3847 [==============================] - 3s 897us/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00031: val_loss did not improve from 0.00232
# Epoch 32/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0028 - val_loss: 0.0041
#
# Epoch 00032: val_loss did not improve from 0.00232
# Epoch 33/70
# 3847/3847 [==============================] - 3s 894us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00033: val_loss did not improve from 0.00232
# Epoch 34/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0026 - val_loss: 0.0035
#
# Epoch 00034: val_loss did not improve from 0.00232
# Epoch 35/70
# 3847/3847 [==============================] - 3s 888us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00035: val_loss did not improve from 0.00232
# Epoch 36/70
# 3847/3847 [==============================] - 3s 909us/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00036: val_loss did not improve from 0.00232
# Epoch 37/70
# 3847/3847 [==============================] - 3s 889us/step - loss: 0.0026 - val_loss: 0.0058
#
# Epoch 00037: val_loss did not improve from 0.00232
# Epoch 38/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00038: val_loss did not improve from 0.00232
# Epoch 39/70
# 3847/3847 [==============================] - 4s 918us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00039: val_loss did not improve from 0.00232
# Epoch 40/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0026 - val_loss: 0.0020
#
# Epoch 00040: val_loss improved from 0.00232 to 0.00200, saving model to DNNLSTMmodel.h5
# Epoch 41/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00041: val_loss did not improve from 0.00200
# Epoch 42/70
# 3847/3847 [==============================] - 3s 893us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00200
# Epoch 43/70
# 3847/3847 [==============================] - 3s 895us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00043: val_loss did not improve from 0.00200
# Epoch 44/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00044: val_loss did not improve from 0.00200
# Epoch 45/70
# 3847/3847 [==============================] - 4s 922us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00200
# Epoch 46/70
# 3847/3847 [==============================] - 3s 900us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00046: val_loss did not improve from 0.00200
# Epoch 47/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00047: val_loss did not improve from 0.00200
# Epoch 48/70
# 3847/3847 [==============================] - 4s 930us/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00048: val_loss did not improve from 0.00200
# Epoch 49/70
# 3847/3847 [==============================] - 3s 882us/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00049: val_loss did not improve from 0.00200
# Epoch 50/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00050: val_loss did not improve from 0.00200
# Epoch 51/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00051: val_loss did not improve from 0.00200
# Epoch 52/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00052: val_loss did not improve from 0.00200
# Epoch 53/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00053: val_loss did not improve from 0.00200
# Epoch 54/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00054: val_loss did not improve from 0.00200
# Epoch 55/70
# 3847/3847 [==============================] - 4s 923us/step - loss: 0.0024 - val_loss: 0.0061
#
# Epoch 00055: val_loss did not improve from 0.00200
# Epoch 56/70
# 3847/3847 [==============================] - 3s 890us/step - loss: 0.0023 - val_loss: 0.0032
#
# Epoch 00056: val_loss did not improve from 0.00200
# Epoch 57/70
# 3847/3847 [==============================] - 3s 889us/step - loss: 0.0025 - val_loss: 0.0044
#
# Epoch 00057: val_loss did not improve from 0.00200
# Epoch 58/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00058: val_loss did not improve from 0.00200
# Epoch 59/70
# 3847/3847 [==============================] - 3s 885us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00059: val_loss did not improve from 0.00200
# Epoch 60/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00060: val_loss did not improve from 0.00200
# Epoch 61/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0024 - val_loss: 0.0041
#
# Epoch 00061: val_loss did not improve from 0.00200
# Epoch 62/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00062: val_loss did not improve from 0.00200
# Epoch 63/70
# 3847/3847 [==============================] - 3s 889us/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00063: val_loss did not improve from 0.00200
# Epoch 64/70
# 3847/3847 [==============================] - 4s 914us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00064: val_loss did not improve from 0.00200
# Epoch 65/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00065: val_loss did not improve from 0.00200
# Epoch 66/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00066: val_loss did not improve from 0.00200
# Epoch 67/70
# 3847/3847 [==============================] - 3s 895us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00067: val_loss did not improve from 0.00200
# Epoch 68/70
# 3847/3847 [==============================] - 4s 922us/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00068: val_loss did not improve from 0.00200
# Epoch 69/70
# 3847/3847 [==============================] - 4s 915us/step - loss: 0.0022 - val_loss: 0.0035
#
# Epoch 00069: val_loss did not improve from 0.00200
# Epoch 70/70
# 3847/3847 [==============================] - 3s 888us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00070: val_loss did not improve from 0.00200
# Model loaded
# mae :  3563.936669371964
# mse :  29855009.482714295
# rmse :  5463.973781298213
# std : 5263.19051436176

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 15s 4ms/step - loss: 0.0092 - val_loss: 0.0059
#
# Epoch 00001: val_loss improved from inf to 0.00587, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 961us/step - loss: 0.0038 - val_loss: 0.0042
#
# Epoch 00002: val_loss improved from 0.00587 to 0.00416, saving model to DNNLSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 4s 966us/step - loss: 0.0036 - val_loss: 0.0043
#
# Epoch 00003: val_loss did not improve from 0.00416
# Epoch 4/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0036 - val_loss: 0.0028
#
# Epoch 00004: val_loss improved from 0.00416 to 0.00283, saving model to DNNLSTMmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 4s 963us/step - loss: 0.0034 - val_loss: 0.0046
#
# Epoch 00005: val_loss did not improve from 0.00283
# Epoch 6/70
# 3847/3847 [==============================] - 4s 942us/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00006: val_loss did not improve from 0.00283
# Epoch 7/70
# 3847/3847 [==============================] - 4s 946us/step - loss: 0.0031 - val_loss: 0.0050
#
# Epoch 00007: val_loss did not improve from 0.00283
# Epoch 8/70
# 3847/3847 [==============================] - 4s 914us/step - loss: 0.0034 - val_loss: 0.0047
#
# Epoch 00008: val_loss did not improve from 0.00283
# Epoch 9/70
# 3847/3847 [==============================] - 4s 917us/step - loss: 0.0031 - val_loss: 0.0052
#
# Epoch 00009: val_loss did not improve from 0.00283
# Epoch 10/70
# 3847/3847 [==============================] - 4s 959us/step - loss: 0.0030 - val_loss: 0.0064
#
# Epoch 00010: val_loss did not improve from 0.00283
# Epoch 11/70
# 3847/3847 [==============================] - 4s 965us/step - loss: 0.0031 - val_loss: 0.0043
#
# Epoch 00011: val_loss did not improve from 0.00283
# Epoch 12/70
# 3847/3847 [==============================] - 4s 964us/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00012: val_loss did not improve from 0.00283
# Epoch 13/70
# 3847/3847 [==============================] - 4s 963us/step - loss: 0.0029 - val_loss: 0.0041
#
# Epoch 00013: val_loss did not improve from 0.00283
# Epoch 14/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0031 - val_loss: 0.0046
#
# Epoch 00014: val_loss did not improve from 0.00283
# Epoch 15/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00015: val_loss did not improve from 0.00283
# Epoch 16/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0029 - val_loss: 0.0023
#
# Epoch 00016: val_loss improved from 0.00283 to 0.00234, saving model to DNNLSTMmodel.h5
# Epoch 17/70
# 3847/3847 [==============================] - 3s 888us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00017: val_loss did not improve from 0.00234
# Epoch 18/70
# 3847/3847 [==============================] - 3s 889us/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00018: val_loss did not improve from 0.00234
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0022
#
# Epoch 00019: val_loss improved from 0.00234 to 0.00218, saving model to DNNLSTMmodel.h5
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00020: val_loss did not improve from 0.00218
# Epoch 21/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0028 - val_loss: 0.0037
#
# Epoch 00021: val_loss did not improve from 0.00218
# Epoch 22/70
# 3847/3847 [==============================] - 3s 864us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00022: val_loss did not improve from 0.00218
# Epoch 23/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0028 - val_loss: 0.0021
#
# Epoch 00023: val_loss improved from 0.00218 to 0.00213, saving model to DNNLSTMmodel.h5
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0023
#
# Epoch 00024: val_loss did not improve from 0.00213
# Epoch 25/70
# 3847/3847 [==============================] - 4s 933us/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00025: val_loss did not improve from 0.00213
# Epoch 26/70
# 3847/3847 [==============================] - 3s 843us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00026: val_loss did not improve from 0.00213
# Epoch 27/70
# 3847/3847 [==============================] - 3s 868us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00027: val_loss did not improve from 0.00213
# Epoch 28/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0027 - val_loss: 0.0038
#
# Epoch 00028: val_loss did not improve from 0.00213
# Epoch 29/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0027 - val_loss: 0.0024
#
# Epoch 00029: val_loss did not improve from 0.00213
# Epoch 30/70
# 3847/3847 [==============================] - 3s 865us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00030: val_loss did not improve from 0.00213
# Epoch 31/70
# 3847/3847 [==============================] - 3s 868us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00031: val_loss did not improve from 0.00213
# Epoch 32/70
# 3847/3847 [==============================] - 3s 890us/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00032: val_loss did not improve from 0.00213
# Epoch 33/70
# 3847/3847 [==============================] - 3s 881us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00033: val_loss did not improve from 0.00213
# Epoch 34/70
# 3847/3847 [==============================] - 3s 871us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00034: val_loss did not improve from 0.00213
# Epoch 35/70
# 3847/3847 [==============================] - 3s 873us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00035: val_loss did not improve from 0.00213
# Epoch 36/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0025 - val_loss: 0.0038
#
# Epoch 00036: val_loss did not improve from 0.00213
# Epoch 37/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00037: val_loss did not improve from 0.00213
# Epoch 38/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00038: val_loss did not improve from 0.00213
# Epoch 39/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00039: val_loss did not improve from 0.00213
# Epoch 40/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00040: val_loss did not improve from 0.00213
# Epoch 41/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0024 - val_loss: 0.0050
#
# Epoch 00041: val_loss did not improve from 0.00213
# Epoch 42/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00042: val_loss did not improve from 0.00213
# Epoch 43/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00043: val_loss did not improve from 0.00213
# Epoch 44/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0024 - val_loss: 0.0051
#
# Epoch 00044: val_loss did not improve from 0.00213
# Epoch 45/70
# 3847/3847 [==============================] - 4s 918us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00045: val_loss did not improve from 0.00213
# Epoch 46/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00046: val_loss did not improve from 0.00213
# Epoch 47/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00047: val_loss did not improve from 0.00213
# Epoch 48/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00048: val_loss did not improve from 0.00213
# Epoch 49/70
# 3847/3847 [==============================] - 3s 866us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00049: val_loss did not improve from 0.00213
# Epoch 50/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0024 - val_loss: 0.0038
#
# Epoch 00050: val_loss did not improve from 0.00213
# Epoch 51/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00051: val_loss did not improve from 0.00213
# Epoch 52/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00052: val_loss did not improve from 0.00213
# Epoch 53/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0025 - val_loss: 0.0048
#
# Epoch 00053: val_loss did not improve from 0.00213
# Epoch 54/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00054: val_loss did not improve from 0.00213
# Epoch 55/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0023 - val_loss: 0.0049
#
# Epoch 00055: val_loss did not improve from 0.00213
# Epoch 56/70
# 3847/3847 [==============================] - 3s 855us/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00056: val_loss did not improve from 0.00213
# Epoch 57/70
# 3847/3847 [==============================] - 3s 856us/step - loss: 0.0022 - val_loss: 0.0039
#
# Epoch 00057: val_loss did not improve from 0.00213
# Epoch 58/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00058: val_loss did not improve from 0.00213
# Epoch 59/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00059: val_loss did not improve from 0.00213
# Epoch 60/70
# 3847/3847 [==============================] - 3s 858us/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00060: val_loss did not improve from 0.00213
# Epoch 61/70
# 3847/3847 [==============================] - 3s 857us/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00061: val_loss did not improve from 0.00213
# Epoch 62/70
# 3847/3847 [==============================] - 3s 856us/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00062: val_loss did not improve from 0.00213
# Epoch 63/70
# 3847/3847 [==============================] - 3s 854us/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00063: val_loss did not improve from 0.00213
# Epoch 64/70
# 3847/3847 [==============================] - 3s 853us/step - loss: 0.0021 - val_loss: 0.0031
#
# Epoch 00064: val_loss did not improve from 0.00213
# Epoch 65/70
# 3847/3847 [==============================] - 3s 850us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00065: val_loss did not improve from 0.00213
# Epoch 66/70
# 3847/3847 [==============================] - 3s 849us/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00066: val_loss did not improve from 0.00213
# Epoch 67/70
# 3847/3847 [==============================] - 3s 849us/step - loss: 0.0021 - val_loss: 0.0024
#
# Epoch 00067: val_loss did not improve from 0.00213
# Epoch 68/70
# 3847/3847 [==============================] - 3s 860us/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00068: val_loss did not improve from 0.00213
# Epoch 69/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0019 - val_loss: 0.0030
#
# Epoch 00069: val_loss did not improve from 0.00213
# Epoch 70/70
# 3847/3847 [==============================] - 3s 852us/step - loss: 0.0021 - val_loss: 0.0047
#
# Epoch 00070: val_loss did not improve from 0.00213
# Model loaded
# mae :  3866.906266170353
# mse :  28721438.5666201
# rmse :  5359.238618182633
# std : 4816.590758286345

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('DNNLSTMmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('DNNLSTMmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 19s 5ms/step - loss: 0.0131 - val_loss: 0.0042
#
# Epoch 00001: val_loss improved from inf to 0.00418, saving model to DNNLSTMmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 995us/step - loss: 0.0041 - val_loss: 0.0029
#
# Epoch 00002: val_loss improved from 0.00418 to 0.00288, saving model to DNNLSTMmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 4s 984us/step - loss: 0.0037 - val_loss: 0.0054
#
# Epoch 00003: val_loss did not improve from 0.00288
# Epoch 4/70
# 3847/3847 [==============================] - 4s 910us/step - loss: 0.0035 - val_loss: 0.0026
#
# Epoch 00004: val_loss improved from 0.00288 to 0.00258, saving model to DNNLSTMmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 4s 931us/step - loss: 0.0035 - val_loss: 0.0041
#
# Epoch 00005: val_loss did not improve from 0.00258
# Epoch 6/70
# 3847/3847 [==============================] - 3s 889us/step - loss: 0.0033 - val_loss: 0.0029
#
# Epoch 00006: val_loss did not improve from 0.00258
# Epoch 7/70
# 3847/3847 [==============================] - 3s 879us/step - loss: 0.0032 - val_loss: 0.0067
#
# Epoch 00007: val_loss did not improve from 0.00258
# Epoch 8/70
# 3847/3847 [==============================] - 4s 958us/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00008: val_loss did not improve from 0.00258
# Epoch 9/70
# 3847/3847 [==============================] - 3s 876us/step - loss: 0.0033 - val_loss: 0.0061
#
# Epoch 00009: val_loss did not improve from 0.00258
# Epoch 10/70
# 3847/3847 [==============================] - 3s 878us/step - loss: 0.0031 - val_loss: 0.0032
#
# Epoch 00010: val_loss did not improve from 0.00258
# Epoch 11/70
# 3847/3847 [==============================] - 4s 922us/step - loss: 0.0031 - val_loss: 0.0027
#
# Epoch 00011: val_loss did not improve from 0.00258
# Epoch 12/70
# 3847/3847 [==============================] - 4s 933us/step - loss: 0.0030 - val_loss: 0.0041
#
# Epoch 00012: val_loss did not improve from 0.00258
# Epoch 13/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0030 - val_loss: 0.0045
#
# Epoch 00013: val_loss did not improve from 0.00258
# Epoch 14/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0032 - val_loss: 0.0041
#
# Epoch 00014: val_loss did not improve from 0.00258
# Epoch 15/70
# 3847/3847 [==============================] - 4s 979us/step - loss: 0.0029 - val_loss: 0.0038
#
# Epoch 00015: val_loss did not improve from 0.00258
# Epoch 16/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0030 - val_loss: 0.0054
#
# Epoch 00016: val_loss did not improve from 0.00258
# Epoch 17/70
# 3847/3847 [==============================] - 3s 880us/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00017: val_loss did not improve from 0.00258
# Epoch 18/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00018: val_loss did not improve from 0.00258
# Epoch 19/70
# 3847/3847 [==============================] - 3s 885us/step - loss: 0.0029 - val_loss: 0.0022
#
# Epoch 00019: val_loss improved from 0.00258 to 0.00215, saving model to DNNLSTMmodel.h5
# Epoch 20/70
# 3847/3847 [==============================] - 3s 891us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00020: val_loss did not improve from 0.00215
# Epoch 21/70
# 3847/3847 [==============================] - 4s 916us/step - loss: 0.0028 - val_loss: 0.0048
#
# Epoch 00021: val_loss did not improve from 0.00215
# Epoch 22/70
# 3847/3847 [==============================] - 4s 921us/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00022: val_loss did not improve from 0.00215
# Epoch 23/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00023: val_loss did not improve from 0.00215
# Epoch 24/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00024: val_loss did not improve from 0.00215
# Epoch 25/70
# 3847/3847 [==============================] - 4s 940us/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00025: val_loss did not improve from 0.00215
# Epoch 26/70
# 3847/3847 [==============================] - 3s 888us/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00026: val_loss did not improve from 0.00215
# Epoch 27/70
# 3847/3847 [==============================] - 3s 903us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00027: val_loss did not improve from 0.00215
# Epoch 28/70
# 3847/3847 [==============================] - 3s 894us/step - loss: 0.0027 - val_loss: 0.0037
#
# Epoch 00028: val_loss did not improve from 0.00215
# Epoch 29/70
# 3847/3847 [==============================] - 3s 893us/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00029: val_loss did not improve from 0.00215
# Epoch 30/70
# 3847/3847 [==============================] - 3s 883us/step - loss: 0.0029 - val_loss: 0.0021
#
# Epoch 00030: val_loss improved from 0.00215 to 0.00211, saving model to DNNLSTMmodel.h5
# Epoch 31/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0027 - val_loss: 0.0056
#
# Epoch 00031: val_loss did not improve from 0.00211
# Epoch 32/70
# 3847/3847 [==============================] - 4s 955us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00032: val_loss did not improve from 0.00211
# Epoch 33/70
# 3847/3847 [==============================] - 4s 938us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00033: val_loss did not improve from 0.00211
# Epoch 34/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0026 - val_loss: 0.0047
#
# Epoch 00034: val_loss did not improve from 0.00211
# Epoch 35/70
# 3847/3847 [==============================] - 4s 929us/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00035: val_loss did not improve from 0.00211
# Epoch 36/70
# 3847/3847 [==============================] - 4s 937us/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00036: val_loss did not improve from 0.00211
# Epoch 37/70
# 3847/3847 [==============================] - 4s 930us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00037: val_loss did not improve from 0.00211
# Epoch 38/70
# 3847/3847 [==============================] - 4s 966us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00038: val_loss did not improve from 0.00211
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0045
#
# Epoch 00039: val_loss did not improve from 0.00211
# Epoch 40/70
# 3847/3847 [==============================] - 4s 957us/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00040: val_loss did not improve from 0.00211
# Epoch 41/70
# 3847/3847 [==============================] - 4s 971us/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00041: val_loss did not improve from 0.00211
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0045
#
# Epoch 00042: val_loss did not improve from 0.00211
# Epoch 43/70
# 3847/3847 [==============================] - 4s 965us/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00043: val_loss did not improve from 0.00211
# Epoch 44/70
# 3847/3847 [==============================] - 4s 943us/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00044: val_loss did not improve from 0.00211
# Epoch 45/70
# 3847/3847 [==============================] - 4s 910us/step - loss: 0.0024 - val_loss: 0.0051
#
# Epoch 00045: val_loss did not improve from 0.00211
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00046: val_loss did not improve from 0.00211
# Epoch 47/70
# 3847/3847 [==============================] - 4s 942us/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00047: val_loss did not improve from 0.00211
# Epoch 48/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00048: val_loss did not improve from 0.00211
# Epoch 49/70
# 3847/3847 [==============================] - 3s 875us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00049: val_loss did not improve from 0.00211
# Epoch 50/70
# 3847/3847 [==============================] - 3s 877us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00050: val_loss did not improve from 0.00211
# Epoch 51/70
# 3847/3847 [==============================] - 3s 887us/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 00051: val_loss did not improve from 0.00211
# Epoch 52/70
# 3847/3847 [==============================] - 3s 872us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00052: val_loss did not improve from 0.00211
# Epoch 53/70
# 3847/3847 [==============================] - 3s 903us/step - loss: 0.0024 - val_loss: 0.0060
#
# Epoch 00053: val_loss did not improve from 0.00211
# Epoch 54/70
# 3847/3847 [==============================] - 3s 909us/step - loss: 0.0024 - val_loss: 0.0037
#
# Epoch 00054: val_loss did not improve from 0.00211
# Epoch 55/70
# 3847/3847 [==============================] - 3s 891us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00055: val_loss did not improve from 0.00211
# Epoch 56/70
# 3847/3847 [==============================] - 4s 922us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00056: val_loss did not improve from 0.00211
# Epoch 57/70
# 3847/3847 [==============================] - 3s 896us/step - loss: 0.0023 - val_loss: 0.0039
#
# Epoch 00057: val_loss did not improve from 0.00211
# Epoch 58/70
# 3847/3847 [==============================] - 4s 918us/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00058: val_loss did not improve from 0.00211
# Epoch 59/70
# 3847/3847 [==============================] - 3s 892us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00059: val_loss did not improve from 0.00211
# Epoch 60/70
# 3847/3847 [==============================] - 3s 884us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00060: val_loss did not improve from 0.00211
# Epoch 61/70
# 3847/3847 [==============================] - 4s 996us/step - loss: 0.0022 - val_loss: 0.0039
#
# Epoch 00061: val_loss did not improve from 0.00211
# Epoch 62/70
# 3847/3847 [==============================] - 3s 886us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00062: val_loss did not improve from 0.00211
# Epoch 63/70
# 3847/3847 [==============================] - 3s 895us/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00063: val_loss did not improve from 0.00211
# Epoch 64/70
# 3847/3847 [==============================] - 4s 976us/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00064: val_loss did not improve from 0.00211
# Epoch 65/70
# 3847/3847 [==============================] - 3s 902us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00065: val_loss did not improve from 0.00211
# Epoch 66/70
# 3847/3847 [==============================] - 4s 919us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00066: val_loss did not improve from 0.00211
# Epoch 67/70
# 3847/3847 [==============================] - 3s 901us/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00067: val_loss did not improve from 0.00211
# Epoch 68/70
# 3847/3847 [==============================] - 3s 898us/step - loss: 0.0021 - val_loss: 0.0041
#
# Epoch 00068: val_loss did not improve from 0.00211
# Epoch 69/70
# 3847/3847 [==============================] - 3s 877us/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00069: val_loss did not improve from 0.00211
# Epoch 70/70
# 3847/3847 [==============================] - 3s 876us/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00070: val_loss did not improve from 0.00211
# Model loaded
# mae :  3932.8440210912136
# mse :  30724034.523693804
# rmse :  5542.926530605814
# std : 4996.572124137705
