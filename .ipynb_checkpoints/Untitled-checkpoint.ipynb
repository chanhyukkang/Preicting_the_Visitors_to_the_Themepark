# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping
 
    
class DNN(models.Sequential):
    def __init__(self, Nin, Nh_l, Pd_l, Nout):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(Nh_l[0], activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dropout(Pd_l[0]))
        self.add(layers.Dense(Nh_l[1], activation='relu', name='Hidden-2'))
        self.add(layers.Dropout(Pd_l[1]))
#         self.add(layers.Dense(Nh_l[2], activation='relu', name='Hidden-3'))
#         self.add(layers.Dropout(Pd_l[2]))
        
        self.add(layers.Dense(Nout))
        self.compile(loss='mean_squared_error', optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999), metrics=['accuracy'])
        
# 데이터 정리
def Data_func():
    df = pd.read_csv('SeoulGrandPark.csv', engine = 'python')    
    
    df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)#날짜 column생성
    # print(df.head())

    df = df.set_index('날짜') 
    # print(df.head()) 
    # df.plot()

    split_date_last = '2016-12-17'
    split_date_start = '2017-3-30'

    train = df.loc[:split_date_last]
    test = df.loc[split_date_start:]
    # print(train.head())

    train['일계'] = train['일계'].str.replace(',', '')
    test['일계'] = test['일계'].str.replace(',', '')

    train['일계'] = train['일계'].astype('float')
    test['일계'] = test['일계'].astype('float')
    
    train_df = pd.DataFrame(train)
    test_df = pd.DataFrame(test)
    #print(train_df)
    
    X_train = train_df.drop(['일계', '년도', '일'], axis=1)
    y_train = train_df[['일계']]
    X_test = test_df.drop(['일계', '년도', '일'], axis=1)
    y_test = test_df[['일계']]
    #print(X_train)
#     print(y_train)
    
    #one-hot-encoding
    X_train = pd.get_dummies(X_train, columns=['요일', '월'])
    X_test = pd.get_dummies(X_test, columns=['요일', '월'])
    #print(test)
    
    sc = MinMaxScaler()

    X_train_sc = sc.fit_transform(X_train)
    X_test_sc = sc.fit_transform(X_test)
    y_train_sc = sc.fit_transform(y_train)
    y_test_sc = sc.fit_transform(y_test)
    #print(pd.DataFrame(X_train_sc))
    #print(X_train_sc.shape)
    
#     X_train_t = X_train.reshape(X_train.shape[0], day, 1)
#     X_test_t = X_test.reshape(X_test.shape[0], day, 1)

    #print('test개수: ', len(y_test))
    
    return (X_train_sc, y_train_sc), (X_test_sc, y_test_sc)
 
# 모델 테스팅
def main():
    Nh_l = [500,500]
    Pd_l = [0, 0, 0, 0]
    number_of_class = 1
    Nout = number_of_class
 
    (X_train, Y_train), (X_test, Y_test) = Data_func()
  
    early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1)

    model = DNN(X_train.shape[1], Nh_l, Pd_l, Nout)
    history = model.fit(X_train, Y_train, epochs=100, batch_size=50, validation_split = 0.2, callbacks=[early_stop], verbose = 1)
    
    plt.figure(figsize=(20,15))
    plt.rcParams['lines.linewidth'] = 0.5
    plt.title('Visitors Result')
    plt.xlabel('2017.3.30~2019.4.30')
    plt.ylabel('visitors')
    plt.plot(Y_test, label='actual')
    Y_pred = model.predict(X_test)
    plt.plot(Y_pred, label='predicted')
    plt.legend()
    plt.show()
 
if __name__ == '__main__':
    main()
# Out:
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Train on 3642 samples, validate on 911 samples
# Epoch 1/100
# 3642/3642 [==============================] - 1s 345us/step - loss: 0.1079 - acc: 2.7457e-04 - val_loss: 0.0048 - val_acc: 0.0000e+00
# Epoch 2/100
# 3642/3642 [==============================] - 0s 116us/step - loss: 0.0041 - acc: 2.7457e-04 - val_loss: 0.0035 - val_acc: 0.0000e+00
# Epoch 3/100
# 3642/3642 [==============================] - 0s 129us/step - loss: 0.0035 - acc: 2.7457e-04 - val_loss: 0.0026 - val_acc: 0.0000e+00
# Epoch 4/100
# 3642/3642 [==============================] - 0s 108us/step - loss: 0.0033 - acc: 2.7457e-04 - val_loss: 0.0036 - val_acc: 0.0000e+00
# Epoch 5/100
# 3642/3642 [==============================] - 1s 314us/step - loss: 0.0032 - acc: 2.7457e-04 - val_loss: 0.0031 - val_acc: 0.0000e+00
# Epoch 6/100
# 3642/3642 [==============================] - 0s 117us/step - loss: 0.0033 - acc: 2.7457e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 7/100
# 3642/3642 [==============================] - 0s 113us/step - loss: 0.0032 - acc: 5.4915e-04 - val_loss: 0.0027 - val_acc: 0.0000e+00
# Epoch 8/100
# 3642/3642 [==============================] - 1s 167us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0025 - val_acc: 0.0000e+00
# Epoch 9/100
# 3642/3642 [==============================] - 0s 126us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0036 - val_acc: 0.0000e+00
# Epoch 10/100
# 3642/3642 [==============================] - 0s 122us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0034 - val_acc: 0.0000e+00
# Epoch 11/100
# 3642/3642 [==============================] - 1s 142us/step - loss: 0.0032 - acc: 5.4915e-04 - val_loss: 0.0051 - val_acc: 0.0000e+00
# Epoch 12/100
# 3642/3642 [==============================] - 0s 118us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0034 - val_acc: 0.0000e+00
# Epoch 13/100
# 3642/3642 [==============================] - 0s 109us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0027 - val_acc: 0.0000e+00
# Epoch 14/100
# 3642/3642 [==============================] - 0s 135us/step - loss: 0.0031 - acc: 5.4915e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 15/100
# 3642/3642 [==============================] - 0s 125us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0028 - val_acc: 0.0000e+00
# Epoch 16/100
# 3642/3642 [==============================] - 1s 339us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0037 - val_acc: 0.0000e+00
# Epoch 17/100
# 3642/3642 [==============================] - 1s 144us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0047 - val_acc: 0.0000e+00
# Epoch 18/100
# 3642/3642 [==============================] - 0s 120us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 19/100
# 3642/3642 [==============================] - 0s 127us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 20/100
# 3642/3642 [==============================] - 0s 117us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0051 - val_acc: 0.0000e+00
# Epoch 21/100
# 3642/3642 [==============================] - 0s 115us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 22/100
# 3642/3642 [==============================] - 0s 131us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0029 - val_acc: 0.0000e+00
# Epoch 23/100
# 3642/3642 [==============================] - 0s 113us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0026 - val_acc: 0.0000e+00
# Epoch 24/100
# 3642/3642 [==============================] - 0s 122us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0023 - val_acc: 0.0000e+00
# Epoch 25/100
# 3642/3642 [==============================] - 1s 138us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0044 - val_acc: 0.0000e+00
# Epoch 26/100
# 3642/3642 [==============================] - 0s 130us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0050 - val_acc: 0.0000e+00
# Epoch 27/100
# 3642/3642 [==============================] - 1s 299us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0051 - val_acc: 0.0000e+00
# Epoch 28/100
# 3642/3642 [==============================] - 1s 199us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0032 - val_acc: 0.0000e+00
# Epoch 29/100
# 3642/3642 [==============================] - 1s 137us/step - loss: 0.0030 - acc: 5.4915e-04 - val_loss: 0.0044 - val_acc: 0.0000e+00
# Epoch 30/100
# 3642/3642 [==============================] - 0s 114us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0040 - val_acc: 0.0000e+00
# Epoch 31/100
# 3642/3642 [==============================] - 0s 109us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0036 - val_acc: 0.0000e+00
# Epoch 32/100
# 3642/3642 [==============================] - 0s 122us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0029 - val_acc: 0.0000e+00
# Epoch 33/100
# 3642/3642 [==============================] - 0s 125us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0047 - val_acc: 0.0000e+00
# Epoch 34/100
# 3642/3642 [==============================] - 0s 116us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0022 - val_acc: 0.0000e+00
# Epoch 35/100
# 3642/3642 [==============================] - 0s 135us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0038 - val_acc: 0.0000e+00
# Epoch 36/100
# 3642/3642 [==============================] - 1s 214us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0060 - val_acc: 0.0000e+00
# Epoch 37/100
# 3642/3642 [==============================] - 0s 114us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 38/100
# 3642/3642 [==============================] - 1s 363us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0037 - val_acc: 0.0000e+00
# Epoch 39/100
# 3642/3642 [==============================] - 0s 121us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0042 - val_acc: 0.0000e+00
# Epoch 40/100
# 3642/3642 [==============================] - 0s 135us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0044 - val_acc: 0.0000e+00
# Epoch 41/100
# 3642/3642 [==============================] - 0s 114us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0029 - val_acc: 0.0000e+00
# Epoch 42/100
# 3642/3642 [==============================] - 0s 118us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0028 - val_acc: 0.0000e+00
# Epoch 43/100
# 3642/3642 [==============================] - 1s 169us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0033 - val_acc: 0.0000e+00
# Epoch 44/100
# 3642/3642 [==============================] - 0s 119us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0036 - val_acc: 0.0000e+00
# Epoch 45/100
# 3642/3642 [==============================] - 0s 125us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 46/100
# 3642/3642 [==============================] - 1s 139us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0027 - val_acc: 0.0000e+00
# Epoch 47/100
# 3642/3642 [==============================] - 0s 115us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0034 - val_acc: 0.0000e+00
# Epoch 48/100
# 3642/3642 [==============================] - 1s 190us/step - loss: 0.0029 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 49/100
# 3642/3642 [==============================] - 1s 279us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0037 - val_acc: 0.0000e+00
# Epoch 50/100
# 3642/3642 [==============================] - 0s 131us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 51/100
# 3642/3642 [==============================] - 1s 140us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0043 - val_acc: 0.0000e+00
# Epoch 52/100
# 3642/3642 [==============================] - 1s 171us/step - loss: 0.0026 - acc: 5.4915e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 53/100
# 3642/3642 [==============================] - 1s 210us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0030 - val_acc: 0.0000e+00
# Epoch 54/100
# 3642/3642 [==============================] - 0s 129us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0034 - val_acc: 0.0000e+00
# Epoch 55/100
# 3642/3642 [==============================] - 1s 142us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0050 - val_acc: 0.0000e+00
# Epoch 56/100
# 3642/3642 [==============================] - 1s 159us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0034 - val_acc: 0.0000e+00
# Epoch 57/100
# 3642/3642 [==============================] - 0s 136us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0047 - val_acc: 0.0000e+00
# Epoch 58/100
# 3642/3642 [==============================] - 1s 275us/step - loss: 0.0026 - acc: 5.4915e-04 - val_loss: 0.0033 - val_acc: 0.0000e+00
# Epoch 59/100
# 3642/3642 [==============================] - 1s 158us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 60/100
# 3642/3642 [==============================] - 1s 154us/step - loss: 0.0026 - acc: 5.4915e-04 - val_loss: 0.0036 - val_acc: 0.0000e+00
# Epoch 61/100
# 3642/3642 [==============================] - 1s 138us/step - loss: 0.0026 - acc: 5.4915e-04 - val_loss: 0.0025 - val_acc: 0.0000e+00
# Epoch 62/100
# 3642/3642 [==============================] - 0s 126us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0040 - val_acc: 0.0000e+00
# Epoch 63/100
# 3642/3642 [==============================] - 0s 127us/step - loss: 0.0027 - acc: 5.4915e-04 - val_loss: 0.0044 - val_acc: 0.0000e+00
# Epoch 64/100
# 3642/3642 [==============================] - 1s 173us/step - loss: 0.0028 - acc: 5.4915e-04 - val_loss: 0.0039 - val_acc: 0.0000e+00
# Epoch 00064: early stopping

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(10))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(10))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(1000, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(500, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(200, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(30))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100)(combinedInput)
x = Dense(10)(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('temp1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=5, batch_size=10, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('temp1.h5')
print("Model loaded")

#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel('2017.3.30~2019.4.30')#수정해야 함
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()

plt.plot(ynewtest-ynew)
plt.show()
# Out:
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/5
# 3847/3847 [==============================] - 107s 28ms/step - loss: 0.0058 - val_loss: 0.0018
#
# Epoch 00001: val_loss improved from inf to 0.00177, saving model to temp1.h5
# Epoch 2/5
# 3847/3847 [==============================] - 72s 19ms/step - loss: 0.0042 - val_loss: 0.0090ETA: 8s - ETA: 1s - loss
#
# Epoch 00002: val_loss did not improve from 0.00177
# Epoch 3/5
# 3847/3847 [==============================] - 72s 19ms/step - loss: 0.0038 - val_loss: 0.0023A: 1s - loss: 0.0 - ETA: 1s - loss:
#
# Epoch 00003: val_loss did not improve from 0.00177
# Epoch 4/5
# 3847/3847 [==============================] - 96s 25ms/step - loss: 0.0039 - val_loss: 0.0053
#
# Epoch 00004: val_loss did not improve from 0.00177
# Epoch 5/5
# 3847/3847 [==============================] - 124s 32ms/step - loss: 0.0036 - val_loss: 0.0029
#
# Epoch 00005: val_loss did not improve from 0.00177
# Model loaded

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(10))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(10))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(1000, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(500, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(200, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(30))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(200)(combinedInput)
x = Dense(100)(x)
x = Dense(30)(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('temp2.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=5, batch_size=10, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('temp2.h5')
print("Model loaded")

#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel('2017.3.30~2019.4.30')#수정해야 함
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()

plt.plot(ynewtest-ynew)
plt.show()
# Out:
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/5
# 3847/3847 [==============================] - 63s 16ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00001: val_loss improved from inf to 0.00337, saving model to temp2.h5
# Epoch 2/5
# 3847/3847 [==============================] - 42s 11ms/step - loss: 0.0042 - val_loss: 0.0029
#
# Epoch 00002: val_loss improved from 0.00337 to 0.00288, saving model to temp2.h5
# Epoch 3/5
# 3847/3847 [==============================] - 50s 13ms/step - loss: 0.0040 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00288 to 0.00187, saving model to temp2.h5
# Epoch 4/5
# 3847/3847 [==============================] - 55s 14ms/step - loss: 0.0039 - val_loss: 0.0017
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00169, saving model to temp2.h5
# Epoch 5/5
# 3847/3847 [==============================] - 56s 15ms/step - loss: 0.0036 - val_loss: 0.0039
#
# Epoch 00005: val_loss did not improve from 0.00169
# Model loaded

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(10))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(10))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(1000, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(500, activation='relu', name='Hidden-2'))
        self.add(layers.Dense(200, activation='relu', name='Hidden-3'))
        self.add(layers.Dense(30))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(200)(combinedInput)
x = Dense(100)(x)
x = Dense(30)(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('temp3.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=5, batch_size=10, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('temp3.h5')
print("Model loaded")

#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel('2018.4.16 ~ 2019.4.30')
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()

print("mse : ", np.square(ynewtest - ynew).mean() / ynew.size )
print("std :", np.std(ynewtest-ynew))

plt.plot(ynewtest-ynew)
plt.show()
# Out:
# Using TensorFlow backend.
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING: Logging before flag parsing goes to stderr.
# W1015 12:43:23.781064 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1015 12:43:23.809005 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1015 12:43:23.815972 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1015 12:43:24.934979 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# W1015 12:43:25.505454 14036 deprecation.py:323] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1015 12:43:28.240184 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1015 12:43:29.606528 14036 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 3847 samples, validate on 962 samples
# Epoch 1/5
# 3847/3847 [==============================] - 42s 11ms/step - loss: 0.0061 - val_loss: 0.0028
#
# Epoch 00001: val_loss improved from inf to 0.00278, saving model to temp3.h5
# Epoch 2/5
# 3847/3847 [==============================] - 35s 9ms/step - loss: 0.0041 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00278 to 0.00187, saving model to temp3.h5
# Epoch 3/5
# 3847/3847 [==============================] - 36s 9ms/step - loss: 0.0037 - val_loss: 0.0044
#
# Epoch 00003: val_loss did not improve from 0.00187
# Epoch 4/5
# 3847/3847 [==============================] - 36s 9ms/step - loss: 0.0038 - val_loss: 0.0025
#
# Epoch 00004: val_loss did not improve from 0.00187
# Epoch 5/5
# 3847/3847 [==============================] - 37s 10ms/step - loss: 0.0037 - val_loss: 0.0021
#
# Epoch 00005: val_loss did not improve from 0.00187
# Model loaded

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 38
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 44
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(10))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(10))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(300, activation='relu', name='Hidden-2'))  
        self.add(layers.Dense(150, activation='relu', name='Hidden-3'))  
        self.add(layers.Dense(100))
        
model3 = DNN(X_train_sc.shape[1])
#***************************주단위, 일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100)(combinedInput)
x = Dense(50)(x)
x = Dense(25)(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('temp4.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=20, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('temp4.h5')
print("Model loaded")

#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 1
plt.title('Visitors Result')
plt.xlabel('2018.4.16 ~ 2019.4.30')
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()

mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mape : ", np.absolute( (ynewtest - ynew)/ynewtest ).mean()*100 )

mse = np.square(y_testLSTM - Y_pred).mean()
rmse = mse ** 0.5
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(y_testLSTM - Y_pred))
print("mae : ", np.absolute(y_testLSTM - Y_pred).mean())
print("mape : ", np.absolute( (y_testLSTM - Y_pred)/y_testLSTM ).mean()*100 )
# Out:
# Using TensorFlow backend.
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING: Logging before flag parsing goes to stderr.
# W1020 15:18:08.531305  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1020 15:18:08.559232  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1020 15:18:08.562226  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1020 15:18:10.722483  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 학습 데이터 수: 4774
# 테스트 데이터 수: 350
# W1020 15:18:11.577162  9200 deprecation.py:323] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1020 15:18:16.550902  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1020 15:18:17.874328  9200 deprecation_wrapper.py:119] From C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 3819 samples, validate on 955 samples
# Epoch 1/20
# 3819/3819 [==============================] - 19s 5ms/step - loss: 0.0178 - val_loss: 0.0063
#
# Epoch 00001: val_loss improved from inf to 0.00632, saving model to temp4.h5
# Epoch 2/20
# 3819/3819 [==============================] - 10s 2ms/step - loss: 0.0042 - val_loss: 0.0024
#
# Epoch 00002: val_loss improved from 0.00632 to 0.00242, saving model to temp4.h5
# Epoch 3/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0039 - val_loss: 0.0055
#
# Epoch 00003: val_loss did not improve from 0.00242
# Epoch 4/20
# 3819/3819 [==============================] - 11s 3ms/step - loss: 0.0035 - val_loss: 0.0038
#
# Epoch 00004: val_loss did not improve from 0.00242
# Epoch 5/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0032 - val_loss: 0.0046
#
# Epoch 00005: val_loss did not improve from 0.00242
# Epoch 6/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0033 - val_loss: 0.0043
#
# Epoch 00006: val_loss did not improve from 0.00242
# Epoch 7/20
# 3819/3819 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00007: val_loss did not improve from 0.00242
# Epoch 8/20
# 3819/3819 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0034
#
# Epoch 00008: val_loss did not improve from 0.00242
# Epoch 9/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0031 - val_loss: 0.0038
#
# Epoch 00009: val_loss did not improve from 0.00242
# Epoch 10/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00010: val_loss did not improve from 0.00242
# Epoch 11/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0030 - val_loss: 0.0038
#
# Epoch 00011: val_loss did not improve from 0.00242
# Epoch 12/20
# 3819/3819 [==============================] - 18s 5ms/step - loss: 0.0031 - val_loss: 0.0032
#
# Epoch 00012: val_loss did not improve from 0.00242
# Epoch 13/20
# 3819/3819 [==============================] - 17s 5ms/step - loss: 0.0031 - val_loss: 0.0022
#
# Epoch 00013: val_loss improved from 0.00242 to 0.00217, saving model to temp4.h5
# Epoch 14/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00014: val_loss did not improve from 0.00217
# Epoch 15/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00015: val_loss did not improve from 0.00217
# Epoch 16/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0029 - val_loss: 0.0042
#
# Epoch 00016: val_loss did not improve from 0.00217
# Epoch 17/20
# 3819/3819 [==============================] - 8s 2ms/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00017: val_loss did not improve from 0.00217
# Epoch 18/20
# 3819/3819 [==============================] - 15s 4ms/step - loss: 0.0028 - val_loss: 0.0024
#
# Epoch 00018: val_loss did not improve from 0.00217
# Epoch 19/20
# 3819/3819 [==============================] - 8s 2ms/step - loss: 0.0031 - val_loss: 0.0025
#
# Epoch 00019: val_loss did not improve from 0.00217
# Epoch 20/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0031 - val_loss: 0.0036
#
# Epoch 00020: val_loss did not improve from 0.00217
# Model loaded
# mse :  30293091.807563342
# rmse :  5503.91604292465
# std : 4899.869450342439
# mae :  3633.8820922442846

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 38
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 44
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(10))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(10))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(20, activation='relu',input_shape=(Nin,), name='Hidden-1'))
#         self.add(layers.Dense(300, activation='relu', name='Hidden-2'))  
#         self.add(layers.Dense(150, activation='relu', name='Hidden-3'))  
        self.add(layers.Dense(10))
        
model3 = DNN(X_train_sc.shape[1])
#***************************주단위, 일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(20)(combinedInput)
x = Dense(10)(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('temp4.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=20, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('temp4.h5')
print("Model loaded")

#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 1
plt.title('Visitors Result')
plt.xlabel('2018.4.16 ~ 2019.4.30')
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()

mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mape : ", np.absolute( (ynewtest - ynew)/ynewtest ).mean()*100 )

mse = np.square(y_testLSTM - Y_pred).mean()
rmse = mse ** 0.5
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(y_testLSTM - Y_pred))
print("mae : ", np.absolute(y_testLSTM - Y_pred).mean())
print("mape : ", np.absolute( (y_testLSTM - Y_pred)/y_testLSTM ).mean()*100 )
# Out:
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Kang ChanHyuk\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4774
# 테스트 데이터 수: 350
# Train on 3819 samples, validate on 955 samples
# Epoch 1/20
# 3819/3819 [==============================] - 23s 6ms/step - loss: 0.0152 - val_loss: 0.0052
#
# Epoch 00001: val_loss improved from inf to 0.00520, saving model to temp4.h5
# Epoch 2/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0072 - val_loss: 0.0036
#
# Epoch 00002: val_loss improved from 0.00520 to 0.00358, saving model to temp4.h5
# Epoch 3/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0055 - val_loss: 0.0032
#
# Epoch 00003: val_loss improved from 0.00358 to 0.00319, saving model to temp4.h5
# Epoch 4/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0050 - val_loss: 0.0035
#
# Epoch 00004: val_loss did not improve from 0.00319
# Epoch 5/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0047 - val_loss: 0.0029
#
# Epoch 00005: val_loss improved from 0.00319 to 0.00292, saving model to temp4.h5
# Epoch 6/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0046 - val_loss: 0.0038
#
# Epoch 00006: val_loss did not improve from 0.00292
# Epoch 7/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0044 - val_loss: 0.0035
#
# Epoch 00007: val_loss did not improve from 0.00292
# Epoch 8/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0044 - val_loss: 0.0032
#
# Epoch 00008: val_loss did not improve from 0.00292
# Epoch 9/20
# 3819/3819 [==============================] - 8s 2ms/step - loss: 0.0042 - val_loss: 0.0031
#
# Epoch 00009: val_loss did not improve from 0.00292
# Epoch 10/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0041 - val_loss: 0.0030
#
# Epoch 00010: val_loss did not improve from 0.00292
# Epoch 11/20
# 3819/3819 [==============================] - 8s 2ms/step - loss: 0.0040 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00292
# Epoch 12/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0039 - val_loss: 0.0029
#
# Epoch 00012: val_loss did not improve from 0.00292
# Epoch 13/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0038 - val_loss: 0.0029
#
# Epoch 00013: val_loss did not improve from 0.00292
# Epoch 14/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0037 - val_loss: 0.0038
#
# Epoch 00014: val_loss did not improve from 0.00292
# Epoch 15/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0037 - val_loss: 0.0030
#
# Epoch 00015: val_loss did not improve from 0.00292
# Epoch 16/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0037 - val_loss: 0.0029
#
# Epoch 00016: val_loss did not improve from 0.00292
# Epoch 17/20
# 3819/3819 [==============================] - 10s 3ms/step - loss: 0.0036 - val_loss: 0.0030
#
# Epoch 00017: val_loss did not improve from 0.00292
# Epoch 18/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0035 - val_loss: 0.0032
#
# Epoch 00018: val_loss did not improve from 0.00292
# Epoch 19/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0035 - val_loss: 0.0030
#
# Epoch 00019: val_loss did not improve from 0.00292
# Epoch 20/20
# 3819/3819 [==============================] - 9s 2ms/step - loss: 0.0035 - val_loss: 0.0032
#
# Epoch 00020: val_loss did not improve from 0.00292
# Model loaded
# mse :  39566967.45398569
# rmse :  6290.227933388876
# std : 6228.666995570645
# mae :  4472.533494688762
# mape :  226.34320357176026
# mse :  0.0029918311417012193
# rmse :  0.054697633785212495
# std : 0.0541623212217533
# mae :  0.03889159569156138
# mape :  226.8670667447048
