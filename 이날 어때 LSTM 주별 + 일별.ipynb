# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

weekfrom = 2
weekto = 33
week = weekto - weekfrom

dayfrom = 14
dayto = 42
day = dayto - dayfrom

df = pd.read_csv('SeoulGrandPark.csv', engine='python')
# print(df.head())

df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)#날짜 column생성
# print(df.head())

df = df.set_index('날짜') 
# print(df.head())
# df.plot()

split_date_last = '2016-12-17'
split_date_start = '2017-3-30'

train = df.loc[:split_date_last, ['일계']]
test = df.loc[split_date_start:, ['일계']]
# print(train.head())

train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

#*************************************주 단위 15년동안의 입장객수 경향************************************************
#주단위 데이터로 변환. train2, test2.
train2 = train.iloc[0:0]
traintmp2 = train
for i in range(int(len(train)/7)):
    traintmp = train['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2 = pd.concat([train2, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2 = test.iloc[0:0]
testtmp2 = test
for i in range(int(len(test)/7)):
    testtmp = test['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2 = pd.concat([test2, testtmp2[i*7+6:i*7+7]], axis=0)
print(test2.head)

plt.plot(train2)
plt.show()

#***********************************************************************************************************************
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()

train_sc2 = sc.fit_transform(train2)
test_sc2 = sc.transform(test2)

train_sc = sc.fit_transform(train)
test_sc = sc.transform(test)

# print(train_sc)

train_sc_df2 = pd.DataFrame(train_sc2, columns=['Scaled'], index=train2.index)
test_sc_df2 = pd.DataFrame(test_sc2, columns=['Scaled'], index=test2.index)
# print(train_sc_df.head())

train_sc_df = pd.DataFrame(train_sc, columns=['Scaled'], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=['Scaled'], index=test.index)
# print(train_sc_df.head())


for s in range(weekfrom, weekto):
    train_sc_df2['shift_{}'.format(s)] = train_sc_df2['Scaled'].shift(s)
    test_sc_df2['shift_{}'.format(s)] = test_sc_df2['Scaled'].shift(s)
    
for s in range(dayfrom, dayto):
    train_sc_df['shift_{}'.format(s)] = train_sc_df['Scaled'].shift(s)
    test_sc_df['shift_{}'.format(s)] = test_sc_df['Scaled'].shift(s)
    

X_train2 = train_sc_df2.dropna().drop('Scaled', axis=1)
y_train2 = train_sc_df2.dropna()[['Scaled']]
# print(X_train.head())
# print(y_train.head())

X_train = train_sc_df.dropna().drop('Scaled', axis=1)
y_train = train_sc_df.dropna()[['Scaled']]
# print(X_train.head())
# print(y_train.head())

X_test2 = test_sc_df2.dropna().drop('Scaled', axis=1)
y_test2 = test_sc_df2.dropna()[['Scaled']]

X_test = test_sc_df.dropna().drop('Scaled', axis=1)
y_test = test_sc_df.dropna()[['Scaled']]

X_train2 = X_train2.values
X_test2= X_test2.values

y_train2 = y_train2.values
y_test2 = y_test2.values

X_train_t2 = X_train2.reshape(X_train2.shape[0], week, 1)
X_test_t2 = X_test2.reshape(X_test2.shape[0], week, 1)

X_train = X_train.values
X_test= X_test.values

y_train = y_train.values
y_test = y_test.values

X_train_t = X_train.reshape(X_train.shape[0], day, 1)
X_test_t = X_test.reshape(X_test.shape[0], day, 1)

print('주간test개수: ', len(y_test2))
print('일별test개수: ', len(y_test))

from keras.layers import LSTM 
from keras.models import Sequential 
from keras.layers import Dense 
import keras.backend as K 
from keras.callbacks import EarlyStopping 
from keras import optimizers
K.clear_session()
model2 = Sequential() # Sequeatial Model 
model2.add(LSTM(60, input_shape=(week, 1), return_sequences = True)) # (timestep, feature)
model2.add(LSTM(60))
model2.add(Dense(1)) # output = 1 
adam2 = optimizers.Adam(lr=0.0004)
model2.compile(loss='mean_squared_error', optimizer=adam2) 
# print(model.summary())

early_stop2 = EarlyStopping(monitor='loss', patience=30, verbose=1)

model2.fit(X_train_t2, y_train2, epochs=200,
          batch_size=10, verbose=1, callbacks=[early_stop2])
#***************************위는 주간, 아래는 일간**********************************************************
model = Sequential() # Sequeatial Model 
model.add(LSTM(56, input_shape=(day, 1), return_sequences = True)) # (timestep, feature)
model.add(LSTM(56))
model.add(Dense(1)) # output = 1 
adam = optimizers.Adam(lr=0.001)
model.compile(loss='mean_squared_error', optimizer=adam) 
# print(model.summary())

early_stop = EarlyStopping(monitor='val_loss', patience=30, verbose=1)

model.fit(X_train_t, y_train, epochs=200,
          batch_size=30, verbose=1, validation_split = 0.2, callbacks=[early_stop])


y_pred2 = model2.predict(X_test_t2)
plt.plot(y_test2)
plt.plot(y_pred2)
plt.show()

y_pred = model.predict(X_test_t)
plt.plot(y_test)
plt.plot(y_pred)
plt.show()
# Out:
# 주간test개수:  76
# 일별test개수:  721
# Epoch 1/200
# 618/618 [==============================] - 3s 5ms/step - loss: 0.0459
# Epoch 2/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0377
# Epoch 3/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0370
# Epoch 4/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0355
# Epoch 5/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0355
# Epoch 6/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0310
# Epoch 7/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0221
# Epoch 8/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0185
# Epoch 9/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0173
# Epoch 10/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0157
# Epoch 11/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0155
# Epoch 12/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0153
# Epoch 13/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0149
# Epoch 14/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0158
# Epoch 15/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0145
# Epoch 16/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0138
# Epoch 17/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0136
# Epoch 18/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0135
# Epoch 19/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0137
# Epoch 20/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0137
# Epoch 21/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0135
# Epoch 22/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0139A: 0s - loss: 0.0
# Epoch 23/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0132
# Epoch 24/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0144
# Epoch 25/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0129
# Epoch 26/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0128
# Epoch 27/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0128
# Epoch 28/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0123
# Epoch 29/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0134
# Epoch 30/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0134
# Epoch 31/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0132
# Epoch 32/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0123
# Epoch 33/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0129
# Epoch 34/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0123
# Epoch 35/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0129
# Epoch 36/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0129
# Epoch 37/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0121
# Epoch 38/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0118
# Epoch 39/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0118
# Epoch 40/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0122
# Epoch 41/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0118
# Epoch 42/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0115
# Epoch 43/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0115
# Epoch 44/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0112
# Epoch 45/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0114
# Epoch 46/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0122
# Epoch 47/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0109
# Epoch 48/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0108
# Epoch 49/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0116
# Epoch 50/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0107
# Epoch 51/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0111
# Epoch 52/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0109
# Epoch 53/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0107
# Epoch 54/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0104
# Epoch 55/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0107
# Epoch 56/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0103
# Epoch 57/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0108
# Epoch 58/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0101
# Epoch 59/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0110
# Epoch 60/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0107
# Epoch 61/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0105
# Epoch 62/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0105
# Epoch 63/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0106
# Epoch 64/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0103
# Epoch 65/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0099
# Epoch 66/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0104
# Epoch 67/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0108
# Epoch 68/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0102
# Epoch 69/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0102
# Epoch 70/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0103
# Epoch 71/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0100
# Epoch 72/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0102
# Epoch 73/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0104
# Epoch 74/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0101
# Epoch 75/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0102
# Epoch 76/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0100
# Epoch 77/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0104
# Epoch 78/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0098
# Epoch 79/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0100
# Epoch 80/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0098
# Epoch 81/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0101
# Epoch 82/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0102
# Epoch 83/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0102
# Epoch 84/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0104
# Epoch 85/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0099
# Epoch 86/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0099
# Epoch 87/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0100
# Epoch 88/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0099
# Epoch 89/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0100
# Epoch 90/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0098
# Epoch 91/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0098
# Epoch 92/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0096
# Epoch 93/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0098
# Epoch 94/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0106
# Epoch 95/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0100
# Epoch 96/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0099
# Epoch 97/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0095
# Epoch 98/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0097
# Epoch 99/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0100
# Epoch 100/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0093
# Epoch 101/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0098
# Epoch 102/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0097
# Epoch 103/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 104/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 105/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0095
# Epoch 106/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0095
# Epoch 107/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0090
# Epoch 108/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0099
# Epoch 109/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0097
# Epoch 110/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0094
# Epoch 111/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0095
# Epoch 112/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0096
# Epoch 113/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0097
# Epoch 114/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0098
# Epoch 115/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0099
# Epoch 116/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0096
# Epoch 117/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0096
# Epoch 118/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0095
# Epoch 119/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0096
# Epoch 120/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 121/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0093
# Epoch 122/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 123/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0095
# Epoch 124/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 125/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 126/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 127/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 128/200
# 618/618 [==============================] - 2s 4ms/step - loss: 0.0093
# Epoch 129/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0094
# Epoch 130/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0092
# Epoch 131/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0091
# Epoch 132/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0093
# Epoch 133/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0092
# Epoch 134/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0096
# Epoch 135/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0092
# Epoch 136/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0093
# Epoch 137/200
# 618/618 [==============================] - 2s 3ms/step - loss: 0.0092
# Epoch 00137: early stopping
# Train on 3609 samples, validate on 903 samples
# Epoch 1/200
# 3609/3609 [==============================] - 5s 1ms/step - loss: 0.0114 - val_loss: 0.0073
# Epoch 2/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0097 - val_loss: 0.0052
# Epoch 3/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0096 - val_loss: 0.0055
# Epoch 4/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0096 - val_loss: 0.0060ETA: 0s
# Epoch 5/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0095 - val_loss: 0.0055
# Epoch 6/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0093 - val_loss: 0.0052
# Epoch 7/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0092 - val_loss: 0.0052
# Epoch 8/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0090 - val_loss: 0.0050
# Epoch 9/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 10/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0053
# Epoch 11/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0090 - val_loss: 0.0049
# Epoch 12/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0049
# Epoch 13/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0058
# Epoch 14/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0053
# Epoch 15/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0088 - val_loss: 0.0049
# Epoch 16/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0086 - val_loss: 0.0049
# Epoch 17/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0049
# Epoch 18/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0087 - val_loss: 0.0049
# Epoch 19/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0052
# Epoch 20/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0085 - val_loss: 0.0051
# Epoch 21/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0081 - val_loss: 0.0051
# Epoch 22/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0077 - val_loss: 0.0046
# Epoch 23/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0074 - val_loss: 0.0045
# Epoch 24/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0072 - val_loss: 0.0045
# Epoch 25/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0070 - val_loss: 0.0045
# Epoch 26/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0048
# Epoch 27/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 28/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0047
# Epoch 29/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 30/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 31/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 32/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 33/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0068 - val_loss: 0.0043
# Epoch 34/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 35/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 36/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 37/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 38/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0050
# Epoch 39/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0047
# Epoch 40/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0048
# Epoch 41/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0048
# Epoch 42/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 43/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 44/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 45/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 46/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 47/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 48/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 49/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 50/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 51/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 52/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0047
# Epoch 53/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0066 - val_loss: 0.0044
# Epoch 54/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 55/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0048
# Epoch 56/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0048
# Epoch 57/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 58/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 59/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 60/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 61/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 62/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0062 - val_loss: 0.0050
# Epoch 63/200
# 3609/3609 [==============================] - 4s 1ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 00063: early stopping
