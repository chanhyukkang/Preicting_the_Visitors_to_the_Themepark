# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='val_loss', patience=80, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# Using TensorFlow backend.
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\dlgus\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0178 - val_loss: 0.0040
#
# Epoch 00001: val_loss improved from inf to 0.00400, saving model to bestmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 2s 466us/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00002: val_loss did not improve from 0.00400
# Epoch 3/100
# 3847/3847 [==============================] - 2s 518us/step - loss: 0.0038 - val_loss: 0.0048
#
# Epoch 00003: val_loss did not improve from 0.00400
# Epoch 4/100
# 3847/3847 [==============================] - 2s 533us/step - loss: 0.0034 - val_loss: 0.0025
#
# Epoch 00004: val_loss improved from 0.00400 to 0.00254, saving model to bestmodel.h5
# Epoch 5/100
# 3847/3847 [==============================] - 2s 534us/step - loss: 0.0035 - val_loss: 0.0033
#
# Epoch 00005: val_loss did not improve from 0.00254
# Epoch 6/100
# 3847/3847 [==============================] - 2s 540us/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00006: val_loss did not improve from 0.00254
# Epoch 7/100
# 3847/3847 [==============================] - 2s 531us/step - loss: 0.0035 - val_loss: 0.0057
#
# Epoch 00007: val_loss did not improve from 0.00254
# Epoch 8/100
# 3847/3847 [==============================] - 2s 541us/step - loss: 0.0032 - val_loss: 0.0046
#
# Epoch 00008: val_loss did not improve from 0.00254
# Epoch 9/100
# 3847/3847 [==============================] - 2s 533us/step - loss: 0.0033 - val_loss: 0.0050
#
# Epoch 00009: val_loss did not improve from 0.00254
# Epoch 10/100
# 3847/3847 [==============================] - 2s 542us/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00010: val_loss did not improve from 0.00254
# Epoch 11/100
# 3847/3847 [==============================] - 2s 539us/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00254
# Epoch 12/100
# 3847/3847 [==============================] - 2s 540us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00012: val_loss did not improve from 0.00254
# Epoch 13/100
# 3847/3847 [==============================] - 2s 526us/step - loss: 0.0030 - val_loss: 0.0050
#
# Epoch 00013: val_loss did not improve from 0.00254
# Epoch 14/100
# 3847/3847 [==============================] - 2s 537us/step - loss: 0.0029 - val_loss: 0.0028
#
# Epoch 00014: val_loss did not improve from 0.00254
# Epoch 15/100
# 3847/3847 [==============================] - 2s 533us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00015: val_loss did not improve from 0.00254
# Epoch 16/100
# 3847/3847 [==============================] - 2s 534us/step - loss: 0.0028 - val_loss: 0.0047
#
# Epoch 00016: val_loss did not improve from 0.00254
# Epoch 17/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00017: val_loss did not improve from 0.00254
# Epoch 18/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00018: val_loss improved from 0.00254 to 0.00253, saving model to bestmodel.h5
# Epoch 19/100
# 3847/3847 [==============================] - 2s 536us/step - loss: 0.0028 - val_loss: 0.0046
#
# Epoch 00019: val_loss did not improve from 0.00253
# Epoch 20/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00020: val_loss did not improve from 0.00253
# Epoch 21/100
# 3847/3847 [==============================] - 2s 535us/step - loss: 0.0027 - val_loss: 0.0043
#
# Epoch 00021: val_loss did not improve from 0.00253
# Epoch 22/100
# 3847/3847 [==============================] - 2s 540us/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00022: val_loss did not improve from 0.00253
# Epoch 23/100
# 3847/3847 [==============================] - 2s 545us/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00023: val_loss did not improve from 0.00253
# Epoch 24/100
# 3847/3847 [==============================] - 2s 527us/step - loss: 0.0028 - val_loss: 0.0039
#
# Epoch 00024: val_loss did not improve from 0.00253
# Epoch 25/100
# 3847/3847 [==============================] - 2s 536us/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00025: val_loss did not improve from 0.00253
# Epoch 26/100
# 3847/3847 [==============================] - 2s 539us/step - loss: 0.0028 - val_loss: 0.0021
#
# Epoch 00026: val_loss improved from 0.00253 to 0.00210, saving model to bestmodel.h5
# Epoch 27/100
# 3847/3847 [==============================] - 2s 538us/step - loss: 0.0028 - val_loss: 0.0033
#
# Epoch 00027: val_loss did not improve from 0.00210
# Epoch 28/100
# 3847/3847 [==============================] - 2s 532us/step - loss: 0.0027 - val_loss: 0.0026
#
# Epoch 00028: val_loss did not improve from 0.00210
# Epoch 29/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00029: val_loss did not improve from 0.00210
# Epoch 30/100
# 3847/3847 [==============================] - 2s 548us/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00030: val_loss did not improve from 0.00210
# Epoch 31/100
# 3847/3847 [==============================] - 2s 536us/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00031: val_loss did not improve from 0.00210
# Epoch 32/100
# 3847/3847 [==============================] - 2s 543us/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00032: val_loss did not improve from 0.00210
# Epoch 33/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00033: val_loss did not improve from 0.00210
# Epoch 34/100
# 3847/3847 [==============================] - 2s 543us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00034: val_loss did not improve from 0.00210
# Epoch 35/100
# 3847/3847 [==============================] - 2s 527us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00035: val_loss did not improve from 0.00210
# Epoch 36/100
# 3847/3847 [==============================] - 2s 547us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00036: val_loss did not improve from 0.00210
# Epoch 37/100
# 3847/3847 [==============================] - 2s 540us/step - loss: 0.0025 - val_loss: 0.0045
#
# Epoch 00037: val_loss did not improve from 0.00210
# Epoch 38/100
# 3847/3847 [==============================] - 2s 537us/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00038: val_loss did not improve from 0.00210
# Epoch 39/100
# 3847/3847 [==============================] - 2s 544us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00039: val_loss did not improve from 0.00210
# Epoch 40/100
# 3847/3847 [==============================] - 2s 545us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00040: val_loss did not improve from 0.00210
# Epoch 41/100
# 3847/3847 [==============================] - 2s 553us/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00041: val_loss did not improve from 0.00210
# Epoch 42/100
# 3847/3847 [==============================] - 2s 535us/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00042: val_loss did not improve from 0.00210
# Epoch 43/100
# 3847/3847 [==============================] - 2s 539us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00043: val_loss did not improve from 0.00210
# Epoch 44/100
# 3847/3847 [==============================] - 2s 540us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00044: val_loss did not improve from 0.00210
# Epoch 45/100
# 3847/3847 [==============================] - 2s 538us/step - loss: 0.0023 - val_loss: 0.0045
#
# Epoch 00045: val_loss did not improve from 0.00210
# Epoch 46/100
# 3847/3847 [==============================] - 2s 554us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00046: val_loss did not improve from 0.00210
# Epoch 47/100
# 3847/3847 [==============================] - 2s 528us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00047: val_loss did not improve from 0.00210
# Epoch 48/100
# 3847/3847 [==============================] - 2s 542us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00048: val_loss did not improve from 0.00210
# Epoch 49/100
# 3847/3847 [==============================] - 2s 537us/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00049: val_loss did not improve from 0.00210
# Epoch 50/100
# 3847/3847 [==============================] - 2s 534us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00050: val_loss did not improve from 0.00210
# Epoch 51/100
# 3847/3847 [==============================] - 2s 541us/step - loss: 0.0024 - val_loss: 0.0036
#
# Epoch 00051: val_loss did not improve from 0.00210
# Epoch 52/100
# 3847/3847 [==============================] - 2s 536us/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00052: val_loss did not improve from 0.00210
# Epoch 53/100
# 3847/3847 [==============================] - 2s 533us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00053: val_loss did not improve from 0.00210
# Epoch 54/100
# 3847/3847 [==============================] - 2s 534us/step - loss: 0.0023 - val_loss: 0.0032
#
# Epoch 00054: val_loss did not improve from 0.00210
# Epoch 55/100
# 3847/3847 [==============================] - 2s 589us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00055: val_loss did not improve from 0.00210
# Epoch 56/100
# 3847/3847 [==============================] - 2s 627us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00056: val_loss did not improve from 0.00210
# Epoch 57/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00057: val_loss did not improve from 0.00210
# Epoch 58/100
# 3847/3847 [==============================] - 2s 571us/step - loss: 0.0023 - val_loss: 0.0029
#
# Epoch 00058: val_loss did not improve from 0.00210
# Epoch 59/100
# 3847/3847 [==============================] - 2s 562us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00059: val_loss did not improve from 0.00210
# Epoch 60/100
# 3847/3847 [==============================] - 2s 566us/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00060: val_loss did not improve from 0.00210
# Epoch 61/100
# 3847/3847 [==============================] - 2s 569us/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00061: val_loss did not improve from 0.00210
# Epoch 62/100
# 3847/3847 [==============================] - 2s 568us/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00062: val_loss did not improve from 0.00210
# Epoch 63/100
# 3847/3847 [==============================] - 2s 594us/step - loss: 0.0022 - val_loss: 0.0040
#
# Epoch 00063: val_loss did not improve from 0.00210
# Epoch 64/100
# 3847/3847 [==============================] - 2s 622us/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00064: val_loss did not improve from 0.00210
# Epoch 65/100
# 3847/3847 [==============================] - 2s 608us/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00065: val_loss did not improve from 0.00210
# Epoch 66/100
# 3847/3847 [==============================] - 2s 569us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00066: val_loss did not improve from 0.00210
# Epoch 67/100
# 3847/3847 [==============================] - 2s 570us/step - loss: 0.0022 - val_loss: 0.0041
#
# Epoch 00067: val_loss did not improve from 0.00210
# Epoch 68/100
# 3847/3847 [==============================] - 2s 572us/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00068: val_loss did not improve from 0.00210
# Epoch 69/100
# 3847/3847 [==============================] - 2s 564us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00069: val_loss did not improve from 0.00210
# Epoch 70/100
# 3847/3847 [==============================] - 2s 559us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00070: val_loss did not improve from 0.00210
# Epoch 71/100
# 3847/3847 [==============================] - 2s 566us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00071: val_loss did not improve from 0.00210
# Epoch 72/100
# 3847/3847 [==============================] - 2s 591us/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00072: val_loss did not improve from 0.00210
# Epoch 73/100
# 3847/3847 [==============================] - 2s 616us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00073: val_loss did not improve from 0.00210
# Epoch 74/100
# 3847/3847 [==============================] - 2s 581us/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00074: val_loss did not improve from 0.00210
# Epoch 75/100
# 3847/3847 [==============================] - 2s 575us/step - loss: 0.0021 - val_loss: 0.0031
#
# Epoch 00075: val_loss did not improve from 0.00210
# Epoch 76/100
# 3847/3847 [==============================] - 2s 567us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00076: val_loss did not improve from 0.00210
# Epoch 77/100
# 3847/3847 [==============================] - 2s 564us/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00077: val_loss did not improve from 0.00210
# Epoch 78/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00078: val_loss did not improve from 0.00210
# Epoch 79/100
# 3847/3847 [==============================] - 2s 569us/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00079: val_loss did not improve from 0.00210
# Epoch 80/100
# 3847/3847 [==============================] - 2s 576us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00080: val_loss did not improve from 0.00210
# Epoch 81/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00081: val_loss did not improve from 0.00210
# Epoch 82/100
# 3847/3847 [==============================] - 2s 573us/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00082: val_loss did not improve from 0.00210
# Epoch 83/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0019 - val_loss: 0.0031
#
# Epoch 00083: val_loss did not improve from 0.00210
# Epoch 84/100
# 3847/3847 [==============================] - 2s 572us/step - loss: 0.0019 - val_loss: 0.0037
#
# Epoch 00084: val_loss did not improve from 0.00210
# Epoch 85/100
# 3847/3847 [==============================] - 2s 571us/step - loss: 0.0020 - val_loss: 0.0027
#
# Epoch 00085: val_loss did not improve from 0.00210
# Epoch 86/100
# 3847/3847 [==============================] - 2s 574us/step - loss: 0.0019 - val_loss: 0.0023
#
# Epoch 00086: val_loss did not improve from 0.00210
# Epoch 87/100
# 3847/3847 [==============================] - 2s 606us/step - loss: 0.0019 - val_loss: 0.0025
#
# Epoch 00087: val_loss did not improve from 0.00210
# Epoch 88/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0019 - val_loss: 0.0024
#
# Epoch 00088: val_loss did not improve from 0.00210
# Epoch 89/100
# 3847/3847 [==============================] - 2s 599us/step - loss: 0.0018 - val_loss: 0.0025
#
# Epoch 00089: val_loss did not improve from 0.00210
# Epoch 90/100
# 3847/3847 [==============================] - 2s 573us/step - loss: 0.0017 - val_loss: 0.0026
#
# Epoch 00090: val_loss did not improve from 0.00210
# Epoch 91/100
# 3847/3847 [==============================] - 2s 595us/step - loss: 0.0017 - val_loss: 0.0026
#
# Epoch 00091: val_loss did not improve from 0.00210
# Epoch 92/100
# 3847/3847 [==============================] - 2s 579us/step - loss: 0.0019 - val_loss: 0.0037
#
# Epoch 00092: val_loss did not improve from 0.00210
# Epoch 93/100
# 3847/3847 [==============================] - 2s 571us/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00093: val_loss did not improve from 0.00210
# Epoch 94/100
# 3847/3847 [==============================] - 2s 552us/step - loss: 0.0018 - val_loss: 0.0023
#
# Epoch 00094: val_loss did not improve from 0.00210
# Epoch 95/100
# 3847/3847 [==============================] - 2s 548us/step - loss: 0.0017 - val_loss: 0.0032
#
# Epoch 00095: val_loss did not improve from 0.00210
# Epoch 96/100
# 3847/3847 [==============================] - 2s 541us/step - loss: 0.0018 - val_loss: 0.0028
#
# Epoch 00096: val_loss did not improve from 0.00210
# Epoch 97/100
# 3847/3847 [==============================] - 2s 543us/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00097: val_loss did not improve from 0.00210
# Epoch 98/100
# 3847/3847 [==============================] - 2s 542us/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00098: val_loss did not improve from 0.00210
# Epoch 99/100
# 3847/3847 [==============================] - 2s 550us/step - loss: 0.0017 - val_loss: 0.0024
#
# Epoch 00099: val_loss did not improve from 0.00210
# Epoch 100/100
# 3847/3847 [==============================] - 2s 546us/step - loss: 0.0017 - val_loss: 0.0025
#
# Epoch 00100: val_loss did not improve from 0.00210
# Model loaded
# mae :  3312.602023327815
# mse :  25077426.214255195
# rmse :  5007.736635872057
# std : 4897.8277323655

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=100, batch_size=100, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/100
# 3847/3847 [==============================] - 11s 3ms/step - loss: 0.0093 - val_loss: 0.0037
#
# Epoch 00001: val_loss improved from inf to 0.00371, saving model to bestmodel.h5
# Epoch 2/100
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0043 - val_loss: 0.0041
#
# Epoch 00002: val_loss did not improve from 0.00371
# Epoch 3/100
# 3847/3847 [==============================] - 3s 715us/step - loss: 0.0037 - val_loss: 0.0049
#
# Epoch 00003: val_loss did not improve from 0.00371
# Epoch 4/100
# 3847/3847 [==============================] - 3s 720us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00004: val_loss improved from 0.00371 to 0.00310, saving model to bestmodel.h5
# Epoch 5/100
# 3847/3847 [==============================] - 3s 687us/step - loss: 0.0034 - val_loss: 0.0028
#
# Epoch 00005: val_loss improved from 0.00310 to 0.00284, saving model to bestmodel.h5
# Epoch 6/100
# 3847/3847 [==============================] - 3s 685us/step - loss: 0.0034 - val_loss: 0.0028
#
# Epoch 00006: val_loss improved from 0.00284 to 0.00278, saving model to bestmodel.h5
# Epoch 7/100
# 3847/3847 [==============================] - 2s 635us/step - loss: 0.0033 - val_loss: 0.0039
#
# Epoch 00007: val_loss did not improve from 0.00278
# Epoch 8/100
# 3847/3847 [==============================] - 2s 644us/step - loss: 0.0034 - val_loss: 0.0036
#
# Epoch 00008: val_loss did not improve from 0.00278
# Epoch 9/100
# 3847/3847 [==============================] - 3s 753us/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00009: val_loss did not improve from 0.00278
# Epoch 10/100
# 3847/3847 [==============================] - 3s 668us/step - loss: 0.0032 - val_loss: 0.0044
#
# Epoch 00010: val_loss did not improve from 0.00278
# Epoch 11/100
# 3847/3847 [==============================] - 3s 747us/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00011: val_loss did not improve from 0.00278
# Epoch 12/100
# 3847/3847 [==============================] - 3s 762us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00012: val_loss did not improve from 0.00278
# Epoch 13/100
# 3847/3847 [==============================] - 3s 664us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00013: val_loss did not improve from 0.00278
# Epoch 14/100
# 3847/3847 [==============================] - 3s 671us/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00014: val_loss did not improve from 0.00278
# Epoch 15/100
# 3847/3847 [==============================] - 3s 707us/step - loss: 0.0034 - val_loss: 0.0025
#
# Epoch 00015: val_loss improved from 0.00278 to 0.00247, saving model to bestmodel.h5
# Epoch 16/100
# 3847/3847 [==============================] - 3s 680us/step - loss: 0.0031 - val_loss: 0.0021
#
# Epoch 00016: val_loss improved from 0.00247 to 0.00214, saving model to bestmodel.h5
# Epoch 17/100
# 3847/3847 [==============================] - 3s 742us/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00017: val_loss did not improve from 0.00214
# Epoch 18/100
# 3847/3847 [==============================] - 3s 777us/step - loss: 0.0029 - val_loss: 0.0031
#
# Epoch 00018: val_loss did not improve from 0.00214
# Epoch 19/100
# 3847/3847 [==============================] - 3s 774us/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00019: val_loss did not improve from 0.00214
# Epoch 20/100
# 3847/3847 [==============================] - 3s 842us/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00020: val_loss did not improve from 0.00214
# Epoch 21/100
# 3847/3847 [==============================] - 3s 829us/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00021: val_loss did not improve from 0.00214
# Epoch 22/100
# 3847/3847 [==============================] - 3s 789us/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00022: val_loss did not improve from 0.00214
# Epoch 23/100
# 3847/3847 [==============================] - 3s 813us/step - loss: 0.0026 - val_loss: 0.0041
#
# Epoch 00023: val_loss did not improve from 0.00214
# Epoch 24/100
# 3847/3847 [==============================] - 3s 783us/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00024: val_loss did not improve from 0.00214
# Epoch 25/100
# 3847/3847 [==============================] - 2s 606us/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00025: val_loss did not improve from 0.00214
# Epoch 26/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00026: val_loss did not improve from 0.00214
# Epoch 27/100
# 3847/3847 [==============================] - 3s 770us/step - loss: 0.0026 - val_loss: 0.0022
#
# Epoch 00027: val_loss did not improve from 0.00214
# Epoch 28/100
# 3847/3847 [==============================] - 3s 800us/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00028: val_loss did not improve from 0.00214
# Epoch 29/100
# 3847/3847 [==============================] - 3s 768us/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00029: val_loss did not improve from 0.00214
# Epoch 30/100
# 3847/3847 [==============================] - 3s 653us/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00030: val_loss did not improve from 0.00214
# Epoch 31/100
# 3847/3847 [==============================] - 3s 756us/step - loss: 0.0027 - val_loss: 0.0040
#
# Epoch 00031: val_loss did not improve from 0.00214
# Epoch 32/100
# 3847/3847 [==============================] - 2s 558us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00032: val_loss did not improve from 0.00214
# Epoch 33/100
# 3847/3847 [==============================] - 2s 520us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00033: val_loss did not improve from 0.00214
# Epoch 34/100
# 3847/3847 [==============================] - 1204s 313ms/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00034: val_loss did not improve from 0.00214
# Epoch 35/100
# 3847/3847 [==============================] - 3s 797us/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00035: val_loss did not improve from 0.00214
# Epoch 36/100
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0023 - val_loss: 0.0041
#
# Epoch 00036: val_loss did not improve from 0.00214
# Epoch 37/100
# 3847/3847 [==============================] - 3s 706us/step - loss: 0.0025 - val_loss: 0.0040
#
# Epoch 00037: val_loss did not improve from 0.00214
# Epoch 38/100
# 3847/3847 [==============================] - 3s 689us/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00038: val_loss did not improve from 0.00214
# Epoch 39/100
# 3847/3847 [==============================] - 3s 687us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00039: val_loss did not improve from 0.00214
# Epoch 40/100
# 3847/3847 [==============================] - 2s 602us/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00040: val_loss did not improve from 0.00214
# Epoch 41/100
# 3847/3847 [==============================] - 2s 535us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00041: val_loss did not improve from 0.00214
# Epoch 42/100
# 3847/3847 [==============================] - 2s 528us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00042: val_loss did not improve from 0.00214
# Epoch 43/100
# 3847/3847 [==============================] - 2s 607us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00043: val_loss did not improve from 0.00214
# Epoch 44/100
# 3847/3847 [==============================] - 2s 598us/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00044: val_loss did not improve from 0.00214
# Epoch 45/100
# 3847/3847 [==============================] - 2s 518us/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00045: val_loss did not improve from 0.00214
# Epoch 46/100
# 3847/3847 [==============================] - 2s 530us/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00046: val_loss did not improve from 0.00214
# Epoch 47/100
# 3847/3847 [==============================] - 2s 584us/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00047: val_loss did not improve from 0.00214
# Epoch 48/100
# 3847/3847 [==============================] - 2s 615us/step - loss: 0.0023 - val_loss: 0.0045
#
# Epoch 00048: val_loss did not improve from 0.00214
# Epoch 49/100
# 3847/3847 [==============================] - 2s 611us/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00049: val_loss did not improve from 0.00214
# Epoch 50/100
# 3847/3847 [==============================] - 2s 572us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00050: val_loss did not improve from 0.00214
# Epoch 51/100
# 3847/3847 [==============================] - 2s 501us/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00051: val_loss did not improve from 0.00214
# Epoch 52/100
# 3847/3847 [==============================] - 2s 515us/step - loss: 0.0022 - val_loss: 0.0039
#
# Epoch 00052: val_loss did not improve from 0.00214
# Epoch 53/100
# 3847/3847 [==============================] - 2s 513us/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00053: val_loss did not improve from 0.00214
# Epoch 54/100
# 3847/3847 [==============================] - 2s 506us/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00054: val_loss did not improve from 0.00214
# Epoch 55/100
# 3847/3847 [==============================] - 2s 500us/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00055: val_loss did not improve from 0.00214
# Epoch 56/100
# 3847/3847 [==============================] - 2s 537us/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00056: val_loss did not improve from 0.00214
# Epoch 57/100
# 3847/3847 [==============================] - 2s 590us/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00057: val_loss did not improve from 0.00214
# Epoch 58/100
# 3847/3847 [==============================] - 2s 577us/step - loss: 0.0021 - val_loss: 0.0031
#
# Epoch 00058: val_loss did not improve from 0.00214
# Epoch 59/100
# 3847/3847 [==============================] - 2s 641us/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00059: val_loss did not improve from 0.00214
# Epoch 60/100
# 3847/3847 [==============================] - 3s 707us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00060: val_loss did not improve from 0.00214
# Epoch 61/100
# 3847/3847 [==============================] - 2s 644us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00061: val_loss did not improve from 0.00214
# Epoch 62/100
# 3847/3847 [==============================] - 2s 529us/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00062: val_loss did not improve from 0.00214
# Epoch 63/100
# 3847/3847 [==============================] - 2s 523us/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00063: val_loss did not improve from 0.00214
# Epoch 64/100
# 3847/3847 [==============================] - 2s 525us/step - loss: 0.0021 - val_loss: 0.0042
#
# Epoch 00064: val_loss did not improve from 0.00214
# Epoch 65/100
# 3847/3847 [==============================] - 2s 553us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00065: val_loss did not improve from 0.00214
# Epoch 66/100
# 3847/3847 [==============================] - 2s 524us/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00066: val_loss did not improve from 0.00214
# Epoch 67/100
# 3847/3847 [==============================] - 2s 543us/step - loss: 0.0021 - val_loss: 0.0034
#
# Epoch 00067: val_loss did not improve from 0.00214
# Epoch 68/100
# 3847/3847 [==============================] - 3s 744us/step - loss: 0.0020 - val_loss: 0.0027
#
# Epoch 00068: val_loss did not improve from 0.00214
# Epoch 69/100
# 3847/3847 [==============================] - 3s 751us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00069: val_loss did not improve from 0.00214
# Epoch 70/100
# 3847/3847 [==============================] - 2s 563us/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00070: val_loss did not improve from 0.00214
# Epoch 71/100
# 3847/3847 [==============================] - 2s 541us/step - loss: 0.0019 - val_loss: 0.0024
#
# Epoch 00071: val_loss did not improve from 0.00214
# Epoch 72/100
# 3847/3847 [==============================] - 2s 541us/step - loss: 0.0020 - val_loss: 0.0032
#
# Epoch 00072: val_loss did not improve from 0.00214
# Epoch 73/100
# 3847/3847 [==============================] - 3s 691us/step - loss: 0.0019 - val_loss: 0.0030
#
# Epoch 00073: val_loss did not improve from 0.00214
# Epoch 74/100
# 3847/3847 [==============================] - 3s 714us/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00074: val_loss did not improve from 0.00214
# Epoch 75/100
# 3847/3847 [==============================] - 3s 748us/step - loss: 0.0018 - val_loss: 0.0025
#
# Epoch 00075: val_loss did not improve from 0.00214
# Epoch 76/100
# 3847/3847 [==============================] - 3s 724us/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00076: val_loss did not improve from 0.00214
# Epoch 77/100
# 3847/3847 [==============================] - 2s 633us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00077: val_loss did not improve from 0.00214
# Epoch 78/100
# 3847/3847 [==============================] - 3s 713us/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00078: val_loss did not improve from 0.00214
# Epoch 79/100
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0018 - val_loss: 0.0047
#
# Epoch 00079: val_loss did not improve from 0.00214
# Epoch 80/100
# 3847/3847 [==============================] - 3s 737us/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00080: val_loss did not improve from 0.00214
# Epoch 81/100
# 3847/3847 [==============================] - 3s 708us/step - loss: 0.0018 - val_loss: 0.0030
#
# Epoch 00081: val_loss did not improve from 0.00214
# Epoch 82/100
# 3847/3847 [==============================] - 3s 673us/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00082: val_loss did not improve from 0.00214
# Epoch 83/100
# 3847/3847 [==============================] - 3s 669us/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00083: val_loss did not improve from 0.00214
# Epoch 84/100
# 3847/3847 [==============================] - 3s 662us/step - loss: 0.0017 - val_loss: 0.0024
#
# Epoch 00084: val_loss did not improve from 0.00214
# Epoch 85/100
# 3847/3847 [==============================] - 3s 655us/step - loss: 0.0016 - val_loss: 0.0031
#
# Epoch 00085: val_loss did not improve from 0.00214
# Epoch 86/100
# 3847/3847 [==============================] - 3s 665us/step - loss: 0.0016 - val_loss: 0.0025
#
# Epoch 00086: val_loss did not improve from 0.00214
# Epoch 87/100
# 3847/3847 [==============================] - 2s 633us/step - loss: 0.0016 - val_loss: 0.0026
#
# Epoch 00087: val_loss did not improve from 0.00214
# Epoch 88/100
# 3847/3847 [==============================] - 3s 674us/step - loss: 0.0016 - val_loss: 0.0030
#
# Epoch 00088: val_loss did not improve from 0.00214
# Epoch 89/100
# 3847/3847 [==============================] - 2s 649us/step - loss: 0.0016 - val_loss: 0.0034
#
# Epoch 00089: val_loss did not improve from 0.00214
# Epoch 90/100
# 3847/3847 [==============================] - 2s 616us/step - loss: 0.0016 - val_loss: 0.0027
#
# Epoch 00090: val_loss did not improve from 0.00214
# Epoch 91/100
# 3847/3847 [==============================] - 3s 695us/step - loss: 0.0015 - val_loss: 0.0025
#
# Epoch 00091: val_loss did not improve from 0.00214
# Epoch 92/100
# 3847/3847 [==============================] - 3s 669us/step - loss: 0.0015 - val_loss: 0.0025
#
# Epoch 00092: val_loss did not improve from 0.00214
# Epoch 93/100
# 3847/3847 [==============================] - 2s 580us/step - loss: 0.0015 - val_loss: 0.0028
#
# Epoch 00093: val_loss did not improve from 0.00214
# Epoch 94/100
# 3847/3847 [==============================] - 3s 676us/step - loss: 0.0014 - val_loss: 0.0023
#
# Epoch 00094: val_loss did not improve from 0.00214
# Epoch 95/100
# 3847/3847 [==============================] - 3s 666us/step - loss: 0.0015 - val_loss: 0.0025
#
# Epoch 00095: val_loss did not improve from 0.00214
# Epoch 96/100
# 3847/3847 [==============================] - 2s 639us/step - loss: 0.0014 - val_loss: 0.0027
#
# Epoch 00096: val_loss did not improve from 0.00214
# Epoch 00096: early stopping
# Model loaded
# mae :  3993.5527075829445
# mse :  30854631.665799476
# rmse :  5554.694560981681
# std : 4903.256372464701

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 8s 2ms/step - loss: 0.0076 - val_loss: 0.0065
#
# Epoch 00001: val_loss improved from inf to 0.00650, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 853us/step - loss: 0.0041 - val_loss: 0.0049
#
# Epoch 00002: val_loss improved from 0.00650 to 0.00493, saving model to bestmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 3s 864us/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00003: val_loss improved from 0.00493 to 0.00389, saving model to bestmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00004: val_loss did not improve from 0.00389
# Epoch 5/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00005: val_loss improved from 0.00389 to 0.00295, saving model to bestmodel.h5
# Epoch 6/70
# 3847/3847 [==============================] - 3s 862us/step - loss: 0.0034 - val_loss: 0.0040
#
# Epoch 00006: val_loss did not improve from 0.00295
# Epoch 7/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0035 - val_loss: 0.0023
#
# Epoch 00007: val_loss improved from 0.00295 to 0.00232, saving model to bestmodel.h5
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0026
#
# Epoch 00008: val_loss did not improve from 0.00232
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0023
#
# Epoch 00009: val_loss did not improve from 0.00232
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0027
#
# Epoch 00010: val_loss did not improve from 0.00232
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0047
#
# Epoch 00011: val_loss did not improve from 0.00232
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00012: val_loss did not improve from 0.00232
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00013: val_loss did not improve from 0.00232
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0031
#
# Epoch 00014: val_loss did not improve from 0.00232
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0038
#
# Epoch 00015: val_loss did not improve from 0.00232
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0026
#
# Epoch 00016: val_loss did not improve from 0.00232
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00017: val_loss did not improve from 0.00232
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0033
#
# Epoch 00018: val_loss did not improve from 0.00232
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00019: val_loss did not improve from 0.00232
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00020: val_loss did not improve from 0.00232
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00021: val_loss did not improve from 0.00232
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00022: val_loss did not improve from 0.00232
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00023: val_loss did not improve from 0.00232
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00024: val_loss did not improve from 0.00232
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0022
#
# Epoch 00025: val_loss improved from 0.00232 to 0.00217, saving model to bestmodel.h5
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0051
#
# Epoch 00026: val_loss did not improve from 0.00217
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00027: val_loss did not improve from 0.00217
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00028: val_loss did not improve from 0.00217
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00029: val_loss did not improve from 0.00217
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00030: val_loss did not improve from 0.00217
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0023
#
# Epoch 00031: val_loss did not improve from 0.00217
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00032: val_loss did not improve from 0.00217
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0022
#
# Epoch 00033: val_loss improved from 0.00217 to 0.00216, saving model to bestmodel.h5
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00034: val_loss did not improve from 0.00216
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00035: val_loss did not improve from 0.00216
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0035
#
# Epoch 00036: val_loss did not improve from 0.00216
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00037: val_loss did not improve from 0.00216
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00038: val_loss did not improve from 0.00216
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00039: val_loss did not improve from 0.00216
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00040: val_loss did not improve from 0.00216
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00041: val_loss did not improve from 0.00216
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00042: val_loss did not improve from 0.00216
# Epoch 43/70
# 3847/3847 [==============================] - 4s 998us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00043: val_loss did not improve from 0.00216
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00044: val_loss did not improve from 0.00216
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00045: val_loss did not improve from 0.00216
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0035
#
# Epoch 00046: val_loss did not improve from 0.00216
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00047: val_loss did not improve from 0.00216
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00048: val_loss did not improve from 0.00216
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00049: val_loss did not improve from 0.00216
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00050: val_loss did not improve from 0.00216
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00051: val_loss did not improve from 0.00216
# Epoch 52/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00052: val_loss did not improve from 0.00216
# Epoch 53/70
# 3847/3847 [==============================] - 4s 977us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00053: val_loss did not improve from 0.00216
# Epoch 54/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0021 - val_loss: 0.0026
#
# Epoch 00054: val_loss did not improve from 0.00216
# Epoch 55/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0021 - val_loss: 0.0024
#
# Epoch 00055: val_loss did not improve from 0.00216
# Epoch 56/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00056: val_loss did not improve from 0.00216
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0020 - val_loss: 0.0027
#
# Epoch 00057: val_loss did not improve from 0.00216
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00058: val_loss did not improve from 0.00216
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00059: val_loss did not improve from 0.00216
# Epoch 60/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0020 - val_loss: 0.0020
#
# Epoch 00060: val_loss improved from 0.00216 to 0.00196, saving model to bestmodel.h5
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0024
#
# Epoch 00061: val_loss did not improve from 0.00196
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00062: val_loss did not improve from 0.00196
# Epoch 63/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00063: val_loss did not improve from 0.00196
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00064: val_loss did not improve from 0.00196
# Epoch 65/70
# 3847/3847 [==============================] - 4s 997us/step - loss: 0.0019 - val_loss: 0.0029
#
# Epoch 00065: val_loss did not improve from 0.00196
# Epoch 66/70
# 3847/3847 [==============================] - 4s 994us/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00066: val_loss did not improve from 0.00196
# Epoch 67/70
# 3847/3847 [==============================] - 4s 988us/step - loss: 0.0020 - val_loss: 0.0039
#
# Epoch 00067: val_loss did not improve from 0.00196
# Epoch 68/70
# 3847/3847 [==============================] - 4s 976us/step - loss: 0.0019 - val_loss: 0.0029
#
# Epoch 00068: val_loss did not improve from 0.00196
# Epoch 69/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00069: val_loss did not improve from 0.00196
# Epoch 70/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0019 - val_loss: 0.0021
#
# Epoch 00070: val_loss did not improve from 0.00196
# Model loaded
# mae :  3218.9246712028207
# mse :  24325335.99896341
# rmse :  4932.07218103744
# std : 4871.095727906356

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 10s 3ms/step - loss: 0.0076 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00243, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 870us/step - loss: 0.0040 - val_loss: 0.0027
#
# Epoch 00002: val_loss did not improve from 0.00243
# Epoch 3/70
# 3847/3847 [==============================] - 3s 871us/step - loss: 0.0035 - val_loss: 0.0045
#
# Epoch 00003: val_loss did not improve from 0.00243
# Epoch 4/70
# 3847/3847 [==============================] - 3s 861us/step - loss: 0.0036 - val_loss: 0.0024
#
# Epoch 00004: val_loss improved from 0.00243 to 0.00238, saving model to bestmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 3s 863us/step - loss: 0.0034 - val_loss: 0.0039
#
# Epoch 00005: val_loss did not improve from 0.00238
# Epoch 6/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0032 - val_loss: 0.0039
#
# Epoch 00006: val_loss did not improve from 0.00238
# Epoch 7/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0039
#
# Epoch 00007: val_loss did not improve from 0.00238
# Epoch 8/70
# 3847/3847 [==============================] - 3s 859us/step - loss: 0.0031 - val_loss: 0.0023
#
# Epoch 00008: val_loss improved from 0.00238 to 0.00228, saving model to bestmodel.h5
# Epoch 9/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0033
#
# Epoch 00009: val_loss did not improve from 0.00228
# Epoch 10/70
# 3847/3847 [==============================] - 4s 930us/step - loss: 0.0031 - val_loss: 0.0047
#
# Epoch 00010: val_loss did not improve from 0.00228
# Epoch 11/70
# 3847/3847 [==============================] - 4s 998us/step - loss: 0.0030 - val_loss: 0.0028
#
# Epoch 00011: val_loss did not improve from 0.00228
# Epoch 12/70
# 3847/3847 [==============================] - 4s 993us/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00012: val_loss did not improve from 0.00228
# Epoch 13/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0029 - val_loss: 0.0043
#
# Epoch 00013: val_loss did not improve from 0.00228
# Epoch 14/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0028 - val_loss: 0.0041
#
# Epoch 00014: val_loss did not improve from 0.00228
# Epoch 15/70
# 3847/3847 [==============================] - 4s 982us/step - loss: 0.0030 - val_loss: 0.0024
#
# Epoch 00015: val_loss did not improve from 0.00228
# Epoch 16/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0029 - val_loss: 0.0044
#
# Epoch 00016: val_loss did not improve from 0.00228
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0025
#
# Epoch 00017: val_loss did not improve from 0.00228
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00018: val_loss did not improve from 0.00228
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0030
#
# Epoch 00019: val_loss did not improve from 0.00228
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00020: val_loss did not improve from 0.00228
# Epoch 21/70
# 3847/3847 [==============================] - 4s 991us/step - loss: 0.0027 - val_loss: 0.0040
#
# Epoch 00021: val_loss did not improve from 0.00228
# Epoch 22/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00022: val_loss did not improve from 0.00228
# Epoch 23/70
# 3847/3847 [==============================] - 4s 983us/step - loss: 0.0025 - val_loss: 0.0036
#
# Epoch 00023: val_loss did not improve from 0.00228
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1000us/step - loss: 0.0026 - val_loss: 0.0021
#
# Epoch 00024: val_loss improved from 0.00228 to 0.00208, saving model to bestmodel.h5
# Epoch 25/70
# 3847/3847 [==============================] - 4s 976us/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00025: val_loss did not improve from 0.00208
# Epoch 26/70
# 3847/3847 [==============================] - 4s 978us/step - loss: 0.0027 - val_loss: 0.0025
#
# Epoch 00026: val_loss did not improve from 0.00208
# Epoch 27/70
# 3847/3847 [==============================] - 4s 981us/step - loss: 0.0025 - val_loss: 0.0024
#
# Epoch 00027: val_loss did not improve from 0.00208
# Epoch 28/70
# 3847/3847 [==============================] - 4s 981us/step - loss: 0.0025 - val_loss: 0.0024
#
# Epoch 00028: val_loss did not improve from 0.00208
# Epoch 29/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00029: val_loss did not improve from 0.00208
# Epoch 30/70
# 3847/3847 [==============================] - 4s 975us/step - loss: 0.0024 - val_loss: 0.0022
#
# Epoch 00030: val_loss did not improve from 0.00208
# Epoch 31/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00031: val_loss did not improve from 0.00208
# Epoch 32/70
# 3847/3847 [==============================] - 4s 993us/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00032: val_loss did not improve from 0.00208
# Epoch 33/70
# 3847/3847 [==============================] - 4s 998us/step - loss: 0.0025 - val_loss: 0.0022
#
# Epoch 00033: val_loss did not improve from 0.00208
# Epoch 34/70
# 3847/3847 [==============================] - 4s 984us/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00034: val_loss improved from 0.00208 to 0.00205, saving model to bestmodel.h5
# Epoch 35/70
# 3847/3847 [==============================] - 4s 993us/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00035: val_loss did not improve from 0.00205
# Epoch 36/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00036: val_loss did not improve from 0.00205
# Epoch 37/70
# 3847/3847 [==============================] - 4s 988us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00037: val_loss did not improve from 0.00205
# Epoch 38/70
# 3847/3847 [==============================] - 4s 988us/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00038: val_loss did not improve from 0.00205
# Epoch 39/70
# 3847/3847 [==============================] - 4s 993us/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00039: val_loss did not improve from 0.00205
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0029
#
# Epoch 00040: val_loss did not improve from 0.00205
# Epoch 41/70
# 3847/3847 [==============================] - 4s 984us/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00041: val_loss did not improve from 0.00205
# Epoch 42/70
# 3847/3847 [==============================] - 4s 989us/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00042: val_loss did not improve from 0.00205
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00043: val_loss did not improve from 0.00205
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0022
#
# Epoch 00044: val_loss did not improve from 0.00205
# Epoch 45/70
# 3847/3847 [==============================] - 4s 998us/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00045: val_loss did not improve from 0.00205
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00046: val_loss did not improve from 0.00205
# Epoch 47/70
# 3847/3847 [==============================] - 4s 984us/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00047: val_loss did not improve from 0.00205
# Epoch 48/70
# 3847/3847 [==============================] - 4s 981us/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00048: val_loss did not improve from 0.00205
# Epoch 49/70
# 3847/3847 [==============================] - 4s 987us/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00049: val_loss did not improve from 0.00205
# Epoch 50/70
# 3847/3847 [==============================] - 4s 985us/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00050: val_loss did not improve from 0.00205
# Epoch 51/70
# 3847/3847 [==============================] - 4s 985us/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00205
# Epoch 52/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00052: val_loss did not improve from 0.00205
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0024
#
# Epoch 00053: val_loss did not improve from 0.00205
# Epoch 54/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0020 - val_loss: 0.0036
#
# Epoch 00054: val_loss did not improve from 0.00205
# Epoch 55/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00055: val_loss did not improve from 0.00205
# Epoch 56/70
# 3847/3847 [==============================] - 4s 988us/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00056: val_loss did not improve from 0.00205
# Epoch 57/70
# 3847/3847 [==============================] - 4s 987us/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00057: val_loss did not improve from 0.00205
# Epoch 58/70
# 3847/3847 [==============================] - 4s 990us/step - loss: 0.0020 - val_loss: 0.0021
#
# Epoch 00058: val_loss did not improve from 0.00205
# Epoch 59/70
# 3847/3847 [==============================] - 4s 986us/step - loss: 0.0020 - val_loss: 0.0027
#
# Epoch 00059: val_loss did not improve from 0.00205
# Epoch 60/70
# 3847/3847 [==============================] - 4s 994us/step - loss: 0.0019 - val_loss: 0.0024
#
# Epoch 00060: val_loss did not improve from 0.00205
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00061: val_loss did not improve from 0.00205
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0019 - val_loss: 0.0047
#
# Epoch 00062: val_loss did not improve from 0.00205
# Epoch 63/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0019 - val_loss: 0.0029
#
# Epoch 00063: val_loss did not improve from 0.00205
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0019 - val_loss: 0.0032
#
# Epoch 00064: val_loss did not improve from 0.00205
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0018 - val_loss: 0.0044
#
# Epoch 00065: val_loss did not improve from 0.00205
# Epoch 66/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0018 - val_loss: 0.0024
#
# Epoch 00066: val_loss did not improve from 0.00205
# Epoch 67/70
# 3847/3847 [==============================] - 4s 995us/step - loss: 0.0017 - val_loss: 0.0024
#
# Epoch 00067: val_loss did not improve from 0.00205
# Epoch 68/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00068: val_loss did not improve from 0.00205
# Epoch 69/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0017 - val_loss: 0.0029
#
# Epoch 00069: val_loss did not improve from 0.00205
# Epoch 70/70
# 3847/3847 [==============================] - 4s 992us/step - loss: 0.0017 - val_loss: 0.0033
#
# Epoch 00070: val_loss did not improve from 0.00205
# Model loaded
# mae :  3030.8553542892655
# mse :  23866712.38018317
# rmse :  4885.356934777967
# std : 4857.975349162293

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 13s 3ms/step - loss: 0.0093 - val_loss: 0.0043
#
# Epoch 00001: val_loss improved from inf to 0.00427, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 3s 908us/step - loss: 0.0044 - val_loss: 0.0062
#
# Epoch 00002: val_loss did not improve from 0.00427
# Epoch 3/70
# 3847/3847 [==============================] - 4s 954us/step - loss: 0.0039 - val_loss: 0.0045
#
# Epoch 00003: val_loss did not improve from 0.00427
# Epoch 4/70
# 3847/3847 [==============================] - 4s 925us/step - loss: 0.0040 - val_loss: 0.0035
#
# Epoch 00004: val_loss improved from 0.00427 to 0.00353, saving model to bestmodel.h5
# Epoch 5/70
# 3847/3847 [==============================] - 4s 934us/step - loss: 0.0037 - val_loss: 0.0025
#
# Epoch 00005: val_loss improved from 0.00353 to 0.00251, saving model to bestmodel.h5
# Epoch 6/70
# 3847/3847 [==============================] - 4s 923us/step - loss: 0.0033 - val_loss: 0.0054
#
# Epoch 00006: val_loss did not improve from 0.00251
# Epoch 7/70
# 3847/3847 [==============================] - 4s 941us/step - loss: 0.0033 - val_loss: 0.0042
#
# Epoch 00007: val_loss did not improve from 0.00251
# Epoch 8/70
# 3847/3847 [==============================] - 4s 948us/step - loss: 0.0032 - val_loss: 0.0049
#
# Epoch 00008: val_loss did not improve from 0.00251
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0035
#
# Epoch 00009: val_loss did not improve from 0.00251
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0037
#
# Epoch 00010: val_loss did not improve from 0.00251
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00011: val_loss did not improve from 0.00251
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0022
#
# Epoch 00012: val_loss improved from 0.00251 to 0.00217, saving model to bestmodel.h5
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0042
#
# Epoch 00013: val_loss did not improve from 0.00217
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0049
#
# Epoch 00014: val_loss did not improve from 0.00217
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0049
#
# Epoch 00015: val_loss did not improve from 0.00217
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0020
#
# Epoch 00016: val_loss improved from 0.00217 to 0.00202, saving model to bestmodel.h5
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00017: val_loss did not improve from 0.00202
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0032
#
# Epoch 00018: val_loss did not improve from 0.00202
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0041
#
# Epoch 00019: val_loss did not improve from 0.00202
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00202
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0038
#
# Epoch 00021: val_loss did not improve from 0.00202
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0025
#
# Epoch 00022: val_loss did not improve from 0.00202
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0040
#
# Epoch 00023: val_loss did not improve from 0.00202
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00024: val_loss did not improve from 0.00202
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00025: val_loss did not improve from 0.00202
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00026: val_loss did not improve from 0.00202
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00027: val_loss did not improve from 0.00202
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00028: val_loss did not improve from 0.00202
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0028
#
# Epoch 00029: val_loss did not improve from 0.00202
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0042
#
# Epoch 00030: val_loss did not improve from 0.00202
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00031: val_loss did not improve from 0.00202
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00032: val_loss did not improve from 0.00202
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00033: val_loss did not improve from 0.00202
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00034: val_loss did not improve from 0.00202
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00035: val_loss did not improve from 0.00202
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00036: val_loss did not improve from 0.00202
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0033
#
# Epoch 00037: val_loss did not improve from 0.00202
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00038: val_loss did not improve from 0.00202
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00039: val_loss did not improve from 0.00202
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00040: val_loss did not improve from 0.00202
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0022
#
# Epoch 00041: val_loss did not improve from 0.00202
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00042: val_loss did not improve from 0.00202
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00043: val_loss did not improve from 0.00202
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00044: val_loss did not improve from 0.00202
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00045: val_loss did not improve from 0.00202
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0033
#
# Epoch 00046: val_loss did not improve from 0.00202
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00047: val_loss did not improve from 0.00202
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00048: val_loss did not improve from 0.00202
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00049: val_loss did not improve from 0.00202
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00050: val_loss did not improve from 0.00202
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00051: val_loss did not improve from 0.00202
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00052: val_loss did not improve from 0.00202
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00053: val_loss did not improve from 0.00202
# Epoch 54/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00054: val_loss did not improve from 0.00202
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00055: val_loss did not improve from 0.00202
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00056: val_loss did not improve from 0.00202
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00057: val_loss did not improve from 0.00202
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0040
#
# Epoch 00058: val_loss did not improve from 0.00202
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0032
#
# Epoch 00059: val_loss did not improve from 0.00202
# Epoch 60/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0038
#
# Epoch 00060: val_loss did not improve from 0.00202
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00061: val_loss did not improve from 0.00202
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00062: val_loss did not improve from 0.00202
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0034
#
# Epoch 00063: val_loss did not improve from 0.00202
# Epoch 64/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0031
#
# Epoch 00064: val_loss did not improve from 0.00202
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00065: val_loss did not improve from 0.00202
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00066: val_loss did not improve from 0.00202
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0024
#
# Epoch 00067: val_loss did not improve from 0.00202
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00068: val_loss did not improve from 0.00202
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00069: val_loss did not improve from 0.00202
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0034
#
# Epoch 00070: val_loss did not improve from 0.00202
# Model loaded
# mae :  3861.855970665077
# mse :  30574275.054484285
# rmse :  5529.400967056403
# std : 4920.0520989629895

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 19s 5ms/step - loss: 0.0090 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00208, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 999us/step - loss: 0.0039 - val_loss: 0.0027
#
# Epoch 00002: val_loss did not improve from 0.00208
# Epoch 3/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0036 - val_loss: 0.0039
#
# Epoch 00003: val_loss did not improve from 0.00208
# Epoch 4/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0035 - val_loss: 0.0034
#
# Epoch 00004: val_loss did not improve from 0.00208
# Epoch 5/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0035 - val_loss: 0.0026
#
# Epoch 00005: val_loss did not improve from 0.00208
# Epoch 6/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0034 - val_loss: 0.0060
#
# Epoch 00006: val_loss did not improve from 0.00208
# Epoch 7/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00208
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00008: val_loss did not improve from 0.00208
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00009: val_loss did not improve from 0.00208
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0026
#
# Epoch 00010: val_loss did not improve from 0.00208
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0045
#
# Epoch 00011: val_loss did not improve from 0.00208
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0022
#
# Epoch 00012: val_loss did not improve from 0.00208
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0035
#
# Epoch 00013: val_loss did not improve from 0.00208
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0028
#
# Epoch 00014: val_loss did not improve from 0.00208
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0033
#
# Epoch 00015: val_loss did not improve from 0.00208
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0030
#
# Epoch 00016: val_loss did not improve from 0.00208
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00017: val_loss did not improve from 0.00208
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00018: val_loss did not improve from 0.00208
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0029
#
# Epoch 00019: val_loss did not improve from 0.00208
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00208
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00021: val_loss did not improve from 0.00208
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00022: val_loss did not improve from 0.00208
# Epoch 23/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0023
#
# Epoch 00023: val_loss did not improve from 0.00208
# Epoch 24/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00024: val_loss did not improve from 0.00208
# Epoch 25/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00025: val_loss did not improve from 0.00208
# Epoch 26/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0057
#
# Epoch 00026: val_loss did not improve from 0.00208
# Epoch 27/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00027: val_loss did not improve from 0.00208
# Epoch 28/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00028: val_loss did not improve from 0.00208
# Epoch 29/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00029: val_loss did not improve from 0.00208
# Epoch 30/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0034
#
# Epoch 00030: val_loss did not improve from 0.00208
# Epoch 31/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00031: val_loss did not improve from 0.00208
# Epoch 32/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00032: val_loss did not improve from 0.00208
# Epoch 33/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00033: val_loss did not improve from 0.00208
# Epoch 34/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00034: val_loss did not improve from 0.00208
# Epoch 35/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00035: val_loss did not improve from 0.00208
# Epoch 36/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0036
#
# Epoch 00036: val_loss did not improve from 0.00208
# Epoch 37/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0039
#
# Epoch 00037: val_loss did not improve from 0.00208
# Epoch 38/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00038: val_loss did not improve from 0.00208
# Epoch 39/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0045
#
# Epoch 00039: val_loss did not improve from 0.00208
# Epoch 40/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00040: val_loss did not improve from 0.00208
# Epoch 41/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00041: val_loss did not improve from 0.00208
# Epoch 42/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00042: val_loss did not improve from 0.00208
# Epoch 43/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00043: val_loss did not improve from 0.00208
# Epoch 44/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00044: val_loss did not improve from 0.00208
# Epoch 45/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00045: val_loss did not improve from 0.00208
# Epoch 46/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00046: val_loss did not improve from 0.00208
# Epoch 47/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00047: val_loss did not improve from 0.00208
# Epoch 48/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00048: val_loss did not improve from 0.00208
# Epoch 49/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0032 - ETA: 0s - l
#
# Epoch 00049: val_loss did not improve from 0.00208
# Epoch 50/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0031
#
# Epoch 00050: val_loss did not improve from 0.00208
# Epoch 51/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00051: val_loss did not improve from 0.00208
# Epoch 52/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0035
#
# Epoch 00052: val_loss did not improve from 0.00208
# Epoch 53/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00053: val_loss did not improve from 0.00208
# Epoch 54/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00054: val_loss did not improve from 0.00208
# Epoch 55/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00055: val_loss did not improve from 0.00208
# Epoch 56/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00056: val_loss did not improve from 0.00208
# Epoch 57/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00057: val_loss did not improve from 0.00208
# Epoch 58/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00058: val_loss did not improve from 0.00208
# Epoch 59/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0033
#
# Epoch 00059: val_loss did not improve from 0.00208
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00060: val_loss did not improve from 0.00208
# Epoch 61/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00061: val_loss did not improve from 0.00208
# Epoch 62/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00062: val_loss did not improve from 0.00208
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0034
#
# Epoch 00063: val_loss did not improve from 0.00208
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00064: val_loss did not improve from 0.00208
# Epoch 65/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00065: val_loss did not improve from 0.00208
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0026
#
# Epoch 00066: val_loss did not improve from 0.00208
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0025
#
# Epoch 00067: val_loss did not improve from 0.00208
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00068: val_loss did not improve from 0.00208
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0018 - val_loss: 0.0028
#
# Epoch 00069: val_loss did not improve from 0.00208
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0018 - val_loss: 0.0027
#
# Epoch 00070: val_loss did not improve from 0.00208
# Model loaded
# mae :  3550.9463359882307
# mse :  27648183.208166983
# rmse :  5258.15397341757
# std : 4866.553929496123

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 20s 5ms/step - loss: 0.0091 - val_loss: 0.0056
#
# Epoch 00001: val_loss improved from inf to 0.00555, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0047 - val_loss: 0.0042
#
# Epoch 00002: val_loss improved from 0.00555 to 0.00420, saving model to bestmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0039 - val_loss: 0.0027
#
# Epoch 00003: val_loss improved from 0.00420 to 0.00275, saving model to bestmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0038 - val_loss: 0.0036
#
# Epoch 00004: val_loss did not improve from 0.00275
# Epoch 5/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0036 - val_loss: 0.0026
#
# Epoch 00005: val_loss improved from 0.00275 to 0.00261, saving model to bestmodel.h5
# Epoch 6/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0035 - val_loss: 0.0029
#
# Epoch 00006: val_loss did not improve from 0.00261
# Epoch 7/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0035 - val_loss: 0.0029
#
# Epoch 00007: val_loss did not improve from 0.00261
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00008: val_loss did not improve from 0.00261
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0042
#
# Epoch 00009: val_loss did not improve from 0.00261
# Epoch 10/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0024
#
# Epoch 00010: val_loss improved from 0.00261 to 0.00235, saving model to bestmodel.h5
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00011: val_loss did not improve from 0.00235
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00012: val_loss did not improve from 0.00235
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00013: val_loss did not improve from 0.00235
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00014: val_loss did not improve from 0.00235
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0025
#
# Epoch 00015: val_loss did not improve from 0.00235
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0018
#
# Epoch 00016: val_loss improved from 0.00235 to 0.00180, saving model to bestmodel.h5
# Epoch 17/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0025
#
# Epoch 00017: val_loss did not improve from 0.00180
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0052
#
# Epoch 00018: val_loss did not improve from 0.00180
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0022
#
# Epoch 00019: val_loss did not improve from 0.00180
# Epoch 20/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00020: val_loss did not improve from 0.00180
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0050
#
# Epoch 00021: val_loss did not improve from 0.00180
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0018
#
# Epoch 00022: val_loss did not improve from 0.00180
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0032
#
# Epoch 00023: val_loss did not improve from 0.00180
# Epoch 24/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0055
#
# Epoch 00024: val_loss did not improve from 0.00180
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0021
#
# Epoch 00025: val_loss did not improve from 0.00180
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00026: val_loss did not improve from 0.00180
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00027: val_loss did not improve from 0.00180
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00028: val_loss did not improve from 0.00180
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0050
#
# Epoch 00029: val_loss did not improve from 0.00180
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0040
#
# Epoch 00030: val_loss did not improve from 0.00180
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00031: val_loss did not improve from 0.00180
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00032: val_loss did not improve from 0.00180
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0042
#
# Epoch 00033: val_loss did not improve from 0.00180
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00034: val_loss did not improve from 0.00180
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0021
#
# Epoch 00035: val_loss did not improve from 0.00180
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0026
#
# Epoch 00036: val_loss did not improve from 0.00180
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0041
#
# Epoch 00037: val_loss did not improve from 0.00180
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00038: val_loss did not improve from 0.00180
# Epoch 39/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0047
#
# Epoch 00039: val_loss did not improve from 0.00180
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0023
#
# Epoch 00040: val_loss did not improve from 0.00180
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00041: val_loss did not improve from 0.00180
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0048
#
# Epoch 00042: val_loss did not improve from 0.00180
# Epoch 43/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0041
#
# Epoch 00043: val_loss did not improve from 0.00180
# Epoch 44/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0020
#
# Epoch 00044: val_loss did not improve from 0.00180
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0024
#
# Epoch 00045: val_loss did not improve from 0.00180
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00046: val_loss did not improve from 0.00180
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00047: val_loss did not improve from 0.00180
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00048: val_loss did not improve from 0.00180
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00049: val_loss did not improve from 0.00180
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00050: val_loss did not improve from 0.00180
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0053
#
# Epoch 00051: val_loss did not improve from 0.00180
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0038
#
# Epoch 00052: val_loss did not improve from 0.00180
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00053: val_loss did not improve from 0.00180
# Epoch 54/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00054: val_loss did not improve from 0.00180
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00055: val_loss did not improve from 0.00180
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0022
#
# Epoch 00056: val_loss did not improve from 0.00180
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0032
#
# Epoch 00057: val_loss did not improve from 0.00180
# Epoch 58/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00058: val_loss did not improve from 0.00180
# Epoch 59/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00059: val_loss did not improve from 0.00180
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00060: val_loss did not improve from 0.00180
# Epoch 61/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00061: val_loss did not improve from 0.00180
# Epoch 62/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00062: val_loss did not improve from 0.00180
# Epoch 63/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00063: val_loss did not improve from 0.00180
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00064: val_loss did not improve from 0.00180
# Epoch 65/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00065: val_loss did not improve from 0.00180
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0031
#
# Epoch 00066: val_loss did not improve from 0.00180
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00067: val_loss did not improve from 0.00180
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00068: val_loss did not improve from 0.00180
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00069: val_loss did not improve from 0.00180
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0023
#
# Epoch 00070: val_loss did not improve from 0.00180
# Model loaded
# mae :  2845.132231377936
# mse :  20183214.814292584
# rmse :  4492.573295372328
# std : 4477.35197663565

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 17s 4ms/step - loss: 0.0144 - val_loss: 0.0033
#
# Epoch 00001: val_loss improved from inf to 0.00326, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0041 - val_loss: 0.0036
#
# Epoch 00002: val_loss did not improve from 0.00326
# Epoch 3/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0040 - val_loss: 0.0028
#
# Epoch 00003: val_loss improved from 0.00326 to 0.00281, saving model to bestmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0037 - val_loss: 0.0031
#
# Epoch 00004: val_loss did not improve from 0.00281
# Epoch 5/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0035 - val_loss: 0.0043
#
# Epoch 00005: val_loss did not improve from 0.00281
# Epoch 6/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00006: val_loss did not improve from 0.00281
# Epoch 7/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00007: val_loss did not improve from 0.00281
# Epoch 8/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0033 - val_loss: 0.0040
#
# Epoch 00008: val_loss did not improve from 0.00281
# Epoch 9/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0034 - val_loss: 0.0036
#
# Epoch 00009: val_loss did not improve from 0.00281
# Epoch 10/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00010: val_loss did not improve from 0.00281
# Epoch 11/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0031 - val_loss: 0.0034
#
# Epoch 00011: val_loss did not improve from 0.00281
# Epoch 12/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0032 - val_loss: 0.0052
#
# Epoch 00012: val_loss did not improve from 0.00281
# Epoch 13/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0049
#
# Epoch 00013: val_loss did not improve from 0.00281
# Epoch 14/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0029
#
# Epoch 00014: val_loss did not improve from 0.00281
# Epoch 15/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0036
#
# Epoch 00015: val_loss did not improve from 0.00281
# Epoch 16/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0021
#
# Epoch 00016: val_loss improved from 0.00281 to 0.00213, saving model to bestmodel.h5
# Epoch 17/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0030
#
# Epoch 00017: val_loss did not improve from 0.00213
# Epoch 18/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0023
#
# Epoch 00018: val_loss did not improve from 0.00213
# Epoch 19/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0030 - val_loss: 0.0037
#
# Epoch 00019: val_loss did not improve from 0.00213
# Epoch 20/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00020: val_loss did not improve from 0.00213
# Epoch 21/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0034
#
# Epoch 00021: val_loss did not improve from 0.00213
# Epoch 22/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00022: val_loss did not improve from 0.00213
# Epoch 23/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0030
#
# Epoch 00023: val_loss did not improve from 0.00213
# Epoch 24/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0033
#
# Epoch 00024: val_loss did not improve from 0.00213
# Epoch 25/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00025: val_loss did not improve from 0.00213
# Epoch 26/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00026: val_loss did not improve from 0.00213
# Epoch 27/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0025
#
# Epoch 00027: val_loss did not improve from 0.00213
# Epoch 28/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0027 - val_loss: 0.0024
#
# Epoch 00028: val_loss did not improve from 0.00213
# Epoch 29/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00029: val_loss did not improve from 0.00213
# Epoch 30/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0046
#
# Epoch 00030: val_loss did not improve from 0.00213
# Epoch 31/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0039
#
# Epoch 00031: val_loss did not improve from 0.00213
# Epoch 32/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00032: val_loss did not improve from 0.00213
# Epoch 33/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00033: val_loss did not improve from 0.00213
# Epoch 34/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00034: val_loss did not improve from 0.00213
# Epoch 35/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00035: val_loss did not improve from 0.00213
# Epoch 36/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00036: val_loss did not improve from 0.00213
# Epoch 37/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0039
#
# Epoch 00037: val_loss did not improve from 0.00213
# Epoch 38/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0026 - val_loss: 0.0036
#
# Epoch 00038: val_loss did not improve from 0.00213
# Epoch 39/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0029
#
# Epoch 00039: val_loss did not improve from 0.00213
# Epoch 40/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00040: val_loss did not improve from 0.00213
# Epoch 41/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0033
#
# Epoch 00041: val_loss did not improve from 0.00213
# Epoch 42/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0042
#
# Epoch 00042: val_loss did not improve from 0.00213
# Epoch 43/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00043: val_loss did not improve from 0.00213
# Epoch 44/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0032
#
# Epoch 00044: val_loss did not improve from 0.00213
# Epoch 45/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00045: val_loss did not improve from 0.00213
# Epoch 46/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00046: val_loss did not improve from 0.00213
# Epoch 47/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00047: val_loss did not improve from 0.00213
# Epoch 48/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0018
#
# Epoch 00048: val_loss improved from 0.00213 to 0.00183, saving model to bestmodel.h5
# Epoch 49/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00049: val_loss did not improve from 0.00183
# Epoch 50/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00050: val_loss did not improve from 0.00183
# Epoch 51/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00183
# Epoch 52/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 00052: val_loss did not improve from 0.00183
# Epoch 53/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00053: val_loss did not improve from 0.00183
# Epoch 54/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00054: val_loss did not improve from 0.00183
# Epoch 55/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00055: val_loss did not improve from 0.00183
# Epoch 56/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0036
#
# Epoch 00056: val_loss did not improve from 0.00183
# Epoch 57/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00057: val_loss did not improve from 0.00183
# Epoch 58/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0020
#
# Epoch 00058: val_loss did not improve from 0.00183
# Epoch 59/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0026
#
# Epoch 00059: val_loss did not improve from 0.00183
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0022
#
# Epoch 00060: val_loss did not improve from 0.00183
# Epoch 61/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0026
#
# Epoch 00061: val_loss did not improve from 0.00183
# Epoch 62/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00062: val_loss did not improve from 0.00183
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00063: val_loss did not improve from 0.00183
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0026
#
# Epoch 00064: val_loss did not improve from 0.00183
# Epoch 65/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00065: val_loss did not improve from 0.00183
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00066: val_loss did not improve from 0.00183
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00067: val_loss did not improve from 0.00183
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00068: val_loss did not improve from 0.00183
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0035
#
# Epoch 00069: val_loss did not improve from 0.00183
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00070: val_loss did not improve from 0.00183
# Model loaded
# mae :  3311.701354376062
# mse :  23720992.98570416
# rmse :  4870.420206276268
# std : 4773.586791165586

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 23s 6ms/step - loss: 0.0102 - val_loss: 0.0044
#
# Epoch 00001: val_loss improved from inf to 0.00444, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0041 - val_loss: 0.0051
#
# Epoch 00002: val_loss did not improve from 0.00444
# Epoch 3/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00003: val_loss improved from 0.00444 to 0.00411, saving model to bestmodel.h5
# Epoch 4/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0035 - val_loss: 0.0052
#
# Epoch 00004: val_loss did not improve from 0.00411
# Epoch 5/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0037 - val_loss: 0.0042
#
# Epoch 00005: val_loss did not improve from 0.00411
# Epoch 6/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0033 - val_loss: 0.0034
#
# Epoch 00006: val_loss improved from 0.00411 to 0.00342, saving model to bestmodel.h5
# Epoch 7/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0031 - val_loss: 0.0024
#
# Epoch 00007: val_loss improved from 0.00342 to 0.00244, saving model to bestmodel.h5
# Epoch 8/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0046
#
# Epoch 00008: val_loss did not improve from 0.00244
# Epoch 9/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0041
#
# Epoch 00009: val_loss did not improve from 0.00244
# Epoch 10/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0025
#
# Epoch 00010: val_loss did not improve from 0.00244
# Epoch 11/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0026
#
# Epoch 00011: val_loss did not improve from 0.00244
# Epoch 12/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0035
#
# Epoch 00012: val_loss did not improve from 0.00244
# Epoch 13/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0034
#
# Epoch 00013: val_loss did not improve from 0.00244
# Epoch 14/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0028
#
# Epoch 00014: val_loss did not improve from 0.00244
# Epoch 15/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00015: val_loss did not improve from 0.00244
# Epoch 16/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0031
#
# Epoch 00016: val_loss did not improve from 0.00244
# Epoch 17/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0029
#
# Epoch 00017: val_loss did not improve from 0.00244
# Epoch 18/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0039
#
# Epoch 00018: val_loss did not improve from 0.00244
# Epoch 19/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0046
#
# Epoch 00019: val_loss did not improve from 0.00244
# Epoch 20/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00020: val_loss did not improve from 0.00244
# Epoch 21/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0044
#
# Epoch 00021: val_loss did not improve from 0.00244
# Epoch 22/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0026
#
# Epoch 00022: val_loss did not improve from 0.00244
# Epoch 23/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0022
#
# Epoch 00023: val_loss improved from 0.00244 to 0.00221, saving model to bestmodel.h5
# Epoch 24/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00024: val_loss did not improve from 0.00221
# Epoch 25/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00025: val_loss did not improve from 0.00221
# Epoch 26/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0020
#
# Epoch 00026: val_loss improved from 0.00221 to 0.00202, saving model to bestmodel.h5
# Epoch 27/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00027: val_loss did not improve from 0.00202
# Epoch 28/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0038
#
# Epoch 00028: val_loss did not improve from 0.00202
# Epoch 29/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00029: val_loss did not improve from 0.00202
# Epoch 30/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00030: val_loss did not improve from 0.00202
# Epoch 31/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00031: val_loss did not improve from 0.00202
# Epoch 32/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00032: val_loss did not improve from 0.00202
# Epoch 33/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00033: val_loss did not improve from 0.00202
# Epoch 34/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0023
#
# Epoch 00034: val_loss did not improve from 0.00202
# Epoch 35/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00035: val_loss did not improve from 0.00202
# Epoch 36/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0031
#
# Epoch 00036: val_loss did not improve from 0.00202
# Epoch 37/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00037: val_loss did not improve from 0.00202
# Epoch 38/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0025
#
# Epoch 00038: val_loss did not improve from 0.00202
# Epoch 39/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00039: val_loss did not improve from 0.00202
# Epoch 40/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0022
#
# Epoch 00040: val_loss did not improve from 0.00202
# Epoch 41/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0026
#
# Epoch 00041: val_loss did not improve from 0.00202
# Epoch 42/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00042: val_loss did not improve from 0.00202
# Epoch 43/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00043: val_loss did not improve from 0.00202
# Epoch 44/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00044: val_loss did not improve from 0.00202
# Epoch 45/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00045: val_loss did not improve from 0.00202
# Epoch 46/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0040
#
# Epoch 00046: val_loss did not improve from 0.00202
# Epoch 47/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00047: val_loss did not improve from 0.00202
# Epoch 48/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00048: val_loss did not improve from 0.00202
# Epoch 49/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0027
#
# Epoch 00049: val_loss did not improve from 0.00202
# Epoch 50/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0037
#
# Epoch 00050: val_loss did not improve from 0.00202
# Epoch 51/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00051: val_loss did not improve from 0.00202
# Epoch 52/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0029
#
# Epoch 00052: val_loss did not improve from 0.00202
# Epoch 53/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00053: val_loss did not improve from 0.00202
# Epoch 54/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0023
#
# Epoch 00054: val_loss did not improve from 0.00202
# Epoch 55/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00055: val_loss did not improve from 0.00202
# Epoch 56/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00056: val_loss did not improve from 0.00202
# Epoch 57/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0020
#
# Epoch 00057: val_loss did not improve from 0.00202
# Epoch 58/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00058: val_loss did not improve from 0.00202
# Epoch 59/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00059: val_loss did not improve from 0.00202
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00060: val_loss did not improve from 0.00202
# Epoch 61/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00061: val_loss did not improve from 0.00202
# Epoch 62/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00062: val_loss did not improve from 0.00202
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00063: val_loss did not improve from 0.00202
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00064: val_loss did not improve from 0.00202
# Epoch 65/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00065: val_loss did not improve from 0.00202
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00066: val_loss did not improve from 0.00202
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0030
#
# Epoch 00067: val_loss did not improve from 0.00202
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00068: val_loss did not improve from 0.00202
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00069: val_loss did not improve from 0.00202
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0018 - val_loss: 0.0025
#
# Epoch 00070: val_loss did not improve from 0.00202
# Model loaded
# mae :  3287.8683546190136
# mse :  23742682.026015364
# rmse :  4872.646306270892
# std : 4694.124098449329

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 30s 8ms/step - loss: 0.0148 - val_loss: 0.0039
#
# Epoch 00001: val_loss improved from inf to 0.00393, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0042 - val_loss: 0.0050
#
# Epoch 00002: val_loss did not improve from 0.00393
# Epoch 3/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00003: val_loss did not improve from 0.00393
# Epoch 4/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0037 - val_loss: 0.0074
#
# Epoch 00004: val_loss did not improve from 0.00393
# Epoch 5/70
# 3847/3847 [==============================] - 4s 1ms/step - loss: 0.0037 - val_loss: 0.0024
#
# Epoch 00005: val_loss improved from 0.00393 to 0.00241, saving model to bestmodel.h5
# Epoch 6/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0034 - val_loss: 0.0055
#
# Epoch 00006: val_loss did not improve from 0.00241
# Epoch 7/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0034 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00241
# Epoch 8/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0037
#
# Epoch 00008: val_loss did not improve from 0.00241
# Epoch 9/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0033 - val_loss: 0.0028
#
# Epoch 00009: val_loss did not improve from 0.00241
# Epoch 10/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00010: val_loss did not improve from 0.00241
# Epoch 11/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0031 - val_loss: 0.0020
#
# Epoch 00011: val_loss improved from 0.00241 to 0.00199, saving model to bestmodel.h5
# Epoch 12/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0026
#
# Epoch 00012: val_loss did not improve from 0.00199
# Epoch 13/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0031 - val_loss: 0.0036
#
# Epoch 00013: val_loss did not improve from 0.00199
# Epoch 14/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0036
#
# Epoch 00014: val_loss did not improve from 0.00199
# Epoch 15/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0030 - val_loss: 0.0021
#
# Epoch 00015: val_loss did not improve from 0.00199
# Epoch 16/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0024
#
# Epoch 00016: val_loss did not improve from 0.00199
# Epoch 17/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0026
#
# Epoch 00017: val_loss did not improve from 0.00199
# Epoch 18/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00018: val_loss did not improve from 0.00199
# Epoch 19/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0022
#
# Epoch 00019: val_loss did not improve from 0.00199
# Epoch 20/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0028 - val_loss: 0.0044
#
# Epoch 00020: val_loss did not improve from 0.00199
# Epoch 21/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00021: val_loss did not improve from 0.00199
# Epoch 22/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0027 - val_loss: 0.0022
#
# Epoch 00022: val_loss did not improve from 0.00199
# Epoch 23/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0031
#
# Epoch 00023: val_loss did not improve from 0.00199
# Epoch 24/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0027 - val_loss: 0.0036
#
# Epoch 00024: val_loss did not improve from 0.00199
# Epoch 25/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00025: val_loss did not improve from 0.00199
# Epoch 26/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0026
#
# Epoch 00026: val_loss did not improve from 0.00199
# Epoch 27/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00027: val_loss did not improve from 0.00199
# Epoch 28/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0026 - val_loss: 0.0027
#
# Epoch 00028: val_loss did not improve from 0.00199
# Epoch 29/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00029: val_loss did not improve from 0.00199
# Epoch 30/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0030
#
# Epoch 00030: val_loss did not improve from 0.00199
# Epoch 31/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0031
#
# Epoch 00031: val_loss did not improve from 0.00199
# Epoch 32/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00032: val_loss did not improve from 0.00199
# Epoch 33/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00033: val_loss did not improve from 0.00199
# Epoch 34/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0025 - val_loss: 0.0037
#
# Epoch 00034: val_loss did not improve from 0.00199
# Epoch 35/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00035: val_loss did not improve from 0.00199
# Epoch 36/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0018
#
# Epoch 00036: val_loss improved from 0.00199 to 0.00182, saving model to bestmodel.h5
# Epoch 37/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0033
#
# Epoch 00037: val_loss did not improve from 0.00182
# Epoch 38/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0043
#
# Epoch 00038: val_loss did not improve from 0.00182
# Epoch 39/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0024
#
# Epoch 00039: val_loss did not improve from 0.00182
# Epoch 40/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00040: val_loss did not improve from 0.00182
# Epoch 41/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0024 - val_loss: 0.0023
#
# Epoch 00041: val_loss did not improve from 0.00182
# Epoch 42/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00042: val_loss did not improve from 0.00182
# Epoch 43/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0024 - val_loss: 0.0034
#
# Epoch 00043: val_loss did not improve from 0.00182
# Epoch 44/70
# 3847/3847 [==============================] - 7s 2ms/step - loss: 0.0023 - val_loss: 0.0024
#
# Epoch 00044: val_loss did not improve from 0.00182
# Epoch 45/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0024 - val_loss: 0.0022
#
# Epoch 00045: val_loss did not improve from 0.00182
# Epoch 46/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00046: val_loss did not improve from 0.00182
# Epoch 47/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00047: val_loss did not improve from 0.00182
# Epoch 48/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0022
#
# Epoch 00048: val_loss did not improve from 0.00182
# Epoch 49/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00049: val_loss did not improve from 0.00182
# Epoch 50/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00050: val_loss did not improve from 0.00182
# Epoch 51/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00051: val_loss did not improve from 0.00182
# Epoch 52/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 00052: val_loss did not improve from 0.00182
# Epoch 53/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00053: val_loss did not improve from 0.00182
# Epoch 54/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00054: val_loss did not improve from 0.00182
# Epoch 55/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0022 - val_loss: 0.0038
#
# Epoch 00055: val_loss did not improve from 0.00182
# Epoch 56/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0024
#
# Epoch 00056: val_loss did not improve from 0.00182
# Epoch 57/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00057: val_loss did not improve from 0.00182
# Epoch 58/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00058: val_loss did not improve from 0.00182
# Epoch 59/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00059: val_loss did not improve from 0.00182
# Epoch 60/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0022
#
# Epoch 00060: val_loss did not improve from 0.00182
# Epoch 61/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0026
#
# Epoch 00061: val_loss did not improve from 0.00182
# Epoch 62/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00062: val_loss did not improve from 0.00182
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0023
#
# Epoch 00063: val_loss did not improve from 0.00182
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00064: val_loss did not improve from 0.00182
# Epoch 65/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0029
#
# Epoch 00065: val_loss did not improve from 0.00182
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0026
#
# Epoch 00066: val_loss did not improve from 0.00182
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00067: val_loss did not improve from 0.00182
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0025
#
# Epoch 00068: val_loss did not improve from 0.00182
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00069: val_loss did not improve from 0.00182
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00070: val_loss did not improve from 0.00182
# Model loaded
# mae :  3252.8395351516738
# mse :  22858847.82082748
# rmse :  4781.09274338278
# std : 4752.147372833068

# %%
import numpy as np
from keras import layers, models
from keras.utils import np_utils
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, concatenate
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

#***************************파일을 읽고, 날짜 column생성*********************************
df = pd.read_csv('SeoulGrandPark2.csv', engine = 'python')    
df["날짜"] = df["년도"].map(str) + '-' +df["월"].map(str) + '-' + df["일"].map(str)
df = df.set_index('날짜')
#**************************train set과 test set분할**************************************
split_date_last = '2018-4-16'
split_date_start = '2017-8-29'
#+8달부터 계산된다.
#*****************위는 DNN용 특성 데이터셋, 아래는 LSTM용 시계열 데이터(앞으로도 계속)***
train = df.loc[:split_date_last]
test = df.loc[split_date_start:]

trainLSTM = df.loc[:split_date_last, ['일계']]
testLSTM = df.loc[split_date_start:, ['일계']]
#**************************데이터를 사용가능하도록 변환**********************************
train['일계'] = train['일계'].str.replace(',', '')
test['일계'] = test['일계'].str.replace(',', '')

train['일계'] = train['일계'].astype('float')
test['일계'] = test['일계'].astype('float')

trainLSTM['일계'] = trainLSTM['일계'].str.replace(',', '')
testLSTM['일계'] = testLSTM['일계'].str.replace(',', '')

trainLSTM['일계'] = trainLSTM['일계'].astype('float')
testLSTM['일계'] = testLSTM['일계'].astype('float')
#***************************이어서 시계열 데이터만 처리********************************************
#***************************주단위 데이터로 변환.**************************************************
train2LSTM = trainLSTM.iloc[0:0]
traintmp2 = trainLSTM.copy()
for i in range(int(len(trainLSTM)/7)):
    traintmp = trainLSTM['일계'][i*7:i*7+7]
    traintmp2['일계'][i*7+6] = traintmp.mean(axis = 0)
    train2LSTM = pd.concat([train2LSTM, traintmp2[i*7+6:i*7+7]], axis=0)
    
test2LSTM = testLSTM.iloc[0:0]
testtmp2 = testLSTM.copy()
for i in range(int(len(testLSTM)/7)):
    testtmp = testLSTM['일계'][i*7:i*7+7]
    testtmp2['일계'][i*7+6] = testtmp.mean(axis = 0)
    test2LSTM = pd.concat([test2LSTM, testtmp2[i*7+6:i*7+7]], axis=0)
#*****************************이어서 주단위 시계열 데이터 처리************************************
weekfrom = 2
weekto = 33
week = weekto - weekfrom

sc = MinMaxScaler()

train_sc2LSTM = sc.fit_transform(train2LSTM)
test_sc2LSTM = sc.transform(test2LSTM)

train_sc_df2LSTM = pd.DataFrame(train_sc2LSTM, columns=['Scaled'], index=train2LSTM.index)
test_sc_df2LSTM = pd.DataFrame(test_sc2LSTM, columns=['Scaled'], index=test2LSTM.index)

for s in range(weekfrom, weekto):
    train_sc_df2LSTM['shift_{}'.format(s)] = train_sc_df2LSTM['Scaled'].shift(s)
    test_sc_df2LSTM['shift_{}'.format(s)] = test_sc_df2LSTM['Scaled'].shift(s)

X_train2LSTM = train_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_test2LSTM = test_sc_df2LSTM.dropna().drop('Scaled', axis=1)

X_train2LSTMc = X_train2LSTM.iloc[0:0].copy()
for i in range(len(trainLSTM)):
    X_train2LSTMc = pd.concat([X_train2LSTMc, X_train2LSTM[int(i/7):int(i/7)+1]], axis=0)

X_test2LSTMc = X_test2LSTM.iloc[0:0].copy()
for i in range(len(testLSTM)):
    X_test2LSTMc = pd.concat([X_test2LSTMc, X_test2LSTM[int(i/7):int(i/7)+1]], axis=0)

#*****************************주단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_train2LSTMc = X_train2LSTMc.values
X_test2LSTMc= X_test2LSTMc.values

X_train_t2LSTMc = X_train2LSTMc.reshape(X_train2LSTMc.shape[0], week, 1)
X_test_t2LSTMc = X_test2LSTMc.reshape(X_test2LSTMc.shape[0], week, 1)
#*******************************이제는 일단위 시계열 데이터 처리 (반복)***************************
dayfrom = 14
dayto = 42
day = dayto - dayfrom

sc = MinMaxScaler()

train_scLSTM = sc.fit_transform(trainLSTM)
test_scLSTM = sc.transform(testLSTM)

train_sc_dfLSTM = pd.DataFrame(train_scLSTM, columns=['Scaled'], index=trainLSTM.index)
test_sc_dfLSTM = pd.DataFrame(test_scLSTM, columns=['Scaled'], index=testLSTM.index)

for s in range(dayfrom, dayto):
    train_sc_dfLSTM['shift_{}'.format(s)] = train_sc_dfLSTM['Scaled'].shift(s)
    test_sc_dfLSTM['shift_{}'.format(s)] = test_sc_dfLSTM['Scaled'].shift(s)
    
X_trainLSTM = train_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_trainLSTM = train_sc_dfLSTM.dropna()[['Scaled']]

X_testLSTM = test_sc_dfLSTM.dropna().drop('Scaled', axis=1)
y_testLSTM = test_sc_dfLSTM.dropna()[['Scaled']]

X_trainLSTM = X_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]
y_trainLSTM = y_trainLSTM.iloc[weekto*7-dayto-6:-(len(trainLSTM)%7)]

X_testLSTM = X_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]
y_testLSTM = y_testLSTM.iloc[weekto*7-dayto-6:-(len(testLSTM)%7)]

#*****************************일단위 시계열 데이터를 model에 들어갈 수 있게 reshape*****************
X_trainLSTM = X_trainLSTM.values
X_testLSTM = X_testLSTM.values

y_trainLSTM = y_trainLSTM.values
y_testLSTM = y_testLSTM.values

X_train_tLSTM = X_trainLSTM.reshape(X_trainLSTM.shape[0], day, 1)
X_test_tLSTM = X_testLSTM.reshape(X_testLSTM.shape[0], day, 1)
#******************************주단위 LSTM모델링**************************************************
model2 = Sequential() 
model2.add(LSTM(week, input_shape=(week, 1), return_sequences = True))
model2.add(LSTM(week))
model2.add(Dense(week, kernel_initializer='he_normal', activation='relu'))
#******************************일단위 LSTM모델링***************************************************
model = Sequential()
model.add(LSTM(day, input_shape=(day, 1), return_sequences = True))
model.add(LSTM(day))
model.add(Dense(day, kernel_initializer='he_normal', activation='relu'))
#*********이어서 DNN용 특성위주 데이터 정리 및 모델에 맞게 변환***********************************
train_df = pd.DataFrame(train)
test_df = pd.DataFrame(test)
    
X_train = train_df.drop(['일계', '년도', '일'], axis=1)
y_train = train_df[['일계']]
X_test = test_df.drop(['일계', '년도', '일'], axis=1)
y_test = test_df[['일계']]

X_train = X_train.iloc[weekto*7-7:-(len(trainLSTM)%7)]
X_test = X_test.iloc[weekto*7-7:-(len(testLSTM)%7)]

X_train = pd.get_dummies(X_train, columns=['요일', '월'])
X_test = pd.get_dummies(X_test, columns=['요일', '월'])

sc2 = MinMaxScaler()

X_train_sc = sc2.fit_transform(X_train)
X_test_sc = sc2.transform(X_test)

y_train_sc = sc2.fit_transform(y_train)
y_test_sc = sc2.transform(y_test)

print("학습 데이터 수:", len(X_train))
print("테스트 데이터 수:", len(X_test))
#*****************************************DNN 모델링*************************************************
class DNN(models.Sequential):
    def __init__(self, Nin):
        super().__init__()
 
        # 첫 번째 은닉층
        self.add(layers.Dense(500, kernel_initializer='he_normal', activation='relu',input_shape=(Nin,), name='Hidden-1'))
        self.add(layers.Dense(250, kernel_initializer='he_normal', activation='relu', name='Hidden-2'))
        self.add(layers.Dense(100, kernel_initializer='he_normal', activation='relu', name='Hidden-3'))
        self.add(layers.Dense(50, kernel_initializer='he_normal', activation='relu'))
        
model3 = DNN(X_train_sc.shape[1])
#***************************일단위 LSTM모델과 DNN모델을 concatenate 및 모델 생성**********************
combinedInput = concatenate([model.output, model3.output, model2.output])

x = Dense(100, kernel_initializer='he_normal', activation='relu')(combinedInput)
x = Dense(10, kernel_initializer='he_normal', activation='relu')(x)
x = Dense(1)(x)

model4 = Model(inputs=[model.input, model3.input, model2.input], outputs=x)

opt = Adam(lr=0.001)
model4.compile(loss="mean_squared_error", optimizer=opt)
#************************************모델 학습************************************************************
mcp_save = ModelCheckpoint('bestmodel.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')

early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1)
model4.fit([X_train_tLSTM, X_train_sc, X_train_t2LSTMc], y_trainLSTM, validation_split = 0.2, epochs=70, batch_size=50, callbacks=[early_stop, mcp_save])

#모델 세이브
from keras.models import load_model
model4 = load_model('bestmodel.h5')
print("Model loaded")
#**********************************plot을 이용한 그래프 그리기******************************************
plt.figure(figsize=(20,15))
plt.rcParams['lines.linewidth'] = 0.5
plt.title('Visitors Result')
plt.xlabel(X_test.index.values[0] + '~' + X_test.index.values[-1])
plt.ylabel('visitors')
ynewtest = sc.inverse_transform(y_testLSTM)
plt.plot(ynewtest, label='actual')
Y_pred = model4.predict([X_test_tLSTM, X_test_sc, X_test_t2LSTMc])
ynew = sc.inverse_transform(Y_pred)
plt.plot(ynew, label='predicted')
plt.legend()
plt.show()
#********************************test셋에 대해서 오차값 구하기*******************************************
mse = np.square(ynewtest - ynew).mean()
rmse = mse ** 0.5
print("mae : ", np.absolute(ynewtest - ynew).mean())
print("mse : ", mse)
print("rmse : ", rmse)
print("std :", np.std(ynewtest-ynew))
# Out:
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dlgus\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 학습 데이터 수: 4809
# 테스트 데이터 수: 385
# Train on 3847 samples, validate on 962 samples
# Epoch 1/70
# 3847/3847 [==============================] - 32s 8ms/step - loss: 0.0065 - val_loss: 0.0035
#
# Epoch 00001: val_loss improved from inf to 0.00353, saving model to bestmodel.h5
# Epoch 2/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0040 - val_loss: 0.0027
#
# Epoch 00002: val_loss improved from 0.00353 to 0.00272, saving model to bestmodel.h5
# Epoch 3/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0037 - val_loss: 0.0054
#
# Epoch 00003: val_loss did not improve from 0.00272
# Epoch 4/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0034 - val_loss: 0.0037
#
# Epoch 00004: val_loss did not improve from 0.00272
# Epoch 5/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0033 - val_loss: 0.0042
#
# Epoch 00005: val_loss did not improve from 0.00272
# Epoch 6/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0033 - val_loss: 0.0030
#
# Epoch 00006: val_loss did not improve from 0.00272
# Epoch 7/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0031 - val_loss: 0.0025
#
# Epoch 00007: val_loss improved from 0.00272 to 0.00251, saving model to bestmodel.h5
# Epoch 8/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0032 - val_loss: 0.0028
#
# Epoch 00008: val_loss did not improve from 0.00251
# Epoch 9/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0024
#
# Epoch 00009: val_loss improved from 0.00251 to 0.00237, saving model to bestmodel.h5
# Epoch 10/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0030 - val_loss: 0.0025
#
# Epoch 00010: val_loss did not improve from 0.00237
# Epoch 11/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0029 - val_loss: 0.0027
#
# Epoch 00011: val_loss did not improve from 0.00237
# Epoch 12/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0038
#
# Epoch 00012: val_loss did not improve from 0.00237
# Epoch 13/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0029 - val_loss: 0.0041
#
# Epoch 00013: val_loss did not improve from 0.00237
# Epoch 14/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0029 - val_loss: 0.0037
#
# Epoch 00014: val_loss did not improve from 0.00237
# Epoch 15/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0028 - val_loss: 0.0036
#
# Epoch 00015: val_loss did not improve from 0.00237
# Epoch 16/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0026 - val_loss: 0.0028
#
# Epoch 00016: val_loss did not improve from 0.00237
# Epoch 17/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0027 - val_loss: 0.0035
#
# Epoch 00017: val_loss did not improve from 0.00237
# Epoch 18/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0021
#
# Epoch 00018: val_loss improved from 0.00237 to 0.00214, saving model to bestmodel.h5
# Epoch 19/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00019: val_loss did not improve from 0.00214
# Epoch 20/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0049
#
# Epoch 00020: val_loss did not improve from 0.00214
# Epoch 21/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0044
#
# Epoch 00021: val_loss did not improve from 0.00214
# Epoch 22/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00022: val_loss did not improve from 0.00214
# Epoch 23/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0026 - val_loss: 0.0020
#
# Epoch 00023: val_loss improved from 0.00214 to 0.00197, saving model to bestmodel.h5
# Epoch 24/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00024: val_loss did not improve from 0.00197
# Epoch 25/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0027
#
# Epoch 00025: val_loss did not improve from 0.00197
# Epoch 26/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00026: val_loss did not improve from 0.00197
# Epoch 27/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0028
#
# Epoch 00027: val_loss did not improve from 0.00197
# Epoch 28/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00028: val_loss did not improve from 0.00197
# Epoch 29/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0025 - val_loss: 0.0042
#
# Epoch 00029: val_loss did not improve from 0.00197
# Epoch 30/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0035
#
# Epoch 00030: val_loss did not improve from 0.00197
# Epoch 31/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 0.0034
#
# Epoch 00031: val_loss did not improve from 0.00197
# Epoch 32/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0020
#
# Epoch 00032: val_loss did not improve from 0.00197
# Epoch 33/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0043
#
# Epoch 00033: val_loss did not improve from 0.00197
# Epoch 34/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0027
#
# Epoch 00034: val_loss did not improve from 0.00197
# Epoch 35/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0026
#
# Epoch 00035: val_loss did not improve from 0.00197
# Epoch 36/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0024 - val_loss: 0.0028
#
# Epoch 00036: val_loss did not improve from 0.00197
# Epoch 37/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00037: val_loss did not improve from 0.00197
# Epoch 38/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0024 - val_loss: 0.0023
#
# Epoch 00038: val_loss did not improve from 0.00197
# Epoch 39/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0031
#
# Epoch 00039: val_loss did not improve from 0.00197
# Epoch 40/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00040: val_loss did not improve from 0.00197
# Epoch 41/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0023 - val_loss: 0.0028
#
# Epoch 00041: val_loss did not improve from 0.00197
# Epoch 42/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0020
#
# Epoch 00042: val_loss did not improve from 0.00197
# Epoch 43/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0025
#
# Epoch 00043: val_loss did not improve from 0.00197
# Epoch 44/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0027
#
# Epoch 00044: val_loss did not improve from 0.00197
# Epoch 45/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0022 - val_loss: 0.0025
#
# Epoch 00045: val_loss did not improve from 0.00197
# Epoch 46/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0023 - val_loss: 0.0034
#
# Epoch 00046: val_loss did not improve from 0.00197
# Epoch 47/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00047: val_loss did not improve from 0.00197
# Epoch 48/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00048: val_loss did not improve from 0.00197
# Epoch 49/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0022 - val_loss: 0.0033
#
# Epoch 00049: val_loss did not improve from 0.00197
# Epoch 50/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0029
#
# Epoch 00050: val_loss did not improve from 0.00197
# Epoch 51/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00051: val_loss did not improve from 0.00197
# Epoch 52/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00052: val_loss did not improve from 0.00197
# Epoch 53/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00053: val_loss did not improve from 0.00197
# Epoch 54/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00054: val_loss did not improve from 0.00197
# Epoch 55/70
# 3847/3847 [==============================] - 6s 2ms/step - loss: 0.0021 - val_loss: 0.0036
#
# Epoch 00055: val_loss did not improve from 0.00197
# Epoch 56/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0021 - val_loss: 0.0025
#
# Epoch 00056: val_loss did not improve from 0.00197
# Epoch 57/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0037
#
# Epoch 00057: val_loss did not improve from 0.00197
# Epoch 58/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00058: val_loss did not improve from 0.00197
# Epoch 59/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0026
#
# Epoch 00059: val_loss did not improve from 0.00197
# Epoch 60/70
# 3847/3847 [==============================] - 6s 1ms/step - loss: 0.0020 - val_loss: 0.0030
#
# Epoch 00060: val_loss did not improve from 0.00197
# Epoch 61/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0032
#
# Epoch 00061: val_loss did not improve from 0.00197
# Epoch 62/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0024
#
# Epoch 00062: val_loss did not improve from 0.00197
# Epoch 63/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0034
#
# Epoch 00063: val_loss did not improve from 0.00197
# Epoch 64/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0021 - val_loss: 0.0033
#
# Epoch 00064: val_loss did not improve from 0.00197
# Epoch 65/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0020 - val_loss: 0.0022
#
# Epoch 00065: val_loss did not improve from 0.00197
# Epoch 66/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0031
#
# Epoch 00066: val_loss did not improve from 0.00197
# Epoch 67/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0029
#
# Epoch 00067: val_loss did not improve from 0.00197
# Epoch 68/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00068: val_loss did not improve from 0.00197
# Epoch 69/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00069: val_loss did not improve from 0.00197
# Epoch 70/70
# 3847/3847 [==============================] - 5s 1ms/step - loss: 0.0018 - val_loss: 0.0029
#
# Epoch 00070: val_loss did not improve from 0.00197
# Model loaded
# mae :  3108.0460710253033
# mse :  23301198.38908636
# rmse :  4827.1314866167
# std : 4776.035614648477
